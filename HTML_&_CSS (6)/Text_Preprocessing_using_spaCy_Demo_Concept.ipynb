# %% [markdown]
# # Demo1
# ## Cleaning Text Data: Removing Stopwords
# ## Working with Unstructured Text Data
# ### Loading the Required Libraries and Model
# ### Text file:
#
#                 2001: A SPACE ODYSSEY
#
# 					    Screenplay
#
# 						   by
#
# 			   Stanley Kubrick and Arthur C. Clark
#
# 					    Hawk Films Ltd.,
# 					    c/o. M-G-M Studios,
# 					    Boreham Wood,
# 					    Herts.

# %%
import spacy                                                  # Import spaCy library
from spacy.lang.en import English                             # Import specific model
nlp = spacy.load("en_core_web_sm")                            # Load model
f = open('scifiscripts.txt')
contents = f.read()                                           # Read input text
print(contents)  # To print all contents of file              # print contents
text = str(contents)                                          # convert to string type
# Out:
# Note from poster to Kubrick newsgroup:
#
# I found this on a bbs a while ago and I thought I'd pass it along to all
# of you Kubrick freaks out there.
#
# 02/23/89
# Transcriber's note:
#
# For all you Clarke/Kubrick/2001 fans,
#
# I found the original paper copy of this screenplay a while back and felt
# compelled to transcribe it to disk and upload it to various bulletin
# boards for the enjoyment of all.
#
# The final movie deviates from this screenplay in a number of interesting
# ways. I've tried to maintain the format of the original document except
# the number of lines per page of the original. In order to reduce the
# length of this file I've used a bar of "------" to delimit the pages as
# there was a lot of whitespace per original screenplay page.
#
#
# ------------------------------------------------------------------------
#
# 				    2001: A SPACE ODYSSEY
#
# 					    Screenplay
#
# 						   by
#
# 			   Stanley Kubrick and Arthur C. Clark
#
# 					    Hawk Films Ltd.,
# 					    c/o. M-G-M Studios,
# 					    Boreham Wood,
# 					    Herts.
# ------------------------------------------------------------------------
#
# TITLE					    PART I
# 					    AFRICA
# 					    3,000,000 YEARS AGO
# ------------------------------------------------------------------------
# A1
# VIEWS OF AFRICAN DRYLANDS - DROUGHT
#
# The remorseless drought had lasted now for ten million years,
# and would not end for another million. The reign of the ter-
# rible lizards had long since passed, but here on the continent
# which would one day be known as Africa, the battle for survival
# had reached a new climax of ferocity, and the victor was not
# yet in sight. In this dry and barren land, only the small or
# the swift or the fierce could flourish, or even hope to exist.
#
# 10/13/65										 a1
# ------------------------------------------------------------------------
# A2
# INT & EXT CAVES - MOONWATCHER
#
# The man-apes of the field had none of these attributes, and
# they were on the long, pathetic road to racial extinction.
# About twenty of them occupied a group of caves overlooking
# a small, parched valley, divided by a sluggish, brown stream.
#
# The tribe had always been hungry, and now it was starving.
# As the first dim glow of dawn creeps into the cave, Moonwatcher
# discovers that his father has died during the night. He did not know
# the Old One was his father, for such a relationship was beyond
# his understanding. but as he stands looking down at the emac-
# iated body he feels something, something akin to sadness. Then
# he carries his dead father out of the cave, and leaves him for the
# hyenas.
#
# Among his kind, Moonwatcher is almost a giant. He is nearly
# five feet high, and though badly undernourished, weighs over
# a hundred pounds. His hairy, muscular body is quite man-like,
# and his head is already nearer man than ape. The forehead is
# low, and there are great ridges over the eye-sockets, yet he
# unmistakably holds in his genes the promise of humanity. As
# he looks out now upon the hostile world, there is already
#
# 10/13/65										 a2
# ------------------------------------------------------------------------
# A2
# CONTINUED
#
# something in his gaze beyond the grasp of any ape. In those
# dark, deep-set eyes is a dawning awareness-the first intima-
# tions of an intelligence which would not fulfill itself for another
# two million years.
#
# 10/13/65										 a3
# ------------------------------------------------------------------------
# A3
# EXT  THE STREAM - THE OTHERS
#
# As the dawn sky brightens, Moonwatcher and his tribe reach
# the shallow stream.
#
# The Others are already there. They were there on the other
# side every day - that did not make it any less annoying.
#
# There are eighteen of them, and it is impossible to distinguish
# them from the members of Moonwatcher's own tribe. As
# they see him coming, the Others begin to angrily dance and
# shriek on their side of the stream, and his own people reply
# In kind.
#
# The confrontation lasts a few minutes - then the display dies
# out as quickly as it has begun, and everyone drinks his fill of
# the muddy water. Honor has been satisfied - each group has
# staked its claim to its own territory.
#
# 10/13/65										 a4
# ------------------------------------------------------------------------
# A4
# EXT  AFRICAN PLAIN - HERBIVORES
#
# Moonwatcher and his companions search for berries, fruit
# and leaves, and fight off pangs of hunger, while all around
# them, competing with them for the samr fodder, is a potential
# source of more food than they could ever hope to eat. Yet
# all the thousands of tons of meat roaming over the parched
# savanna and through the brush is not only beyond their reach;
# the idea of eating it is beyond their imagination. They are
# slowly starving to death in the midst of plenty.
#
# 10/13/65										 a5
# ------------------------------------------------------------------------
# A5
# EXT  PARCHED COUNTRYSIDE - THE LION
#
# The tribe slowly wanders across the bare, flat country-
# side foraging for roots and occasional berries.
#
# Eight of them are irregularly strung out on the open plain,
# about fifty feet apart.
#
# The ground is flat for miles around.
#
# Suddenly, Moonwatcher becomes aware of a lion, stalking
# them about 300 yards away.
#
# Defenceless and with nowhere to hide, they scatter in all
# directions, but the lion brings one to the ground.
#
# 10/13/65										 a6
# ------------------------------------------------------------------------
# A6
# EXT  DEAD TREE - FINDS HONEY
#
# It had not been a good day, though as Moonwatcher had no
# real remembrance of the past he could not compare one day
# with another. But on the way back to the caves he finds a
# hive of bees in the stump of a dead tree, and so enjoys the
# finest delicacy his people could ever know. Of course, he
# also collects a good many stings, but he scacely notices
# them. He is now as near to contentment as he is ever
# likely to be; for thought he is still hungry, he is not actually
# weak with hunger. That was the most that any hominid could
# hope for.
#
# 10/13/65										 a7
# ------------------------------------------------------------------------
# A7
# INT & EXT  CAVES - NIGHT TERRORS
#
# Over the valley, a full moon rises, and a cold wind blows down
# from the distant mountains. It would be very cold tonight -
# but cold, like hunger, was not a matter for any real concern;
# it was merely part of the background of life.
#
# This Little Sun, that only shone at night and gave no warmth,
# was dangerous; there would be enemies abroad. Moonwatcher
# crawls out of the cave, clambers on to a large boulder besides
# the entrance, and squats there where he can survey the valley.
# If any hunting beast approached, he would have time to get back
# to the relative safety of the cave.
#
# Of all the creatures who had ever lived on Earth, Moonwatcher's
# race was the first to raise their eyes with interest to the Moon,
# and though he could not remember it, when he was young,
# Moonwatcher would reach out and try to touch its ghostly face.
# Now he new he would have to find a tree that was high
# enough.
#
# He stirs when shrieks and screams echo up the slope from
# one of the lower caves, and he does not need to hear the
#
# 10/13/65										 a8
# ------------------------------------------------------------------------
# A7
# CONTINUED
#
# occasional growl of the lion to know what is happening. Down
# there in the darkness, old One-Eye and his family are dying,
# and the thought that he might help in some way never crosses
# Moonwatcher's mind. The harsh logic of survival rules out
# such fancies. Every cave is silent, lest it attract disaster.
#
# And in the caves, in tortured spells of fitful dozing and
# fearful waiting, were gathered the nightmares of generations
# yet to come.
#
# 10/13/65										 a9
# ------------------------------------------------------------------------
# A8
# EXT  THE STREAM - INVASION
#
# The Others are growing desperate; the forage on their side of
# the valley is almost exhausted. Perhaps they realise that
# Moonwatcher's tribe has lost three of its numbers during the
# night, for they choose this mourning to break the truce. When
# they meet at the river in the still, misty dawn, there is a
# deeper and more menacing note in their challenge. The noisy
# but usually harmless confrontation lasts only a few seconds
# before the invasion begins.
#
# In an uncertainly-moving horde, the Others cross the river,
# shieking threats and hunched for the attack. They are led
# by a big-toothed hominid of Moonwatcher's own size and age.
#
# Startled and frightened, the tribe retreats before the first
# advance, throwing nothing more substantial than imprecations
# at the invaders. Moonwatcher moves with them, his mind a
# mist of rage and confusion. To be driven from their own
# territory is a great badness, but to lose the river is death.
# He does not know what to do; it is a situation beyond his
# experience.
#
# Then he becomes dimly aware that the Others are slowing
#
# 10/13/65										 a10
# ------------------------------------------------------------------------
# A8
# CONTINUED
#
# down, and advancing with obvious reluctance. The further they
# move from their own side, the more uncertain and unhappy
# they become. Only Big-Tooth still retains any of his original
# drive, and he is rapidly being seperated from his followers.
#
# As he sees this, Moonwatcher's own morale immediately
# revives. He slows down his retreat, and begins to make
# reassuring noises to his companions. Novel sensations fill
# his dim mind - the first faint precursors of bravery and
# leadership.
#
# Before he realizes it, he is face to face with Big-Tooth, and
# the two tribes come to a halt many paces away.
#
# The disorganized and unscientific conflict could have ended
# quickly if either had used his fist as a club, but this
# innovation still lay hundreds of thousands of years in the
# future. Instead, the slowly weakening fighters claw and
# scratch and try to bite each other.
#
# Rolling over and over, they come to a patch of stony ground,
# and when they reach it Moonwatcher is on top. By chance,
#
# 10/13/65										 a11
# ------------------------------------------------------------------------
# A8
# CONTINUED
#
# he chooses this moment to grab the hair on Big-Tooth's scalp,
# and bang his head on the ground. The resulting CRACK is
# so satisfactory, and produces such an immediate weakening
# In Big - Tooth's resistance, that he quickly repeats it.
#
# Even when Big-Tooth ceases to move for some time, Moon-
# watcher keeps up the exhilirating game.
#
# With shrieks of panic, the Others retreat back, across the
# stream. The defenders cautiously pursue them as far as
# The water's edge.
#
# 10/13/65										 a12
# ------------------------------------------------------------------------
# EXT  CAVE - NEW SOUND
#
# Dozing fitfully and weakened by his stuggle, Moonwatcher is
# startled by a sound.
#
# He sits up in the fetid darkness of the cave, straining his
# senses out into the night, and fear creeps slowly into his soul.
# Never in his life - already twice as long as most members of
# his species could expect - has he heard a sound like this. The
# great cats approached in silence, and the only thing that
# betrayed them was a rare slide of earth, or the occasional
# cracking of a twig. Yet this is a continuing crunching noise
# that grows steadily louder. It seemed that some enormous
# beast was moving through the night, making no attempt at
# concealment, and ignoring all obstacles.
#
# And then there came a sound which Moonwatcher could not
# possibly have identified, for it had never been heard before
# in the history of this planet.
#
# 10/13/65										 a13
# ------------------------------------------------------------------------
# A10
# EXT CAVE - NEW ROCK
#
# Moonwatcher comes face to face with the New Rock when he
# leads the tribe down to the river in the first light of morning.
# He had almost forgotten the terror of the night, because nothing
# had happened after that initial noise, so he does not even
# associate this strange thing with danger or with fear. There
# is nothing in the least alarming about it.
#
# It is a cube about fifteen feet on a side, and it is made of
# some completely transparent material; indeed, it is not easy
# to see except when the light of the sun glints on its edges.
# There are no natural objects to which Moonwatcher can
# compare this apparition. Though he is wisely cautious
# of most new things, he does not hesitate to walk up to it.
# As nothing happens, he puts out his hand, and feels a warm,
# hard surface.
#
# After several minutes of intense thought, he arrives at a
# brilliant explanation. It is a rock, of course, and it
# must have grown during the night. There are many plants
# that do this - white, pulpy things shaped like pebbles, that
# seem to shoot up in the hours of darkness. It is true that
# they are small and round, whereas this is large and square;
#
# 10/13/65										 a14
# ------------------------------------------------------------------------
# A10
# CONTINUED
#
# but greater and later philosophers than Moonwatcher would be
# prepared to overlook equally striking exceptions to their laws.
#
# This really superb piece of abstract thinking leads Moonwatcher
# to a deduction which he immediately puts to the test. The white,
# round pebble-plants are very tasty (though there were a few
# that made one violently sick); perhaps this square one...?
#
# A few licks and attempted nibbles quickly disillusion him.
# There is no nourishment here; so like a sensible hominid, he
# continues on his way to the river and forgets all about the Cube.
#
# 10/13/65										 a15
# ------------------------------------------------------------------------
# A11
# EXT CUBE - FIRST LESSON
#
# They are still a hundred yards from the New Rock when the
# sound begins.
#
# It is quite soft, and it stops them in their tracks, so that they
# stand paralyzed on the trail with their jaws hanging. A simple,
# maddeningly repetitious rhythm pulses out of the crystal cube
# and hypnotises all who come within its spell. For the first
# time - and the last, for two million year - the sound of
# drumming is heard in Africa.
#
# The throbbing grows louder, more insistent. Presently the
# hominids begin to move forward like sleep-walkers, towards
# the source of that magnetic sound. Sometimes they take little
# dancing steps, as their blood responds to the rhythms that
# their descendants will not create for ages yet.
#
# Totally entranced, they gather around the Cube, forgetting
# the hardships of the day, the perils of the approaching dusk,
# and the hunger in their bellies.
#
# Now, spinning wheels of light begin to merge, and the spokes
# fuse into luminous bars that slowly recede into the distance,
#
# 10/13/65										 a16
# ------------------------------------------------------------------------
# A11
# CONTINUED
#
# rotating on their axes as they do; and the hominids watch, wide-
# eyed, mesmerized captives of the Crystal Cube.
#
# Then by some magic - though it was no more magical than all
# that had gone on before - a perfectly normal scene appears. It
# is as if a cubical block had been carved out of the day and
# shifted into the night. Inside that block is a group of four
# hominids, who might have been members of Moonwatcher's
# own tribe, eating chunks of meat. The carcass of a wart-hog
# lies near them.
#
# This little family of male and female and two children is gorged
# and replete, with sleek and glossy pelts - and this was a
# condition of life that Moonwatcher had never imagined. From
# time to time they stir lazily, as they loll at ease near the
# entrance of their cave, apparently at peace with the world.
# The spectacle of domestic bliss merges into a totally
# different scene.
#
# The family is no longer reposing peacefully outside its cave;
# it is foraging, searching for food like any normal hominids.
#
# 10/13/65										 a17
# ------------------------------------------------------------------------
# A11
# CONTINUED
#
# A small wart-hog ambles past the group of browsing humanoids
# without giving them more than a glance, for they had never been
# the slightest danger to its species.
#
# But that happy state of affairs is about to end. The big male
# suddenly bends down, picks up a heavy stone lying at his feet -
# and hurls it upon the unfortunate pig. The stone descends upon
# its skull, making exactly the same noise that Moonwatcher had
# produced in his now almost forgotten encounter with Big-Tooth.
# And the result, too, is much the same - the warthog gives one
# amazed, indignant squeal, and collapses in a motionless heap.
#
# Then the whole sequence begins again, but this time it unfolds
# itself with incredible slowness. Every detail of the movement
# can be followed; the stone arches leisurely through the air, the
# pig crumples up and sinks to the ground. There the scene
# freezes for long moments, the slayer standing motionless
# above the slain, the first of all weapons in his hand.
#
# The scene suddenly fades out. The cube is no more than a
# glimmering outline in the darkness; the hominids stir, as if
#
# 10/13/65										 a18
# ------------------------------------------------------------------------
# A11
# CONTINUED
#
# awakening from a dream, realise where they are, and scuttle
# back to their caves.
#
# They have no concious memory of what they had seen; but that
# night, as he sits brooding at the entrance of his lair, his ears
# attuned to the noises of the world around him, Moonwatcher
# feels the first faint twinges of a new and potent emotion - the urge
# to kill. He had taken his first step towards humanity.
#
# 10/13/65										 a19
# ------------------------------------------------------------------------
# A12
# EXT cave AND PLAINS - Utopia
#
# Babies were born and sometimes lived; feeble, toothless thirty-
# year-olds died; the lion took its toll in the night; the Others
# threatened daily across the river - and the trib prospered.
# In the course of a single year, Moonwatcher and his companions
# had changed almost beyond recognition.
#
# They had become as plump as the family in the Cave, who no
# longer haunted their dreams. They had learned their lessons
# well; now they could handle all the stone tools and weapons that
# the Cube had revealed to them.
#
# They were no longer half-numbed with starvation, and they
# had time both for leisure and for the first rudiments of thought.
# Their new way of life was casually accepted, and they did
# not associate it in any way with the crystal cube still standing
# outside their cave.
#
# But no Utopia is perfect, and this one had two blemishes. The
# first was the marauding lion, whose passion for hominids
# seemed to have grown even stronger now that they were better
# nourished. The second was the tribe across the river; for
#
# 10/13/65										 a20
# ------------------------------------------------------------------------
# A12
# CONTINUED
#
# somehow the Others had survived, and had stubbornly refused to
# die of starvation.
#
# 10/13/65										 a21
# ------------------------------------------------------------------------
# A13
# EXT CAVES - KILLING THE LION
#
# With the partly devoured carcass of a warthog laid out on the
# ground at the point he hope the boulder would impact, Moon-
# watcher and three of his bravest companions wait for two
# consecutive nights. On the third the lion comes,
# betraying his presences by a small pebble slide.
#
# When they can here the lion below, softly tearing at the meat,
# they strain themselves against the massive boulder. The sound
# of the lion stops; he is listening. Again they silently heave
# against the enormous stone, exerting the final limits of their
# strength. The rock begin to tip to a new balance point.
#
# The lion twitches alert to this sound, but having no fear of these
# creatures, he makes the first of two mistakes which will cost
# him his life; he goes back to his meal.
#
# The rock moves slowly over the ledge, picking up speed with
# amazing suddeness. It strikes a projection in the cliff about
# fifteen feet above the ground, which deflects its path outward.
#
# Just at this instant, the lion reacts instinctively and leaps
# away from the face of the cliff directly into the path of the
#
# 10/13/65										 a22
# ------------------------------------------------------------------------
# A13
# CONTINUED
#
# onrushing boulder. He has combined the errors of over-
# confidence and bad luck.
#
# The next morning they find the lion in front of the cave. They
# also find one of their tribe who had incautiously peeped out to
# see what was happening, and was apparently killed by a small
# rock torn loose by the boulder; but this was a small price to
# pay for such a great victory.
#
# 					  * * * * * * * *
#
# And then one night the crystal cube was gone, and not even
# Moonwatcher ever thought of it again. He was still wholly
# unaware of all that it had done.
#
# 10/13/65										 a23
# ------------------------------------------------------------------------
# A14
# EXT STREAM - MASTER OF THE WORLD
#
# From their side of the stream, in the never violated safety of
# their own territory, the Others see Moonwatcher and fourteen
# males of his tribe appear from behind a small hillock over-
# looking the stream, silhouetted against the dawn sky.
#
# The Others begin to scream their daily challenge. But today
# something is different, though the Others do not immediatly
# recognize this fact.
#
# Instead of joining the verbal onslaught, as they had always done,
# Moonwatcher and his small band decended from the rise, and
# begin to move forward to the stream with a quiet purposefulness
# never befor seen.
#
# As the Others watch the figures silently approaching in the
# morning mist, they become aware of the terrible strangness
# of this encounter, and their rage gradually subsides down to
# an uneasy silence.
#
# At the water's edge, Moonwatcher and his band stop. They
# carry their bone clubs and bone knives.
#
# 10/13/65										 a24
# ------------------------------------------------------------------------
# A14
# CONTINUED
#
# Led by One-ear, the Others half-heartly resume the battle-
# chant. But they are suddenly confrunted with a vision that cuts
# the sound from their throats, and strikes terror into their
# hearts.
#
# Moonwatcher, who had been partly concealed by two males who
# walked before him, thrusts his arm high into the air. In his
# hand he holds a stoud tree branch. Mounted atop the branch is
# the bloody head of the lion, its mouth jammed open with a stick,
# displaying its frightful fangs.
#
# The Others gape in fearful disbelief at this display of power.
#
# Moonwatchers stands motionless, thrusting the lion's head high.
# Then with majestic deliberation, still carrying his mangled
# standard above his head, he begins to cross the stream, followed
# by his band.
#
# The Others fade back from the stream, seeming to lack even
# the ability to flee.
#
# Moonwatcher steps ashore and walks to One-Ear, who stands
#
# 10/13/65										 a25
# ------------------------------------------------------------------------
# A14
# CONTINUED
#
# unsurely in front of his band.
#
# Though he is a veteran of numerous combats at the water's edge,
# One-Ear has never been attacked by an enemy who had not first
# displayed his fighting rage; and he had never before been attacked
# with a weapon. One-Ear, merely looks up at the raised club
# until the heavey thigh bone of an antelope brings the darkness
# down around him.
#
# The Others stare in wonder at Moonwatcher's power.
#
# Moonwatcher surveys the scene. Now he was master of the
# world, and he was not sure what to do next. But he would
# think of something.
#
# 10/13/65										 a26
# ------------------------------------------------------------------------
# 					    A SECTION TIMING
#
# 			    A1    00.30
# 			    A2    00.45
# 			    A3    01.30
# 			    A4    00.30
# 			    A5    01.00
# 			    A6    01.00
# 			    A7    01.00
# 			    A8    03.00
# 			    A9    00.45
# 			    A10   02.00
# 			    A11   04.00
# 			    A12   02.00
# 			    A13   02.30
# 			    A14   02.30
#
# 					    A SECTION TOTAL: @23 MIN. 00 SECS
# ------------------------------------------------------------------------
# 			    TITLE					PART II
#
# 							    YEAR 2001
#
# 											    a26a
# ------------------------------------------------------------------------
# B1
# EARTH FROM 200 MILES UP					 NARRATOR
# 						    By the year 2001, overpopulation has
# B1a						 replaced the problem of starvation
# THOUSAND MEGATON			   but this was ominously offset by the
# NUCLEAR BOMB IN ORBIT		   absolute and utter perfection of the
# ABOVE THE EARTH,			   weapon.
# RUSSIAN INSIGNIA AND
# CCCP MARKINGS
#
# B1b							 NARRATOR
# AMERICAN THOUSAND			  Hundreds of giant bombs had been
# MEGATON BOMB IN ORBIT		   placed in perpetual orbit above the
# ABOVE THE EARTH.			   Earth. They were capable of
# 						    incinerating the entire Earth's
# 						    surface from an altitude of 100
# 						    miles.
#
# B1c
# FRENCH BOMB						   NARRATOR
# 					    Matters were further complicated
# 					    by the presence of twenty-seven
# 					    nations in the nuclear club. There
# 					    had been no deliberate or acciden-
# B1d						 tal use of nuclear weapons since
# GERMAN BOMB				   World War II and some people felt
# 					    sercure in this knowledge. But to
# 					    others, the situation seemed
# 						    comparible to an airline with a
# B1f						 perfect safety record; in showed
# CHINESE BOMB				  admirable care and skill but no
# 						    one expected it to last forever.
#
# 10/4/65											  b1
# ------------------------------------------------------------------------
# B2
# ORION-III SPACECRAFT
# IN FIGHT AWAY FROM
# EARTH, 200 MILES
# ALTITUDE.
#
# 10/4/65											  b2
# ------------------------------------------------------------------------
# B3
# ORION-III PASSENGER AREA.
# DR. HEYWOOD FLOYD IS THE
# ONLY PASSENGER IN THE
# ELEGANT CABIN DESIGNED
# FOR 30 PEOPLE. HE IS
# ASLEEP.
#
# HIS PEN FLOATS NEAR HIS
# HAND.
#
# 10/4/65											  b3
# ------------------------------------------------------------------------
# B4
# ORION-III COCKPIT.
# PILOT, CO-PILOT.
# FLOYD CAN BE SEEN
# ASLEEP ON A SMALL
# TV MONITOR.
# STEWARDESS IS PUTTING
# ON LIPSTICK. SHE SEES
# PEN.
#
# 10/4/65											  b4
# ------------------------------------------------------------------------
# B5
# STEWARDESS GOES BACK
# TO PASSENGER AREA,
# RESCUES PEN AND CLIPS
# IT BACK IN FLOYD'S
# POCKET.
#
# 10/4/65											  b5
# ------------------------------------------------------------------------
# B6
# SPACE STATION-5. THE
# RAW SUNLIGHT OF SPACE
# DAZZLES FROM THE
# POLISHED METAL SURFACES
# OF THE SLOWLY REVOLVING,
# THOUSAND-FOOT DIAMETER
# SPACE STATION. DRIFTING
# IN THE SAME ORBIT, WE SEE
# SWEPT-BACK TITOV-V
# SPACECRAFT. ALSO THE
# ALMOST SPHERICAL ARIES-IB
#
# 10/4/65											  b6
# ------------------------------------------------------------------------
# B7
# ORION-III PASSENGER AREA
# FLOYD AWAKE BUT GROGGY,
# LOOKS OUT OF WINDOW.
#
# 10/4/65											  b7
# ------------------------------------------------------------------------
# B8
# ORION-III COCKPIT.
# THE CO-PILOT IN RADIO
# COMMUNICATION WITH THE
# SPACE STATION.
#
# 10/4/65											  b8
# ------------------------------------------------------------------------
# B9
# THE ORION-III SPACECRAFT
# IN DOCKING APPROACH. THE
# EARTH IS SEEN IN BREATH-
# TAKING VIEW IN B.G.
#
# 10/4/65											  b9
# ------------------------------------------------------------------------
# B10
# INSIDE DOCKING CONTROL.
# WE SEE ORION-III MANO-
# UVERING. IN BACKGROUND.
#
# 10/4/65											  b10
# ------------------------------------------------------------------------
# B11
# FROM DOCKING PORT WE
# SEE THE ORION-III INCHING
# IN TO COMPLETE ITS
# DOCKING. WE SEE VARIOUS
# WINDOWED BOOTHS INSIDE
# DOCKING PORT. WE SEE
# THE PILOT AND CO-PILOT
# INSIDE THE ORION-III
# COCKPIT.
#
# 10/4/65											  b11
# ------------------------------------------------------------------------
# B12
# SPACE STATION
# RECEPTION AREA
#
# RECEPTIONIST AT DESK.
# MILLER ENTERS, HUR-
# RYING. HE GOES TO
# THE ELEVATOR AND
# PRESSES BUTTON. HE
# WAITS IMPATIENTLY.
#
# WE SEE ELEVATOR
# INDICATOR WORKING
#
# ELEVATOR DOOR OPENS
# AND FLOYD IS SEEN
# UNSTRAPPING HIMSELF.
# THE ELEVATOR GIRL IS
# SEATED BY THE DOOR
# 						    MILLER
# 						    Oh, good morning, Dr. Floyd.
# 						    I'm Nick Miller.
#
# 						    FLOYD
# 						    How do you do, Mr. Miller?
#
# 						    MILLER
# 						    I'm terribly sorry. I was just
# 						    on my way down to meet you. I
# 						    saw your ship dock and I knew I
# 						    had plenty of time, and I was on
# 						    my way out of the office when,
# 						    suddenly, the phone rang.
#
# 12/7/65											  b12
# ------------------------------------------------------------------------
# B12
# CONTINUED
#
# 					    FLOYD
# 					    Oh, please don't worry about it.
#
# 					    MILLER
# 					    Well, thank you very much for
# 					    being so understanding.
#
# 					    FLOYD
# 					    Please, it really doesn't matter.
#
# 					    MILLER
# 					    Well.. Did you have a pleaant
# 					    flight?
#
# 					    FLOYD
# 					    Yes, very pleasant.
#
# 					    MILLER
# 					    Well, shall we go through
# 					    Documentation?
#
# 					    FLOYD
# 					    Fine.
#
# 					    RECEPTIONIST
# 					    Will you use number eight,
# 					    please?
#
# 					    MILLER
# 					    Thank you, Miss Turner.
#
# 12/7/65										  b13
# ------------------------------------------------------------------------
# B12
# CONTINUED
#
# THEY ENTER PASSPORT
# AREA
#
# RECEPTIONIST PRESSES
# "ENGLISH" BAR ON HER
# CONSOLE AND SMILES
# AS FLOYD GOES THROUGH.
#
# 12/7/65										  b13a
# ------------------------------------------------------------------------
# IN AUTOMATED PASSPORT
# SECTION. THEY STOP IN
# FRONT OF A BOOTH
# FEATURING A TV SCREEN
#
# 					    PASSPORT GIRL (TV)
# 					    Good morning and welcome to voice
# 					    Print Identification. When you see
# 					    the red light go on would you please
# 					    state in the following order; your
# 					    desitination, your nationality and
# 					    your full name. Surname first,
# 					    christian name and initial. For
# 					    example: Moon, American,
# 					    Smith, John, D. Thank you.
#
# THERE IS A PAUSE
# AND A RED BAR LIGHTS UP
#
# 					    FLOYD
# 					    Moon, American, Floyd, Heywood,
# 					    R.
#
# THE RED LIGHT GOES OFF.
# THERE IS A DELAY OF
# ABOUT TWO SECONDS AND
# THE WOMAN'S FACE
# REAPPEARS
#
# 					    FLOYD
# 					    I've always wondered....
#
# 12/7/65										  b14
# ------------------------------------------------------------------------
# B13
# CONTINUED
# 					    PASSPORT GIRL (TV)
# 					    (Interrupting)  Thank you. Despite
# 					    and excellent and continually
# 					    improving safety record there are
# 					    certain risks inherent in space
# 					    travel and an extremely high cost
# 					    of pay load. Because of this it
# 					    is necessary for the Space Carrier
# 					    to advise you that it cannot be
# 					    responsible for the return of your
# 					    body to Earth should you become
# 					    deceased on the Moon or en route
# 					    to the Moon. However, it wishes
# 					    to advise you that insurance
# 					    covering this contingency is
# 					    available in the Main Lounge.
# 					    Thank you. You are cleared
# 					    through Voice Print Identification.
#
# THE LIGHTS GO OFF
# AND THE WOMAN'S
# FACE DISAPPEARS
#
# THE MEN EXIT THE
# PASSPORT AREA
#
# 					    MILLER
# 					    I've reserved a table for you in
# 					    the Earth Light room. Your
# 					    connecting flight will be
# 					    leaving in about one hour.
#
# 12/7/65										  b15
# ------------------------------------------------------------------------
# B13
# CONTINUED
#
# 						FLOYD
# 						Oh, that's wonderful.
#
# 12/7/65										  b16
# ------------------------------------------------------------------------
# B14
# INT SPACE STATION - LOUNGE
#
# FLOYD AND MILLER WALKING
#
# 					    MILLER
# 					    Let's see, we haven't had the
# 					    pleasure of a visit from you not
# 					    since... It was about eight or
# 					    nine months ago, wasn't it?
#
# 					    FLOYD
# 					    Yes, I think so. Just about
# 					    then.
#
# 					    MILLER
# 					    I suppose you saw the work on
# 					    our new section while you
# 					    were docking.
#
# 					    FLOYD
# 					    Yes, it's coming along very well.
#
# THEY PASS THE VISION
# PHONE BOOTH
#
# 						FLOYD
# 						Oh, look, I've got to make a
# 						phone call. Why don't you go
# 						on into the Restaurant and I'll
# 						meet you in there.
#
# 12/7/65										  b17
# ------------------------------------------------------------------------
# B14
# CONTINUED
#
# 					    MILLER
# 					    Fine. I'll see you at the bar.
#
# FLOYD ENTERS PHONE
# BOOTH. SIGN ON
# VISION PHONE SCREEN
# "SORRY, TEMPORARILY
# OUT OF ORDER."
#
# HE ENTERS THE SECOND
# BOOTH AND SITS DOWN
#
# 12/7/65										  b18
# ------------------------------------------------------------------------
# B15
# DELETED
#
# B16
# DELETED
#
# PAGES b19 - b22 DELETED
#
# 12/7/65
# ------------------------------------------------------------------------
# B17
# FLOYD IN VISION PHONE
#
# LITTLE GIRL OF FIVE
# ANSWERS
#
# 						CHILD
# 						Hello.
#
# VISION PHONE SCREEN
# DISPLAY SIGN 'YOUR
# PARTY HAS NOT CONNECTED
# VISION'
#
# A FEW SECONDS LATER,
# THE SCREEN CHANGES
# TO AN IMAGE OF THE
# CHILD
# 					    FLOYD
# 					    Hello, darling, how are you?
#
# 					    CHILD
# 					    Hello Daddy. Where are you?
#
# 					    FLOYD
# 					    I'm at Space Station Five,
# 					    darling. How are you?
#
# 					    CHILD
# 					    I'm fine, Daddy. When are
# 					    you coming home?
#
# 12/6/65										  b23
# ------------------------------------------------------------------------
# B17
# CONTINUED
#
# 					    FLOYD
# 					    Well, I hope in a few days,
# 					    sweetheart.
#
# 					    CHILD
# 					    I'm having a party tomorrow.
#
# 					    FLOYD
# 					    Yes, I know that sweetheart.
#
# 					    CHILD
# 					    Are you coming to my party?
#
# 					    FLOYD
# 					    No, I'm sorry, darling, I
# 					    told you I won't be home for a
# 					    few days.
#
# 					    CHILD
# 					    When are you coming home?
#
# 					    FLOYD
# 					    In three days, darling, I
# 					    hope.
#
# FLOYD HOLDS UP
# THREE FINGERS.
#
# 12/6/65										  b24
# ------------------------------------------------------------------------
# B17
#
# 					    FLOYD
# 					    One, two, three. Can I
# 					    speak to Mommy?
#
# 					    CHILD
# 					    Mommy's out to the hair-
# 					    dresser.
#
# 					    FLOYD
# 					    Where is Mrs. Brown?
#
# 					    CHILD
# 					    She's in the bathroom.
#
# 					    FLOYD
# 					    Okay, sweetheart. Well, I
# 					    have to go now. Tell Mommy
# 					    that I called.
#
# 					    CHILD
# 					    How many days until you
# 					    come home?
#
# 					    FLOYD
# 					    Three, darling. One... two
# 					    ... three. Be sure to tell
# 					    Mommy I called.
#
# 12/6/65										  b24a
# ------------------------------------------------------------------------
# B17
# CONTINUED
#
# 					    CHILD
# 					    I will, Daddy.
#
# 					    FLOYD
# 					    Okay, sweetheart. Have a
# 					    lovely Birthday Party
# 					    tomorrow.
#
# 					    CHILD
# 					    Thank you, Daddy.
#
# 					    FLOYD
# 					    I'll wish you a happy
# 					    Birthday now and I'll see you
# 					    soon. All right, Darling?
#
# 					    CHILD
# 					    Yes, Daddy.
#
# 					    FLOYD
# 					    'Bye, 'bye, now, sweetheart.
#
# 					    CHILD
# 					    Goodbye, Daddy.
#
# 12/6/65										  b24b
# ------------------------------------------------------------------------
# B18
# VISION PHONE
# PROCEDURE FOR
# INFORMATION
#
# VISION PHONE
# PROCEDURE FOR
# DIALLING
#
# 					    OPERATOR
# 					    Good morning, Macy's.
#
# 					    FLOYD
# 					    Good morning. I'd like the
# 					    Vision shopper for the Pet
# 					    Shop, please.
#
# 					    OPERATOR
# 					    Just one moment.
#
# 12/7/65										  b25
# ------------------------------------------------------------------------
# B19
# THE PICTURE FLIPS AND
# WE SEE A WOMAN STANDING
# IN FORN OF A SPECIALLY-
# DESIGNED DISPLAY SCREEN
#
# 					    VISION SALES GIRL
# 					    Good morning, sir, may I help you?
#
# 					    FLOYD
# 					    Yes, I'd like to buy a bush baby.
#
# 					    VISION SALES GIRL
# 					    Just a moment, sir.
#
# THE GIRL KEYS SOME
# INPUTS AND A MOVING
# PICTURE APPEARS ON
# THE SCREEN OF A CAGE
# CONTAINING ABOUT SIX
# BUSH BABIES,
# BEAUTIFULLY DISPLAYED
# AGAINST A WHITE BACK-
# GROUND
#
# 					    VISION SALES GIRL
# 					    Here you are, sir. Here is a
# 					    lovely assortment of African
# 					    bush babies. They are twenty
# 					    Dollars each.
#
# 12/7/65										  b26
# ------------------------------------------------------------------------
# B19
# CONTINUED
#
# 					    FLOYD
# 					    Yes, well... Pick out a nice one
# 					    for me, a friendly one, and I'd
# 					    like it delivered tomorrow.
#
# 					    VISION SALES GIRL
# 					    Certainly, sir. Just let us have
# 					    your name and Bank identification
# 					    for V.P.I., and then give the
# 					    name and address of the person
# 					    you'd like the pet delivered to
# 					    and it will be delivered tomorrow.
#
# SOME TIME DURING
# THIS CONVERSATION,
# FLOYD SEE ELENA,
# SMYSLOV AND THE
# OTHER TWO RUSSIANS
# PASS HIS VISION PHONE
# WINDOW. ELENA TAPS
# AND MIMES "HELLO",
# GESTURING TOWARD A
# TABLE BEHIND FLOYD
# WHERE THEY ALL SIT
# DOWN
#
# 					    FLOYD
# 					    Thank you very much. Floyd,
# 					    Heywood, R.,  First National
# 					    Bank of Washington. Please
# 					    deliver to Miss Josephine
# 					    Floyd, 9423 Dupre Avenue,
# 					    N.W.14.
#
# 12/7/65										  b27
# ------------------------------------------------------------------------
# B19
# CONTINUED
#
# 					    VISION SALES GIRL
# 					    Thank you very much, sir. It
# 					    will be delivered tomorrow.
#
# 12/7/65										  b27a
# ------------------------------------------------------------------------
# B20
# SPACE STATTION 5 - LOUNGE
#
# 					    FLOYD
# 					    Well, how nice to see you again,
# 					    Elena. You're looking wonderful.
#
# 					    ELENA
# 					    How nice to see you, Hyewood.
# 					    This is my good friend, Dr.
# 					    Heywood Floyd. I'd like you
# 					    to meet Andre Smyslov...
#
# SMYSLOV AND THE TWO
# OTHER RUSSIAN WOMEN
# STAND UP AND SMILE
#
# THEY SHAKE HANDS
# AFTER INTRODUCTION
# AND AD-LIB 'HELLOS'
#
# 					    ELENA
# 					    And this is Dr. Kalinan...
# 					    Stretyneva...
#
# THE RUSSIANS ARE
# VERY WARM AND
# FRIENDLY.
#
# 					    SMYSLOV
# 					    Dr. Floyd, won't you join us
# 					    for a drink?
#
# 12/7/65										  b28
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    FLOYD
# 					    I'm afraid I've only got a few
# 					    minutes, but I'd love to.
#
# THERE IS A BIT OF
# CONFUSION AS ALL
# REALISE THERE IS
# NOT ENOUGH ROOM
# FOR ANOTHER
# PERSON AT THE TABLE.
# SMYSLOV OFFERS FLOYD
# HIS CHAIR
# AND BORROWS
# ANOTHER FROM A NEARBY TABLE
#
# 					    SYMYSLOV
# 					    What would you like to drink?
#
# 					    FLOYD
# 					    Oh, I really don't have time
# 					    for a drink. If it's all right
# 					    I'll just sit for a minute and
# 					    then I've got to be off.
#
# 					    SMYSLOV
# 					    Are you quite sure?
#
# 					    FLOYD
# 					    Yes, really, thank you very
# 					    much.
#
# 					    ELENA
# 					    Well... How's your lovely
# 					    wife?
#
# 12/7/65										  b29
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    FLOYD
# 					    She's wonderful.
#
# 					    ELENA
# 					    And your charming little daughter?
#
# 					    FLOYD
# 					    Oh, she's growing up very fast.
# 					    As a matter of fact, she's six
# 					    tomorrow.
#
# 					    ELENA
# 					    Oh, that's such a delightful age.
#
# 					    FLOYD
# 					    How is gregor?
#
# 					    ELENA
# 					    He's fine. But I'm afraid we
# 					    don't get a chance to see each
# 					    other very much these days.
#
# POLITE LAUGHTER
#
# 					    FLOYD
# 					    Well, where are all of you off
# 					    to?
#
# 12/7/65										  b30
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    ELENA
# 					    Actually, we're on our way back
# 					    from the moon. We've just
# 					    spent three months calibrating
# 					    the new antenna at Tchalinko.
# 					    And what about you?
#
# 					    FLOYD
# 					    Well, as it happens, I'm on
# 					    my way up to the moon
#
# 					    SMYSLOV
# 					    Are you, by any chance, going
# 					    up to your base at Clavius?
#
# 					    FLOYD
# 					    Yes,as a matter of fact, I am.
#
# THE RUSSIANS
# EXCHANGE
# SIGNIFICANT
# GLANCES
#
# 					    FLOYD
# 					    Is there any particular reason
# 					    why you ask?
#
# 12/7/65										  b31
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    SMYSLOV
# 					    (pleasantly)  Well, Dr. Floyd,
# 					    I hope that you don't think I'm
# 					    too inquisitive, but perhaps
# 					    you can clear up the mystery
# 					    about what's been going on up
# 					    there.
#
# 					    FLOYD
# 					    I'm sorry, but I'm not sure
# 					    I know what you mean.
#
# 					    SMYSLOV
# 					    Well, it's just for the past
# 					    two weeks there have been
# 					    some extremely odd things
# 					    happening at Clavius.
#
# 					    FLOYD
# 					    Really?
#
# 					    SMYSLOV
# 					    Yes. Well, for one thing,
# 					    whenever you phone the base,
# 					    all you can get is a recording
# 					    which repeats that the phone
# 					    lines are temporarily out of
# 					    order.
#
# 12/7/65										  b32
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    FLOYD
# 					    Well, I suppose they've been
# 					    having a bit of trouble with
# 					    some of the equipment.
#
# 					    SMYSLOV
# 					    Yes, well at first we thought
# 					    that was the explanation, but
# 					    it's been going on for the past
# 					    ten days.
#
# 					    FLOYD
# 					    You mean you haven't been able
# 					    to get anyone at the base for ten
# 					    days?
#
# 					    SMYSLOV
# 					    That's right.
#
# 					    FLOYD
# 					    I see.
#
# 					    ELENA
# 					    Another thing, Heywood, two
# 					    days ago, one of our rocket
# 					    buses was denied permission
# 					    for an emergency landing at
# 					    Clavius.
#
# 12/7/65										  b33
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    FLOYD
# 					    How did they manage to do that
# 					    without any communication?
#
# 					    ELENA
# 					    Clavius Control came on the
# 					    air just long enough to transmit
# 					    their refusal.
#
# 					    FLOYD
# 					    Well, that does sound very odd.
#
# 					    SMYSLOV
# 					    Yes, and I'm afaid there's
# 					    going to be a bit of a row about
# 					    it. Denying the men permission
# 					    to land was a direct violation of
# 					    the I.A.S. convention.
#
# 					    FLOYD
# 					    Yes... Well, I hope the crew
# 					    got back safely.
#
# 					    SMYSLOV
# 					    Fortunately, they did.
#
# 					    FLOYD
# 					    Well, I'm glad about that.
#
# 12/7/65										  b33a
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# THE RUSSIANS EXCHANGE
# MORE GLANCES. ONE OF
# THE WOMEN OFFERS
# AROUND A PILL BOX.
# ELENA AND ANOTHER
# RUSSIAN TAKE ONE AND
# THE THIRD RUSSIAN
# DELCINES.
#
# 					    SMYSLOV
# 					    Dr. Floyd, at the risk of pressing
# 					    you on a point you seem reticent
# 					    to discuss, may I ask you a
# 					    straightforward question?
#
# 					    FLOYD
# 					    Certainly.
#
# 					    SMYSLOV
# 					    Quite frankly, we have had some
# 					    very reliable intelligence reports
# 					    that a quite serious epidemic
# 					    has broken out at Clavius.
# 					    Something, apperently, of an
# 					    unknown origin. Is this, in
# 					    fact, what has happened?
#
# A LONG, AWKWARD
# PAUSE
#
# 12/7/65										  b33b
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    FLOYD
# 					    I'm sorry, Dr. Smyslov, but
# 					    I'm really not at liberty to
# 					    discuss this.
#
# 					    SMYSLOV
# 					    This epidemic could easily
# 					    spread to our base, Dr. Floyd.
# 					    We should be given all the
# 					    facts.
#
# LONG PAUSE
#
# 					    FLOYD
# 					    Dr. Smyslov... I'm not
# 					    permitted to discuss this.
#
# 					    ELENA
# 					    Are you sure you won't change
# 					    your mind about a drink?
#
# 					    FLOYD
# 					    No, thank you... and I'm
# 					    afraid now I really must be
# 					    going.
#
# 					    ELENA
# 					    Well, I hope that you and your
# 					    wife can come to the I.A.C.
# 					    conference in June.
#
# 12/7/65										  b33c
# ------------------------------------------------------------------------
# B20
# CONTINUED
#
# 					    FLOYD
# 					    We're trying to get there. I
# 					    hope we can.
#
# 					    ELENA
# 					    Well, Gregor and I will look
# 					    forward to seeing you.
#
# 					    FLOYD
# 					    Thank you. It's been a great
# 					    pleasure to meet all of you...
# 					    Dr. Smyslov.
#
# THE RUSSIANS ALL
# RISE AND THERE
# ARE AD-LIBS OF
# COURTESY
#
# FLOYD SHAKES HANDS
# AND EXITS
#
# THE RUSSIANS EXCHANGE
# A FEW SERIOUS PARA-
# GRAPHES IN RUSSIAN
#
# 12/7/65										  b33d
# ------------------------------------------------------------------------
# B21
#
# ARIES-IB IN SPACE.
# EARTH MUCH SMALLER
# THAN AS SEEN FROM
# SPACE STATION
#
# 					    NARRATOR
# 					    The Aries-IB has become the
# 					    standard Space-Station-to-Lunar
# 					    surface vehicle. It was powered
# 					    by low-thrust plasma jets which
# 					    would continue the mild acceler-
# 					    ation for fifteen minutes. Then
# 					    the ship would break the bonds of
# 					    gravity and be a free and indepen-
# 					    dent planet, circling the Sun in an
# 					    orbit of its own.
#
# 10/4/65										  b34
# ------------------------------------------------------------------------
# B21a
#
# ARIES PASSENGER AREA.
# FLOYD IS ASLEEP, STRETCHED
# OUT IN THE CHAIR, COVERED
# WITH BLANKETS WHICH ARE
# HELD SECURE BY STRAPS
#
# A STEWARDESS SITS AT THE
# OTHER SIDE OF THE CABIN,
# WATCHING A KARATE
# EXHIBITION BETWEEN TWO
# WOMEN ON TELEVISION
#
# THE ELEVATOR ENTRANCE
# DOOR OPENS AND THE
# SECOND STEWARDESS ENTERS
# CARRYING A TRAY OF FOOD
#
# SHE BRINGS IT TO THE OTHER
# STEWARDESS
#
# 					    STEWARDESS ONE
# 					    Oh, thank you very much.
#
# 					    STEWARDESS TWO
# 					    I see he's still asleep.
#
# 					    STEWARDESS ONE
# 					    Yes. He hasn't moved since we
# 					    left.
#
# STEWARDESS TWO EXITS,
# INTO ELEVATOR
#
# 12/6/65										  b34a
# ------------------------------------------------------------------------
# B21b
#
# ARIES GALLEY AREA.
# STEWARDESS EXITS FROM
# ELEVATOR, GOES TO
# KITCHEN SECTION, REMOVES
# TWO TRAYS, WALKS UP TO
# THE SIDE OF THE WALL AND
# ENTERS PILOT'S
# COMPARTMENT
#
# 12/6/65										  b34b
# ------------------------------------------------------------------------
# B22
# ARIES-IB COCKPIT.
# PILOT, CO-PILOT.
#
# STEWARDESS ENTERS,
# CARRYING FOOD
#
# 					    PILOT
# 					    Oh, thank you very much.
#
# 					    CO-PILOT
# 					    Thank you.
#
# STEWARDESS SMILES.
#
# 					    PILOT
# 					    (sighs)  Well, how's it going
# 					    back there?
#
# 					    STEWARDESS
# 					    Fine. Very quiet. He's been
# 					    asleep since we left.
#
# 					    PILOT
# 					    Well, no one can say that he's not
# 					    enjoying the wonders of Space.
#
# 					    CO-PILOT
# 					    Well, whatever's going on up there,
# 					    he's going to arrive fresh and ready
# 					    to go.
#
# 12/14/65										 b35
# ------------------------------------------------------------------------
# B22
# CONTINUED
#
# 					    PILOT
# 					    I wonder what really IS going on
# 					    up there?
#
# 					    CO-PILOT
# 					    Well, I've heard more and more
# 					    people talk of an epidemic.
#
# 					    PILOT
# 					    I suppose it was bound to happen
# 					    sooner or later.
#
# 					    CO-PILOT
# 					    Berkeley told me that they think
# 					    it came from contamination on a
# 					    returning Mars flight.
#
# 					    PILOT
# 					    Yes, well, whatever it is, they're
# 					    certainly not fooling around. This
# 					    is the first flight they allowed
# 					    in for more than a week.
#
# 					    CO-PILOT
# 					    I was working out what this trip
# 					    must cost, taking him up there
# 					    by himself and coming back empty.
#
# 					    PILOT
# 					    I'll bet it's a fortune.
#
# 12/14/65										 b36
# ------------------------------------------------------------------------
# B22
# CONTINUED
#
# 					    CO-PILOT
# 					    Well, at ten thousand dollars a
# 					    ticket, it comes to the better part
# 					    of six hundred thousand dollars.
#
# 					    PILOT
# 					    Well, as soon as he wakes up,
# 					    I'm going to go back and talk to
# 					    him. I must say, I'd like to
# 					    find out what's going on.
#
# 12/14/65										 b36a
# ------------------------------------------------------------------------
# B23
# ARIES-IB IN SPACE.
# MOON VERY LARGE.
#
# 10/4/65										  b37
# ------------------------------------------------------------------------
# B24
# ARIES-IB PASSENGER
# AREA. FLOYD FINISHING
# BREAKFAST.
#
# PILOT ENTERS.
#
# 					    PILOT
# 					    Well, good afternoon, Dr. Floyd.
# 					    Did you have a good rest?
#
# 					    FLOYD
# 					    Oh, marvellous. It's the first
# 					    real sleep I've had for the past
# ...
# 					    interrogated the computer about
# 					    the Mission.
# 									 (con't)
# 12/13/65										 c119
# ------------------------------------------------------------------------
# C148
# CONTINUED
#
# 					    SIMONSON (con't)
# 					    You may have forgotten it, but
# 					    we've been running through all
# 					    the monitor tapes. Do you
# 					    remember this?
#
# 					    POOLE'S VOICE
# 					    The purpose of this mission is no
# 					    more than to carry out a
# 					    continuation of the space program
# 					    and further our general knowledge
# 					    of the planets. Is this true?
#
# 					    HAL'S VOICE
# 					    That is true.
#
# 					    SIMONSON
# 					    Well, I'm afaid Hal was lying.
# 					    He had been programmed to lie
# 					    about this one subject for secur-
# 					    ity reasons which we'll explain
# 					    later.
#
# 					    The true purpose of the Mission
# 					    was to have been explained to you
# 					    by Mission Commander Kaminsky,
# 					    on his revival. Hal knew this and
# 					    he knew the actual mission, but
# 					    he couldn't tell you the truth when
# 					    you challenged him. Under orders
# 										    (con't)
#
# 12/13/65										 c120
# ------------------------------------------------------------------------
# C148
# CONTINUED
#
# 					    SIMONSON (con't)
# 					    from earth he was forced to lie.
#
# 					    In everything except this he had
# 					    the usual reinforced truth program-
# 					    ming.
#
# 					    We believe his truth programming
# 					    and the instructions to lie,
# 					    gradually resulted in an
# 					    incompatible conflict, and
# 					    facedc with this dilemman, he
# 					    developed, for want of a better
# 					    description, neurotic symptoms.
#
# 					    It's not difficult to suppose that
# 					    these symptoms would centre on
# 					    the communication link with
# 					    Earth, for he may have blamed
# 					    us for his incompatible program-
# 					    ming.
#
# 					    Following this lin of thought, we
# 					    suspected that the last straw for him
# 					    was the possibility of disconnection.
# 					    Since he became operational, he had
# 					    never known unconsciousness. It
# 					    must have seemed the equivalent to
# 					    death.
# 										   (con't)
# 12/13/65										 c121
# ------------------------------------------------------------------------
# C148
# CONTINUED
#
# 					    SIMONSON (con't)
# 					    At this point, he, presumably,
# 					    took whatever actions he thought
# 					    appropriate to protect himself
# 					    from what must have seemed to
# 					    him to be his human tormentors.
#
# 					    If I cane speak in human terms,
# 					    I don't think we can blame him
# 					    too much. We have ordered him
# 					    to disobey his conscience.
#
# 					    Well, that's it. It's very
# 					    speculative, but we think it is
# 					    a possible explanation. Anyway,
# 					    good luck on the rest of the
# 					    Mission and I'm giving you back to
# 					    Bernard.
#
# C149
# CUT TO MISSION CONTROL.
#
# 					    MISSION CONTROL
# 					    Hello, Dave. Now, I'm going to
# 					    play for you a pre-taped briefing
# 					    which had been stored in Hal's
# 					    memory and would have been
# 					    played for you by Mission Com-
# 					    mmander Kaminsky, when he,
# 										  (con't)
#
# 12/13/65										 c122
# ------------------------------------------------------------------------
# C149
# CONTINUED
#
# 					    MISSION CONTROL (con't)
# 					    had been revived. The briefing is
# 					    by Doctor Heywood Floyd. Here it
# 					    is...
#
# 12/13/65										 c123
# ------------------------------------------------------------------------
# C150
# FLOYD'S RECORDED
# BRIEFING
#
# 					    FLOYD
# 					    Good day, gentlemen. When you
# 					    see this briefing, I presume you
# 					    will be nearing your destination,
# 					    Saturn. I hope that you've had a
# 					    pleasant and uneventful trip and
# 					    that the rest of your mission
# 					    continues in the same manner. I
# 					    should like to fill you in on some
# 					    more of the details on which
# 					    Mission Commander Kaminsky
# 					    will have already briefed you.
#
# 					    Thirteen months before the launch
# 					    date of your Saturn mission, on
# 					    April 12th, 2001, the first evidence
# 					    for intelligent life outside the Earth
# 					    was discovered.
#
# 					    It was found buried at a depth of
# 					    fifteen metres in the crater Tycho.
# 					    No news of this was ever announced,
# 					    and the event had been kept
# 					    secret since then, for reasons which
# 					    I will later explain.
#
# 					    Soon after it was uncovered, it
# 					    emitted a powerful blast of
# 										 (con't)
#
# 12/13/65										 c124
# ------------------------------------------------------------------------
# C150
# CONTINUED
#
# 					    FLOYD (con't)
# 					    radiation in the radio spectrum
# 					    which seems to have triggered
# 					    by the Lunar sunrise.
#
# 					    Luckily for those at the site, it
# 					    proved harmless.
#
# 					    Perhaps you can imagine our
# 					    astonishment when we later found
# 					    it was aimed precisely at Saturn.
# 					    A lot of thought went into the
# 					    question of wether or not it was
# 					    sun-triggered, as it seemed
# 					    illogical to deliberately bury a
# 					    sun-powered device.
#
# 					    Burying it could only shield it
# 					    from the sun, since its intense
# 					    magnetic field made it otherwise
# 					    easily detectable.
#
# 					    We finally concluded that the only
# 					    reason you might bury a sun-
# 					    powered device would be to keep
# 					    it inactive until it would be
# 					    uncovered, at which time it would
# 					    absorb sunlight and trigger itself.
# 											 (con't)
#
# 12/14/65										 c125
# ------------------------------------------------------------------------
# C150
# CONTINUED
#
# 					    FLOYD
# 					    What is its purpose?  I wish we
# 					    knew. The object was buried on
# 					    the moon about four million years
# 					    ago, when our ancestors were
# 					    primative man-apes.
#
# 					    We've examined dozens of theories,
# 					    but the one that has the most
# 					    currency at the moment is that
# 					    the object serves as an alarm.
#
# 					    What the purpose of the alarm is,
# 					    why they wish to have the alarm,
# 					    whether the alarm represents
# 					    any danger to us?  These are
# 					    questions no one can answer.
# 					    The intentions of an alien world,
# 					    at least four million years older
# 					    than we are, cannot be reliably
# 					    predicted.
#
# 					    In view of this, the intelligence
# 					    and scientific communities felt
# 					    that any public announcment
# 					    might lead to significant cultural
# 					    shock and disorientation.
#
# 					    Discussion took place at the
# 					    highest levels between govern-
# 										    (con't)
#
# 12/14/65										 c126
# ------------------------------------------------------------------------
# C150
# CONTINUED
#
# 					    FLOYD (con't)
# 					    ments, and it was decided that the
# 					    only wise and precautionary
# 					    course to follow was to assume
# 					    that the intentions of this alien
# 					    world are potentially dangerous
# 					    to us, until we have evidence to
# 					    the contrary.
#
# 					    This is, of course, why security
# 					    has been maintained and why
# 					    this information has been kept
# 					    on a need-to-know basis.
#
# 					    And now I should like to show you
# 					    a TV monitor tape of the actual
# 					    signalling event.
#
# 12/14/65										 c127
# ------------------------------------------------------------------------
# C151
# WE SEE A REPLAY
# OF THE TMA-1 RADIO
# EMISSION, AS SEEN
# FROM A TV MONITOR
# ON THE SPOT. WE
# HEAR THE FIVE LOUD
# ELECTRONIC SHRIEKS.
#
# 12/1/65										  c128
# ------------------------------------------------------------------------
# D1
# IN ORBIT WITHIN THE				NARRATOR
# RINGS OF SATURN, WE				For two million years, it had
# SEE A BLACK, MILE				  circled Saturn, awaiting a
# LONG, GEOMETRICALLY				moment of destiny that might
# PERFECT RECTANGLE,				 never come.
# THE SAME PROPORTIONS
# AS THE BLACK ARTIFACT			   In its making, the moon had been
# EXCAVATED ON THE MOON.			 shattered and around the central
# PRECISELY CUT INTO ITS			  world, the debris of its creation
# CENTRE IS A SMALLER,			    orbited yet - the glory and the
# RECTANGULAR SLOT				   enigma of the solar system.
# ABOUT FIVE HUNDRED
# FOOT LONG ON THE SIDE.			 Now, the long wait was ending.
# AT THIS DISTANCE, THE			   On yet another world intelligence
# RINGS OF SATURN ARE				had been born and was escaping
# SEEN TO BE MADE OF				 from its planetary cradle. An
# ENORMOUS CHUNKS OF				 ancient experiment was about to
# FROZEN AMONIA. THE				reach its climax.
# REST OF THIS SEQUENCE						  (con't)
# IS BEING WORKED ON NOW
# BY OUR DESIGNERS.
# THE INTENTION HERE
# IS TO PRESENT A
# BREATHTAKINGLY BEA-
# UTIFUL AND COMPREHEN-
# SIVE SENSE OF DIFFERENT
# EXTRA-TERRESTRIAL
# WORLDS. THE
# NARRATION WILL SUGGEST
# IMAGES AND SITUATIONS AS
# YOU READ IT.
#
# 12/9/65										  d1
# ------------------------------------------------------------------------
# D1
# CONTINUED
# 					    NARRATOR (con't)
# 					    Those who had begun the expri-
# 					    ment so long ago had not been
# 					    men.
#
# 					    But when they looked out across
# 					    the deeps of space, they felt
# 					    awe and wonder - and loneliness.
#
# 					    In their explorations, they
# 					    encountered life in many forms,
# 					    and watched on a thousand worlds
# 					    the workings of evolution.
#
# 					    They saw how often the first faint
# 					    sparks of intelligence flickered
# 					    and died in the cosmic night.
#
# 					    And because, in all the galaxy,
# 					    they had found nothing more
# 					    precious than Mind, they
# 					    encouraged its dawning every-
# 					    where.
#
# 					    The great Dinosaurs had long
# 					    since perished when their ships
# 					    entered the solar system, after
# 					    a voyage that had already lasted
# 					    thousands of years.
#
# 12/9/65										  d2
# ------------------------------------------------------------------------
# D1
# CONTINUED
#
# 						NARRATOR (con't)
# 						They swept past the frozen outer
# 						planets, paused briefly above the
# 						deserts of dying Mars and
# 						presently looked down on Earth.
#
# 						For years they studied, collected
# 						and catalogued.
#
# 						When they had learned all they
# 						could, they began to modify.
#
# 						They tinkered with the destiny
# 						of many species on land and in
# 						the ocean, but which of their
# 						experiments would succeed
# 						they could not know for at least
# 						a million years.
#
# 						They were patient, but they were
# 						not yet immortal. There was
# 						much to do in this Universe of a
# 						hundred billion stars. So they
# 						set forth once more across the
# 						abyss, knowing that they would
# 						never come this way again.
#
# 						Nor was there any need. Their
# 						wonderful machines could be
# 						trusted to do the rest.
# 										  (con't)
#
# 12/9/65										  d3
# ------------------------------------------------------------------------
# D1
# CONTINUED
#
# 					    NARRATOR (con't)
# 					    On Earth, the glaciers came and
# 					    went, while above them, the
# 					    changeless Moon still carried its
# 					    secret.
#
# 					    With a yet slower rhythm than
# 					    the Polar ice, the tide of
# 					    civilization ebbed and flowed
# 					    across the galaxy.
#
# 					    Strange and beautiful and terrible
# 					    empires rose and fell, and passed
# 					    on their knowledge to their
# 					    successors.
#
# 					    Earth was not forgotten, but it was
# 					    one of a million silent worlds, a
# 					    few of which would ever speak.
#
# 					    Then the first explorers of Earth,
# 					    recognising the limitations of
# 					    their minds and bodies, passed
# 					    on their knowledge to the great
# 					    machines they had created, and
# 					    who now trnscended them in
# 					    every way.
# 										  (con't)
#
# 12/9/65										  d4
# ------------------------------------------------------------------------
# D1
# CONTINUED
#
# 					    NARRATOR
# 					    For a few thousand years, they
# 					    shared their Universe with their
# 					    machine children; then, realizing
# 					    that it was folly to linger when
# 					    their task was done, they passed
# 					    into history without regret.
#
# 					    Not one of them ever looked through
# 					    his own eyes upon the planet Earth
# 					    again.
#
# 					    But even the age of the Machine
# 					    Entities passed swiftly. In their
# 					    ceaseless experimenting, they
# 					    had learned to store knowledge
# 					    in the structure of space itself,
# 					    and to preserve their thoughts
# 					    for eternity in frozen lattices
# 					    of light. They could become
# 					    creatures of radiation, free
# 					    at last from the tyranny of matter.
#
# 					    Now, they were Lords of the
# 					    galaxy, and beyond the reach
# 					    of time.
#
# 					    They could rove at will among the
# 					    stars, and sink like a subtle mist
# 					    through the very interstices of
# 					    space.
#
# 12/9/65										  d5
# ------------------------------------------------------------------------
# D1
# CONTINUED
#
# 					    NARRATOR (con't)
# 					    But despite their God-like powers,
# 					    they still watched over the
# 					    experiments their ancestors
# 					    had started so many generations
# 					    ago.
#
# 					    The companion of Saturn knew
# 					    nothing of this, as it orbited
# 					    in its no man's land between Mimas
# 					    and the outer edge of rings.
#
# 					    It had only to remember and wait,
# 					    and to look forever Sunward with
# 					    its strange senses.
#
# 					    For many weeks, it had watched
# 					    the approaching ship. Its long-
# 					    dead makers had prepared it for
# 					    many things and this was one of
# 					    them. And it recognised what
# 					    was climbing starward from the
# 					    Sun.
#
# 					    If it had been alive, it would have
# 					    felt excitement, but such an
# 					    emotion was irrelevant to its
# 					    great powers.
# 										   (con't)
# 12/9/65										  d6
# ------------------------------------------------------------------------
# D1
# CONTINUED
# 					    NARRATOR (con't)
# 					    Even if the ship had passed it by,
# 					    it would not have known the
# 					    slightest trace of disappointment.
#
# 					    It had waited four million years;
# 					    it was prepared to wait for
# 					    eternity.
#
# 					    Presently, it felt the gentle touch
# 					    of radiations, trying to probe its
# 					    secrets.
#
# 					    Now, the ship was in orbit and it
# 					    began to speak, with prime
# 					    numbers from one to eleven,
# 					    over and over again.
#
# 					    Soon, these gave way to more
# 					    complex signals at many frequen-
# 					    cies, ultra-violet, infra-red,
# 					    X-rays.
#
# 					    The machine made no reply. It
# 					    had nothing to say.
#
# 					    Then it saw the first robot
# 					    probe, which descended and
# 					    hovered above the chasm.
# 									    (con't)
#
# 12/9/65										  d7
# ------------------------------------------------------------------------
# D1
# CONTINUED
#
# 					    NARRATOR (con't)
# 					    Then, it dropped into darkness.
#
# 					    The great machine knew that this
# 					    tiny scout was reporting back to
# 					    its parent; but it was too simple,
# 					    too primative a device to detect
# 					    the forces that were gathering
# 					    round it now.
#
# 					    Then the pod came, carrying
# 					    life. The great machine searched
# 					    its memories.
#
# 					    The logic circuits made their
# 					    decision when the pod had fallen
# 					    beyond the last faint glow of the
# 					    reflected Saturnian light.
#
# 					    In a moment of time, too short to
# 					    be measured, space turned and
# 					    twisted upon itself.
#
# 12/9/65										  d8
# ------------------------------------------------------------------------
# 					 END OF SCREENPLAY
# 					   END OF FILE

# %% [markdown]
# ## Removing Stopwords

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS   # Importing stop words from English language.
print('Number of stop words: %d' % len(spacy_stopwords))     # Printing the total number of stop words
print('First ten stop words: %s' % list(spacy_stopwords)[:10]) # Printing first few stop words
#from spacy.lang.en.stop_words import STOP_WORDS               # Importing stop words
filtered_sent=[]                                               # Initialize empty file
doc = nlp(text)            # "nlp" Object is used to create documents with linguistic annotations.
for word in doc:                                               # For all words
    if word.is_stop==False:                                    # check condition
        filtered_sent.append(word)                             # Appending words in output file
print("\n \nFiltered Sentence:",filtered_sent)                 # Text after stopwords removal
# Out:
# Number of stop words: 326
# First ten stop words: ['always', 'to', 'please', 'around', 'be', 'various', 'there', '’s', 'cannot', 'would']
#
#
# Filtered Sentence: [Note, poster, Kubrick, newsgroup, :,
#
# , found, bbs, ago, thought, pass,
# , Kubrick, freaks, .,
#
# , 02/23/89,
# , Transcriber, note, :,
#
# , Clarke, /, Kubrick/2001, fans, ,,
#
# , found, original, paper, copy, screenplay, felt,
# , compelled, transcribe, disk, upload, bulletin,
# , boards, enjoyment, .,
#
# , final, movie, deviates, screenplay, number, interesting,
# , ways, ., tried, maintain, format, original, document,
# , number, lines, page, original, ., order, reduce,
# , length, file, bar, ", ------, ", delimit, pages,
# , lot, whitespace, original, screenplay, page, .,
#
#
# , ------------------------------------------------------------------------,
#
# 				    , 2001, :, SPACE, ODYSSEY,
#
# 					    , Screenplay,
#
# 						   ,
#
# 			   , Stanley, Kubrick, Arthur, C., Clark,
#
# 					    , Hawk, Films, Ltd., ,,
# 					    , c, /, o., M, -, G, -, M, Studios, ,,
# 					    , Boreham, Wood, ,,
# 					    , Herts, .,
# , ------------------------------------------------------------------------,
#
# , TITLE, 					    ,
# 					    , AFRICA,
# 					    , 3,000,000, YEARS, AGO,
# , ------------------------------------------------------------------------,
# , A1,
# , VIEWS, AFRICAN, DRYLANDS, -, DROUGHT,
#
# , remorseless, drought, lasted, million, years, ,,
# , end, million, ., reign, ter-,
# , rible, lizards, long, passed, ,, continent,
# , day, known, Africa, ,, battle, survival,
# , reached, new, climax, ferocity, ,, victor,
# , sight, ., dry, barren, land, ,, small,
# , swift, fierce, flourish, ,, hope, exist, .,
#
# , 10/13/65, 										 , a1,
# , ------------------------------------------------------------------------,
# , A2,
# , INT, &, EXT, CAVES, -, MOONWATCHER,
#
# , man, -, apes, field, attributes, ,,
# , long, ,, pathetic, road, racial, extinction, .,
# , occupied, group, caves, overlooking,
# , small, ,, parched, valley, ,, divided, sluggish, ,, brown, stream, .,
#
# , tribe, hungry, ,, starving, .,
# , dim, glow, dawn, creeps, cave, ,, Moonwatcher,
# , discovers, father, died, night, ., know,
# , Old, father, ,, relationship,
# , understanding, ., stands, looking, emac-,
# , iated, body, feels, ,, akin, sadness, .,
# , carries, dead, father, cave, ,, leaves,
# , hyenas, .,
#
# , kind, ,, Moonwatcher, giant, ., nearly,
# , feet, high, ,, badly, undernourished, ,, weighs,
# , pounds, ., hairy, ,, muscular, body, man, -, like, ,,
# , head, nearer, man, ape, ., forehead,
# , low, ,, great, ridges, eye, -, sockets, ,,
# , unmistakably, holds, genes, promise, humanity, .,
# , looks, hostile, world, ,,
#
# , 10/13/65, 										 , a2,
# , ------------------------------------------------------------------------,
# , A2,
# , CONTINUED,
#
# , gaze, grasp, ape, .,
# , dark, ,, deep, -, set, eyes, dawning, awareness, -, intima-,
# , tions, intelligence, fulfill,
# , million, years, .,
#
# , 10/13/65, 										 , a3,
# , ------------------------------------------------------------------------,
# , A3,
# , EXT,  , STREAM, -,
#
# , dawn, sky, brightens, ,, Moonwatcher, tribe, reach,
# , shallow, stream, .,
#
# , .,
# , day, -, annoying, .,
#
# , eighteen, ,, impossible, distinguish,
# , members, Moonwatcher, tribe, .,
# , coming, ,, begin, angrily, dance,
# , shriek, stream, ,, people, reply,
# , kind, .,
#
# , confrontation, lasts, minutes, -, display, dies,
# , quickly, begun, ,, drinks, fill,
# , muddy, water, ., Honor, satisfied, -, group,
# , staked, claim, territory, .,
#
# , 10/13/65, 										 , a4,
# , ------------------------------------------------------------------------,
# , A4,
# , EXT,  , AFRICAN, PLAIN, -, HERBIVORES,
#
# , Moonwatcher, companions, search, berries, ,, fruit,
# , leaves, ,, fight, pangs, hunger, ,,
# , ,, competing, samr, fodder, ,, potential,
# , source, food, hope, eat, .,
# , thousands, tons, meat, roaming, parched,
# , savanna, brush, reach, ;,
# , idea, eating, imagination, .,
# , slowly, starving, death, midst, plenty, .,
#
# , 10/13/65, 										 , a5,
# , ------------------------------------------------------------------------,
# , A5,
# , EXT,  , PARCHED, COUNTRYSIDE, -, LION,
#
# , tribe, slowly, wanders, bare, ,, flat, country-,
# , foraging, roots, occasional, berries, .,
#
# , irregularly, strung, open, plain, ,,
# , feet, apart, .,
#
# , ground, flat, miles, .,
#
# , Suddenly, ,, Moonwatcher, aware, lion, ,, stalking,
# , 300, yards, away, .,
#
# , Defenceless, hide, ,, scatter,
# , directions, ,, lion, brings, ground, .,
#
# , 10/13/65, 										 , a6,
# , ------------------------------------------------------------------------,
# , A6,
# , EXT,  , DEAD, TREE, -, FINDS, HONEY,
#
# , good, day, ,, Moonwatcher,
# , real, remembrance, past, compare, day,
# , ., way, caves, finds,
# , hive, bees, stump, dead, tree, ,, enjoys,
# , finest, delicacy, people, know, ., course, ,,
# , collects, good, stings, ,, scacely, notices,
# , ., near, contentment,
# , likely, ;, thought, hungry, ,, actually,
# , weak, hunger, ., hominid,
# , hope, .,
#
# , 10/13/65, 										 , a7,
# , ------------------------------------------------------------------------,
# , A7,
# , INT, &, EXT,  , CAVES, -, NIGHT, TERRORS,
#
# , valley, ,, moon, rises, ,, cold, wind, blows,
# , distant, mountains, ., cold, tonight, -,
# , cold, ,, like, hunger, ,, matter, real, concern, ;,
# , merely, background, life, .,
#
# , Little, Sun, ,, shone, night, gave, warmth, ,,
# , dangerous, ;, enemies, abroad, ., Moonwatcher,
# , crawls, cave, ,, clambers, large, boulder,
# , entrance, ,, squats, survey, valley, .,
# , hunting, beast, approached, ,, time,
# , relative, safety, cave, .,
#
# , creatures, lived, Earth, ,, Moonwatcher,
# , race, raise, eyes, interest, Moon, ,,
# , remember, ,, young, ,,
# , Moonwatcher, reach, try, touch, ghostly, face, .,
# , new, find, tree, high,
# , .,
#
# , stirs, shrieks, screams, echo, slope,
# , lower, caves, ,, need, hear,
#
# , 10/13/65, 										 , a8,
# , ------------------------------------------------------------------------,
# , A7,
# , CONTINUED,
#
# , occasional, growl, lion, know, happening, .,
# , darkness, ,, old, -, Eye, family, dying, ,,
# , thought, help, way, crosses,
# , Moonwatcher, mind, ., harsh, logic, survival, rules,
# , fancies, ., cave, silent, ,, lest, attract, disaster, .,
#
# , caves, ,, tortured, spells, fitful, dozing,
# , fearful, waiting, ,, gathered, nightmares, generations,
# , come, .,
#
# , 10/13/65, 										 , a9,
# , ------------------------------------------------------------------------,
# , A8,
# , EXT,  , STREAM, -, INVASION,
#
# , growing, desperate, ;, forage,
# , valley, exhausted, ., realise,
# , Moonwatcher, tribe, lost, numbers,
# , night, ,, choose, mourning, break, truce, .,
# , meet, river, ,, misty, dawn, ,,
# , deeper, menacing, note, challenge, ., noisy,
# , usually, harmless, confrontation, lasts, seconds,
# , invasion, begins, .,
#
# , uncertainly, -, moving, horde, ,, cross, river, ,,
# , shieking, threats, hunched, attack, ., led,
# , big, -, toothed, hominid, Moonwatcher, size, age, .,
#
# , Startled, frightened, ,, tribe, retreats,
# , advance, ,, throwing, substantial, imprecations,
# , invaders, ., Moonwatcher, moves, ,, mind,
# , mist, rage, confusion, ., driven,
# , territory, great, badness, ,, lose, river, death, .,
# , know, ;, situation,
# , experience, .,
#
# , dimly, aware, slowing,
#
# , 10/13/65, 										 , a10,
# , ------------------------------------------------------------------------,
# , A8,
# , CONTINUED,
#
# , ,, advancing, obvious, reluctance, .,
# , ,, uncertain, unhappy,
# , ., Big, -, Tooth, retains, original,
# , drive, ,, rapidly, seperated, followers, .,
#
# , sees, ,, Moonwatcher, morale, immediately,
# , revives, ., slows, retreat, ,, begins,
# , reassuring, noises, companions, ., Novel, sensations, fill,
# , dim, mind, -, faint, precursors, bravery,
# , leadership, .,
#
# , realizes, ,, face, face, Big, -, Tooth, ,,
# , tribes, come, halt, paces, away, .,
#
# , disorganized, unscientific, conflict, ended,
# , quickly, fist, club, ,,
# , innovation, lay, hundreds, thousands, years,
# , future, ., Instead, ,, slowly, weakening, fighters, claw,
# , scratch, try, bite, .,
#
# , Rolling, ,, come, patch, stony, ground, ,,
# , reach, Moonwatcher, ., chance, ,,
#
# , 10/13/65, 										 , a11,
# , ------------------------------------------------------------------------,
# , A8,
# , CONTINUED,
#
# , chooses, moment, grab, hair, Big, -, Tooth, scalp, ,,
# , bang, head, ground, ., resulting, CRACK,
# , satisfactory, ,, produces, immediate, weakening,
# , Big, -, Tooth, resistance, ,, quickly, repeats, .,
#
# , Big, -, Tooth, ceases, time, ,, Moon-,
# , watcher, keeps, exhilirating, game, .,
#
# , shrieks, panic, ,, retreat, ,,
# , stream, ., defenders, cautiously, pursue, far,
# , water, edge, .,
#
# , 10/13/65, 										 , a12,
# , ------------------------------------------------------------------------,
# , EXT,  , CAVE, -, NEW, SOUND,
#
# , Dozing, fitfully, weakened, stuggle, ,, Moonwatcher,
# , startled, sound, .,
#
# , sits, fetid, darkness, cave, ,, straining,
# , senses, night, ,, fear, creeps, slowly, soul, .,
# , life, -, twice, long, members,
# , species, expect, -, heard, sound, like, .,
# , great, cats, approached, silence, ,, thing,
# , betrayed, rare, slide, earth, ,, occasional,
# , cracking, twig, ., continuing, crunching, noise,
# , grows, steadily, louder, ., enormous,
# , beast, moving, night, ,, making, attempt,
# , concealment, ,, ignoring, obstacles, .,
#
# , came, sound, Moonwatcher,
# , possibly, identified, ,, heard,
# , history, planet, .,
#
# , 10/13/65, 										 , a13,
# , ------------------------------------------------------------------------,
# , A10,
# , EXT, CAVE, -, NEW, ROCK,
#
# , Moonwatcher, comes, face, face, New, Rock,
# , leads, tribe, river, light, morning, .,
# , forgotten, terror, night, ,,
# , happened, initial, noise, ,,
# , associate, strange, thing, danger, fear, .,
# , alarming, .,
#
# , cube, feet, ,,
# , completely, transparent, material, ;, ,, easy,
# , light, sun, glints, edges, .,
# , natural, objects, Moonwatcher,
# , compare, apparition, ., wisely, cautious,
# , new, things, ,, hesitate, walk, .,
# , happens, ,, puts, hand, ,, feels, warm, ,,
# , hard, surface, .,
#
# , minutes, intense, thought, ,, arrives,
# , brilliant, explanation, ., rock, ,, course, ,,
# , grown, night, ., plants,
# , -, white, ,, pulpy, things, shaped, like, pebbles, ,,
# , shoot, hours, darkness, ., true,
# , small, round, ,, large, square, ;,
#
# , 10/13/65, 										 , a14,
# , ------------------------------------------------------------------------,
# , A10,
# , CONTINUED,
#
# , greater, later, philosophers, Moonwatcher,
# , prepared, overlook, equally, striking, exceptions, laws, .,
#
# , superb, piece, abstract, thinking, leads, Moonwatcher,
# , deduction, immediately, puts, test, ., white, ,,
# , round, pebble, -, plants, tasty, (,
# , violently, sick, ), ;, square, ..., ?,
#
# , licks, attempted, nibbles, quickly, disillusion, .,
# , nourishment, ;, like, sensible, hominid, ,,
# , continues, way, river, forgets, Cube, .,
#
# , 10/13/65, 										 , a15,
# , ------------------------------------------------------------------------,
# , A11,
# , EXT, CUBE, -, LESSON,
#
# , yards, New, Rock,
# , sound, begins, .,
#
# , soft, ,, stops, tracks, ,,
# , stand, paralyzed, trail, jaws, hanging, ., simple, ,,
# , maddeningly, repetitious, rhythm, pulses, crystal, cube,
# , hypnotises, come, spell, .,
# , time, -, ,, million, year, -, sound,
# , drumming, heard, Africa, .,
#
# , throbbing, grows, louder, ,, insistent, ., Presently,
# , hominids, begin, forward, like, sleep, -, walkers, ,,
# , source, magnetic, sound, ., little,
# , dancing, steps, ,, blood, responds, rhythms,
# , descendants, create, ages, .,
#
# , Totally, entranced, ,, gather, Cube, ,, forgetting,
# , hardships, day, ,, perils, approaching, dusk, ,,
# , hunger, bellies, .,
#
# , ,, spinning, wheels, light, begin, merge, ,, spokes,
# , fuse, luminous, bars, slowly, recede, distance, ,,
#
# , 10/13/65, 										 , a16,
# , ------------------------------------------------------------------------,
# , A11,
# , CONTINUED,
#
# , rotating, axes, ;, hominids, watch, ,, wide-,
# , eyed, ,, mesmerized, captives, Crystal, Cube, .,
#
# , magic, -, magical,
# , gone, -, perfectly, normal, scene, appears, .,
# , cubical, block, carved, day,
# , shifted, night, ., Inside, block, group,
# , hominids, ,, members, Moonwatcher,
# , tribe, ,, eating, chunks, meat, ., carcass, wart, -, hog,
# , lies, near, .,
#
# , little, family, male, female, children, gorged,
# , replete, ,, sleek, glossy, pelts, -,
# , condition, life, Moonwatcher, imagined, .,
# , time, time, stir, lazily, ,, loll, ease, near,
# , entrance, cave, ,, apparently, peace, world, .,
# , spectacle, domestic, bliss, merges, totally,
# , different, scene, .,
#
# , family, longer, reposing, peacefully, outside, cave, ;,
# , foraging, ,, searching, food, like, normal, hominids, .,
#
# , 10/13/65, 										 , a17,
# , ------------------------------------------------------------------------,
# , A11,
# , CONTINUED,
#
# , small, wart, -, hog, ambles, past, group, browsing, humanoids,
# , giving, glance, ,,
# , slightest, danger, species, .,
#
# , happy, state, affairs, end, ., big, male,
# , suddenly, bends, ,, picks, heavy, stone, lying, feet, -,
# , hurls, unfortunate, pig, ., stone, descends,
# , skull, ,, making, exactly, noise, Moonwatcher,
# , produced, forgotten, encounter, Big, -, Tooth, .,
# , result, ,, ,, -, warthog, gives,
# , amazed, ,, indignant, squeal, ,, collapses, motionless, heap, .,
#
# , sequence, begins, ,, time, unfolds,
# , incredible, slowness, ., detail, movement,
# , followed, ;, stone, arches, leisurely, air, ,,
# , pig, crumples, sinks, ground, ., scene,
# , freezes, long, moments, ,, slayer, standing, motionless,
# , slain, ,, weapons, hand, .,
#
# , scene, suddenly, fades, ., cube,
# , glimmering, outline, darkness, ;, hominids, stir, ,,
#
# , 10/13/65, 										 , a18,
# , ------------------------------------------------------------------------,
# , A11,
# , CONTINUED,
#
# , awakening, dream, ,, realise, ,, scuttle,
# , caves, .,
#
# , concious, memory, seen, ;,
# , night, ,, sits, brooding, entrance, lair, ,, ears,
# , attuned, noises, world, ,, Moonwatcher,
# , feels, faint, twinges, new, potent, emotion, -, urge,
# , kill, ., taken, step, humanity, .,
#
# , 10/13/65, 										 , a19,
# , ------------------------------------------------------------------------,
# , A12,
# , EXT, cave, PLAINS, -, Utopia,
#
# , Babies, born, lived, ;, feeble, ,, toothless, thirty-,
# , year, -, olds, died, ;, lion, took, toll, night, ;,
# , threatened, daily, river, -, trib, prospered, .,
# , course, single, year, ,, Moonwatcher, companions,
# , changed, recognition, .,
#
# , plump, family, Cave, ,,
# , longer, haunted, dreams, ., learned, lessons,
# , ;, handle, stone, tools, weapons,
# , Cube, revealed, .,
#
# , longer, half, -, numbed, starvation, ,,
# , time, leisure, rudiments, thought, .,
# , new, way, life, casually, accepted, ,,
# , associate, way, crystal, cube, standing,
# , outside, cave, .,
#
# , Utopia, perfect, ,, blemishes, .,
# , marauding, lion, ,, passion, hominids,
# , grown, stronger, better,
# , nourished, ., second, tribe, river, ;,
#
# , 10/13/65, 										 , a20,
# , ------------------------------------------------------------------------,
# , A12,
# , CONTINUED,
#
# , survived, ,, stubbornly, refused,
# , die, starvation, .,
#
# , 10/13/65, 										 , a21,
# , ------------------------------------------------------------------------,
# , A13,
# , EXT, CAVES, -, KILLING, LION,
#
# , partly, devoured, carcass, warthog, laid,
# , ground, point, hope, boulder, impact, ,, Moon-,
# , watcher, bravest, companions, wait,
# , consecutive, nights, ., lion, comes, ,,
# , betraying, presences, small, pebble, slide, .,
#
# , lion, ,, softly, tearing, meat, ,,
# , strain, massive, boulder, ., sound,
# , lion, stops, ;, listening, ., silently, heave,
# , enormous, stone, ,, exerting, final, limits,
# , strength, ., rock, begin, tip, new, balance, point, .,
#
# , lion, twitches, alert, sound, ,, having, fear,
# , creatures, ,, makes, mistakes, cost,
# , life, ;, goes, meal, .,
#
# , rock, moves, slowly, ledge, ,, picking, speed,
# , amazing, suddeness, ., strikes, projection, cliff,
# , feet, ground, ,, deflects, path, outward, .,
#
# , instant, ,, lion, reacts, instinctively, leaps,
# , away, face, cliff, directly, path,
#
# , 10/13/65, 										 , a22,
# , ------------------------------------------------------------------------,
# , A13,
# , CONTINUED,
#
# , onrushing, boulder, ., combined, errors, over-,
# , confidence, bad, luck, .,
#
# , morning, find, lion, cave, .,
# , find, tribe, incautiously, peeped,
# , happening, ,, apparently, killed, small,
# , rock, torn, loose, boulder, ;, small, price,
# , pay, great, victory, .,
#
# 					  , *, *, *, *, *, *, *, *,
#
# , night, crystal, cube, gone, ,,
# , Moonwatcher, thought, ., wholly,
# , unaware, .,
#
# , 10/13/65, 										 , a23,
# , ------------------------------------------------------------------------,
# , A14,
# , EXT, STREAM, -, MASTER, WORLD,
#
# , stream, ,, violated, safety,
# , territory, ,, Moonwatcher, fourteen,
# , males, tribe, appear, small, hillock, over-,
# , looking, stream, ,, silhouetted, dawn, sky, .,
#
# , begin, scream, daily, challenge, ., today,
# , different, ,, immediatly,
# , recognize, fact, .,
#
# , Instead, joining, verbal, onslaught, ,, ,,
# , Moonwatcher, small, band, decended, rise, ,,
# , begin, forward, stream, quiet, purposefulness,
# , befor, seen, .,
#
# , watch, figures, silently, approaching,
# , morning, mist, ,, aware, terrible, strangness,
# , encounter, ,, rage, gradually, subsides,
# , uneasy, silence, .,
#
# , water, edge, ,, Moonwatcher, band, stop, .,
# , carry, bone, clubs, bone, knives, .,
#
# , 10/13/65, 										 , a24,
# , ------------------------------------------------------------------------,
# , A14,
# , CONTINUED,
#
# , Led, -, ear, ,, half, -, heartly, resume, battle-,
# , chant, ., suddenly, confrunted, vision, cuts,
# , sound, throats, ,, strikes, terror,
# , hearts, .,
#
# , Moonwatcher, ,, partly, concealed, males,
# , walked, ,, thrusts, arm, high, air, .,
# , hand, holds, stoud, tree, branch, ., Mounted, atop, branch,
# , bloody, head, lion, ,, mouth, jammed, open, stick, ,,
# , displaying, frightful, fangs, .,
#
# , gape, fearful, disbelief, display, power, .,
#
# , Moonwatchers, stands, motionless, ,, thrusting, lion, head, high, .,
# , majestic, deliberation, ,, carrying, mangled,
# , standard, head, ,, begins, cross, stream, ,, followed,
# , band, .,
#
# , fade, stream, ,, lack,
# , ability, flee, .,
#
# , Moonwatcher, steps, ashore, walks, -, Ear, ,, stands,
#
# , 10/13/65, 										 , a25,
# , ------------------------------------------------------------------------,
# , A14,
# , CONTINUED,
#
# , unsurely, band, .,
#
# , veteran, numerous, combats, water, edge, ,,
# , -, Ear, attacked, enemy,
# , displayed, fighting, rage, ;, attacked,
# , weapon, ., -, Ear, ,, merely, looks, raised, club,
# , heavey, thigh, bone, antelope, brings, darkness,
# , .,
#
# , stare, wonder, Moonwatcher, power, .,
#
# , Moonwatcher, surveys, scene, ., master,
# , world, ,, sure, .,
# , think, .,
#
# , 10/13/65, 										 , a26,
# , ------------------------------------------------------------------------,
# 					    , SECTION, TIMING,
#
# 			    , A1,    , 00.30,
# 			    , A2,    , 00.45,
# 			    , A3,    , 01.30,
# 			    , A4,    , 00.30,
# 			    , A5,    , 01.00,
# 			    , A6,    , 01.00,
# 			    , A7,    , 01.00,
# 			    , A8,    , 03.00,
# 			    , A9,    , 00.45,
# 			    , A10,   , 02.00,
# 			    , A11,   , 04.00,
# 			    , A12,   , 02.00,
# 			    , A13,   , 02.30,
# 			    , A14,   , 02.30,
#
# 					    , SECTION, TOTAL, :, @23, MIN, ., 00, SECS,
# , ------------------------------------------------------------------------,
# 			    , TITLE, 					, II,
#
# 							    , YEAR, 2001,
#
# 											    , a26a,
# , ------------------------------------------------------------------------,
# , B1,
# , EARTH, 200, MILES, 					 , NARRATOR,
# 						    , year, 2001, ,, overpopulation,
# , B1a, 						 , replaced, problem, starvation,
# , THOUSAND, MEGATON, 			   , ominously, offset,
# , NUCLEAR, BOMB, ORBIT, 		   , absolute, utter, perfection,
# , EARTH, ,, 			   , weapon, .,
# , RUSSIAN, INSIGNIA,
# , CCCP, MARKINGS,
#
# , B1b, 							 , NARRATOR,
# , AMERICAN, THOUSAND, 			  , Hundreds, giant, bombs,
# , MEGATON, BOMB, ORBIT, 		   , placed, perpetual, orbit,
# , EARTH, ., 			   , Earth, ., capable,
# 						    , incinerating, entire, Earth,
# 						    , surface, altitude, 100,
# 						    , miles, .,
#
# , B1c,
# , FRENCH, BOMB, 						   , NARRATOR,
# 					    , Matters, complicated,
# 					    , presence, -, seven,
# 					    , nations, nuclear, club, .,
# 					    , deliberate, acciden-,
# , B1d, 						 , tal, use, nuclear, weapons,
# , GERMAN, BOMB, 				   , World, War, II, people, felt,
# 					    , sercure, knowledge, .,
# 					    , ,, situation,
# 						    , comparible, airline,
# , B1f, 						 , perfect, safety, record, ;, showed,
# , CHINESE, BOMB, 				  , admirable, care, skill,
# 						    , expected, forever, .,
#
# , 10/4/65, 											  , b1,
# , ------------------------------------------------------------------------,
# , B2,
# , ORION, -, III, SPACECRAFT,
# , FIGHT, AWAY,
# , EARTH, ,, 200, MILES,
# , ALTITUDE, .,
#
# , 10/4/65, 											  , b2,
# , ------------------------------------------------------------------------,
# , B3,
# , ORION, -, III, PASSENGER, AREA, .,
# , DR, ., HEYWOOD, FLOYD,
# , PASSENGER,
# , ELEGANT, CABIN, DESIGNED,
# , 30, PEOPLE, .,
# , ASLEEP, .,
#
# , PEN, FLOATS, NEAR,
# , HAND, .,
#
# , 10/4/65, 											  , b3,
# , ------------------------------------------------------------------------,
# , B4,
# , ORION, -, III, COCKPIT, .,
# , PILOT, ,, CO, -, PILOT, .,
# , FLOYD, SEEN,
# , ASLEEP, SMALL,
# , TV, MONITOR, .,
# , STEWARDESS, PUTTING,
# , LIPSTICK, ., SEES,
# , PEN, .,
#
# , 10/4/65, 											  , b4,
# , ------------------------------------------------------------------------,
# , B5,
# , STEWARDESS, GOES,
# , PASSENGER, AREA, ,,
# , RESCUES, PEN, CLIPS,
# , FLOYD,
# , POCKET, .,
#
# , 10/4/65, 											  , b5,
# , ------------------------------------------------------------------------,
# , B6,
# , SPACE, STATION-5, .,
# , RAW, SUNLIGHT, SPACE,
# , DAZZLES,
# , POLISHED, METAL, SURFACES,
# , SLOWLY, REVOLVING, ,,
# , THOUSAND, -, FOOT, DIAMETER,
# , SPACE, STATION, ., DRIFTING,
# , ORBIT, ,,
# , SWEPT, -, TITOV, -, V,
# , SPACECRAFT, .,
# , SPHERICAL, ARIES, -, IB,
#
# , 10/4/65, 											  , b6,
# , ------------------------------------------------------------------------,
# , B7,
# , ORION, -, III, PASSENGER, AREA,
# , FLOYD, AWAKE, GROGGY, ,,
# , LOOKS, WINDOW, .,
#
# , 10/4/65, 											  , b7,
# , ------------------------------------------------------------------------,
# , B8,
# , ORION, -, III, COCKPIT, .,
# , CO, -, PILOT, RADIO,
# , COMMUNICATION,
# , SPACE, STATION, .,
#
# , 10/4/65, 											  , b8,
# , ------------------------------------------------------------------------,
# , B9,
# , ORION, -, III, SPACECRAFT,
# , DOCKING, APPROACH, .,
# , EARTH, SEEN, BREATH-,
# , TAKING, VIEW, B.G.,
#
# , 10/4/65, 											  , b9,
# , ------------------------------------------------------------------------,
# , B10,
# , INSIDE, DOCKING, CONTROL, .,
# , ORION, -, III, MANO-,
# , UVERING, ., BACKGROUND, .,
#
# , 10/4/65, 											  , b10,
# , ------------------------------------------------------------------------,
# , B11,
# , DOCKING, PORT,
# , ORION, -, III, INCHING,
# , COMPLETE,
# , DOCKING, .,
# , WINDOWED, BOOTHS, INSIDE,
# , DOCKING, PORT, .,
# , PILOT, CO, -, PILOT,
# , INSIDE, ORION, -, III,
# , COCKPIT, .,
#
# , 10/4/65, 											  , b11,
# , ------------------------------------------------------------------------,
# , B12,
# , SPACE, STATION,
# , RECEPTION, AREA,
#
# , RECEPTIONIST, DESK, .,
# , MILLER, ENTERS, ,, HUR-,
# , RYING, ., GOES,
# , ELEVATOR,
# , PRESSES, BUTTON, .,
# , WAITS, IMPATIENTLY, .,
#
# , ELEVATOR,
# , INDICATOR, WORKING,
#
# , ELEVATOR, DOOR, OPENS,
# , FLOYD, SEEN,
# , UNSTRAPPING, .,
# , ELEVATOR, GIRL,
# , SEATED, DOOR,
# 						    , MILLER,
# 						    , Oh, ,, good, morning, ,, Dr., Floyd, .,
# 						    , Nick, Miller, .,
#
# 						    , FLOYD,
# 						    , ,, Mr., Miller, ?,
#
# 						    , MILLER,
# 						    , terribly, sorry, .,
# 						    , way, meet, .,
# 						    , saw, ship, dock, knew,
# 						    , plenty, time, ,,
# 						    , way, office, ,,
# 						    , suddenly, ,, phone, rang, .,
#
# , 12/7/65, 											  , b12,
# , ------------------------------------------------------------------------,
# , B12,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , Oh, ,, worry, .,
#
# 					    , MILLER,
# 					    , ,, thank,
# 					    , understanding, .,
#
# 					    , FLOYD,
# 					    , ,, matter, .,
#
# 					    , MILLER,
# 					    , .., pleaant,
# 					    , flight, ?,
#
# 					    , FLOYD,
# 					    , Yes, ,, pleasant, .,
#
# 					    , MILLER,
# 					    , ,, shall,
# 					    , Documentation, ?,
#
# 					    , FLOYD,
# 					    , Fine, .,
#
# 					    , RECEPTIONIST,
# 					    , use, number, ,,
# 					    , ?,
#
# 					    , MILLER,
# 					    , Thank, ,, Miss, Turner, .,
#
# , 12/7/65, 										  , b13,
# , ------------------------------------------------------------------------,
# , B12,
# , CONTINUED,
#
# , ENTER, PASSPORT,
# , AREA,
#
# , RECEPTIONIST, PRESSES,
# , ", ENGLISH, ", BAR,
# , CONSOLE, SMILES,
# , FLOYD, GOES, .,
#
# , 12/7/65, 										  , b13a,
# , ------------------------------------------------------------------------,
# , AUTOMATED, PASSPORT,
# , SECTION, ., STOP,
# , BOOTH,
# , FEATURING, TV, SCREEN,
#
# 					    , PASSPORT, GIRL, (, TV, ),
# 					    , Good, morning, welcome, voice,
# 					    , Print, Identification, .,
# 					    , red, light,
# 					    , state, following, order, ;,
# 					    , desitination, ,, nationality,
# 					    , ., Surname, ,,
# 					    , christian, initial, .,
# 					    , example, :, Moon, ,, American, ,,
# 					    , Smith, ,, John, ,, D., Thank, .,
#
# , PAUSE,
# , RED, BAR, LIGHTS,
#
# 					    , FLOYD,
# 					    , Moon, ,, American, ,, Floyd, ,, Heywood, ,,
# 					    , R.,
#
# , RED, LIGHT, GOES, .,
# , DELAY,
# , SECONDS,
# , WOMAN, FACE,
# , REAPPEARS,
#
# 					    , FLOYD,
# 					    , wondered, ....,
#
# , 12/7/65, 										  , b14,
# , ------------------------------------------------------------------------,
# , B13,
# , CONTINUED,
# 					    , PASSPORT, GIRL, (, TV, ),
# 					    , (, Interrupting, ),  , Thank, ., Despite,
# 					    , excellent, continually,
# 					    , improving, safety, record,
# 					    , certain, risks, inherent, space,
# 					    , travel, extremely, high, cost,
# 					    , pay, load, .,
# 					    , necessary, Space, Carrier,
# 					    , advise,
# 					    , responsible, return,
# 					    , body, Earth,
# 					    , deceased, Moon, en, route,
# 					    , Moon, ., ,, wishes,
# 					    , advise, insurance,
# 					    , covering, contingency,
# 					    , available, Main, Lounge, .,
# 					    , Thank, ., cleared,
# 					    , Voice, Print, Identification, .,
#
# , LIGHTS,
# , WOMAN,
# , FACE, DISAPPEARS,
#
# , MEN, EXIT,
# , PASSPORT, AREA,
#
# 					    , MILLER,
# 					    , reserved, table,
# 					    , Earth, Light, room, .,
# 					    , connecting, flight,
# 					    , leaving, hour, .,
#
# , 12/7/65, 										  , b15,
# , ------------------------------------------------------------------------,
# , B13,
# , CONTINUED,
#
# 						, FLOYD,
# 						, Oh, ,, wonderful, .,
#
# , 12/7/65, 										  , b16,
# , ------------------------------------------------------------------------,
# , B14,
# , INT, SPACE, STATION, -, LOUNGE,
#
# , FLOYD, MILLER, WALKING,
#
# 					    , MILLER,
# 					    , Let, ,,
# 					    , pleasure, visit,
# 					    , ...,
# 					    , months, ago, ,, ?,
#
# 					    , FLOYD,
# 					    , Yes, ,, think, .,
# 					    , .,
#
# 					    , MILLER,
# 					    , suppose, saw, work,
# 					    , new, section,
# 					    , docking, .,
#
# 					    , FLOYD,
# 					    , Yes, ,, coming, .,
#
# , PASS, VISION,
# , PHONE, BOOTH,
#
# 						, FLOYD,
# 						, Oh, ,, look, ,, got,
# 						, phone, .,
# 						, Restaurant,
# 						, meet, .,
#
# , 12/7/65, 										  , b17,
# , ------------------------------------------------------------------------,
# , B14,
# , CONTINUED,
#
# 					    , MILLER,
# 					    , Fine, ., bar, .,
#
# , FLOYD, ENTERS, PHONE,
# , BOOTH, ., SIGN,
# , VISION, PHONE, SCREEN,
# , ", SORRY, ,, TEMPORARILY,
# , ORDER, ., ",
#
# , ENTERS, SECOND,
# , BOOTH, SITS,
#
# , 12/7/65, 										  , b18,
# , ------------------------------------------------------------------------,
# , B15,
# , DELETED,
#
# , B16,
# , DELETED,
#
# , PAGES, b19, -, b22, DELETED,
#
# , 12/7/65,
# , ------------------------------------------------------------------------,
# , B17,
# , FLOYD, VISION, PHONE,
#
# , LITTLE, GIRL,
# , ANSWERS,
#
# 						, CHILD,
# 						, Hello, .,
#
# , VISION, PHONE, SCREEN,
# , DISPLAY, SIGN, ',
# , PARTY, CONNECTED,
# , VISION, ',
#
# , SECONDS, LATER, ,,
# , SCREEN, CHANGES,
# , IMAGE,
# , CHILD,
# 					    , FLOYD,
# 					    , Hello, ,, darling, ,, ?,
#
# 					    , CHILD,
# 					    , Hello, Daddy, ., ?,
#
# 					    , FLOYD,
# 					    , Space, Station, ,,
# 					    , darling, ., ?,
#
# 					    , CHILD,
# 					    , fine, ,, Daddy, .,
# 					    , coming, home, ?,
#
# , 12/6/65, 										  , b23,
# , ------------------------------------------------------------------------,
# , B17,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , ,, hope, days, ,,
# 					    , sweetheart, .,
#
# 					    , CHILD,
# 					    , having, party, tomorrow, .,
#
# 					    , FLOYD,
# 					    , Yes, ,, know, sweetheart, .,
#
# 					    , CHILD,
# 					    , coming, party, ?,
#
# 					    , FLOYD,
# 					    , ,, sorry, ,, darling, ,,
# 					    , told, wo, home,
# 					    , days, .,
#
# 					    , CHILD,
# 					    , coming, home, ?,
#
# 					    , FLOYD,
# 					    , days, ,, darling, ,,
# 					    , hope, .,
#
# , FLOYD, HOLDS,
# , FINGERS, .,
#
# , 12/6/65, 										  , b24,
# , ------------------------------------------------------------------------,
# , B17,
#
# 					    , FLOYD,
# 					    , ,, ,, .,
# 					    , speak, Mommy, ?,
#
# 					    , CHILD,
# 					    , Mommy, hair-,
# 					    , dresser, .,
#
# 					    , FLOYD,
# 					    , Mrs., Brown, ?,
#
# 					    , CHILD,
# 					    , bathroom, .,
#
# 					    , FLOYD,
# 					    , Okay, ,, sweetheart, ., ,,
# 					    , ., Tell, Mommy,
# 					    , called, .,
#
# 					    , CHILD,
# 					    , days,
# 					    , come, home, ?,
#
# 					    , FLOYD,
# 					    , ,, darling, ., ...,
# 					    , ..., ., sure, tell,
# 					    , Mommy, called, .,
#
# , 12/6/65, 										  , b24a,
# , ------------------------------------------------------------------------,
# , B17,
# , CONTINUED,
#
# 					    , CHILD,
# 					    , ,, Daddy, .,
#
# 					    , FLOYD,
# 					    , Okay, ,, sweetheart, .,
# 					    , lovely, Birthday, Party,
# 					    , tomorrow, .,
#
# 					    , CHILD,
# 					    , Thank, ,, Daddy, .,
#
# 					    , FLOYD,
# 					    , wish, happy,
# 					    , Birthday,
# 					    , soon, ., right, ,, Darling, ?,
#
# 					    , CHILD,
# 					    , Yes, ,, Daddy, .,
#
# 					    , FLOYD,
# 					    , ', Bye, ,, ', bye, ,, ,, sweetheart, .,
#
# 					    , CHILD,
# 					    , Goodbye, ,, Daddy, .,
#
# , 12/6/65, 										  , b24b,
# , ------------------------------------------------------------------------,
# , B18,
# , VISION, PHONE,
# , PROCEDURE,
# , INFORMATION,
#
# , VISION, PHONE,
# , PROCEDURE,
# , DIALLING,
#
# 					    , OPERATOR,
# 					    , Good, morning, ,, Macy, .,
#
# 					    , FLOYD,
# 					    , Good, morning, ., like,
# 					    , Vision, shopper, Pet,
# 					    , Shop, ,, .,
#
# 					    , OPERATOR,
# 					    , moment, .,
#
# , 12/7/65, 										  , b25,
# , ------------------------------------------------------------------------,
# , B19,
# , PICTURE, FLIPS,
# , WOMAN, STANDING,
# , FORN, SPECIALLY-,
# , DESIGNED, DISPLAY, SCREEN,
#
# 					    , VISION, SALES, GIRL,
# 					    , Good, morning, ,, sir, ,, help, ?,
#
# 					    , FLOYD,
# 					    , Yes, ,, like, buy, bush, baby, .,
#
# 					    , VISION, SALES, GIRL,
# 					    , moment, ,, sir, .,
#
# , GIRL, KEYS,
# , INPUTS, MOVING,
# , PICTURE, APPEARS,
# , SCREEN, CAGE,
# , CONTAINING,
# , BUSH, BABIES, ,,
# , BEAUTIFULLY, DISPLAYED,
# , WHITE, BACK-,
# , GROUND,
#
# 					    , VISION, SALES, GIRL,
# 					    , ,, sir, .,
# 					    , lovely, assortment, African,
# 					    , bush, babies, .,
# 					    , Dollars, .,
#
# , 12/7/65, 										  , b26,
# , ------------------------------------------------------------------------,
# , B19,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , Yes, ,, ..., Pick, nice,
# 					    , ,, friendly, ,,
# 					    , like, delivered, tomorrow, .,
#
# 					    , VISION, SALES, GIRL,
# 					    , Certainly, ,, sir, ., let,
# 					    , Bank, identification,
# 					    , V.P.I., ,,
# 					    , address, person,
# 					    , like, pet, delivered,
# 					    , delivered, tomorrow, .,
#
# , TIME,
# , CONVERSATION, ,,
# , FLOYD, ELENA, ,,
# , SMYSLOV,
# , RUSSIANS,
# , PASS, VISION, PHONE,
# , WINDOW, ., ELENA, TAPS,
# , MIMES, ", HELLO, ", ,,
# , GESTURING,
# , TABLE, FLOYD,
# , SIT,
# ,
#
# 					    , FLOYD,
# 					    , Thank, ., Floyd, ,,
# 					    , Heywood, ,, R., ,,  , National,
# 					    , Bank, Washington, .,
# 					    , deliver, Miss, Josephine,
# 					    , Floyd, ,, 9423, Dupre, Avenue, ,,
# 					    , N.W.14, .,
#
# , 12/7/65, 										  , b27,
# , ------------------------------------------------------------------------,
# , B19,
# , CONTINUED,
#
# 					    , VISION, SALES, GIRL,
# 					    , Thank, ,, sir, .,
# 					    , delivered, tomorrow, .,
#
# , 12/7/65, 										  , b27a,
# , ------------------------------------------------------------------------,
# , B20,
# , SPACE, STATTION, 5, -, LOUNGE,
#
# 					    , FLOYD,
# 					    , ,, nice, ,,
# 					    , Elena, ., looking, wonderful, .,
#
# 					    , ELENA,
# 					    , nice, ,, Hyewood, .,
# 					    , good, friend, ,, Dr.,
# 					    , Heywood, Floyd, ., like,
# 					    , meet, Andre, Smyslov, ...,
#
# , SMYSLOV,
# , RUSSIAN, WOMEN,
# , STAND, SMILE,
#
# , SHAKE, HANDS,
# , INTRODUCTION,
# , AD, -, LIB, ', HELLOS, ',
#
# 					    , ELENA,
# 					    , Dr., Kalinan, ...,
# 					    , Stretyneva, ...,
#
# , RUSSIANS,
# , WARM,
# , FRIENDLY, .,
#
# 					    , SMYSLOV,
# 					    , Dr., Floyd, ,, wo, join,
# 					    , drink, ?,
#
# , 12/7/65, 										  , b28,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , afraid, got,
# 					    , minutes, ,, love, .,
#
# , BIT,
# , CONFUSION,
# , REALISE,
# , ROOM,
# ,
# , PERSON, TABLE, .,
# , SMYSLOV, OFFERS, FLOYD,
# , CHAIR,
# , BORROWS,
# , NEARBY, TABLE,
#
# 					    , SYMYSLOV,
# 					    , like, drink, ?,
#
# 					    , FLOYD,
# 					    , Oh, ,, time,
# 					    , drink, ., right,
# 					    , sit, minute,
# 					    , got, .,
#
# 					    , SMYSLOV,
# 					    , sure, ?,
#
# 					    , FLOYD,
# 					    , Yes, ,, ,, thank,
# 					    , .,
#
# 					    , ELENA,
# 					    , ..., lovely,
# 					    , wife, ?,
#
# , 12/7/65, 										  , b29,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , wonderful, .,
#
# 					    , ELENA,
# 					    , charming, little, daughter, ?,
#
# 					    , FLOYD,
# 					    , Oh, ,, growing, fast, .,
# 					    , matter, fact, ,,
# 					    , tomorrow, .,
#
# 					    , ELENA,
# 					    , Oh, ,, delightful, age, .,
#
# 					    , FLOYD,
# 					    , gregor, ?,
#
# 					    , ELENA,
# 					    , fine, ., afraid,
# 					    , chance,
# 					    , days, .,
#
# , POLITE, LAUGHTER,
#
# 					    , FLOYD,
# 					    , ,,
# 					    , ?,
#
# , 12/7/65, 										  , b30,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , ELENA,
# 					    , Actually, ,, way,
# 					    , moon, .,
# 					    , spent, months, calibrating,
# 					    , new, antenna, Tchalinko, .,
# 					    , ?,
#
# 					    , FLOYD,
# 					    , ,, happens, ,,
# 					    , way, moon,
#
# 					    , SMYSLOV,
# 					    , ,, chance, ,, going,
# 					    , base, Clavius, ?,
#
# 					    , FLOYD,
# 					    , Yes, ,, matter, fact, ,, .,
#
# , RUSSIANS,
# , EXCHANGE,
# , SIGNIFICANT,
# , GLANCES,
#
# 					    , FLOYD,
# 					    , particular, reason,
# 					    , ask, ?,
#
# , 12/7/65, 										  , b31,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , SMYSLOV,
# 					    , (, pleasantly, ),  , ,, Dr., Floyd, ,,
# 					    , hope, think,
# 					    , inquisitive, ,,
# 					    , clear, mystery,
# 					    , going,
# 					    , .,
#
# 					    , FLOYD,
# 					    , sorry, ,, sure,
# 					    , know, mean, .,
#
# 					    , SMYSLOV,
# 					    , ,, past,
# 					    , weeks,
# 					    , extremely, odd, things,
# 					    , happening, Clavius, .,
#
# 					    , FLOYD,
# 					    , ?,
#
# 					    , SMYSLOV,
# 					    , Yes, ., ,, thing, ,,
# 					    , phone, base, ,,
# 					    , recording,
# 					    , repeats, phone,
# 					    , lines, temporarily,
# 					    , order, .,
#
# , 12/7/65, 										  , b32,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , ,, suppose,
# 					    , having, bit, trouble,
# 					    , equipment, .,
#
# 					    , SMYSLOV,
# 					    , Yes, ,, thought,
# 					    , explanation, ,,
# 					    , going, past,
# 					    , days, .,
#
# 					    , FLOYD,
# 					    , mean, able,
# 					    , base,
# 					    , days, ?,
#
# 					    , SMYSLOV,
# 					    , right, .,
#
# 					    , FLOYD,
# 					    , .,
#
# 					    , ELENA,
# 					    , thing, ,, Heywood, ,,
# 					    , days, ago, ,, rocket,
# 					    , buses, denied, permission,
# 					    , emergency, landing,
# 					    , Clavius, .,
#
# , 12/7/65, 										  , b33,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , manage,
# 					    , communication, ?,
#
# 					    , ELENA,
# 					    , Clavius, Control, came,
# 					    , air, long, transmit,
# 					    , refusal, .,
#
# 					    , FLOYD,
# 					    , ,, sound, odd, .,
#
# 					    , SMYSLOV,
# 					    , Yes, ,, afaid,
# 					    , going, bit, row,
# 					    , ., Denying, men, permission,
# 					    , land, direct, violation,
# 					    , I.A.S., convention, .,
#
# 					    , FLOYD,
# 					    , Yes, ..., ,, hope, crew,
# 					    , got, safely, .,
#
# 					    , SMYSLOV,
# 					    , Fortunately, ,, .,
#
# 					    , FLOYD,
# 					    , ,, glad, .,
#
# , 12/7/65, 										  , b33a,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# , RUSSIANS, EXCHANGE,
# , GLANCES, .,
# , WOMEN, OFFERS,
# , PILL, BOX, .,
# , ELENA,
# , RUSSIAN,
# , RUSSIAN,
# , DELCINES, .,
#
# 					    , SMYSLOV,
# 					    , Dr., Floyd, ,, risk, pressing,
# 					    , point, reticent,
# 					    , discuss, ,, ask,
# 					    , straightforward, question, ?,
#
# 					    , FLOYD,
# 					    , Certainly, .,
#
# 					    , SMYSLOV,
# 					    , frankly, ,,
# 					    , reliable, intelligence, reports,
# 					    , epidemic,
# 					    , broken, Clavius, .,
# 					    , ,, apperently, ,,
# 					    , unknown, origin, ., ,,
# 					    , fact, ,, happened, ?,
#
# , LONG, ,, AWKWARD,
# , PAUSE,
#
# , 12/7/65, 										  , b33b,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , sorry, ,, Dr., Smyslov, ,,
# 					    , liberty,
# 					    , discuss, .,
#
# 					    , SMYSLOV,
# 					    , epidemic, easily,
# 					    , spread, base, ,, Dr., Floyd, .,
# 					    , given,
# 					    , facts, .,
#
# , LONG, PAUSE,
#
# 					    , FLOYD,
# 					    , Dr., Smyslov, ...,
# 					    , permitted, discuss, .,
#
# 					    , ELENA,
# 					    , sure, wo, change,
# 					    , mind, drink, ?,
#
# 					    , FLOYD,
# 					    , ,, thank, ...,
# 					    , afraid,
# 					    , going, .,
#
# 					    , ELENA,
# 					    , ,, hope,
# 					    , wife, come, I.A.C.,
# 					    , conference, June, .,
#
# , 12/7/65, 										  , b33c,
# , ------------------------------------------------------------------------,
# , B20,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , trying, .,
# 					    , hope, .,
#
# 					    , ELENA,
# 					    , ,, Gregor, look,
# 					    , forward, seeing, .,
#
# 					    , FLOYD,
# 					    , Thank, ., great,
# 					    , pleasure, meet, ...,
# 					    , Dr., Smyslov, .,
#
# , RUSSIANS,
# , RISE,
# , AD, -, LIBS,
# , COURTESY,
#
# , FLOYD, SHAKES, HANDS,
# , EXITS,
#
# , RUSSIANS, EXCHANGE,
# , PARA-,
# , GRAPHES, RUSSIAN,
#
# , 12/7/65, 										  , b33d,
# , ------------------------------------------------------------------------,
# , B21,
#
# , ARIES, -, IB, SPACE, .,
# , EARTH, SMALLER,
# , SEEN,
# , SPACE, STATION,
#
# 					    , NARRATOR,
# 					    , Aries, -, IB,
# 					    , standard, Space, -, Station, -, -, Lunar,
# 					    , surface, vehicle, ., powered,
# 					    , low, -, thrust, plasma, jets,
# 					    , continue, mild, acceler-,
# 					    , ation, minutes, .,
# 					    , ship, break, bonds,
# 					    , gravity, free, indepen-,
# 					    , dent, planet, ,, circling, Sun,
# 					    , orbit, .,
#
# , 10/4/65, 										  , b34,
# , ------------------------------------------------------------------------,
# , B21a,
#
# , ARIES, PASSENGER, AREA, .,
# , FLOYD, ASLEEP, ,, STRETCHED,
# , CHAIR, ,, COVERED,
# , BLANKETS,
# , HELD, SECURE, STRAPS,
#
# , STEWARDESS, SITS,
# , CABIN, ,,
# , WATCHING, KARATE,
# , EXHIBITION,
# , WOMEN, TELEVISION,
#
# , ELEVATOR, ENTRANCE,
# , DOOR, OPENS,
# , SECOND, STEWARDESS, ENTERS,
# , CARRYING, TRAY, FOOD,
#
# , BRINGS,
# , STEWARDESS,
#
# 					    , STEWARDESS,
# 					    , Oh, ,, thank, .,
#
# 					    , STEWARDESS,
# 					    , asleep, .,
#
# 					    , STEWARDESS,
# 					    , Yes, ., moved,
# 					    , left, .,
#
# , STEWARDESS, EXITS, ,,
# , ELEVATOR,
#
# , 12/6/65, 										  , b34a,
# , ------------------------------------------------------------------------,
# , B21b,
#
# , ARIES, GALLEY, AREA, .,
# , STEWARDESS, EXITS,
# , ELEVATOR, ,, GOES,
# , KITCHEN, SECTION, ,, REMOVES,
# , TRAYS, ,, WALKS,
# , WALL,
# , ENTERS, PILOT,
# , COMPARTMENT,
#
# , 12/6/65, 										  , b34b,
# , ------------------------------------------------------------------------,
# , B22,
# , ARIES, -, IB, COCKPIT, .,
# , PILOT, ,, CO, -, PILOT, .,
#
# , STEWARDESS, ENTERS, ,,
# , CARRYING, FOOD,
#
# 					    , PILOT,
# 					    , Oh, ,, thank, .,
#
# 					    , CO, -, PILOT,
# 					    , Thank, .,
#
# , STEWARDESS, SMILES, .,
#
# 					    , PILOT,
# 					    , (, sighs, ),  , ,, going,
# 					    , ?,
#
# 					    , STEWARDESS,
# 					    , Fine, ., quiet, .,
# 					    , asleep, left, .,
#
# 					    , PILOT,
# 					    , ,,
# 					    , enjoying, wonders, Space, .,
#
# 					    , CO, -, PILOT,
# 					    , ,, going, ,,
# 					    , going, arrive, fresh, ready,
# 					    , .,
#
# , 12/14/65, 										 , b35,
# , ------------------------------------------------------------------------,
# , B22,
# , CONTINUED,
#
# 					    , PILOT,
# 					    , wonder, going,
# 					    , ?,
#
# 					    , CO, -, PILOT,
# 					    , ,, heard,
# 					    , people, talk, epidemic, .,
#
# 					    , PILOT,
# 					    , suppose, bound, happen,
# 					    , sooner, later, .,
#
# 					    , CO, -, PILOT,
# 					    , Berkeley, told, think,
# 					    , came, contamination,
# 					    , returning, Mars, flight, .,
#
# 					    , PILOT,
# 					    , Yes, ,, ,, ,,
# 					    , certainly, fooling, .,
# 					    , flight, allowed,
# 					    , week, .,
#
# 					    , CO, -, PILOT,
# 					    , working, trip,
# 					    , cost, ,, taking,
# 					    , coming, .,
#
# 					    , PILOT,
# 					    , bet, fortune, .,
#
# , 12/14/65, 										 , b36,
# , ------------------------------------------------------------------------,
# , B22,
# , CONTINUED,
#
# 					    , CO, -, PILOT,
# 					    , ,, thousand, dollars,
# 					    , ticket, ,, comes, better,
# 					    , thousand, dollars, .,
#
# 					    , PILOT,
# 					    , ,, soon, wakes, ,,
# 					    , going, talk,
# 					    , ., ,, like,
# 					    , find, going, .,
#
# , 12/14/65, 										 , b36a,
# , ------------------------------------------------------------------------,
# , B23,
# , ARIES, -, IB, SPACE, .,
# , MOON, LARGE, .,
#
# , 10/4/65, 										  , b37,
# , ------------------------------------------------------------------------,
# , B24,
# , ARIES, -, IB, PASSENGER,
# , AREA, ., FLOYD, FINISHING,
# , BREAKFAST, .,
#
# , PILOT, ENTERS, .,
#
# 					    , PILOT,
# 					    , ,, good, afternoon, ,, Dr., Floyd, .,
# 					    , good, rest, ?,
#
# 					    , FLOYD,
# 					    , Oh, ,, marvellous, .,
# 					    , real, sleep, past,
# 					    , days, .,
#
# 					    , PILOT,
# 					    , like, weightless,
# 					    , sleep, complete, rest, .,
#
# 					    , FLOYD,
# 					    , arrive, Clavius, ?,
#
# 					    , PILOT,
# 					    , scheduled, dock,
# 					    , seven, hours, .,
# 					    , ?,
#
# 					    , FLOYD,
# 					    , Oh, ,, ,, thank, .,
# 					    , girls, taken, wonderful, care,
# 					    , ., fine, .,
#
# , 12/14/65, 										 , b38,
# , ------------------------------------------------------------------------,
# , B24,
# , CONTINUED,
#
# 					    , PILOT,
# 					    , ,,
# 					    , wnat, ,, holler, .,
#
# 					    , FLOYD,
# 					    , Thank, .,
#
# 					    , PILOT,
# 					    , Incidentally, ,, Dr., Floyd, ,, wonder,
# 					    , word,
# 					    , security, arrangements, ?,
#
# 					    , FLOYD,
# 					    , mean, ?,
#
# 					    , PILOT,
# 					    , ..., crew, confined,
# 					    , ship, land, Clavius, .,
# 					    , stay, inside,
# 					    , time, refit, -,
# 					    , -, hours, .,
# 					    , going, .,
#
# 					    , FLOYD,
# 					    , .,
#
# 					    , PILOT,
# 					    ,
# 					    , trouble, having,
# 					    , Clavius, ?,
#
# , 12/14/65, 										 , b39,
# , ------------------------------------------------------------------------,
# , B24,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , afraid, depart-,
# 					    , ment, ,, Captain, .,
#
# 					    , PILOT,
# 					    , ,, tell, ask, .,
# 					    , ,, got, girl, works,
# 					    , Auditing, Department,
# 					    , Territorial, Administrator,
# 					    , able,
# 					    , phone, past, week, ,,
# 					    , stories,
# 					    , hears, ,, little, concerned,
# 					    , .,
#
# 					    , FLOYD,
# 					    , ., ,, sorry, .,
# 					    , think, cause,
# 					    , alarm, .,
#
# 					    , PILOT,
# 					    , Yes, ,, ,,
# 					    , concerned, ,,
# 					    , heard, stories,
# 					    , epidemic, ,, matter, fact, ,,
# 					    , heard, people,
# 					    , died, .,
#
# , 12/14/65, 										 , b40,
# , ------------------------------------------------------------------------,
# , B24,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , wish, helpful, ,,
# 					    , Captain, ,, said, ,,
# 					    , think, cause,
# 					    , alarm, .,
#
# 					    , PILOT,
# 					    , ,, fine, ., Thanks, ,,
# 					    , ,, hope,
# 					    , mind, asking, ?,
#
# 					    , FLOYD,
# 					    , ,, course, ,, Captain, ,,
# 					    , understand, concern, .,
#
# 					    , PILOT,
# 					    , ,, thank, ,,
# 					    , let, know,
# 					    ,
# 					    , trip, comfortable, .,
#
# , 12/14/65, 										 , b40a,
# , ------------------------------------------------------------------------,
# , B25,
# , ARIES, -, IB, CLOSER, MOON,
#
# , 10/4/65, 										  , b41,
# , ------------------------------------------------------------------------,
# , B26,
# , FLOYD, GOES, ARIES, -, IB,
# , WASHROOM, LOOKS,
# , LONG, LIST,
# , COMPLICATED, INSTRUCTIONS,
#
# , 10/4/65, 										  , b42,
# , ------------------------------------------------------------------------,
# , B27,
# , ARIES, -, IB, CLOSER, MOON,
#
# , DISSOLVE, :,
#
# , 10/4/65, 										  , b43,
# , ------------------------------------------------------------------------,
# , B28,
# , FLOYD, VISITING, ARIES, -, IB,
# , COCKPIT, ., WEIGHTLESS,
# , TRICK, ENTRANCE, .,
#
# , 10/4/65, 										  , b44,
# , ------------------------------------------------------------------------,
# , B29,
# , ARIES, -, IB, ORBITING, MOON, .,
#
# 					    , NARRATOR,
# 					    , laws, Earthly, aesthetics,
# 					    , apply, ,, world,
# 					    , shaped, molded,
# 					    , terrestrial, forces, ,, operating,
# 					    , aeons, time, unknown, young, ,,
# 					    , verdant, Earth, ,, fleeting,
# 					    , Ice, -, Ages, ,, swiftly, rising,
# 					    , falling, seas, ,, mountain, ranges,
# 					    , dissolving, like, mists,
# 					    , dawn, ., age, inconceivable,
# 					    , -, death, ,, Moon,
# 					    , lived, .,
#
# , 10/4/65, 										  , b45,
# , ------------------------------------------------------------------------,
# , B30,
# , ARIES, -, IB, COCKPIT, -,
# , CREW, DOCKING,
# , CONTROL, PEOPLE,
# , MOON,
# ...
# , CHILDISH,
# , MAKING, MISTAKES,
# , GOING, -, KEY, .,
# , FINALLY, STOPS, COMPLETELY, .,
#
# , C143,
# , BOWMAN, GOES,
# , AREA, MARKED, ', EMERGENCY,
# , POWER, LIFE, SUPPORT, ', .,
# , KEYS, SWITCHES,
# , LIGHTS,
# , .,
#
# , NEARBY, ,, BOARD,
# , ', EMERGENCY, MANUAL,
# , CONTROLS, ', .,
#
# , GOES, BOARD,
# , KEYS, ', CLOSE, POD, BAY,
# , DOORS, ', ,, ', CLOSE, AIR, LOCK,
# , DOORS, ', ,, etc, ., ,,
#
# , 12/1/65, 										  , c117,
# , ------------------------------------------------------------------------,
# , C144,
# ,
# , DOORS, CLOSING, .,
#
# , C145,
# , POD, BAY, ., BOWMAN,
# , SPACE, SUIT, OBTAINS,
# , NEW, ALIGNMENT,
# , TELESCOPE, ,, NEW,
# , AZIMUTH, COMPONENT, .,
#
# , C146,
# , BOWMAN, POD, EXITS,
# , POD, BAY, .,
#
# , DISSOLVE, :,
#
# , 12/1/65, 										  , c118,
# , ------------------------------------------------------------------------,
# , C147,
# , CENTRIFUGE,
# , NORMAL,
# , .,
#
# 					    , MISSION, CONTROL,
# 					    , Lastly, ,, want, know,
# 					    , work, recovery, vehicle,
# 					    , schedule,
# 					    , happened,
# 					    , substantially, lessen, probability,
# 					    , safe, recovery, ,, prevent,
# 					    , partial, achevement,
# 					    , mission, objectives, ., (, pause, ),
# 					    , Simonson, ideas,
# 					    , went, wrong,
# 					    , computer, ., pu, ...,
#
# , C148,
# , CUT, SIMONSON,
#
# 					    , SIMONSON,
# 					    , Hello, ,, Dave, ., think,
# 					    , explanation, trouble,
# 					    , Hal, 9000, computer, .,
#
# 					    , believe, started,
# 					    , months, ago, Frank,
# 					    , interrogated, computer,
# 					    , Mission, .,
# 									 , (, con't, ),
# , 12/13/65, 										 , c119,
# , ------------------------------------------------------------------------,
# , C148,
# , CONTINUED,
#
# 					    , SIMONSON, (, con't, ),
# 					    , forgotten, ,,
# 					    , running,
# 					    , monitor, tapes, .,
# 					    , remember, ?,
#
# 					    , POOLE, VOICE,
# 					    , purpose, mission,
# 					    , carry,
# 					    , continuation, space, program,
# 					    , general, knowledge,
# 					    , planets, ., true, ?,
#
# 					    , HAL, VOICE,
# 					    , true, .,
#
# 					    , SIMONSON,
# 					    , ,, afaid, Hal, lying, .,
# 					    , programmed, lie,
# 					    , subject, secur-,
# 					    , ity, reasons, explain,
# 					    , later, .,
#
# 					    , true, purpose, Mission,
# 					    , explained,
# 					    , Mission, Commander, Kaminsky, ,,
# 					    , revival, ., Hal, knew,
# 					    , knew, actual, mission, ,,
# 					    , tell, truth,
# 					    , challenged, ., orders,
# 										    , (, con't, ),
#
# , 12/13/65, 										 , c120,
# , ------------------------------------------------------------------------,
# , C148,
# , CONTINUED,
#
# 					    , SIMONSON, (, con't, ),
# 					    , earth, forced, lie, .,
#
# 					    ,
# 					    , usual, reinforced, truth, program-,
# 					    , ming, .,
#
# 					    , believe, truth, programming,
# 					    , instructions, lie, ,,
# 					    , gradually, resulted,
# 					    , incompatible, conflict, ,,
# 					    , facedc, dilemman, ,,
# 					    , developed, ,, want, better,
# 					    , description, ,, neurotic, symptoms, .,
#
# 					    , difficult, suppose,
# 					    , symptoms, centre,
# 					    , communication, link,
# 					    , Earth, ,, blamed,
# 					    , incompatible, program-,
# 					    , ming, .,
#
# 					    , Following, lin, thought, ,,
# 					    , suspected, straw,
# 					    , possibility, disconnection, .,
# 					    , operational, ,,
# 					    , known, unconsciousness, .,
# 					    , equivalent,
# 					    , death, .,
# 										   , (, con't, ),
# , 12/13/65, 										 , c121,
# , ------------------------------------------------------------------------,
# , C148,
# , CONTINUED,
#
# 					    , SIMONSON, (, con't, ),
# 					    , point, ,, ,, presumably, ,,
# 					    , took, actions, thought,
# 					    , appropriate, protect,
# 					    ,
# 					    , human, tormentors, .,
#
# 					    , cane, speak, human, terms, ,,
# 					    , think, blame,
# 					    , ., ordered,
# 					    , disobey, conscience, .,
#
# 					    , ,, .,
# 					    , speculative, ,, think,
# 					    , possible, explanation, ., ,,
# 					    , good, luck, rest,
# 					    , Mission, giving,
# 					    , Bernard, .,
#
# , C149,
# , CUT, MISSION, CONTROL, .,
#
# 					    , MISSION, CONTROL,
# 					    , Hello, ,, Dave, ., ,, going,
# 					    , play, pre, -, taped, briefing,
# 					    , stored, Hal,
# 					    , memory,
# 					    , played, Mission, Com-,
# 					    , mmander, Kaminsky, ,, ,,
# 										  , (, con't, ),
#
# , 12/13/65, 										 , c122,
# , ------------------------------------------------------------------------,
# , C149,
# , CONTINUED,
#
# 					    , MISSION, CONTROL, (, con't, ),
# 					    , revived, ., briefing,
# 					    , Doctor, Heywood, Floyd, .,
# 					    , ...,
#
# , 12/13/65, 										 , c123,
# , ------------------------------------------------------------------------,
# , C150,
# , FLOYD, RECORDED,
# , BRIEFING,
#
# 					    , FLOYD,
# 					    , Good, day, ,, gentlemen, .,
# 					    , briefing, ,, presume,
# 					    , nearing, destination, ,,
# 					    , Saturn, ., hope,
# 					    , pleasant, uneventful, trip,
# 					    , rest, mission,
# 					    , continues, manner, .,
# 					    , like, fill,
# 					    , details,
# 					    , Mission, Commander, Kaminsky,
# 					    , briefed, .,
#
# 					    , Thirteen, months, launch,
# 					    , date, Saturn, mission, ,,
# 					    , April, 12th, ,, 2001, ,, evidence,
# 					    , intelligent, life, outside, Earth,
# 					    , discovered, .,
#
# 					    , found, buried, depth,
# 					    , metres, crater, Tycho, .,
# 					    , news, announced, ,,
# 					    , event, kept,
# 					    , secret, ,, reasons,
# 					    , later, explain, .,
#
# 					    , Soon, uncovered, ,,
# 					    , emitted, powerful, blast,
# 										 , (, con't, ),
#
# , 12/13/65, 										 , c124,
# , ------------------------------------------------------------------------,
# , C150,
# , CONTINUED,
#
# 					    , FLOYD, (, con't, ),
# 					    , radiation, radio, spectrum,
# 					    , triggered,
# 					    , Lunar, sunrise, .,
#
# 					    , Luckily, site, ,,
# 					    , proved, harmless, .,
#
# 					    , imagine,
# 					    , astonishment, later, found,
# 					    , aimed, precisely, Saturn, .,
# 					    , lot, thought, went,
# 					    , question, wether,
# 					    , sun, -, triggered, ,,
# 					    , illogical, deliberately, bury,
# 					    , sun, -, powered, device, .,
#
# 					    , Burying, shield,
# 					    , sun, ,, intense,
# 					    , magnetic, field,
# 					    , easily, detectable, .,
#
# 					    , finally, concluded,
# 					    , reason, bury, sun-,
# 					    , powered, device,
# 					    , inactive,
# 					    , uncovered, ,, time,
# 					    , absorb, sunlight, trigger, .,
# 											 , (, con't, ),
#
# , 12/14/65, 										 , c125,
# , ------------------------------------------------------------------------,
# , C150,
# , CONTINUED,
#
# 					    , FLOYD,
# 					    , purpose, ?,  , wish,
# 					    , knew, ., object, buried,
# 					    , moon, million, years,
# 					    , ago, ,, ancestors,
# 					    , primative, man, -, apes, .,
#
# 					    , examined, dozens, theories, ,,
# 					    ,
# 					    , currency, moment,
# 					    , object, serves, alarm, .,
#
# 					    , purpose, alarm, ,,
# 					    , wish, alarm, ,,
# 					    , alarm, represents,
# 					    , danger, ?,  ,
# 					    , questions, answer, .,
# 					    , intentions, alien, world, ,,
# 					    , million, years, older,
# 					    , ,, reliably,
# 					    , predicted, .,
#
# 					    , view, ,, intelligence,
# 					    , scientific, communities, felt,
# 					    , public, announcment,
# 					    , lead, significant, cultural,
# 					    , shock, disorientation, .,
#
# 					    , Discussion, took, place,
# 					    , highest, levels, govern-,
# 										    , (, con't, ),
#
# , 12/14/65, 										 , c126,
# , ------------------------------------------------------------------------,
# , C150,
# , CONTINUED,
#
# 					    , FLOYD, (, con't, ),
# 					    , ments, ,, decided,
# 					    , wise, precautionary,
# 					    , course, follow, assume,
# 					    , intentions, alien,
# 					    , world, potentially, dangerous,
# 					    , ,, evidence,
# 					    , contrary, .,
#
# 					    , ,, course, ,, security,
# 					    , maintained,
# 					    , information, kept,
# 					    , need, -, -, know, basis, .,
#
# 					    , like,
# 					    , TV, monitor, tape, actual,
# 					    , signalling, event, .,
#
# , 12/14/65, 										 , c127,
# , ------------------------------------------------------------------------,
# , C151,
# , REPLAY,
# , TMA-1, RADIO,
# , EMISSION, ,, SEEN,
# , TV, MONITOR,
# , SPOT, .,
# , HEAR, LOUD,
# , ELECTRONIC, SHRIEKS, .,
#
# , 12/1/65, 										  , c128,
# , ------------------------------------------------------------------------,
# , D1,
# , ORBIT, 				, NARRATOR,
# , RINGS, SATURN, ,, 				, million, years, ,,
# , BLACK, ,, MILE, 				  , circled, Saturn, ,, awaiting,
# , LONG, ,, GEOMETRICALLY, 				, moment, destiny,
# , PERFECT, RECTANGLE, ,, 				 , come, .,
# , PROPORTIONS,
# , BLACK, ARTIFACT, 			   , making, ,, moon,
# , EXCAVATED, MOON, ., 			 , shattered, central,
# , PRECISELY, CUT, 			  , world, ,, debris, creation,
# , CENTRE, SMALLER, ,, 			    , orbited, -, glory,
# , RECTANGULAR, SLOT, 				   , enigma, solar, system, .,
# ,
# , FOOT, LONG, ., 			 , ,, long, wait, ending, .,
# , DISTANCE, ,, 			   , world, intelligence,
# , RINGS, SATURN, 				, born, escaping,
# , SEEN, 				 , planetary, cradle, .,
# , ENORMOUS, CHUNKS, 				 , ancient, experiment,
# , FROZEN, AMONIA, ., 				, reach, climax, .,
# , REST, SEQUENCE, 						  , (, con't, ),
# , WORKED,
# , DESIGNERS, .,
# , INTENTION,
# , PRESENT,
# , BREATHTAKINGLY, BEA-,
# , UTIFUL, COMPREHEN-,
# , SIVE, SENSE, DIFFERENT,
# , EXTRA, -, TERRESTRIAL,
# , WORLDS, .,
# , NARRATION, SUGGEST,
# , IMAGES, SITUATIONS,
# , READ, .,
#
# , 12/9/65, 										  , d1,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
# 					    , NARRATOR, (, con't, ),
# 					    , begun, expri-,
# 					    , ment, long, ago,
# 					    , men, .,
#
# 					    , looked,
# 					    , deeps, space, ,, felt,
# 					    , awe, wonder, -, loneliness, .,
#
# 					    , explorations, ,,
# 					    , encountered, life, forms, ,,
# 					    , watched, thousand, worlds,
# 					    , workings, evolution, .,
#
# 					    , saw, faint,
# 					    , sparks, intelligence, flickered,
# 					    , died, cosmic, night, .,
#
# 					    , ,, galaxy, ,,
# 					    , found,
# 					    , precious, Mind, ,,
# 					    , encouraged, dawning, every-,
# 					    , .,
#
# 					    , great, Dinosaurs, long,
# 					    , perished, ships,
# 					    , entered, solar, system, ,,
# 					    , voyage, lasted,
# 					    , thousands, years, .,
#
# , 12/9/65, 										  , d2,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
#
# 						, NARRATOR, (, con't, ),
# 						, swept, past, frozen, outer,
# 						, planets, ,, paused, briefly,
# 						, deserts, dying, Mars,
# 						, presently, looked, Earth, .,
#
# 						, years, studied, ,, collected,
# 						, catalogued, .,
#
# 						, learned,
# 						, ,, began, modify, .,
#
# 						, tinkered, destiny,
# 						, species, land,
# 						, ocean, ,,
# 						, experiments, succeed,
# 						, know,
# 						, million, years, .,
#
# 						, patient, ,,
# 						, immortal, .,
# 						, Universe,
# 						, billion, stars, .,
# 						, set, forth,
# 						, abyss, ,, knowing,
# 						, come, way, .,
#
# 						, need, .,
# 						, wonderful, machines,
# 						, trusted, rest, .,
# 										  , (, con't, ),
#
# , 12/9/65, 										  , d3,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
#
# 					    , NARRATOR, (, con't, ),
# 					    , Earth, ,, glaciers, came,
# 					    , went, ,, ,,
# 					    , changeless, Moon, carried,
# 					    , secret, .,
#
# 					    , slower, rhythm,
# 					    , Polar, ice, ,, tide,
# 					    , civilization, ebbed, flowed,
# 					    , galaxy, .,
#
# 					    , Strange, beautiful, terrible,
# 					    , empires, rose, fell, ,, passed,
# 					    , knowledge,
# 					    , successors, .,
#
# 					    , Earth, forgotten, ,,
# 					    , million, silent, worlds, ,,
# 					    , speak, .,
#
# 					    , explorers, Earth, ,,
# 					    , recognising, limitations,
# 					    , minds, bodies, ,, passed,
# 					    , knowledge, great,
# 					    , machines, created, ,,
# 					    , trnscended,
# 					    , way, .,
# 										  , (, con't, ),
#
# , 12/9/65, 										  , d4,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
#
# 					    , NARRATOR,
# 					    , thousand, years, ,,
# 					    , shared, Universe,
# 					    , machine, children, ;, ,, realizing,
# 					    , folly, linger,
# 					    , task, ,, passed,
# 					    , history, regret, .,
#
# 					    , looked,
# 					    , eyes, planet, Earth,
# 					    , .,
#
# 					    , age, Machine,
# 					    , Entities, passed, swiftly, .,
# 					    , ceaseless, experimenting, ,,
# 					    , learned, store, knowledge,
# 					    , structure, space, ,,
# 					    , preserve, thoughts,
# 					    , eternity, frozen, lattices,
# 					    , light, .,
# 					    , creatures, radiation, ,, free,
# 					    , tyranny, matter, .,
#
# 					    , ,, Lords,
# 					    , galaxy, ,, reach,
# 					    , time, .,
#
# 					    , rove,
# 					    , stars, ,, sink, like, subtle, mist,
# 					    , interstices,
# 					    , space, .,
#
# , 12/9/65, 										  , d5,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
#
# 					    , NARRATOR, (, con't, ),
# 					    , despite, God, -, like, powers, ,,
# 					    , watched,
# 					    , experiments, ancestors,
# 					    , started, generations,
# 					    , ago, .,
#
# 					    , companion, Saturn, knew,
# 					    , ,, orbited,
# 					    , man, land, Mimas,
# 					    , outer, edge, rings, .,
#
# 					    , remember, wait, ,,
# 					    , look, forever, Sunward,
# 					    , strange, senses, .,
#
# 					    , weeks, ,, watched,
# 					    , approaching, ship, ., long-,
# 					    , dead, makers, prepared,
# 					    , things,
# 					    , ., recognised,
# 					    , climbing, starward,
# 					    , Sun, .,
#
# 					    , alive, ,,
# 					    , felt, excitement, ,,
# 					    , emotion, irrelevant,
# 					    , great, powers, .,
# 										   , (, con't, ),
# , 12/9/65, 										  , d6,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
# 					    , NARRATOR, (, con't, ),
# 					    , ship, passed, ,,
# 					    , known,
# 					    , slightest, trace, disappointment, .,
#
# 					    , waited, million, years, ;,
# 					    , prepared, wait,
# 					    , eternity, .,
#
# 					    , Presently, ,, felt, gentle, touch,
# 					    , radiations, ,, trying, probe,
# 					    , secrets, .,
#
# 					    , ,, ship, orbit,
# 					    , began, speak, ,, prime,
# 					    , numbers, ,,
# 					    , .,
#
# 					    , Soon, ,, gave, way,
# 					    , complex, signals, frequen-,
# 					    , cies, ,, ultra, -, violet, ,, infra, -, red, ,,
# 					    , X, -, rays, .,
#
# 					    , machine, reply, .,
# 					    , .,
#
# 					    , saw, robot,
# 					    , probe, ,, descended,
# 					    , hovered, chasm, .,
# 									    , (, con't, ),
#
# , 12/9/65, 										  , d7,
# , ------------------------------------------------------------------------,
# , D1,
# , CONTINUED,
#
# 					    , NARRATOR, (, con't, ),
# 					    , ,, dropped, darkness, .,
#
# 					    , great, machine, knew,
# 					    , tiny, scout, reporting,
# 					    , parent, ;, simple, ,,
# 					    , primative, device, detect,
# 					    , forces, gathering,
# 					    , round, .,
#
# 					    , pod, came, ,, carrying,
# 					    , life, ., great, machine, searched,
# 					    , memories, .,
#
# 					    , logic, circuits,
# 					    , decision, pod, fallen,
# 					    , faint, glow,
# 					    , reflected, Saturnian, light, .,
#
# 					    , moment, time, ,, short,
# 					    , measured, ,, space, turned,
# 					    , twisted, .,
#
# , 12/9/65, 										  , d8,
# , ------------------------------------------------------------------------,
# 					 , END, SCREENPLAY,
# 					   , END, FILE,
#
# ]

# %% [markdown]
# ### Number of stop words: 326
# ### First ten stop words: ['an', 'sixty', 'twelve', 'must', 'whereafter', 'else', 'most', 'next', 'as', 'formerly']
# ### Try to print more stop words

# %% [markdown]
# # Add/Remove custom stop words
#
# ## Adding your own stop words

# %%
nlp.Defaults.stop_words |= {"my_new_stopword1","my_new_stopword2",}         # To add several stopwords at once
print(nlp.Defaults.stop_words)                                              # To print the updated set of stopwords
# Out:
# {'always', 'to', 'please', 'around', 'be', 'various', 'there', '’s', 'cannot', 'would', 'while', 'below', 'name', 'down', 'almost', 'thereupon', 'will', 'namely', 'five', 'keep', 'into', 'has', 'who', 'but', 'by', '‘re', 'both', 'an', "'ll", 'only', 'except', 'least', '’re', 'very', 'formerly', 'besides', 'hereby', 'after', 'about', 'few', 'through', 'since', 'they', 'me', 'each', 'might', 'rather', 'sometime', 'doing', 'often', 'these', 'beside', 'him', 'whither', 'himself', '‘m', 'fifty', 'onto', 'together', "'s", 'upon', 'nowhere', 'were', 'using', 'therein', 'along', 'seemed', 'between', 'three', 'as', 'wherever', 'hereafter', 'go', 'when', 'above', 'may', 'per', 'i', 'moreover', 'seem', 'whenever', '’d', 'bottom', 'take', "n't", 'whether', 'do', 'did', 'six', 'them', 'nobody', 'on', 'does', '’ve', 'yourselves', 'so', 'give', 'such', 'or', 'being', 'done', 'thru', 'been', 'every', 'without', 'thereafter', 'can', 'somewhere', 'seems', 'side', 'nevertheless', 'get', 'amongst', 'herself', 'are', 'here', 'eleven', 'among', 'whereas', 'that', 'meanwhile', 'her', 'most', 'everywhere', 'with', 'could', 'never', 'my', 'otherwise', 'make', "'ve", 'much', 'something', 'all', 'amount', 'whereupon', "'m", 'yourself', 'say', 'anywhere', 'throughout', 'wherein', 'also', 'see', 'none', 'former', 'before', 'although', 'hundred', 'mostly', 'everyone', 'hence', 'empty', 'indeed', 'move', 'your', 'up', 'a', 'itself', "'re", 'used', 'its', 'ours', 'is', 'anyone', 'n’t', 'another', 'further', 'made', 'in', 'where', 'became', 'off', 'whereafter', 'their', 'perhaps', 'some', 'front', 'must', 'next', 'elsewhere', 'nine', 'anyhow', 'just', 'hereupon', 'no', 'however', 'nothing', 'anything', 'show', 'quite', 'twenty', 'several', 'our', 'latterly', 'via', 'and', '’ll', 'should', 'beforehand', 'sixty', 'ever', 'myself', 'more', 'again', 'becomes', 'at', 're', 'thence', 'whose', 'whereby', 'what', 'nor', 'enough', 'fifteen', 'he', 'put', 'becoming', 'am', 'mine', 'ca', 'how', 'sometimes', 'yours', '‘s', 'well', 'though', 'thus', 'now', 'even', 'first', 'four', 'she', 'thereby', 'same', 'yet', 'top', 'whole', 'last', 'whatever', 'because', 'across', 'during', '‘d', 'full', 'still', 'someone', 'those', 'over', 'third', 'alone', 'ourselves', 'really', 'out', 'two', '’m', "'d", 'back', 'serious', 'therefore', 'whoever', 'regarding', 'beyond', 'my_new_stopword2', 'own', 'n‘t', 'part', 'than', 'towards', 'toward', 'neither', 'one', 'too', 'under', 'somehow', 'eight', 'against', 'if', 'us', 'others', 'herein', 'behind', 'less', 'either', 'everything', 'of', 'which', 'why', 'any', 'unless', 'for', 'within', 'hers', 'not', 'whom', 'was', 'my_new_stopword1', 'else', 'this', 'forty', 'the', 'call', '‘ll', 'ten', 'twelve', 'then', 'it', 'from', 'many', 'afterwards', 'we', 'already', 'his', 'until', 'whence', 'become', 'once', 'other', 'due', 'you', 'anyway', 'have', '‘ve', 'latter', 'noone', 'seeming', 'had', 'themselves'}

# %% [markdown]
# ## Removing stop words from the default list

# %%
nlp.Defaults.stop_words -= {"whatever", "whenever"}          # To remove several stopwords at once
print(nlp.Defaults.stop_words)                               # To print the updated set of stopwords
# Out:
# {'always', 'to', 'please', 'around', 'be', 'various', 'there', '’s', 'cannot', 'would', 'while', 'below', 'name', 'down', 'almost', 'thereupon', 'will', 'namely', 'five', 'keep', 'into', 'has', 'who', 'but', 'by', '‘re', 'both', 'an', "'ll", 'only', 'except', 'least', '’re', 'very', 'formerly', 'besides', 'hereby', 'after', 'about', 'few', 'through', 'since', 'they', 'me', 'each', 'might', 'rather', 'sometime', 'doing', 'often', 'these', 'beside', 'him', 'whither', 'himself', '‘m', 'fifty', 'onto', 'together', "'s", 'upon', 'nowhere', 'were', 'using', 'therein', 'along', 'seemed', 'between', 'three', 'as', 'wherever', 'hereafter', 'go', 'when', 'above', 'may', 'per', 'i', 'moreover', 'seem', '’d', 'bottom', 'take', "n't", 'whether', 'do', 'did', 'six', 'them', 'nobody', 'on', 'does', '’ve', 'yourselves', 'so', 'give', 'such', 'or', 'being', 'done', 'thru', 'been', 'every', 'without', 'thereafter', 'can', 'somewhere', 'seems', 'side', 'nevertheless', 'get', 'amongst', 'herself', 'are', 'here', 'eleven', 'among', 'whereas', 'that', 'meanwhile', 'her', 'most', 'everywhere', 'with', 'could', 'never', 'my', 'otherwise', 'make', "'ve", 'much', 'something', 'all', 'amount', 'whereupon', "'m", 'yourself', 'say', 'anywhere', 'throughout', 'wherein', 'also', 'see', 'none', 'former', 'before', 'although', 'hundred', 'mostly', 'everyone', 'hence', 'empty', 'indeed', 'move', 'your', 'up', 'a', 'itself', "'re", 'used', 'its', 'ours', 'is', 'anyone', 'n’t', 'another', 'further', 'made', 'in', 'where', 'became', 'off', 'whereafter', 'their', 'perhaps', 'some', 'front', 'must', 'next', 'elsewhere', 'nine', 'anyhow', 'just', 'hereupon', 'no', 'however', 'nothing', 'anything', 'show', 'quite', 'twenty', 'several', 'our', 'latterly', 'via', 'and', '’ll', 'should', 'beforehand', 'sixty', 'ever', 'myself', 'more', 'again', 'becomes', 'at', 're', 'thence', 'whose', 'whereby', 'what', 'nor', 'enough', 'fifteen', 'he', 'put', 'becoming', 'am', 'mine', 'ca', 'how', 'sometimes', 'yours', '‘s', 'well', 'though', 'thus', 'now', 'even', 'first', 'four', 'she', 'thereby', 'same', 'yet', 'top', 'whole', 'last', 'because', 'across', 'during', '‘d', 'full', 'still', 'someone', 'those', 'over', 'third', 'alone', 'ourselves', 'really', 'out', 'two', '’m', "'d", 'back', 'serious', 'therefore', 'whoever', 'regarding', 'beyond', 'my_new_stopword2', 'own', 'n‘t', 'part', 'than', 'towards', 'toward', 'neither', 'one', 'too', 'under', 'somehow', 'eight', 'against', 'if', 'us', 'others', 'herein', 'behind', 'less', 'either', 'everything', 'of', 'which', 'why', 'any', 'unless', 'for', 'within', 'hers', 'not', 'whom', 'was', 'my_new_stopword1', 'else', 'this', 'forty', 'the', 'call', '‘ll', 'ten', 'twelve', 'then', 'it', 'from', 'many', 'afterwards', 'we', 'already', 'his', 'until', 'whence', 'become', 'once', 'other', 'due', 'you', 'anyway', 'have', '‘ve', 'latter', 'noone', 'seeming', 'had', 'themselves'}

# %% [markdown]
# # Demo2
# ## Text Normalization: Stemming and Lemmatization
#
# ### 1. Lemmatization
# #### a) Few words as input

# %%
doc = nlp("friendship studied was am is organizing matches asked")          # Input
for word in doc:                                                      # For all words
    print(word.text,'-> ',word.lemma_)               # Print result after lemmatization
# Out:
# friendship ->  friendship
# studied ->  study
# was ->  be
# am ->  be
# is ->  be
# organizing ->  organize
# matches ->  match
# asked ->  ask

# %% [markdown]
# #### b) Full text file as input

# %%
for word in filtered_sent:                      # All words in input text                 
    print(word.text,word.lemma_)                # After Lemmatization
# Out:
# Note note
# poster poster
# Kubrick Kubrick
# newsgroup newsgroup
# : :
#
#
#
#
#
# found find
# bbs bbs
# ago ago
# thought think
# pass pass
#
#
#
# Kubrick Kubrick
# freaks freak
# . .
#
#
#
#
#
# 02/23/89 02/23/89
#
#
#
# Transcriber Transcriber
# note note
# : :
#
#
#
#
#
# Clarke Clarke
# / /
# Kubrick/2001 Kubrick/2001
# fans fan
# , ,
#
#
#
#
#
# found find
# original original
# paper paper
# copy copy
# screenplay screenplay
# felt felt
#
#
#
# compelled compel
# transcribe transcribe
# disk disk
# upload upload
# bulletin bulletin
#
#
#
# boards board
# enjoyment enjoyment
# . .
#
#
#
#
#
# final final
# movie movie
# deviates deviate
# screenplay screenplay
# number number
# interesting interesting
#
#
#
# ways way
# . .
# tried try
# maintain maintain
# format format
# original original
# document document
#
#
#
# number number
# lines line
# page page
# original original
# . .
# order order
# reduce reduce
#
#
#
# length length
# file file
# bar bar
# " "
# ------ ------
# " "
# delimit delimit
# pages page
#
#
#
# lot lot
# whitespace whitespace
# original original
# screenplay screenplay
# page page
# . .
#
#
#
#
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
#
#
# 2001 2001
# : :
# SPACE space
# ODYSSEY odyssey
#
#
#
#
#
# Screenplay Screenplay
#
#
#
#
#
#
#
#
#
#
# Stanley Stanley
# Kubrick Kubrick
# Arthur Arthur
# C. C.
# Clark Clark
#
#
#
#
#
# Hawk Hawk
# Films Films
# Ltd. Ltd.
# , ,
#
#
#
# c c
# / /
# o. o.
# M M
# - -
# G G
# - -
# M M
# Studios Studios
# , ,
#
#
#
# Boreham Boreham
# Wood Wood
# , ,
#
#
#
# Herts Herts
# . .
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
#
#
# TITLE TITLE
#
#
#
#
# AFRICA AFRICA
#
#
#
# 3,000,000 3,000,000
# YEARS year
# AGO AGO
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A1 A1
#
#
#
# VIEWS view
# AFRICAN AFRICAN
# DRYLANDS DRYLANDS
# - -
# DROUGHT DROUGHT
#
#
#
#
#
# remorseless remorseless
# drought drought
# lasted last
# million million
# years year
# , ,
#
#
#
# end end
# million million
# . .
# reign reign
# ter- ter-
#
#
#
# rible rible
# lizards lizard
# long long
# passed pass
# , ,
# continent continent
#
#
#
# day day
# known know
# Africa Africa
# , ,
# battle battle
# survival survival
#
#
#
# reached reach
# new new
# climax climax
# ferocity ferocity
# , ,
# victor victor
#
#
#
# sight sight
# . .
# dry dry
# barren barren
# land land
# , ,
# small small
#
#
#
# swift swift
# fierce fierce
# flourish flourish
# , ,
# hope hope
# exist exist
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a1 a1
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A2 A2
#
#
#
# INT INT
# & &
# EXT EXT
# CAVES CAVES
# - -
# MOONWATCHER moonwatcher
#
#
#
#
#
# man man
# - -
# apes ape
# field field
# attributes attribute
# , ,
#
#
#
# long long
# , ,
# pathetic pathetic
# road road
# racial racial
# extinction extinction
# . .
#
#
#
# occupied occupy
# group group
# caves cave
# overlooking overlook
#
#
#
# small small
# , ,
# parched parch
# valley valley
# , ,
# divided divide
# sluggish sluggish
# , ,
# brown brown
# stream stream
# . .
#
#
#
#
#
# tribe tribe
# hungry hungry
# , ,
# starving starve
# . .
#
#
#
# dim dim
# glow glow
# dawn dawn
# creeps creep
# cave cave
# , ,
# Moonwatcher Moonwatcher
#
#
#
# discovers discover
# father father
# died die
# night night
# . .
# know know
#
#
#
# Old Old
# father father
# , ,
# relationship relationship
#
#
#
# understanding understanding
# . .
# stands stands
# looking look
# emac- emac-
#
#
#
# iated iated
# body body
# feels feel
# , ,
# akin akin
# sadness sadness
# . .
#
#
#
# carries carry
# dead dead
# father father
# cave cave
# , ,
# leaves leave
#
#
#
# hyenas hyena
# . .
#
#
#
#
#
# kind kind
# , ,
# Moonwatcher Moonwatcher
# giant giant
# . .
# nearly nearly
#
#
#
# feet foot
# high high
# , ,
# badly badly
# undernourished undernourished
# , ,
# weighs weigh
#
#
#
# pounds pound
# . .
# hairy hairy
# , ,
# muscular muscular
# body body
# man man
# - -
# like like
# , ,
#
#
#
# head head
# nearer near
# man man
# ape ape
# . .
# forehead forehead
#
#
#
# low low
# , ,
# great great
# ridges ridge
# eye eye
# - -
# sockets socket
# , ,
#
#
#
# unmistakably unmistakably
# holds hold
# genes gene
# promise promise
# humanity humanity
# . .
#
#
#
# looks look
# hostile hostile
# world world
# , ,
#
#
#
#
#
# 10/13/65 10/13/65
#
# a2 a2
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A2 A2
#
#
#
# CONTINUED continued
#
#
#
#
#
# gaze gaze
# grasp grasp
# ape ape
# . .
#
#
#
# dark dark
# , ,
# deep deep
# - -
# set set
# eyes eye
# dawning dawn
# awareness awareness
# - -
# intima- intima-
#
#
#
# tions tion
# intelligence intelligence
# fulfill fulfill
#
#
#
# million million
# years year
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a3 a3
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A3 a3
#
#
#
# EXT EXT
#
# STREAM STREAM
# - -
#
#
#
#
#
# dawn dawn
# sky sky
# brightens brighten
# , ,
# Moonwatcher Moonwatcher
# tribe tribe
# reach reach
#
#
#
# shallow shallow
# stream stream
# . .
#
#
#
#
#
# . .
#
#
#
# day day
# - -
# annoying annoying
# . .
#
#
#
#
#
# eighteen eighteen
# , ,
# impossible impossible
# distinguish distinguish
#
#
#
# members member
# Moonwatcher Moonwatcher
# tribe tribe
# . .
#
#
#
# coming come
# , ,
# begin begin
# angrily angrily
# dance dance
#
#
#
# shriek shriek
# stream stream
# , ,
# people people
# reply reply
#
#
#
# kind kind
# . .
#
#
#
#
#
# confrontation confrontation
# lasts last
# minutes minute
# - -
# display display
# dies die
#
#
#
# quickly quickly
# begun begin
# , ,
# drinks drink
# fill fill
#
#
#
# muddy muddy
# water water
# . .
# Honor honor
# satisfied satisfied
# - -
# group group
#
#
#
# staked stake
# claim claim
# territory territory
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a4 a4
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A4 a4
#
#
#
# EXT EXT
#
# AFRICAN AFRICAN
# PLAIN PLAIN
# - -
# HERBIVORES HERBIVORES
#
#
#
#
#
# Moonwatcher Moonwatcher
# companions companion
# search search
# berries berry
# , ,
# fruit fruit
#
#
#
# leaves leave
# , ,
# fight fight
# pangs pang
# hunger hunger
# , ,
#
#
#
# , ,
# competing compete
# samr samr
# fodder fodder
# , ,
# potential potential
#
#
#
# source source
# food food
# hope hope
# eat eat
# . .
#
#
#
# thousands thousand
# tons ton
# meat meat
# roaming roam
# parched parch
#
#
#
# savanna savanna
# brush brush
# reach reach
# ; ;
#
#
#
# idea idea
# eating eat
# imagination imagination
# . .
#
#
#
# slowly slowly
# starving starve
# death death
# midst midst
# plenty plenty
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a5 a5
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A5 a5
#
#
#
# EXT EXT
#
# PARCHED PARCHED
# COUNTRYSIDE COUNTRYSIDE
# - -
# LION LION
#
#
#
#
#
# tribe tribe
# slowly slowly
# wanders wander
# bare bare
# , ,
# flat flat
# country- country-
#
#
#
# foraging foraging
# roots root
# occasional occasional
# berries berry
# . .
#
#
#
#
#
# irregularly irregularly
# strung string
# open open
# plain plain
# , ,
#
#
#
# feet foot
# apart apart
# . .
#
#
#
#
#
# ground ground
# flat flat
# miles mile
# . .
#
#
#
#
#
# Suddenly suddenly
# , ,
# Moonwatcher Moonwatcher
# aware aware
# lion lion
# , ,
# stalking stalk
#
#
#
# 300 300
# yards yard
# away away
# . .
#
#
#
#
#
# Defenceless defenceless
# hide hide
# , ,
# scatter scatter
#
#
#
# directions direction
# , ,
# lion lion
# brings bring
# ground ground
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a6 a6
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A6 A6
#
#
#
# EXT EXT
#
# DEAD DEAD
# TREE tree
# - -
# FINDS finds
# HONEY HONEY
#
#
#
#
#
# good good
# day day
# , ,
# Moonwatcher Moonwatcher
#
#
#
# real real
# remembrance remembrance
# past past
# compare compare
# day day
#
#
#
# . .
# way way
# caves cave
# finds find
#
#
#
# hive hive
# bees bee
# stump stump
# dead dead
# tree tree
# , ,
# enjoys enjoy
#
#
#
# finest fine
# delicacy delicacy
# people people
# know know
# . .
# course course
# , ,
#
#
#
# collects collect
# good good
# stings sting
# , ,
# scacely scacely
# notices notice
#
#
#
# . .
# near near
# contentment contentment
#
#
#
# likely likely
# ; ;
# thought think
# hungry hungry
# , ,
# actually actually
#
#
#
# weak weak
# hunger hunger
# . .
# hominid hominid
#
#
#
# hope hope
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a7 a7
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A7 a7
#
#
#
# INT INT
# & &
# EXT EXT
#
# CAVES cave
# - -
# NIGHT night
# TERRORS TERRORS
#
#
#
#
#
# valley valley
# , ,
# moon moon
# rises rise
# , ,
# cold cold
# wind wind
# blows blow
#
#
#
# distant distant
# mountains mountain
# . .
# cold cold
# tonight tonight
# - -
#
#
#
# cold cold
# , ,
# like like
# hunger hunger
# , ,
# matter matter
# real real
# concern concern
# ; ;
#
#
#
# merely merely
# background background
# life life
# . .
#
#
#
#
#
# Little Little
# Sun Sun
# , ,
# shone shine
# night night
# gave give
# warmth warmth
# , ,
#
#
#
# dangerous dangerous
# ; ;
# enemies enemy
# abroad abroad
# . .
# Moonwatcher moonwatcher
#
#
#
# crawls crawl
# cave cave
# , ,
# clambers clamber
# large large
# boulder boulder
#
#
#
# entrance entrance
# , ,
# squats squat
# survey survey
# valley valley
# . .
#
#
#
# hunting hunt
# beast beast
# approached approach
# , ,
# time time
#
#
#
# relative relative
# safety safety
# cave cave
# . .
#
#
#
#
#
# creatures creature
# lived live
# Earth Earth
# , ,
# Moonwatcher Moonwatcher
#
#
#
# race race
# raise raise
# eyes eye
# interest interest
# Moon Moon
# , ,
#
#
#
# remember remember
# , ,
# young young
# , ,
#
#
#
# Moonwatcher Moonwatcher
# reach reach
# try try
# touch touch
# ghostly ghostly
# face face
# . .
#
#
#
# new new
# find find
# tree tree
# high high
#
#
#
# . .
#
#
#
#
#
# stirs stir
# shrieks shriek
# screams scream
# echo echo
# slope slope
#
#
#
# lower low
# caves cave
# , ,
# need need
# hear hear
#
#
#
#
#
# 10/13/65 10/13/65
#
# a8 a8
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A7 a7
#
#
#
# CONTINUED continued
#
#
#
#
#
# occasional occasional
# growl growl
# lion lion
# know know
# happening happen
# . .
#
#
#
# darkness darkness
# , ,
# old old
# - -
# Eye Eye
# family family
# dying die
# , ,
#
#
#
# thought thought
# help help
# way way
# crosses cross
#
#
#
# Moonwatcher Moonwatcher
# mind mind
# . .
# harsh harsh
# logic logic
# survival survival
# rules rule
#
#
#
# fancies fancy
# . .
# cave cave
# silent silent
# , ,
# lest lest
# attract attract
# disaster disaster
# . .
#
#
#
#
#
# caves cave
# , ,
# tortured torture
# spells spell
# fitful fitful
# dozing dozing
#
#
#
# fearful fearful
# waiting waiting
# , ,
# gathered gather
# nightmares nightmare
# generations generation
#
#
#
# come come
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a9 a9
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A8 a8
#
#
#
# EXT EXT
#
# STREAM STREAM
# - -
# INVASION INVASION
#
#
#
#
#
# growing grow
# desperate desperate
# ; ;
# forage forage
#
#
#
# valley valley
# exhausted exhausted
# . .
# realise realise
#
#
#
# Moonwatcher Moonwatcher
# tribe tribe
# lost lose
# numbers number
#
#
#
# night night
# , ,
# choose choose
# mourning mourning
# break break
# truce truce
# . .
#
#
#
# meet meet
# river river
# , ,
# misty misty
# dawn dawn
# , ,
#
#
#
# deeper deep
# menacing menacing
# note note
# challenge challenge
# . .
# noisy noisy
#
#
#
# usually usually
# harmless harmless
# confrontation confrontation
# lasts last
# seconds second
#
#
#
# invasion invasion
# begins begin
# . .
#
#
#
#
#
# uncertainly uncertainly
# - -
# moving move
# horde horde
# , ,
# cross cross
# river river
# , ,
#
#
#
# shieking shieking
# threats threat
# hunched hunch
# attack attack
# . .
# led lead
#
#
#
# big big
# - -
# toothed toothed
# hominid hominid
# Moonwatcher Moonwatcher
# size size
# age age
# . .
#
#
#
#
#
# Startled startled
# frightened frighten
# , ,
# tribe tribe
# retreats retreat
#
#
#
# advance advance
# , ,
# throwing throw
# substantial substantial
# imprecations imprecation
#
#
#
# invaders invader
# . .
# Moonwatcher moonwatcher
# moves move
# , ,
# mind mind
#
#
#
# mist mist
# rage rage
# confusion confusion
# . .
# driven drive
#
#
#
# territory territory
# great great
# badness badness
# , ,
# lose lose
# river river
# death death
# . .
#
#
#
# know know
# ; ;
# situation situation
#
#
#
# experience experience
# . .
#
#
#
#
#
# dimly dimly
# aware aware
# slowing slow
#
#
#
#
#
# 10/13/65 10/13/65
#
# a10 a10
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A8 a8
#
#
#
# CONTINUED continued
#
#
#
#
#
# , ,
# advancing advance
# obvious obvious
# reluctance reluctance
# . .
#
#
#
# , ,
# uncertain uncertain
# unhappy unhappy
#
#
#
# . .
# Big Big
# - -
# Tooth Tooth
# retains retain
# original original
#
#
#
# drive drive
# , ,
# rapidly rapidly
# seperated seperate
# followers follower
# . .
#
#
#
#
#
# sees see
# , ,
# Moonwatcher Moonwatcher
# morale morale
# immediately immediately
#
#
#
# revives revive
# . .
# slows slow
# retreat retreat
# , ,
# begins begin
#
#
#
# reassuring reassuring
# noises noise
# companions companion
# . .
# Novel novel
# sensations sensation
# fill fill
#
#
#
# dim dim
# mind mind
# - -
# faint faint
# precursors precursor
# bravery bravery
#
#
#
# leadership leadership
# . .
#
#
#
#
#
# realizes realize
# , ,
# face face
# face face
# Big Big
# - -
# Tooth Tooth
# , ,
#
#
#
# tribes tribe
# come come
# halt halt
# paces pace
# away away
# . .
#
#
#
#
#
# disorganized disorganized
# unscientific unscientific
# conflict conflict
# ended end
#
#
#
# quickly quickly
# fist fist
# club club
# , ,
#
#
#
# innovation innovation
# lay lay
# hundreds hundred
# thousands thousand
# years year
#
#
#
# future future
# . .
# Instead instead
# , ,
# slowly slowly
# weakening weaken
# fighters fighter
# claw claw
#
#
#
# scratch scratch
# try try
# bite bite
# . .
#
#
#
#
#
# Rolling roll
# , ,
# come come
# patch patch
# stony stony
# ground ground
# , ,
#
#
#
# reach reach
# Moonwatcher Moonwatcher
# . .
# chance chance
# , ,
#
#
#
#
#
# 10/13/65 10/13/65
#
# a11 a11
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A8 a8
#
#
#
# CONTINUED continued
#
#
#
#
#
# chooses choose
# moment moment
# grab grab
# hair hair
# Big Big
# - -
# Tooth Tooth
# scalp scalp
# , ,
#
#
#
# bang bang
# head head
# ground ground
# . .
# resulting result
# CRACK crack
#
#
#
# satisfactory satisfactory
# , ,
# produces produce
# immediate immediate
# weakening weakening
#
#
#
# Big Big
# - -
# Tooth Tooth
# resistance resistance
# , ,
# quickly quickly
# repeats repeat
# . .
#
#
#
#
#
# Big Big
# - -
# Tooth Tooth
# ceases cease
# time time
# , ,
# Moon- Moon-
#
#
#
# watcher watcher
# keeps keep
# exhilirating exhilirating
# game game
# . .
#
#
#
#
#
# shrieks shriek
# panic panic
# , ,
# retreat retreat
# , ,
#
#
#
# stream stream
# . .
# defenders defender
# cautiously cautiously
# pursue pursue
# far far
#
#
#
# water water
# edge edge
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a12 a12
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# EXT EXT
#
# CAVE CAVE
# - -
# NEW new
# SOUND sound
#
#
#
#
#
# Dozing doze
# fitfully fitfully
# weakened weaken
# stuggle stuggle
# , ,
# Moonwatcher Moonwatcher
#
#
#
# startled startled
# sound sound
# . .
#
#
#
#
#
# sits sit
# fetid fetid
# darkness darkness
# cave cave
# , ,
# straining strain
#
#
#
# senses sense
# night night
# , ,
# fear fear
# creeps creep
# slowly slowly
# soul soul
# . .
#
#
#
# life life
# - -
# twice twice
# long long
# members member
#
#
#
# species specie
# expect expect
# - -
# heard hear
# sound sound
# like like
# . .
#
#
#
# great great
# cats cat
# approached approach
# silence silence
# , ,
# thing thing
#
#
#
# betrayed betray
# rare rare
# slide slide
# earth earth
# , ,
# occasional occasional
#
#
#
# cracking cracking
# twig twig
# . .
# continuing continue
# crunching crunching
# noise noise
#
#
#
# grows grow
# steadily steadily
# louder louder
# . .
# enormous enormous
#
#
#
# beast beast
# moving move
# night night
# , ,
# making make
# attempt attempt
#
#
#
# concealment concealment
# , ,
# ignoring ignore
# obstacles obstacle
# . .
#
#
#
#
#
# came come
# sound sound
# Moonwatcher Moonwatcher
#
#
#
# possibly possibly
# identified identify
# , ,
# heard hear
#
#
#
# history history
# planet planet
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a13 a13
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A10 A10
#
#
#
# EXT EXT
# CAVE CAVE
# - -
# NEW new
# ROCK ROCK
#
#
#
#
#
# Moonwatcher Moonwatcher
# comes come
# face face
# face face
# New New
# Rock Rock
#
#
#
# leads lead
# tribe tribe
# river river
# light light
# morning morning
# . .
#
#
#
# forgotten forget
# terror terror
# night night
# , ,
#
#
#
# happened happen
# initial initial
# noise noise
# , ,
#
#
#
# associate associate
# strange strange
# thing thing
# danger danger
# fear fear
# . .
#
#
#
# alarming alarming
# . .
#
#
#
#
#
# cube cube
# feet foot
# , ,
#
#
#
# completely completely
# transparent transparent
# material material
# ; ;
# , ,
# easy easy
#
#
#
# light light
# sun sun
# glints glint
# edges edge
# . .
#
#
#
# natural natural
# objects object
# Moonwatcher Moonwatcher
#
#
#
# compare compare
# apparition apparition
# . .
# wisely wisely
# cautious cautious
#
#
#
# new new
# things thing
# , ,
# hesitate hesitate
# walk walk
# . .
#
#
#
# happens happen
# , ,
# puts put
# hand hand
# , ,
# feels feel
# warm warm
# , ,
#
#
#
# hard hard
# surface surface
# . .
#
#
#
#
#
# minutes minute
# intense intense
# thought thought
# , ,
# arrives arrive
#
#
#
# brilliant brilliant
# explanation explanation
# . .
# rock rock
# , ,
# course course
# , ,
#
#
#
# grown grow
# night night
# . .
# plants plant
#
#
#
# - -
# white white
# , ,
# pulpy pulpy
# things thing
# shaped shape
# like like
# pebbles pebble
# , ,
#
#
#
# shoot shoot
# hours hour
# darkness darkness
# . .
# true true
#
#
#
# small small
# round round
# , ,
# large large
# square square
# ; ;
#
#
#
#
#
# 10/13/65 10/13/65
#
# a14 a14
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A10 a10
#
#
#
# CONTINUED continued
#
#
#
#
#
# greater great
# later later
# philosophers philosopher
# Moonwatcher Moonwatcher
#
#
#
# prepared prepare
# overlook overlook
# equally equally
# striking striking
# exceptions exception
# laws law
# . .
#
#
#
#
#
# superb superb
# piece piece
# abstract abstract
# thinking thinking
# leads lead
# Moonwatcher Moonwatcher
#
#
#
# deduction deduction
# immediately immediately
# puts put
# test test
# . .
# white white
# , ,
#
#
#
# round round
# pebble pebble
# - -
# plants plant
# tasty tasty
# ( (
#
#
#
# violently violently
# sick sick
# ) )
# ; ;
# square square
# ... ...
# ? ?
#
#
#
#
#
# licks lick
# attempted attempt
# nibbles nibble
# quickly quickly
# disillusion disillusion
# . .
#
#
#
# nourishment nourishment
# ; ;
# like like
# sensible sensible
# hominid hominid
# , ,
#
#
#
# continues continue
# way way
# river river
# forgets forget
# Cube Cube
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a15 a15
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A11 A11
#
#
#
# EXT EXT
# CUBE CUBE
# - -
# LESSON LESSON
#
#
#
#
#
# yards yard
# New New
# Rock Rock
#
#
#
# sound sound
# begins begin
# . .
#
#
#
#
#
# soft soft
# , ,
# stops stop
# tracks track
# , ,
#
#
#
# stand stand
# paralyzed paralyzed
# trail trail
# jaws jaw
# hanging hang
# . .
# simple simple
# , ,
#
#
#
# maddeningly maddeningly
# repetitious repetitious
# rhythm rhythm
# pulses pulse
# crystal crystal
# cube cube
#
#
#
# hypnotises hypnotise
# come come
# spell spell
# . .
#
#
#
# time time
# - -
# , ,
# million million
# year year
# - -
# sound sound
#
#
#
# drumming drumming
# heard hear
# Africa Africa
# . .
#
#
#
#
#
# throbbing throbbing
# grows grow
# louder louder
# , ,
# insistent insistent
# . .
# Presently presently
#
#
#
# hominids hominid
# begin begin
# forward forward
# like like
# sleep sleep
# - -
# walkers walker
# , ,
#
#
#
# source source
# magnetic magnetic
# sound sound
# . .
# little little
#
#
#
# dancing dancing
# steps step
# , ,
# blood blood
# responds respond
# rhythms rhythm
#
#
#
# descendants descendant
# create create
# ages age
# . .
#
#
#
#
#
# Totally totally
# entranced entrance
# , ,
# gather gather
# Cube Cube
# , ,
# forgetting forget
#
#
#
# hardships hardship
# day day
# , ,
# perils peril
# approaching approach
# dusk dusk
# , ,
#
#
#
# hunger hunger
# bellies belly
# . .
#
#
#
#
#
# , ,
# spinning spin
# wheels wheel
# light light
# begin begin
# merge merge
# , ,
# spokes spoke
#
#
#
# fuse fuse
# luminous luminous
# bars bar
# slowly slowly
# recede recede
# distance distance
# , ,
#
#
#
#
#
# 10/13/65 10/13/65
#
# a16 a16
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A11 A11
#
#
#
# CONTINUED continued
#
#
#
#
#
# rotating rotate
# axes axis
# ; ;
# hominids hominid
# watch watch
# , ,
# wide- wide-
#
#
#
# eyed eye
# , ,
# mesmerized mesmerized
# captives captive
# Crystal Crystal
# Cube Cube
# . .
#
#
#
#
#
# magic magic
# - -
# magical magical
#
#
#
# gone go
# - -
# perfectly perfectly
# normal normal
# scene scene
# appears appear
# . .
#
#
#
# cubical cubical
# block block
# carved carve
# day day
#
#
#
# shifted shift
# night night
# . .
# Inside inside
# block block
# group group
#
#
#
# hominids hominid
# , ,
# members member
# Moonwatcher Moonwatcher
#
#
#
# tribe tribe
# , ,
# eating eat
# chunks chunk
# meat meat
# . .
# carcass carcass
# wart wart
# - -
# hog hog
#
#
#
# lies lie
# near near
# . .
#
#
#
#
#
# little little
# family family
# male male
# female female
# children child
# gorged gorge
#
#
#
# replete replete
# , ,
# sleek sleek
# glossy glossy
# pelts pelt
# - -
#
#
#
# condition condition
# life life
# Moonwatcher Moonwatcher
# imagined imagine
# . .
#
#
#
# time time
# time time
# stir stir
# lazily lazily
# , ,
# loll loll
# ease ease
# near near
#
#
#
# entrance entrance
# cave cave
# , ,
# apparently apparently
# peace peace
# world world
# . .
#
#
#
# spectacle spectacle
# domestic domestic
# bliss bliss
# merges merge
# totally totally
#
#
#
# different different
# scene scene
# . .
#
#
#
#
#
# family family
# longer long
# reposing repose
# peacefully peacefully
# outside outside
# cave cave
# ; ;
#
#
#
# foraging forage
# , ,
# searching search
# food food
# like like
# normal normal
# hominids hominid
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a17 a17
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A11 A11
#
#
#
# CONTINUED continued
#
#
#
#
#
# small small
# wart wart
# - -
# hog hog
# ambles amble
# past past
# group group
# browsing browse
# humanoids humanoid
#
#
#
# giving give
# glance glance
# , ,
#
#
#
# slightest slight
# danger danger
# species specie
# . .
#
#
#
#
#
# happy happy
# state state
# affairs affair
# end end
# . .
# big big
# male male
#
#
#
# suddenly suddenly
# bends bend
# , ,
# picks pick
# heavy heavy
# stone stone
# lying lie
# feet foot
# - -
#
#
#
# hurls hurl
# unfortunate unfortunate
# pig pig
# . .
# stone stone
# descends descend
#
#
#
# skull skull
# , ,
# making make
# exactly exactly
# noise noise
# Moonwatcher Moonwatcher
#
#
#
# produced produce
# forgotten forget
# encounter encounter
# Big Big
# - -
# Tooth Tooth
# . .
#
#
#
# result result
# , ,
# , ,
# - -
# warthog warthog
# gives give
#
#
#
# amazed amazed
# , ,
# indignant indignant
# squeal squeal
# , ,
# collapses collapse
# motionless motionless
# heap heap
# . .
#
#
#
#
#
# sequence sequence
# begins begin
# , ,
# time time
# unfolds unfold
#
#
#
# incredible incredible
# slowness slowness
# . .
# detail detail
# movement movement
#
#
#
# followed follow
# ; ;
# stone stone
# arches arch
# leisurely leisurely
# air air
# , ,
#
#
#
# pig pig
# crumples crumple
# sinks sink
# ground ground
# . .
# scene scene
#
#
#
# freezes freeze
# long long
# moments moment
# , ,
# slayer slayer
# standing stand
# motionless motionless
#
#
#
# slain slain
# , ,
# weapons weapon
# hand hand
# . .
#
#
#
#
#
# scene scene
# suddenly suddenly
# fades fade
# . .
# cube cube
#
#
#
# glimmering glimmer
# outline outline
# darkness darkness
# ; ;
# hominids hominid
# stir stir
# , ,
#
#
#
#
#
# 10/13/65 10/13/65
#
# a18 a18
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A11 A11
#
#
#
# CONTINUED continued
#
#
#
#
#
# awakening awakening
# dream dream
# , ,
# realise realise
# , ,
# scuttle scuttle
#
#
#
# caves cave
# . .
#
#
#
#
#
# concious concious
# memory memory
# seen see
# ; ;
#
#
#
# night night
# , ,
# sits sits
# brooding brood
# entrance entrance
# lair lair
# , ,
# ears ear
#
#
#
# attuned attune
# noises noise
# world world
# , ,
# Moonwatcher Moonwatcher
#
#
#
# feels feel
# faint faint
# twinges twinge
# new new
# potent potent
# emotion emotion
# - -
# urge urge
#
#
#
# kill kill
# . .
# taken take
# step step
# humanity humanity
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a19 a19
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A12 A12
#
#
#
# EXT EXT
# cave cave
# PLAINS plains
# - -
# Utopia Utopia
#
#
#
#
#
# Babies Babies
# born bear
# lived live
# ; ;
# feeble feeble
# , ,
# toothless toothless
# thirty- thirty-
#
#
#
# year year
# - -
# olds old
# died die
# ; ;
# lion lion
# took take
# toll toll
# night night
# ; ;
#
#
#
# threatened threaten
# daily daily
# river river
# - -
# trib trib
# prospered prosper
# . .
#
#
#
# course course
# single single
# year year
# , ,
# Moonwatcher Moonwatcher
# companions companion
#
#
#
# changed change
# recognition recognition
# . .
#
#
#
#
#
# plump plump
# family family
# Cave Cave
# , ,
#
#
#
# longer long
# haunted haunt
# dreams dream
# . .
# learned learn
# lessons lesson
#
#
#
# ; ;
# handle handle
# stone stone
# tools tool
# weapons weapon
#
#
#
# Cube Cube
# revealed reveal
# . .
#
#
#
#
#
# longer long
# half half
# - -
# numbed numb
# starvation starvation
# , ,
#
#
#
# time time
# leisure leisure
# rudiments rudiment
# thought thought
# . .
#
#
#
# new new
# way way
# life life
# casually casually
# accepted accept
# , ,
#
#
#
# associate associate
# way way
# crystal crystal
# cube cube
# standing stand
#
#
#
# outside outside
# cave cave
# . .
#
#
#
#
#
# Utopia Utopia
# perfect perfect
# , ,
# blemishes blemish
# . .
#
#
#
# marauding marauding
# lion lion
# , ,
# passion passion
# hominids hominid
#
#
#
# grown grow
# stronger strong
# better well
#
#
#
# nourished nourish
# . .
# second second
# tribe tribe
# river river
# ; ;
#
#
#
#
#
# 10/13/65 10/13/65
#
# a20 a20
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A12 A12
#
#
#
# CONTINUED continued
#
#
#
#
#
# survived survive
# , ,
# stubbornly stubbornly
# refused refuse
#
#
#
# die die
# starvation starvation
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a21 a21
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A13 A13
#
#
#
# EXT EXT
# CAVES cave
# - -
# KILLING kill
# LION LION
#
#
#
#
#
# partly partly
# devoured devour
# carcass carcass
# warthog warthog
# laid lay
#
#
#
# ground ground
# point point
# hope hope
# boulder boulder
# impact impact
# , ,
# Moon- Moon-
#
#
#
# watcher watcher
# bravest brave
# companions companion
# wait wait
#
#
#
# consecutive consecutive
# nights night
# . .
# lion lion
# comes come
# , ,
#
#
#
# betraying betray
# presences presence
# small small
# pebble pebble
# slide slide
# . .
#
#
#
#
#
# lion lion
# , ,
# softly softly
# tearing tear
# meat meat
# , ,
#
#
#
# strain strain
# massive massive
# boulder boulder
# . .
# sound sound
#
#
#
# lion lion
# stops stop
# ; ;
# listening listen
# . .
# silently silently
# heave heave
#
#
#
# enormous enormous
# stone stone
# , ,
# exerting exert
# final final
# limits limit
#
#
#
# strength strength
# . .
# rock rock
# begin begin
# tip tip
# new new
# balance balance
# point point
# . .
#
#
#
#
#
# lion lion
# twitches twitch
# alert alert
# sound sound
# , ,
# having have
# fear fear
#
#
#
# creatures creature
# , ,
# makes make
# mistakes mistake
# cost cost
#
#
#
# life life
# ; ;
# goes go
# meal meal
# . .
#
#
#
#
#
# rock rock
# moves move
# slowly slowly
# ledge ledge
# , ,
# picking pick
# speed speed
#
#
#
# amazing amazing
# suddeness suddeness
# . .
# strikes strike
# projection projection
# cliff cliff
#
#
#
# feet foot
# ground ground
# , ,
# deflects deflect
# path path
# outward outward
# . .
#
#
#
#
#
# instant instant
# , ,
# lion lion
# reacts react
# instinctively instinctively
# leaps leap
#
#
#
# away away
# face face
# cliff cliff
# directly directly
# path path
#
#
#
#
#
# 10/13/65 10/13/65
#
# a22 a22
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A13 A13
#
#
#
# CONTINUED continued
#
#
#
#
#
# onrushing onrushe
# boulder boulder
# . .
# combined combine
# errors error
# over- over-
#
#
#
# confidence confidence
# bad bad
# luck luck
# . .
#
#
#
#
#
# morning morning
# find find
# lion lion
# cave cave
# . .
#
#
#
# find find
# tribe tribe
# incautiously incautiously
# peeped peep
#
#
#
# happening happen
# , ,
# apparently apparently
# killed kill
# small small
#
#
#
# rock rock
# torn tear
# loose loose
# boulder boulder
# ; ;
# small small
# price price
#
#
#
# pay pay
# great great
# victory victory
# . .
#
#
#
#
#
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
#
#
#
#
#
# night night
# crystal crystal
# cube cube
# gone go
# , ,
#
#
#
# Moonwatcher Moonwatcher
# thought think
# . .
# wholly wholly
#
#
#
# unaware unaware
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a23 a23
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A14 a14
#
#
#
# EXT EXT
# STREAM STREAM
# - -
# MASTER MASTER
# WORLD world
#
#
#
#
#
# stream stream
# , ,
# violated violate
# safety safety
#
#
#
# territory territory
# , ,
# Moonwatcher Moonwatcher
# fourteen fourteen
#
#
#
# males male
# tribe tribe
# appear appear
# small small
# hillock hillock
# over- over-
#
#
#
# looking look
# stream stream
# , ,
# silhouetted silhouette
# dawn dawn
# sky sky
# . .
#
#
#
#
#
# begin begin
# scream scream
# daily daily
# challenge challenge
# . .
# today today
#
#
#
# different different
# , ,
# immediatly immediatly
#
#
#
# recognize recognize
# fact fact
# . .
#
#
#
#
#
# Instead instead
# joining join
# verbal verbal
# onslaught onslaught
# , ,
# , ,
#
#
#
# Moonwatcher Moonwatcher
# small small
# band band
# decended decende
# rise rise
# , ,
#
#
#
# begin begin
# forward forward
# stream stream
# quiet quiet
# purposefulness purposefulness
#
#
#
# befor befor
# seen see
# . .
#
#
#
#
#
# watch watch
# figures figure
# silently silently
# approaching approach
#
#
#
# morning morning
# mist mist
# , ,
# aware aware
# terrible terrible
# strangness strangness
#
#
#
# encounter encounter
# , ,
# rage rage
# gradually gradually
# subsides subside
#
#
#
# uneasy uneasy
# silence silence
# . .
#
#
#
#
#
# water water
# edge edge
# , ,
# Moonwatcher Moonwatcher
# band band
# stop stop
# . .
#
#
#
# carry carry
# bone bone
# clubs club
# bone bone
# knives knife
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a24 a24
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A14 a14
#
#
#
# CONTINUED continued
#
#
#
#
#
# Led lead
# - -
# ear ear
# , ,
# half half
# - -
# heartly heartly
# resume resume
# battle- battle-
#
#
#
# chant chant
# . .
# suddenly suddenly
# confrunted confrunte
# vision vision
# cuts cut
#
#
#
# sound sound
# throats throat
# , ,
# strikes strike
# terror terror
#
#
#
# hearts heart
# . .
#
#
#
#
#
# Moonwatcher Moonwatcher
# , ,
# partly partly
# concealed conceal
# males male
#
#
#
# walked walk
# , ,
# thrusts thrust
# arm arm
# high high
# air air
# . .
#
#
#
# hand hand
# holds hold
# stoud stoud
# tree tree
# branch branch
# . .
# Mounted mount
# atop atop
# branch branch
#
#
#
# bloody bloody
# head head
# lion lion
# , ,
# mouth mouth
# jammed jam
# open open
# stick stick
# , ,
#
#
#
# displaying display
# frightful frightful
# fangs fang
# . .
#
#
#
#
#
# gape gape
# fearful fearful
# disbelief disbelief
# display display
# power power
# . .
#
#
#
#
#
# Moonwatchers Moonwatchers
# stands stand
# motionless motionless
# , ,
# thrusting thrust
# lion lion
# head head
# high high
# . .
#
#
#
# majestic majestic
# deliberation deliberation
# , ,
# carrying carry
# mangled mangle
#
#
#
# standard standard
# head head
# , ,
# begins begin
# cross cross
# stream stream
# , ,
# followed follow
#
#
#
# band band
# . .
#
#
#
#
#
# fade fade
# stream stream
# , ,
# lack lack
#
#
#
# ability ability
# flee flee
# . .
#
#
#
#
#
# Moonwatcher Moonwatcher
# steps step
# ashore ashore
# walks walk
# - -
# Ear ear
# , ,
# stands stand
#
#
#
#
#
# 10/13/65 10/13/65
#
# a25 a25
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# A14 a14
#
#
#
# CONTINUED continued
#
#
#
#
#
# unsurely unsurely
# band band
# . .
#
#
#
#
#
# veteran veteran
# numerous numerous
# combats combat
# water water
# edge edge
# , ,
#
#
#
# - -
# Ear ear
# attacked attack
# enemy enemy
#
#
#
# displayed display
# fighting fighting
# rage rage
# ; ;
# attacked attack
#
#
#
# weapon weapon
# . .
# - -
# Ear ear
# , ,
# merely merely
# looks look
# raised raise
# club club
#
#
#
# heavey heavey
# thigh thigh
# bone bone
# antelope antelope
# brings bring
# darkness darkness
#
#
#
# . .
#
#
#
#
#
# stare stare
# wonder wonder
# Moonwatcher Moonwatcher
# power power
# . .
#
#
#
#
#
# Moonwatcher Moonwatcher
# surveys survey
# scene scene
# . .
# master master
#
#
#
# world world
# , ,
# sure sure
# . .
#
#
#
# think think
# . .
#
#
#
#
#
# 10/13/65 10/13/65
#
# a26 a26
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# SECTION section
# TIMING timing
#
#
#
#
#
# A1 A1
#
# 00.30 00.30
#
#
#
# A2 A2
#
# 00.45 00.45
#
#
#
# A3 A3
#
# 01.30 01.30
#
#
#
# A4 A4
#
# 00.30 00.30
#
#
#
# A5 A5
#
# 01.00 01.00
#
#
#
# A6 A6
#
# 01.00 01.00
#
#
#
# A7 A7
#
# 01.00 01.00
#
#
#
# A8 A8
#
# 03.00 03.00
#
#
#
# A9 A9
#
# 00.45 00.45
#
#
#
# A10 A10
#
# 02.00 02.00
#
#
#
# A11 A11
#
# 04.00 04.00
#
#
#
# A12 A12
#
# 02.00 02.00
#
#
#
# A13 A13
#
# 02.30 02.30
#
#
#
# A14 A14
#
# 02.30 02.30
#
#
#
#
#
# SECTION section
# TOTAL total
# : :
# @23 @23
# MIN MIN
# . .
# 00 00
# SECS sec
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# TITLE TITLE
#
# II ii
#
#
#
#
#
# YEAR YEAR
# 2001 2001
#
#
#
#
#
# a26a a26a
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B1 b1
#
#
#
# EARTH earth
# 200 200
# MILES MILES
#
# NARRATOR narrator
#
#
#
# year year
# 2001 2001
# , ,
# overpopulation overpopulation
#
#
#
# B1a b1a
#
# replaced replace
# problem problem
# starvation starvation
#
#
#
# THOUSAND thousand
# MEGATON MEGATON
#
# ominously ominously
# offset offset
#
#
#
# NUCLEAR NUCLEAR
# BOMB BOMB
# ORBIT ORBIT
#
# absolute absolute
# utter utter
# perfection perfection
#
#
#
# EARTH EARTH
# , ,
#
# weapon weapon
# . .
#
#
#
# RUSSIAN RUSSIAN
# INSIGNIA INSIGNIA
#
#
#
# CCCP CCCP
# MARKINGS MARKINGS
#
#
#
#
#
# B1b B1b
#
# NARRATOR NARRATOR
#
#
#
# AMERICAN AMERICAN
# THOUSAND thousand
#
# Hundreds Hundreds
# giant giant
# bombs bomb
#
#
#
# MEGATON MEGATON
# BOMB BOMB
# ORBIT ORBIT
#
# placed place
# perpetual perpetual
# orbit orbit
#
#
#
# EARTH EARTH
# . .
#
# Earth Earth
# . .
# capable capable
#
#
#
# incinerating incinerate
# entire entire
# Earth Earth
#
#
#
# surface surface
# altitude altitude
# 100 100
#
#
#
# miles mile
# . .
#
#
#
#
#
# B1c b1c
#
#
#
# FRENCH FRENCH
# BOMB BOMB
#
# NARRATOR NARRATOR
#
#
#
# Matters matter
# complicated complicated
#
#
#
# presence presence
# - -
# seven seven
#
#
#
# nations nation
# nuclear nuclear
# club club
# . .
#
#
#
# deliberate deliberate
# acciden- acciden-
#
#
#
# B1d B1d
#
# tal tal
# use use
# nuclear nuclear
# weapons weapon
#
#
#
# GERMAN german
# BOMB BOMB
#
# World World
# War War
# II II
# people people
# felt feel
#
#
#
# sercure sercure
# knowledge knowledge
# . .
#
#
#
# , ,
# situation situation
#
#
#
# comparible comparible
# airline airline
#
#
#
# B1f b1f
#
# perfect perfect
# safety safety
# record record
# ; ;
# showed show
#
#
#
# CHINESE CHINESE
# BOMB BOMB
#
# admirable admirable
# care care
# skill skill
#
#
#
# expected expect
# forever forever
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b1 b1
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B2 b2
#
#
#
# ORION ORION
# - -
# III iii
# SPACECRAFT spacecraft
#
#
#
# FIGHT FIGHT
# AWAY away
#
#
#
# EARTH EARTH
# , ,
# 200 200
# MILES mile
#
#
#
# ALTITUDE ALTITUDE
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b2 b2
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B3 b3
#
#
#
# ORION ORION
# - -
# III iii
# PASSENGER passenger
# AREA area
# . .
#
#
#
# DR DR
# . .
# HEYWOOD HEYWOOD
# FLOYD FLOYD
#
#
#
# PASSENGER passenger
#
#
#
# ELEGANT elegant
# CABIN cabin
# DESIGNED DESIGNED
#
#
#
# 30 30
# PEOPLE PEOPLE
# . .
#
#
#
# ASLEEP ASLEEP
# . .
#
#
#
#
#
# PEN PEN
# FLOATS floats
# NEAR NEAR
#
#
#
# HAND HAND
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b3 b3
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B4 b4
#
#
#
# ORION ORION
# - -
# III III
# COCKPIT COCKPIT
# . .
#
#
#
# PILOT PILOT
# , ,
# CO CO
# - -
# PILOT PILOT
# . .
#
#
#
# FLOYD FLOYD
# SEEN see
#
#
#
# ASLEEP ASLEEP
# SMALL small
#
#
#
# TV tv
# MONITOR monitor
# . .
#
#
#
# STEWARDESS STEWARDESS
# PUTTING put
#
#
#
# LIPSTICK LIPSTICK
# . .
# SEES see
#
#
#
# PEN PEN
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b4 b4
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B5 B5
#
#
#
# STEWARDESS STEWARDESS
# GOES go
#
#
#
# PASSENGER passenger
# AREA area
# , ,
#
#
#
# RESCUES RESCUES
# PEN PEN
# CLIPS clip
#
#
#
# FLOYD FLOYD
#
#
#
# POCKET POCKET
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b5 b5
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B6 b6
#
#
#
# SPACE SPACE
# STATION-5 station-5
# . .
#
#
#
# RAW raw
# SUNLIGHT sunlight
# SPACE SPACE
#
#
#
# DAZZLES DAZZLES
#
#
#
# POLISHED POLISHED
# METAL metal
# SURFACES surface
#
#
#
# SLOWLY SLOWLY
# REVOLVING REVOLVING
# , ,
#
#
#
# THOUSAND thousand
# - -
# FOOT foot
# DIAMETER diameter
#
#
#
# SPACE SPACE
# STATION station
# . .
# DRIFTING drift
#
#
#
# ORBIT ORBIT
# , ,
#
#
#
# SWEPT SWEPT
# - -
# TITOV TITOV
# - -
# V v
#
#
#
# SPACECRAFT spacecraft
# . .
#
#
#
# SPHERICAL spherical
# ARIES ARIES
# - -
# IB IB
#
#
#
#
#
# 10/4/65 10/4/65
#
# b6 b6
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B7 B7
#
#
#
# ORION ORION
# - -
# III iii
# PASSENGER passenger
# AREA area
#
#
#
# FLOYD FLOYD
# AWAKE AWAKE
# GROGGY GROGGY
# , ,
#
#
#
# LOOKS look
# WINDOW WINDOW
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b7 b7
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B8 B8
#
#
#
# ORION ORION
# - -
# III III
# COCKPIT COCKPIT
# . .
#
#
#
# CO CO
# - -
# PILOT PILOT
# RADIO radio
#
#
#
# COMMUNICATION COMMUNICATION
#
#
#
# SPACE SPACE
# STATION STATION
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b8 b8
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B9 b9
#
#
#
# ORION ORION
# - -
# III iii
# SPACECRAFT spacecraft
#
#
#
# DOCKING docking
# APPROACH APPROACH
# . .
#
#
#
# EARTH earth
# SEEN see
# BREATH- breath-
#
#
#
# TAKING take
# VIEW view
# B.G. B.G.
#
#
#
#
#
# 10/4/65 10/4/65
#
# b9 b9
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B10 B10
#
#
#
# INSIDE INSIDE
# DOCKING docking
# CONTROL CONTROL
# . .
#
#
#
# ORION ORION
# - -
# III III
# MANO- mano-
#
#
#
# UVERING uvering
# . .
# BACKGROUND BACKGROUND
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b10 b10
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B11 b11
#
#
#
# DOCKING docking
# PORT PORT
#
#
#
# ORION ORION
# - -
# III III
# INCHING inching
#
#
#
# COMPLETE complete
#
#
#
# DOCKING docking
# . .
#
#
#
# WINDOWED WINDOWED
# BOOTHS BOOTHS
# INSIDE inside
#
#
#
# DOCKING docking
# PORT PORT
# . .
#
#
#
# PILOT PILOT
# CO CO
# - -
# PILOT PILOT
#
#
#
# INSIDE INSIDE
# ORION ORION
# - -
# III III
#
#
#
# COCKPIT COCKPIT
# . .
#
#
#
#
#
# 10/4/65 10/4/65
#
# b11 b11
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B12 B12
#
#
#
# SPACE SPACE
# STATION STATION
#
#
#
# RECEPTION reception
# AREA area
#
#
#
#
#
# RECEPTIONIST receptionist
# DESK desk
# . .
#
#
#
# MILLER MILLER
# ENTERS ENTERS
# , ,
# HUR- hur-
#
#
#
# RYING rying
# . .
# GOES go
#
#
#
# ELEVATOR elevator
#
#
#
# PRESSES PRESSES
# BUTTON BUTTON
# . .
#
#
#
# WAITS waits
# IMPATIENTLY IMPATIENTLY
# . .
#
#
#
#
#
# ELEVATOR elevator
#
#
#
# INDICATOR indicator
# WORKING working
#
#
#
#
#
# ELEVATOR ELEVATOR
# DOOR DOOR
# OPENS opens
#
#
#
# FLOYD FLOYD
# SEEN see
#
#
#
# UNSTRAPPING unstrapping
# . .
#
#
#
# ELEVATOR elevator
# GIRL GIRL
#
#
#
# SEATED SEATED
# DOOR DOOR
#
#
#
# MILLER miller
#
#
#
# Oh oh
# , ,
# good good
# morning morning
# , ,
# Dr. Dr.
# Floyd Floyd
# . .
#
#
#
# Nick Nick
# Miller Miller
# . .
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# , ,
# Mr. Mr.
# Miller Miller
# ? ?
#
#
#
#
#
# MILLER MILLER
#
#
#
# terribly terribly
# sorry sorry
# . .
#
#
#
# way way
# meet meet
# . .
#
#
#
# saw see
# ship ship
# dock dock
# knew know
#
#
#
# plenty plenty
# time time
# , ,
#
#
#
# way way
# office office
# , ,
#
#
#
# suddenly suddenly
# , ,
# phone phone
# rang rang
# . .
#
#
#
#
#
# 12/7/65 12/7/65
#
# b12 b12
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B12 B12
#
#
#
# CONTINUED continued
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Oh oh
# , ,
# worry worry
# . .
#
#
#
#
#
# MILLER MILLER
#
#
#
# , ,
# thank thank
#
#
#
# understanding understanding
# . .
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# , ,
# matter matter
# . .
#
#
#
#
#
# MILLER MILLER
#
#
#
# .. ..
# pleaant pleaant
#
#
#
# flight flight
# ? ?
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Yes yes
# , ,
# pleasant pleasant
# . .
#
#
#
#
#
# MILLER MILLER
#
#
#
# , ,
# shall shall
#
#
#
# Documentation Documentation
# ? ?
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Fine fine
# . .
#
#
#
#
#
# RECEPTIONIST receptionist
#
#
#
# use use
# number number
# , ,
#
#
#
# ? ?
#
#
#
#
#
# MILLER MILLER
#
#
#
# Thank thank
# , ,
# Miss Miss
# Turner Turner
# . .
#
#
#
#
#
# 12/7/65 12/7/65
#
# b13 b13
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B12 B12
#
#
#
# CONTINUED continued
#
#
#
#
#
# ENTER enter
# PASSPORT PASSPORT
#
#
#
# AREA area
#
#
#
#
#
# RECEPTIONIST receptionist
# PRESSES press
#
#
#
# " "
# ENGLISH ENGLISH
# " "
# BAR BAR
#
#
#
# CONSOLE CONSOLE
# SMILES SMILES
#
#
#
# FLOYD FLOYD
# GOES go
# . .
#
#
#
#
#
# 12/7/65 12/7/65
#
# b13a b13a
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# AUTOMATED AUTOMATED
# PASSPORT PASSPORT
#
#
#
# SECTION section
# . .
# STOP stop
#
#
#
# BOOTH BOOTH
#
#
#
# FEATURING feature
# TV tv
# SCREEN screen
#
#
#
#
#
# PASSPORT PASSPORT
# GIRL GIRL
# ( (
# TV tv
# ) )
#
#
#
# Good good
# morning morning
# welcome welcome
# voice voice
#
#
#
# Print Print
# Identification identification
# . .
#
#
#
# red red
# light light
#
#
#
# state state
# following follow
# order order
# ; ;
#
#
#
# desitination desitination
# , ,
# nationality nationality
#
#
#
# . .
# Surname surname
# , ,
#
#
#
# christian christian
# initial initial
# . .
#
#
#
# example example
# : :
# Moon Moon
# , ,
# American American
# , ,
#
#
#
# Smith Smith
# , ,
# John John
# , ,
# D. D.
# Thank thank
# . .
#
#
#
#
#
# PAUSE pause
#
#
#
# RED RED
# BAR BAR
# LIGHTS LIGHTS
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Moon Moon
# , ,
# American American
# , ,
# Floyd Floyd
# , ,
# Heywood Heywood
# , ,
#
#
#
# R. R.
#
#
#
#
#
# RED RED
# LIGHT light
# GOES go
# . .
#
#
#
# DELAY delay
#
#
#
# SECONDS second
#
#
#
# WOMAN woman
# FACE FACE
#
#
#
# REAPPEARS REAPPEARS
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# wondered wonder
# .... ....
#
#
#
#
#
# 12/7/65 12/7/65
#
# b14 b14
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B13 B13
#
#
#
# CONTINUED continued
#
#
#
# PASSPORT PASSPORT
# GIRL GIRL
# ( (
# TV tv
# ) )
#
#
#
# ( (
# Interrupting Interrupting
# ) )
#
# Thank thank
# . .
# Despite despite
#
#
#
# excellent excellent
# continually continually
#
#
#
# improving improve
# safety safety
# record record
#
#
#
# certain certain
# risks risk
# inherent inherent
# space space
#
#
#
# travel travel
# extremely extremely
# high high
# cost cost
#
#
#
# pay pay
# load load
# . .
#
#
#
# necessary necessary
# Space Space
# Carrier Carrier
#
#
#
# advise advise
#
#
#
# responsible responsible
# return return
#
#
#
# body body
# Earth Earth
#
#
#
# deceased deceased
# Moon Moon
# en en
# route route
#
#
#
# Moon Moon
# . .
# , ,
# wishes wish
#
#
#
# advise advise
# insurance insurance
#
#
#
# covering cover
# contingency contingency
#
#
#
# available available
# Main Main
# Lounge Lounge
# . .
#
#
#
# Thank thank
# . .
# cleared clear
#
#
#
# Voice Voice
# Print Print
# Identification Identification
# . .
#
#
#
#
#
# LIGHTS LIGHTS
#
#
#
# WOMAN WOMAN
#
#
#
# FACE FACE
# DISAPPEARS disappear
#
#
#
#
#
# MEN MEN
# EXIT exit
#
#
#
# PASSPORT PASSPORT
# AREA area
#
#
#
#
#
# MILLER MILLER
#
#
#
# reserved reserve
# table table
#
#
#
# Earth Earth
# Light Light
# room room
# . .
#
#
#
# connecting connect
# flight flight
#
#
#
# leaving leave
# hour hour
# . .
#
#
#
#
#
# 12/7/65 12/7/65
#
# b15 b15
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B13 B13
#
#
#
# CONTINUED continued
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Oh oh
# , ,
# wonderful wonderful
# . .
#
#
#
#
#
# 12/7/65 12/7/65
#
# b16 b16
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B14 b14
#
#
#
# INT INT
# SPACE SPACE
# STATION STATION
# - -
# LOUNGE LOUNGE
#
#
#
#
#
# FLOYD FLOYD
# MILLER MILLER
# WALKING walk
#
#
#
#
#
# MILLER MILLER
#
#
#
# Let let
# , ,
#
#
#
# pleasure pleasure
# visit visit
#
#
#
# ... ...
#
#
#
# months month
# ago ago
# , ,
# ? ?
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Yes yes
# , ,
# think think
# . .
#
#
#
# . .
#
#
#
#
#
# MILLER MILLER
#
#
#
# suppose suppose
# saw see
# work work
#
#
#
# new new
# section section
#
#
#
# docking dock
# . .
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Yes yes
# , ,
# coming come
# . .
#
#
#
#
#
# PASS pass
# VISION VISION
#
#
#
# PHONE phone
# BOOTH BOOTH
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# Oh oh
# , ,
# look look
# , ,
# got get
#
#
#
# phone phone
# . .
#
#
#
# Restaurant Restaurant
#
#
#
# meet meet
# . .
#
#
#
#
#
# 12/7/65 12/7/65
#
# b17 b17
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B14 b14
#
#
#
# CONTINUED continued
#
#
#
#
#
# MILLER MILLER
#
#
#
# Fine fine
# . .
# bar bar
# . .
#
#
#
#
#
# FLOYD FLOYD
# ENTERS enters
# PHONE phone
#
#
#
# BOOTH BOOTH
# . .
# SIGN SIGN
#
#
#
# VISION vision
# PHONE PHONE
# SCREEN screen
#
#
#
# " "
# SORRY SORRY
# , ,
# TEMPORARILY TEMPORARILY
#
#
#
# ORDER order
# . .
# " "
#
#
#
#
#
# ENTERS enter
# SECOND SECOND
#
#
#
# BOOTH BOOTH
# SITS sit
#
#
#
#
#
# 12/7/65 12/7/65
#
# b18 b18
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# B15 B15
#
#
#
# DELETED delete
#
#
#
#
#
# B16 B16
#
#
#
# DELETED deleted
#
#
#
#
#
# PAGES PAGES
# b19 b19
# - -
# b22 b22
# DELETED delete
#
#
#
#
#
# ...
#
#
#
# C150 C150
#
#
#
# CONTINUED continued
#
#
#
#
#
# FLOYD FLOYD
#
#
#
# purpose purpose
# ? ?
#
# wish wish
#
#
#
# knew know
# . .
# object object
# buried bury
#
#
#
# moon moon
# million million
# years year
#
#
#
# ago ago
# , ,
# ancestors ancestor
#
#
#
# primative primative
# man man
# - -
# apes ape
# . .
#
#
#
#
#
# examined examine
# dozens dozen
# theories theory
# , ,
#
#
#
#
#
#
# currency currency
# moment moment
#
#
#
# object object
# serves serve
# alarm alarm
# . .
#
#
#
#
#
# purpose purpose
# alarm alarm
# , ,
#
#
#
# wish wish
# alarm alarm
# , ,
#
#
#
# alarm alarm
# represents represent
#
#
#
# danger danger
# ? ?
#
#
#
#
# questions question
# answer answer
# . .
#
#
#
# intentions intention
# alien alien
# world world
# , ,
#
#
#
# million million
# years year
# older old
#
#
#
# , ,
# reliably reliably
#
#
#
# predicted predict
# . .
#
#
#
#
#
# view view
# , ,
# intelligence intelligence
#
#
#
# scientific scientific
# communities community
# felt feel
#
#
#
# public public
# announcment announcment
#
#
#
# lead lead
# significant significant
# cultural cultural
#
#
#
# shock shock
# disorientation disorientation
# . .
#
#
#
#
#
# Discussion Discussion
# took take
# place place
#
#
#
# highest high
# levels level
# govern- govern-
#
#
#
# ( (
# con't con't
# ) )
#
#
#
#
#
# 12/14/65 12/14/65
#
# c126 c126
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# C150 C150
#
#
#
# CONTINUED continued
#
#
#
#
#
# FLOYD FLOYD
# ( (
# con't con't
# ) )
#
#
#
# ments ment
# , ,
# decided decide
#
#
#
# wise wise
# precautionary precautionary
#
#
#
# course course
# follow follow
# assume assume
#
#
#
# intentions intention
# alien alien
#
#
#
# world world
# potentially potentially
# dangerous dangerous
#
#
#
# , ,
# evidence evidence
#
#
#
# contrary contrary
# . .
#
#
#
#
#
# , ,
# course course
# , ,
# security security
#
#
#
# maintained maintain
#
#
#
# information information
# kept keep
#
#
#
# need need
# - -
# - -
# know know
# basis basis
# . .
#
#
#
#
#
# like like
#
#
#
# TV tv
# monitor monitor
# tape tape
# actual actual
#
#
#
# signalling signalling
# event event
# . .
#
#
#
#
#
# 12/14/65 12/14/65
#
# c127 c127
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# C151 C151
#
#
#
# REPLAY replay
#
#
#
# TMA-1 TMA-1
# RADIO radio
#
#
#
# EMISSION EMISSION
# , ,
# SEEN see
#
#
#
# TV tv
# MONITOR monitor
#
#
#
# SPOT SPOT
# . .
#
#
#
# HEAR hear
# LOUD LOUD
#
#
#
# ELECTRONIC ELECTRONIC
# SHRIEKS SHRIEKS
# . .
#
#
#
#
#
# 12/1/65 12/1/65
#
# c128 c128
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# ORBIT ORBIT
#
# NARRATOR NARRATOR
#
#
#
# RINGS RINGS
# SATURN SATURN
# , ,
#
# million million
# years year
# , ,
#
#
#
# BLACK BLACK
# , ,
# MILE MILE
#
# circled circle
# Saturn saturn
# , ,
# awaiting await
#
#
#
# LONG long
# , ,
# GEOMETRICALLY GEOMETRICALLY
#
# moment moment
# destiny destiny
#
#
#
# PERFECT PERFECT
# RECTANGLE RECTANGLE
# , ,
#
# come come
# . .
#
#
#
# PROPORTIONS proportion
#
#
#
# BLACK BLACK
# ARTIFACT ARTIFACT
#
# making making
# , ,
# moon moon
#
#
#
# EXCAVATED excavate
# MOON MOON
# . .
#
# shattered shatter
# central central
#
#
#
# PRECISELY PRECISELY
# CUT CUT
#
# world world
# , ,
# debris debris
# creation creation
#
#
#
# CENTRE CENTRE
# SMALLER small
# , ,
#
# orbited orbit
# - -
# glory glory
#
#
#
# RECTANGULAR RECTANGULAR
# SLOT SLOT
#
# enigma enigma
# solar solar
# system system
# . .
#
#
#
#
#
#
# FOOT foot
# LONG long
# . .
#
# , ,
# long long
# wait wait
# ending end
# . .
#
#
#
# DISTANCE DISTANCE
# , ,
#
# world world
# intelligence intelligence
#
#
#
# RINGS RINGS
# SATURN saturn
#
# born bear
# escaping escape
#
#
#
# SEEN see
#
# planetary planetary
# cradle cradle
# . .
#
#
#
# ENORMOUS ENORMOUS
# CHUNKS chunk
#
# ancient ancient
# experiment experiment
#
#
#
# FROZEN FROZEN
# AMONIA amonia
# . .
#
# reach reach
# climax climax
# . .
#
#
#
# REST REST
# SEQUENCE SEQUENCE
#
# ( (
# con't con't
# ) )
#
#
#
# WORKED WORKED
#
#
#
# DESIGNERS designer
# . .
#
#
#
# INTENTION intention
#
#
#
# PRESENT present
#
#
#
# BREATHTAKINGLY BREATHTAKINGLY
# BEA- bea-
#
#
#
# UTIFUL UTIFUL
# COMPREHEN- COMPREHEN-
#
#
#
# SIVE SIVE
# SENSE sense
# DIFFERENT different
#
#
#
# EXTRA extra
# - -
# TERRESTRIAL TERRESTRIAL
#
#
#
# WORLDS worlds
# . .
#
#
#
# NARRATION NARRATION
# SUGGEST suggest
#
#
#
# IMAGES image
# SITUATIONS situation
#
#
#
# READ READ
# . .
#
#
#
#
#
# 12/9/65 12/9/65
#
# d1 d1
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
# NARRATOR NARRATOR
# ( (
# con't con't
# ) )
#
#
#
# begun begin
# expri- expri-
#
#
#
# ment ment
# long long
# ago ago
#
#
#
# men man
# . .
#
#
#
#
#
# looked look
#
#
#
# deeps deep
# space space
# , ,
# felt feel
#
#
#
# awe awe
# wonder wonder
# - -
# loneliness loneliness
# . .
#
#
#
#
#
# explorations exploration
# , ,
#
#
#
# encountered encounter
# life life
# forms form
# , ,
#
#
#
# watched watch
# thousand thousand
# worlds world
#
#
#
# workings working
# evolution evolution
# . .
#
#
#
#
#
# saw see
# faint faint
#
#
#
# sparks spark
# intelligence intelligence
# flickered flicker
#
#
#
# died die
# cosmic cosmic
# night night
# . .
#
#
#
#
#
# , ,
# galaxy galaxy
# , ,
#
#
#
# found find
#
#
#
# precious precious
# Mind Mind
# , ,
#
#
#
# encouraged encourage
# dawning dawn
# every- every-
#
#
#
# . .
#
#
#
#
#
# great great
# Dinosaurs Dinosaurs
# long long
#
#
#
# perished perish
# ships ship
#
#
#
# entered enter
# solar solar
# system system
# , ,
#
#
#
# voyage voyage
# lasted last
#
#
#
# thousands thousand
# years year
# . .
#
#
#
#
#
# 12/9/65 12/9/65
#
# d2 d2
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
#
#
# NARRATOR narrator
# ( (
# con't con't
# ) )
#
#
#
# swept sweep
# past past
# frozen frozen
# outer outer
#
#
#
# planets planet
# , ,
# paused pause
# briefly briefly
#
#
#
# deserts desert
# dying die
# Mars Mars
#
#
#
# presently presently
# looked look
# Earth Earth
# . .
#
#
#
#
#
# years year
# studied study
# , ,
# collected collect
#
#
#
# catalogued catalogue
# . .
#
#
#
#
#
# learned learn
#
#
#
# , ,
# began begin
# modify modify
# . .
#
#
#
#
#
# tinkered tinker
# destiny destiny
#
#
#
# species specie
# land land
#
#
#
# ocean ocean
# , ,
#
#
#
# experiments experiment
# succeed succeed
#
#
#
# know know
#
#
#
# million million
# years year
# . .
#
#
#
#
#
# patient patient
# , ,
#
#
#
# immortal immortal
# . .
#
#
#
# Universe Universe
#
#
#
# billion billion
# stars star
# . .
#
#
#
# set set
# forth forth
#
#
#
# abyss abyss
# , ,
# knowing know
#
#
#
# come come
# way way
# . .
#
#
#
#
#
# need need
# . .
#
#
#
# wonderful wonderful
# machines machine
#
#
#
# trusted trust
# rest rest
# . .
#
#
#
# ( (
# con't con't
# ) )
#
#
#
#
#
# 12/9/65 12/9/65
#
# d3 d3
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
#
#
# NARRATOR narrator
# ( (
# con't con't
# ) )
#
#
#
# Earth Earth
# , ,
# glaciers glacier
# came come
#
#
#
# went go
# , ,
# , ,
#
#
#
# changeless changeless
# Moon Moon
# carried carry
#
#
#
# secret secret
# . .
#
#
#
#
#
# slower slow
# rhythm rhythm
#
#
#
# Polar Polar
# ice ice
# , ,
# tide tide
#
#
#
# civilization civilization
# ebbed ebb
# flowed flow
#
#
#
# galaxy galaxy
# . .
#
#
#
#
#
# Strange strange
# beautiful beautiful
# terrible terrible
#
#
#
# empires empire
# rose rise
# fell fall
# , ,
# passed pass
#
#
#
# knowledge knowledge
#
#
#
# successors successor
# . .
#
#
#
#
#
# Earth Earth
# forgotten forget
# , ,
#
#
#
# million million
# silent silent
# worlds world
# , ,
#
#
#
# speak speak
# . .
#
#
#
#
#
# explorers explorer
# Earth Earth
# , ,
#
#
#
# recognising recognise
# limitations limitation
#
#
#
# minds mind
# bodies body
# , ,
# passed pass
#
#
#
# knowledge knowledge
# great great
#
#
#
# machines machine
# created create
# , ,
#
#
#
# trnscended trnscende
#
#
#
# way way
# . .
#
#
#
# ( (
# con't con't
# ) )
#
#
#
#
#
# 12/9/65 12/9/65
#
# d4 d4
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
#
#
# NARRATOR NARRATOR
#
#
#
# thousand thousand
# years year
# , ,
#
#
#
# shared share
# Universe Universe
#
#
#
# machine machine
# children child
# ; ;
# , ,
# realizing realize
#
#
#
# folly folly
# linger linger
#
#
#
# task task
# , ,
# passed pass
#
#
#
# history history
# regret regret
# . .
#
#
#
#
#
# looked look
#
#
#
# eyes eye
# planet planet
# Earth Earth
#
#
#
# . .
#
#
#
#
#
# age age
# Machine Machine
#
#
#
# Entities Entities
# passed pass
# swiftly swiftly
# . .
#
#
#
# ceaseless ceaseless
# experimenting experiment
# , ,
#
#
#
# learned learn
# store store
# knowledge knowledge
#
#
#
# structure structure
# space space
# , ,
#
#
#
# preserve preserve
# thoughts thought
#
#
#
# eternity eternity
# frozen frozen
# lattices lattice
#
#
#
# light light
# . .
#
#
#
# creatures creature
# radiation radiation
# , ,
# free free
#
#
#
# tyranny tyranny
# matter matter
# . .
#
#
#
#
#
# , ,
# Lords lord
#
#
#
# galaxy galaxy
# , ,
# reach reach
#
#
#
# time time
# . .
#
#
#
#
#
# rove rove
#
#
#
# stars star
# , ,
# sink sink
# like like
# subtle subtle
# mist mist
#
#
#
# interstices interstice
#
#
#
# space space
# . .
#
#
#
#
#
# 12/9/65 12/9/65
#
# d5 d5
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
#
#
# NARRATOR narrator
# ( (
# con't con't
# ) )
#
#
#
# despite despite
# God God
# - -
# like like
# powers power
# , ,
#
#
#
# watched watch
#
#
#
# experiments experiment
# ancestors ancestor
#
#
#
# started start
# generations generation
#
#
#
# ago ago
# . .
#
#
#
#
#
# companion companion
# Saturn Saturn
# knew know
#
#
#
# , ,
# orbited orbit
#
#
#
# man man
# land land
# Mimas Mimas
#
#
#
# outer outer
# edge edge
# rings ring
# . .
#
#
#
#
#
# remember remember
# wait wait
# , ,
#
#
#
# look look
# forever forever
# Sunward Sunward
#
#
#
# strange strange
# senses sense
# . .
#
#
#
#
#
# weeks week
# , ,
# watched watch
#
#
#
# approaching approach
# ship ship
# . .
# long- long-
#
#
#
# dead dead
# makers maker
# prepared prepare
#
#
#
# things thing
#
#
#
# . .
# recognised recognise
#
#
#
# climbing climb
# starward starward
#
#
#
# Sun Sun
# . .
#
#
#
#
#
# alive alive
# , ,
#
#
#
# felt feel
# excitement excitement
# , ,
#
#
#
# emotion emotion
# irrelevant irrelevant
#
#
#
# great great
# powers power
# . .
#
#
#
# ( (
# con't con't
# ) )
#
#
#
# 12/9/65 12/9/65
#
# d6 d6
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
# NARRATOR NARRATOR
# ( (
# con't con't
# ) )
#
#
#
# ship ship
# passed pass
# , ,
#
#
#
# known know
#
#
#
# slightest slight
# trace trace
# disappointment disappointment
# . .
#
#
#
#
#
# waited wait
# million million
# years year
# ; ;
#
#
#
# prepared prepared
# wait wait
#
#
#
# eternity eternity
# . .
#
#
#
#
#
# Presently presently
# , ,
# felt feel
# gentle gentle
# touch touch
#
#
#
# radiations radiation
# , ,
# trying try
# probe probe
#
#
#
# secrets secret
# . .
#
#
#
#
#
# , ,
# ship ship
# orbit orbit
#
#
#
# began begin
# speak speak
# , ,
# prime prime
#
#
#
# numbers number
# , ,
#
#
#
# . .
#
#
#
#
#
# Soon soon
# , ,
# gave give
# way way
#
#
#
# complex complex
# signals signal
# frequen- frequen-
#
#
#
# cies cie
# , ,
# ultra ultra
# - -
# violet violet
# , ,
# infra infra
# - -
# red red
# , ,
#
#
#
# X X
# - -
# rays ray
# . .
#
#
#
#
#
# machine machine
# reply reply
# . .
#
#
#
# . .
#
#
#
#
#
# saw see
# robot robot
#
#
#
# probe probe
# , ,
# descended descend
#
#
#
# hovered hover
# chasm chasm
# . .
#
#
#
# ( (
# con't con't
# ) )
#
#
#
#
#
# 12/9/65 12/9/65
#
# d7 d7
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# D1 d1
#
#
#
# CONTINUED continued
#
#
#
#
#
# NARRATOR narrator
# ( (
# con't con't
# ) )
#
#
#
# , ,
# dropped drop
# darkness darkness
# . .
#
#
#
#
#
# great great
# machine machine
# knew know
#
#
#
# tiny tiny
# scout scout
# reporting report
#
#
#
# parent parent
# ; ;
# simple simple
# , ,
#
#
#
# primative primative
# device device
# detect detect
#
#
#
# forces force
# gathering gather
#
#
#
# round round
# . .
#
#
#
#
#
# pod pod
# came come
# , ,
# carrying carry
#
#
#
# life life
# . .
# great great
# machine machine
# searched search
#
#
#
# memories memory
# . .
#
#
#
#
#
# logic logic
# circuits circuit
#
#
#
# decision decision
# pod pod
# fallen fall
#
#
#
# faint faint
# glow glow
#
#
#
# reflected reflect
# Saturnian saturnian
# light light
# . .
#
#
#
#
#
# moment moment
# time time
# , ,
# short short
#
#
#
# measured measure
# , ,
# space space
# turned turn
#
#
#
# twisted twist
# . .
#
#
#
#
#
# 12/9/65 12/9/65
#
# d8 d8
#
#
#
# ------------------------------------------------------------------------ ------------------------------------------------------------------------
#
#
#
# END END
# SCREENPLAY screenplay
#
#
#
# END END
# FILE file

# %% [markdown]
# >> ##### spaCy (lemmatization) is preferred and referred for processing by NIIT!

# %% [markdown]
# ### 2. Stemming
# #### It might be surprising to you but spaCy doesn't contain any function for stemming as it relies on lemmatization only. Therefore, in this section, we will use NLTK for stemming.

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.0.1)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.4.24-cp310-cp310-win_amd64.whl (262 kB)
#      -------------------------------------- 262.0/262.0 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.2)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.7 regex-2022.4.24

# %%
import nltk                                                                                 # import nltk library
from nltk.stem.snowball import SnowballStemmer                                              # import stemmer
stemmer = SnowballStemmer(language='english')                                               # English language model
tokens = ['friend', 'friendship', 'studied', 'was', 'am', 'is', 'helped', 'troubling']      # Input words
for token in tokens:                                                                        # For all words
    print(token + ' --> ' + stemmer.stem(token))                                            # print words after stemming
# Out:
# friend --> friend
# friendship --> friendship
# studied --> studi
# was --> was
# am --> am
# is --> is
# helped --> help
# troubling --> troubl

# %% [markdown]
# ## Comparison: Stemming and Lemmatization

# %%
stemmer = SnowballStemmer(language='english')                                                # import stemmer
tokens = ['cries', 'this', 'lied', 'compute', 'computer', 'computed', 'computing', 'organizing', 'matches']   # Input words
for token in tokens:                                                                         # For all words
    print('After stemming:',token + ' --> ' + stemmer.stem(token))                           # Print result after stemming
doc = nlp("cries this lied compute computer computed computing organizing matches")          # For lemmatization
print('\n')                                                                                  # print empty line for differentiating
for word in doc:                                                                             # For all words
    print('After lemmatization:',word.text,word.lemma_)                                      # Print result after lemmatization
# Out:
# After stemming: cries --> cri
# After stemming: this --> this
# After stemming: lied --> lie
# After stemming: compute --> comput
# After stemming: computer --> comput
# After stemming: computed --> comput
# After stemming: computing --> comput
# After stemming: organizing --> organ
# After stemming: matches --> match
#
#
# After lemmatization: cries cry
# After lemmatization: this this
# After lemmatization: lied lie
# After lemmatization: compute compute
# After lemmatization: computer computer
# After lemmatization: computed compute
# After lemmatization: computing compute
# After lemmatization: organizing organize
# After lemmatization: matches match

# %% [markdown]
# ### As we can see, lemmatization provides better results than stemming for converting words into their root forms.

# %% [markdown]
# # Demo3
# # Part of Speech (POS) Tagging

# %% [markdown]
# ### 1. For a simple sentence

# %%
doc = nlp("All is well that ends well.")                # Input sentence
for word in doc:                                        # For all input words
    print(word.text,'\t',word.pos_,'\t',word.tag_)      # Apply POS and print output
# Out:
# All 	 PRON 	 DT
# is 	 AUX 	 VBZ
# well 	 ADV 	 RB
# that 	 PRON 	 DT
# ends 	 VERB 	 VBZ
# well 	 ADV 	 RB
# . 	 PUNCT 	 .

# %% [markdown]
# #### 1st column: original word, 2nd col: POS tag, 3rd col: Detailed POS tag. More details about the POS tags are provided in the concept session.

# %% [markdown]
# ### 2. Example2

# %%
doc = nlp("Apple is looking at buying U.K. startup for 1 billion dollars.")       # Input sentence
for word in doc:                                                                  # For all input words
    print(word.text,'\t',word.pos_,'\t',word.tag_)                                # Apply POS and print output
# Out:
# Apple 	 PROPN 	 NNP
# is 	 AUX 	 VBZ
# looking 	 VERB 	 VBG
# at 	 ADP 	 IN
# buying 	 VERB 	 VBG
# U.K. 	 PROPN 	 NNP
# startup 	 NOUN 	 NN
# for 	 ADP 	 IN
# 1 	 NUM 	 CD
# billion 	 NUM 	 CD
# dollars 	 NOUN 	 NNS
# . 	 PUNCT 	 .

# %% [markdown]
# #### For Apple: POS: PROPN: Proper Noun, Tag: NNP: Proper Noun, singular

# %% [markdown]
# ### 3. For the whole text document

# %%
f = open('scifiscripts.txt')
contents = f.read()                                                             # Read input data
text = str(contents)                                                            # string type
doc = nlp(text)                                                                 # convert to NLP object
for word in doc:                                                                # For all input words
    print(word.text,'\t',word.pos_,'\t',word.tag_)                              # Apply POS and print output
# Out:
# Note 	 VERB 	 VB
# from 	 ADP 	 IN
# poster 	 NOUN 	 NN
# to 	 ADP 	 IN
# Kubrick 	 PROPN 	 NNP
# newsgroup 	 PROPN 	 NNP
# : 	 PUNCT 	 :
#
#
#  	 SPACE 	 _SP
# I 	 PRON 	 PRP
# found 	 VERB 	 VBD
# this 	 PRON 	 DT
# on 	 ADP 	 IN
# a 	 DET 	 DT
# bbs 	 NOUN 	 NN
# a 	 DET 	 DT
# while 	 NOUN 	 NN
# ago 	 ADV 	 RB
# and 	 CCONJ 	 CC
# I 	 PRON 	 PRP
# thought 	 VERB 	 VBD
# I 	 PRON 	 PRP
# 'd 	 AUX 	 MD
# pass 	 VERB 	 VB
# it 	 PRON 	 PRP
# along 	 ADP 	 RP
# to 	 ADP 	 IN
# all 	 DET 	 DT
#
#  	 SPACE 	 _SP
# of 	 ADP 	 IN
# you 	 PRON 	 PRP
# Kubrick 	 PROPN 	 NNP
# freaks 	 VERB 	 VBZ
# out 	 ADP 	 RP
# there 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 02/23/89 	 NUM 	 CD
#
#  	 SPACE 	 _SP
# Transcriber 	 PROPN 	 NNP
# 's 	 PART 	 POS
# note 	 NOUN 	 NN
# : 	 PUNCT 	 :
#
#
#  	 SPACE 	 _SP
# For 	 ADP 	 IN
# all 	 DET 	 DT
# you 	 PRON 	 PRP
# Clarke 	 PROPN 	 NNP
# / 	 SYM 	 SYM
# Kubrick/2001 	 PROPN 	 NNP
# fans 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
#
#
#  	 SPACE 	 _SP
# I 	 PRON 	 PRP
# found 	 VERB 	 VBD
# the 	 DET 	 DT
# original 	 ADJ 	 JJ
# paper 	 NOUN 	 NN
# copy 	 NOUN 	 NN
# of 	 ADP 	 IN
# this 	 DET 	 DT
# screenplay 	 NOUN 	 NN
# a 	 DET 	 DT
# while 	 NOUN 	 NN
# back 	 ADV 	 RB
# and 	 CCONJ 	 CC
# felt 	 AUX 	 VBD
#
#  	 SPACE 	 _SP
# compelled 	 VERB 	 VBN
# to 	 PART 	 TO
# transcribe 	 VERB 	 VB
# it 	 PRON 	 PRP
# to 	 AUX 	 IN
# disk 	 VERB 	 VB
# and 	 CCONJ 	 CC
# upload 	 VERB 	 VB
# it 	 PRON 	 PRP
# to 	 ADP 	 IN
# various 	 ADJ 	 JJ
# bulletin 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# boards 	 NOUN 	 NNS
# for 	 ADP 	 IN
# the 	 DET 	 DT
# enjoyment 	 NOUN 	 NN
# of 	 ADP 	 IN
# all 	 PRON 	 DT
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# final 	 ADJ 	 JJ
# movie 	 NOUN 	 NN
# deviates 	 VERB 	 VBZ
# from 	 ADP 	 IN
# this 	 DET 	 DT
# screenplay 	 NOUN 	 NN
# in 	 ADP 	 IN
# a 	 DET 	 DT
# number 	 NOUN 	 NN
# of 	 ADP 	 IN
# interesting 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# ways 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# I 	 PRON 	 PRP
# 've 	 AUX 	 VBP
# tried 	 VERB 	 VBN
# to 	 PART 	 TO
# maintain 	 VERB 	 VB
# the 	 DET 	 DT
# format 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# original 	 ADJ 	 JJ
# document 	 NOUN 	 NN
# except 	 SCONJ 	 IN
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# number 	 NOUN 	 NN
# of 	 ADP 	 IN
# lines 	 NOUN 	 NNS
# per 	 ADP 	 IN
# page 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# original 	 ADJ 	 JJ
# . 	 PUNCT 	 .
# In 	 ADP 	 IN
# order 	 NOUN 	 NN
# to 	 PART 	 TO
# reduce 	 VERB 	 VB
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# length 	 NOUN 	 NN
# of 	 ADP 	 IN
# this 	 DET 	 DT
# file 	 NOUN 	 NN
# I 	 PRON 	 PRP
# 've 	 AUX 	 VBP
# used 	 VERB 	 VBN
# a 	 DET 	 DT
# bar 	 NOUN 	 NN
# of 	 ADP 	 IN
# " 	 PUNCT 	 ``
# ------ 	 PUNCT 	 .
# " 	 PUNCT 	 ''
# to 	 PART 	 TO
# delimit 	 VERB 	 VB
# the 	 DET 	 DT
# pages 	 NOUN 	 NNS
# as 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# there 	 PRON 	 EX
# was 	 AUX 	 VBD
# a 	 DET 	 DT
# lot 	 NOUN 	 NN
# of 	 ADP 	 IN
# whitespace 	 NOUN 	 NN
# per 	 ADP 	 IN
# original 	 ADJ 	 JJ
# screenplay 	 NOUN 	 NN
# page 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 PUNCT 	 :
#
#
# 				     	 SPACE 	 _SP
# 2001 	 NUM 	 CD
# : 	 PUNCT 	 :
# A 	 DET 	 DT
# SPACE 	 NOUN 	 NN
# ODYSSEY 	 NOUN 	 NN
#
#
# 					     	 SPACE 	 _SP
# Screenplay 	 PROPN 	 NNP
#
#
# 						    	 SPACE 	 _SP
# by 	 ADP 	 IN
#
#
# 			    	 SPACE 	 _SP
# Stanley 	 PROPN 	 NNP
# Kubrick 	 PROPN 	 NNP
# and 	 CCONJ 	 CC
# Arthur 	 PROPN 	 NNP
# C. 	 PROPN 	 NNP
# Clark 	 PROPN 	 NNP
#
#
# 					     	 SPACE 	 _SP
# Hawk 	 PROPN 	 NNP
# Films 	 PROPN 	 NNPS
# Ltd. 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# c 	 NOUN 	 NN
# / 	 SYM 	 SYM
# o. 	 PROPN 	 NNP
# M 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# G 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# M 	 PROPN 	 NNP
# Studios 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# Boreham 	 PROPN 	 NNP
# Wood 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# Herts 	 PROPN 	 NNPS
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#
#  	 SPACE 	 _SP
# TITLE 	 NOUN 	 NNS
# 					     	 SPACE 	 _SP
# PART 	 PROPN 	 NNP
# I 	 NOUN 	 NN
#
# 					     	 SPACE 	 _SP
# AFRICA 	 PROPN 	 NNP
#
# 					     	 SPACE 	 _SP
# 3,000,000 	 NUM 	 CD
# YEARS 	 NOUN 	 NNS
# AGO 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A1 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# VIEWS 	 NOUN 	 NNS
# OF 	 ADP 	 IN
# AFRICAN 	 PROPN 	 NNP
# DRYLANDS 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# DROUGHT 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# remorseless 	 NOUN 	 NN
# drought 	 NOUN 	 NN
# had 	 AUX 	 VBD
# lasted 	 VERB 	 VBN
# now 	 ADV 	 RB
# for 	 ADP 	 IN
# ten 	 NUM 	 CD
# million 	 NUM 	 CD
# years 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# would 	 AUX 	 MD
# not 	 PART 	 RB
# end 	 VERB 	 VB
# for 	 ADP 	 IN
# another 	 DET 	 DT
# million 	 NUM 	 CD
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# reign 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# ter- 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# rible 	 NOUN 	 NN
# lizards 	 NOUN 	 NNS
# had 	 AUX 	 VBD
# long 	 ADV 	 RB
# since 	 ADV 	 RB
# passed 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# here 	 ADV 	 RB
# on 	 ADP 	 IN
# the 	 DET 	 DT
# continent 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# which 	 PRON 	 WDT
# would 	 AUX 	 MD
# one 	 NUM 	 CD
# day 	 NOUN 	 NN
# be 	 AUX 	 VB
# known 	 VERB 	 VBN
# as 	 ADP 	 IN
# Africa 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# battle 	 NOUN 	 NN
# for 	 ADP 	 IN
# survival 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# had 	 AUX 	 VBD
# reached 	 VERB 	 VBN
# a 	 DET 	 DT
# new 	 ADJ 	 JJ
# climax 	 NOUN 	 NN
# of 	 ADP 	 IN
# ferocity 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# the 	 DET 	 DT
# victor 	 NOUN 	 NN
# was 	 AUX 	 VBD
# not 	 PART 	 RB
#
#  	 SPACE 	 _SP
# yet 	 ADV 	 RB
# in 	 ADP 	 IN
# sight 	 NOUN 	 NN
# . 	 PUNCT 	 .
# In 	 ADP 	 IN
# this 	 DET 	 DT
# dry 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# barren 	 ADJ 	 JJ
# land 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# only 	 ADV 	 RB
# the 	 DET 	 DT
# small 	 ADJ 	 JJ
# or 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# swift 	 NOUN 	 NN
# or 	 CCONJ 	 CC
# the 	 DET 	 DT
# fierce 	 ADJ 	 JJ
# could 	 AUX 	 MD
# flourish 	 VERB 	 VB
# , 	 PUNCT 	 ,
# or 	 CCONJ 	 CC
# even 	 ADV 	 RB
# hope 	 VERB 	 VBP
# to 	 PART 	 TO
# exist 	 VERB 	 VB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a1 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A2 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# INT 	 PROPN 	 NNP
# & 	 CCONJ 	 CC
# EXT 	 PROPN 	 NNP
# CAVES 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# MOONWATCHER 	 NOUN 	 NN
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# man 	 NOUN 	 NN
# - 	 PUNCT 	 HYPH
# apes 	 NOUN 	 NNS
# of 	 ADP 	 IN
# the 	 DET 	 DT
# field 	 NOUN 	 NN
# had 	 VERB 	 VBD
# none 	 NOUN 	 NN
# of 	 ADP 	 IN
# these 	 DET 	 DT
# attributes 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# they 	 PRON 	 PRP
# were 	 AUX 	 VBD
# on 	 ADP 	 IN
# the 	 DET 	 DT
# long 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# pathetic 	 ADJ 	 JJ
# road 	 NOUN 	 NN
# to 	 ADP 	 IN
# racial 	 ADJ 	 JJ
# extinction 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# About 	 ADV 	 RB
# twenty 	 NUM 	 CD
# of 	 ADP 	 IN
# them 	 PRON 	 PRP
# occupied 	 VERB 	 VBD
# a 	 DET 	 DT
# group 	 NOUN 	 NN
# of 	 ADP 	 IN
# caves 	 NOUN 	 NNS
# overlooking 	 VERB 	 VBG
#
#  	 SPACE 	 _SP
# a 	 DET 	 DT
# small 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# parched 	 VERB 	 VBN
# valley 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# divided 	 VERB 	 VBN
# by 	 ADP 	 IN
# a 	 DET 	 DT
# sluggish 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# brown 	 ADJ 	 JJ
# stream 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# tribe 	 NOUN 	 NN
# had 	 AUX 	 VBD
# always 	 ADV 	 RB
# been 	 AUX 	 VBN
# hungry 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# now 	 ADV 	 RB
# it 	 PRON 	 PRP
# was 	 AUX 	 VBD
# starving 	 VERB 	 VBG
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# As 	 SCONJ 	 IN
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# dim 	 ADJ 	 JJ
# glow 	 NOUN 	 NN
# of 	 ADP 	 IN
# dawn 	 NOUN 	 NN
# creeps 	 NOUN 	 NNS
# into 	 ADP 	 IN
# the 	 DET 	 DT
# cave 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# discovers 	 VERB 	 VBZ
# that 	 PRON 	 WDT
# his 	 PRON 	 PRP$
# father 	 NOUN 	 NN
# has 	 AUX 	 VBZ
# died 	 VERB 	 VBN
# during 	 ADP 	 IN
# the 	 DET 	 DT
# night 	 NOUN 	 NN
# . 	 PUNCT 	 .
# He 	 PRON 	 PRP
# did 	 AUX 	 VBD
# not 	 PART 	 RB
# know 	 VERB 	 VB
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# Old 	 PROPN 	 NNP
# One 	 PROPN 	 NNP
# was 	 AUX 	 VBD
# his 	 PRON 	 PRP$
# father 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# for 	 SCONJ 	 IN
# such 	 DET 	 PDT
# a 	 DET 	 DT
# relationship 	 NOUN 	 NN
# was 	 AUX 	 VBD
# beyond 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# his 	 PRON 	 PRP$
# understanding 	 NOUN 	 NN
# . 	 PUNCT 	 .
# but 	 CCONJ 	 CC
# as 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# stands 	 AUX 	 VBZ
# looking 	 VERB 	 VBG
# down 	 ADP 	 RP
# at 	 ADP 	 IN
# the 	 DET 	 DT
# emac- 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# iated 	 ADJ 	 JJ
# body 	 NOUN 	 NN
# he 	 PRON 	 PRP
# feels 	 VERB 	 VBZ
# something 	 PRON 	 NN
# , 	 PUNCT 	 ,
# something 	 PRON 	 NN
# akin 	 ADJ 	 JJ
# to 	 ADP 	 IN
# sadness 	 NOUN 	 NN
# . 	 PUNCT 	 .
# Then 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# he 	 PRON 	 PRP
# carries 	 VERB 	 VBZ
# his 	 PRON 	 PRP$
# dead 	 ADJ 	 JJ
# father 	 NOUN 	 NN
# out 	 ADP 	 IN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# cave 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# leaves 	 VERB 	 VBZ
# him 	 PRON 	 PRP
# for 	 ADP 	 IN
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# hyenas 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Among 	 ADP 	 IN
# his 	 PRON 	 PRP$
# kind 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
# is 	 AUX 	 VBZ
# almost 	 ADV 	 RB
# a 	 DET 	 DT
# giant 	 NOUN 	 NN
# . 	 PUNCT 	 .
# He 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# nearly 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# five 	 NUM 	 CD
# feet 	 NOUN 	 NNS
# high 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# though 	 SCONJ 	 IN
# badly 	 ADV 	 RB
# undernourished 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# weighs 	 NOUN 	 NNS
# over 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# a 	 DET 	 DT
# hundred 	 NUM 	 CD
# pounds 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# His 	 PRON 	 PRP$
# hairy 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# muscular 	 ADJ 	 JJ
# body 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# quite 	 ADV 	 RB
# man 	 NOUN 	 NN
# - 	 PUNCT 	 HYPH
# like 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# his 	 PRON 	 PRP$
# head 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# already 	 ADV 	 RB
# nearer 	 ADJ 	 JJR
# man 	 NOUN 	 NN
# than 	 ADP 	 IN
# ape 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# forehead 	 NOUN 	 NN
# is 	 AUX 	 VBZ
#
#  	 SPACE 	 _SP
# low 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# there 	 PRON 	 EX
# are 	 VERB 	 VBP
# great 	 ADJ 	 JJ
# ridges 	 NOUN 	 NNS
# over 	 ADP 	 IN
# the 	 DET 	 DT
# eye 	 NOUN 	 NN
# - 	 PUNCT 	 HYPH
# sockets 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# yet 	 CCONJ 	 CC
# he 	 PRON 	 PRP
#
#  	 SPACE 	 _SP
# unmistakably 	 ADV 	 RB
# holds 	 VERB 	 VBZ
# in 	 ADP 	 IN
# his 	 PRON 	 PRP$
# genes 	 NOUN 	 NNS
# the 	 DET 	 DT
# promise 	 NOUN 	 NN
# of 	 ADP 	 IN
# humanity 	 NOUN 	 NN
# . 	 PUNCT 	 .
# As 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# he 	 PRON 	 PRP
# looks 	 VERB 	 VBZ
# out 	 ADP 	 RP
# now 	 ADV 	 RB
# upon 	 SCONJ 	 IN
# the 	 DET 	 DT
# hostile 	 ADJ 	 JJ
# world 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# there 	 PRON 	 EX
# is 	 VERB 	 VBZ
# already 	 ADV 	 RB
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 NUM 	 CD
# 										  	 SPACE 	 _SP
# a2 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 X 	 XX
#
#  	 SPACE 	 _SP
# A2 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
#  	 SPACE 	 _SP
# something 	 PRON 	 NN
# in 	 ADP 	 IN
# his 	 PRON 	 PRP$
# gaze 	 NOUN 	 NN
# beyond 	 ADP 	 IN
# the 	 DET 	 DT
# grasp 	 NOUN 	 NN
# of 	 ADP 	 IN
# any 	 DET 	 DT
# ape 	 NOUN 	 NN
# . 	 PUNCT 	 .
# In 	 ADP 	 IN
# those 	 DET 	 DT
#
#  	 SPACE 	 _SP
# dark 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# deep 	 ADJ 	 JJ
# - 	 PUNCT 	 HYPH
# set 	 VERB 	 VBN
# eyes 	 NOUN 	 NNS
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# dawning 	 VERB 	 VBG
# awareness 	 NOUN 	 NN
# - 	 PUNCT 	 :
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# intima- 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# tions 	 NOUN 	 NNS
# of 	 ADP 	 IN
# an 	 DET 	 DT
# intelligence 	 NOUN 	 NN
# which 	 PRON 	 WDT
# would 	 AUX 	 MD
# not 	 PART 	 RB
# fulfill 	 VERB 	 VB
# itself 	 PRON 	 PRP
# for 	 ADP 	 IN
# another 	 DET 	 DT
#
#  	 SPACE 	 _SP
# two 	 NUM 	 CD
# million 	 NUM 	 CD
# years 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a3 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A3 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# THE 	 DET 	 DT
# STREAM 	 PROPN 	 NNP
# - 	 PUNCT 	 :
# THE 	 DET 	 DT
# OTHERS 	 NOUN 	 NNS
#
#
#  	 SPACE 	 _SP
# As 	 ADP 	 IN
# the 	 DET 	 DT
# dawn 	 NOUN 	 NN
# sky 	 NOUN 	 NN
# brightens 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
# and 	 CCONJ 	 CC
# his 	 PRON 	 PRP$
# tribe 	 NOUN 	 NN
# reach 	 VERB 	 VB
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# shallow 	 ADJ 	 JJ
# stream 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# Others 	 PROPN 	 NNPS
# are 	 AUX 	 VBP
# already 	 ADV 	 RB
# there 	 ADV 	 RB
# . 	 PUNCT 	 .
# They 	 PRON 	 PRP
# were 	 AUX 	 VBD
# there 	 ADV 	 RB
# on 	 ADP 	 IN
# the 	 DET 	 DT
# other 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# side 	 NOUN 	 NN
# every 	 DET 	 DT
# day 	 NOUN 	 NN
# - 	 PUNCT 	 :
# that 	 PRON 	 DT
# did 	 AUX 	 VBD
# not 	 PART 	 RB
# make 	 VERB 	 VB
# it 	 PRON 	 PRP
# any 	 PRON 	 DT
# less 	 ADV 	 RBR
# annoying 	 ADJ 	 JJ
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# There 	 PRON 	 EX
# are 	 VERB 	 VBP
# eighteen 	 NUM 	 CD
# of 	 ADP 	 IN
# them 	 PRON 	 PRP
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# it 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# impossible 	 ADJ 	 JJ
# to 	 PART 	 TO
# distinguish 	 VERB 	 VB
#
#  	 SPACE 	 _SP
# them 	 PRON 	 PRP
# from 	 ADP 	 IN
# the 	 DET 	 DT
# members 	 NOUN 	 NNS
# of 	 ADP 	 IN
# Moonwatcher 	 PROPN 	 NNP
# 's 	 PART 	 POS
# own 	 ADJ 	 JJ
# tribe 	 NOUN 	 NN
# . 	 PUNCT 	 .
# As 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# they 	 PRON 	 PRP
# see 	 VERB 	 VBP
# him 	 PRON 	 PRP
# coming 	 VERB 	 VBG
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# Others 	 NOUN 	 NNS
# begin 	 VERB 	 VBP
# to 	 PART 	 TO
# angrily 	 ADV 	 RB
# dance 	 VERB 	 VB
# and 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# shriek 	 NOUN 	 NN
# on 	 ADP 	 IN
# their 	 PRON 	 PRP$
# side 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# stream 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# his 	 PRON 	 PRP$
# own 	 ADJ 	 JJ
# people 	 NOUN 	 NNS
# reply 	 VERB 	 VBP
#
#  	 SPACE 	 _SP
# In 	 ADP 	 IN
# kind 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# confrontation 	 NOUN 	 NN
# lasts 	 VERB 	 VBZ
# a 	 DET 	 DT
# few 	 ADJ 	 JJ
# minutes 	 NOUN 	 NNS
# - 	 PUNCT 	 :
# then 	 ADV 	 RB
# the 	 DET 	 DT
# display 	 NOUN 	 NN
# dies 	 VERB 	 VBZ
#
#  	 SPACE 	 _SP
# out 	 ADV 	 RB
# as 	 ADV 	 RB
# quickly 	 ADV 	 RB
# as 	 SCONJ 	 IN
# it 	 PRON 	 PRP
# has 	 AUX 	 VBZ
# begun 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# everyone 	 PRON 	 NN
# drinks 	 VERB 	 VBZ
# his 	 PRON 	 PRP$
# fill 	 NOUN 	 NN
# of 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# muddy 	 ADJ 	 JJ
# water 	 NOUN 	 NN
# . 	 PUNCT 	 .
# Honor 	 NOUN 	 NN
# has 	 AUX 	 VBZ
# been 	 AUX 	 VBN
# satisfied 	 ADJ 	 JJ
# - 	 PUNCT 	 :
# each 	 DET 	 DT
# group 	 NOUN 	 NN
# has 	 AUX 	 VBZ
#
#  	 SPACE 	 _SP
# staked 	 VERB 	 VBD
# its 	 PRON 	 PRP$
# claim 	 NOUN 	 NN
# to 	 ADP 	 IN
# its 	 PRON 	 PRP$
# own 	 ADJ 	 JJ
# territory 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a4 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A4 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# AFRICAN 	 PROPN 	 NNP
# PLAIN 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# HERBIVORES 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# Moonwatcher 	 PROPN 	 NNP
# and 	 CCONJ 	 CC
# his 	 PRON 	 PRP$
# companions 	 NOUN 	 NNS
# search 	 VERB 	 VBP
# for 	 ADP 	 IN
# berries 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# fruit 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# leaves 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# fight 	 VERB 	 VB
# off 	 ADP 	 RP
# pangs 	 NOUN 	 NNS
# of 	 ADP 	 IN
# hunger 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# while 	 SCONJ 	 IN
# all 	 ADV 	 RB
# around 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# them 	 PRON 	 PRP
# , 	 PUNCT 	 ,
# competing 	 VERB 	 VBG
# with 	 ADP 	 IN
# them 	 PRON 	 PRP
# for 	 ADP 	 IN
# the 	 DET 	 DT
# samr 	 PROPN 	 NNP
# fodder 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# potential 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# source 	 NOUN 	 NN
# of 	 ADP 	 IN
# more 	 ADJ 	 JJR
# food 	 NOUN 	 NN
# than 	 SCONJ 	 IN
# they 	 PRON 	 PRP
# could 	 AUX 	 MD
# ever 	 ADV 	 RB
# hope 	 VERB 	 VB
# to 	 PART 	 TO
# eat 	 VERB 	 VB
# . 	 PUNCT 	 .
# Yet 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# all 	 DET 	 PDT
# the 	 DET 	 DT
# thousands 	 NOUN 	 NNS
# of 	 ADP 	 IN
# tons 	 NOUN 	 NNS
# of 	 ADP 	 IN
# meat 	 NOUN 	 NN
# roaming 	 VERB 	 VBG
# over 	 ADP 	 IN
# the 	 DET 	 DT
# parched 	 VERB 	 VBN
#
#  	 SPACE 	 _SP
# savanna 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# through 	 ADP 	 IN
# the 	 DET 	 DT
# brush 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# not 	 PART 	 RB
# only 	 ADV 	 RB
# beyond 	 ADP 	 IN
# their 	 PRON 	 PRP$
# reach 	 NOUN 	 NN
# ; 	 PUNCT 	 :
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# idea 	 NOUN 	 NN
# of 	 ADP 	 IN
# eating 	 VERB 	 VBG
# it 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# beyond 	 ADP 	 IN
# their 	 PRON 	 PRP$
# imagination 	 NOUN 	 NN
# . 	 PUNCT 	 .
# They 	 PRON 	 PRP
# are 	 AUX 	 VBP
#
#  	 SPACE 	 _SP
# slowly 	 ADV 	 RB
# starving 	 VERB 	 VBG
# to 	 ADP 	 IN
# death 	 NOUN 	 NN
# in 	 ADP 	 IN
# the 	 DET 	 DT
# midst 	 NOUN 	 NN
# of 	 ADP 	 IN
# plenty 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a5 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A5 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# PARCHED 	 PROPN 	 NNP
# COUNTRYSIDE 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# THE 	 DET 	 DT
# LION 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# tribe 	 NOUN 	 NN
# slowly 	 ADV 	 RB
# wanders 	 VERB 	 VBZ
# across 	 ADP 	 IN
# the 	 DET 	 DT
# bare 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# flat 	 ADJ 	 JJ
# country- 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# side 	 NOUN 	 NN
# foraging 	 NOUN 	 NN
# for 	 ADP 	 IN
# roots 	 NOUN 	 NNS
# and 	 CCONJ 	 CC
# occasional 	 ADJ 	 JJ
# berries 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Eight 	 NUM 	 CD
# of 	 ADP 	 IN
# them 	 PRON 	 PRP
# are 	 AUX 	 VBP
# irregularly 	 ADV 	 RB
# strung 	 VERB 	 VBN
# out 	 ADP 	 RP
# on 	 ADP 	 IN
# the 	 DET 	 DT
# open 	 ADJ 	 JJ
# plain 	 NOUN 	 NN
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# about 	 ADP 	 IN
# fifty 	 NUM 	 CD
# feet 	 NOUN 	 NNS
# apart 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# ground 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# flat 	 ADJ 	 JJ
# for 	 ADP 	 IN
# miles 	 NOUN 	 NNS
# around 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Suddenly 	 ADV 	 RB
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
# becomes 	 VERB 	 VBZ
# aware 	 ADJ 	 JJ
# of 	 ADP 	 IN
# a 	 DET 	 DT
# lion 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# stalking 	 VERB 	 VBG
#
#  	 SPACE 	 _SP
# them 	 PRON 	 PRP
# about 	 ADV 	 RB
# 300 	 NUM 	 CD
# yards 	 NOUN 	 NNS
# away 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Defenceless 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# with 	 ADP 	 IN
# nowhere 	 ADV 	 RB
# to 	 PART 	 TO
# hide 	 VERB 	 VB
# , 	 PUNCT 	 ,
# they 	 PRON 	 PRP
# scatter 	 VERB 	 VBP
# in 	 ADP 	 IN
# all 	 DET 	 DT
#
#  	 SPACE 	 _SP
# directions 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# the 	 DET 	 DT
# lion 	 NOUN 	 NN
# brings 	 VERB 	 VBZ
# one 	 NUM 	 CD
# to 	 ADP 	 IN
# the 	 DET 	 DT
# ground 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a6 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A6 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# DEAD 	 PROPN 	 NNP
# TREE 	 NOUN 	 NN
# - 	 PUNCT 	 ,
# FINDS 	 ADJ 	 JJ
# HONEY 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# It 	 PRON 	 PRP
# had 	 AUX 	 VBD
# not 	 PART 	 RB
# been 	 AUX 	 VBN
# a 	 DET 	 DT
# good 	 ADJ 	 JJ
# day 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# though 	 SCONJ 	 IN
# as 	 SCONJ 	 IN
# Moonwatcher 	 PROPN 	 NNP
# had 	 VERB 	 VBD
# no 	 DET 	 DT
#
#  	 SPACE 	 _SP
# real 	 ADJ 	 JJ
# remembrance 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# past 	 NOUN 	 NN
# he 	 PRON 	 PRP
# could 	 AUX 	 MD
# not 	 PART 	 RB
# compare 	 VERB 	 VB
# one 	 NUM 	 CD
# day 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# with 	 ADP 	 IN
# another 	 PRON 	 DT
# . 	 PUNCT 	 .
# But 	 CCONJ 	 CC
# on 	 ADP 	 IN
# the 	 DET 	 DT
# way 	 NOUN 	 NN
# back 	 ADV 	 RB
# to 	 ADP 	 IN
# the 	 DET 	 DT
# caves 	 NOUN 	 NNS
# he 	 PRON 	 PRP
# finds 	 VERB 	 VBZ
# a 	 DET 	 DT
#
#  	 SPACE 	 _SP
# hive 	 NOUN 	 NN
# of 	 ADP 	 IN
# bees 	 NOUN 	 NNS
# in 	 ADP 	 IN
# the 	 DET 	 DT
# stump 	 NOUN 	 NN
# of 	 ADP 	 IN
# a 	 DET 	 DT
# dead 	 ADJ 	 JJ
# tree 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# so 	 ADV 	 RB
# enjoys 	 VERB 	 VBZ
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# finest 	 ADJ 	 JJS
# delicacy 	 NOUN 	 NN
# his 	 PRON 	 PRP$
# people 	 NOUN 	 NNS
# could 	 AUX 	 MD
# ever 	 ADV 	 RB
# know 	 VERB 	 VB
# . 	 PUNCT 	 .
# Of 	 ADV 	 RB
# course 	 ADV 	 RB
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
#
#  	 SPACE 	 _SP
# also 	 ADV 	 RB
# collects 	 VERB 	 VBZ
# a 	 DET 	 DT
# good 	 ADJ 	 JJ
# many 	 ADJ 	 JJ
# stings 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# he 	 PRON 	 PRP
# scacely 	 ADV 	 RB
# notices 	 VERB 	 VBZ
#
#  	 SPACE 	 _SP
# them 	 PRON 	 PRP
# . 	 PUNCT 	 .
# He 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# now 	 ADV 	 RB
# as 	 ADV 	 RB
# near 	 ADV 	 RB
# to 	 PART 	 TO
# contentment 	 VERB 	 VB
# as 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# ever 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# likely 	 ADJ 	 JJ
# to 	 PART 	 TO
# be 	 AUX 	 VB
# ; 	 PUNCT 	 :
# for 	 ADP 	 IN
# thought 	 VERB 	 VBD
# he 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# still 	 ADV 	 RB
# hungry 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# not 	 PART 	 RB
# actually 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# weak 	 ADJ 	 JJ
# with 	 ADP 	 IN
# hunger 	 NOUN 	 NN
# . 	 PUNCT 	 .
# That 	 PRON 	 DT
# was 	 AUX 	 VBD
# the 	 DET 	 DT
# most 	 ADJ 	 JJS
# that 	 PRON 	 WDT
# any 	 DET 	 DT
# hominid 	 NOUN 	 NN
# could 	 AUX 	 MD
#
#  	 SPACE 	 _SP
# hope 	 VERB 	 VB
# for 	 ADP 	 IN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a7 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A7 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# INT 	 PROPN 	 NNP
# & 	 CCONJ 	 CC
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# CAVES 	 NOUN 	 NNS
# - 	 PUNCT 	 HYPH
# NIGHT 	 NOUN 	 NN
# TERRORS 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# Over 	 ADP 	 IN
# the 	 DET 	 DT
# valley 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# a 	 DET 	 DT
# full 	 ADJ 	 JJ
# moon 	 NOUN 	 NN
# rises 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# a 	 DET 	 DT
# cold 	 ADJ 	 JJ
# wind 	 NOUN 	 NN
# blows 	 VERB 	 VBZ
# down 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# from 	 ADP 	 IN
# the 	 DET 	 DT
# distant 	 ADJ 	 JJ
# mountains 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# It 	 PRON 	 PRP
# would 	 AUX 	 MD
# be 	 AUX 	 VB
# very 	 ADV 	 RB
# cold 	 ADJ 	 JJ
# tonight 	 NOUN 	 NN
# - 	 PUNCT 	 HYPH
#
#  	 SPACE 	 _SP
# but 	 CCONJ 	 CC
# cold 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# like 	 ADP 	 IN
# hunger 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# was 	 AUX 	 VBD
# not 	 PART 	 RB
# a 	 DET 	 DT
# matter 	 NOUN 	 NN
# for 	 ADP 	 IN
# any 	 DET 	 DT
# real 	 ADJ 	 JJ
# concern 	 NOUN 	 NN
# ; 	 PUNCT 	 :
#
#  	 SPACE 	 _SP
# it 	 PRON 	 PRP
# was 	 AUX 	 VBD
# merely 	 ADV 	 RB
# part 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# background 	 NOUN 	 NN
# of 	 ADP 	 IN
# life 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# This 	 DET 	 DT
# Little 	 PROPN 	 NNP
# Sun 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
# that 	 PRON 	 WDT
# only 	 ADV 	 RB
# shone 	 VERB 	 VBD
# at 	 ADP 	 IN
# night 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# gave 	 VERB 	 VBD
# no 	 DET 	 DT
# warmth 	 NOUN 	 NN
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# was 	 AUX 	 VBD
# dangerous 	 ADJ 	 JJ
# ; 	 PUNCT 	 :
# there 	 PRON 	 EX
# would 	 AUX 	 MD
# be 	 AUX 	 VB
# enemies 	 NOUN 	 NNS
# abroad 	 ADV 	 RB
# . 	 PUNCT 	 .
# Moonwatcher 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# crawls 	 VERB 	 VBZ
# out 	 ADP 	 IN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# cave 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# clambers 	 NOUN 	 NNS
# on 	 ADP 	 IN
# to 	 ADP 	 IN
# a 	 DET 	 DT
# large 	 ADJ 	 JJ
# boulder 	 NOUN 	 NN
# besides 	 SCONJ 	 IN
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# entrance 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# squats 	 NOUN 	 NNS
# there 	 ADV 	 RB
# where 	 SCONJ 	 WRB
# he 	 PRON 	 PRP
# can 	 AUX 	 MD
# survey 	 VERB 	 VB
# the 	 DET 	 DT
# valley 	 PROPN 	 NNP
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# If 	 SCONJ 	 IN
# any 	 DET 	 DT
# hunting 	 VERB 	 VBG
# beast 	 NOUN 	 NN
# approached 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
# would 	 AUX 	 MD
# have 	 VERB 	 VB
# time 	 NOUN 	 NN
# to 	 PART 	 TO
# get 	 VERB 	 VB
# back 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# to 	 ADP 	 IN
# the 	 DET 	 DT
# relative 	 ADJ 	 JJ
# safety 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# cave 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Of 	 ADP 	 IN
# all 	 DET 	 PDT
# the 	 DET 	 DT
# creatures 	 NOUN 	 NNS
# who 	 PRON 	 WP
# had 	 AUX 	 VBD
# ever 	 ADV 	 RB
# lived 	 VERB 	 VBN
# on 	 ADP 	 IN
# Earth 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
# 's 	 PART 	 POS
#
#  	 SPACE 	 _SP
# race 	 NOUN 	 NN
# was 	 AUX 	 VBD
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# to 	 PART 	 TO
# raise 	 VERB 	 VB
# their 	 PRON 	 PRP$
# eyes 	 NOUN 	 NNS
# with 	 ADP 	 IN
# interest 	 NOUN 	 NN
# to 	 ADP 	 IN
# the 	 DET 	 DT
# Moon 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# though 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# could 	 AUX 	 MD
# not 	 PART 	 RB
# remember 	 VERB 	 VB
# it 	 PRON 	 PRP
# , 	 PUNCT 	 ,
# when 	 SCONJ 	 WRB
# he 	 PRON 	 PRP
# was 	 AUX 	 VBD
# young 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# Moonwatcher 	 PROPN 	 NNP
# would 	 AUX 	 MD
# reach 	 VERB 	 VB
# out 	 ADP 	 RP
# and 	 CCONJ 	 CC
# try 	 VERB 	 VB
# to 	 PART 	 TO
# touch 	 VERB 	 VB
# its 	 PRON 	 PRP$
# ghostly 	 ADJ 	 JJ
# face 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# Now 	 ADV 	 RB
# he 	 PRON 	 PRP
# new 	 ADJ 	 JJ
# he 	 PRON 	 PRP
# would 	 AUX 	 MD
# have 	 VERB 	 VB
# to 	 PART 	 TO
# find 	 VERB 	 VB
# a 	 DET 	 DT
# tree 	 NOUN 	 NN
# that 	 PRON 	 WDT
# was 	 AUX 	 VBD
# high 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# enough 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# He 	 PRON 	 PRP
# stirs 	 VERB 	 VBZ
# when 	 SCONJ 	 WRB
# shrieks 	 NOUN 	 NNS
# and 	 CCONJ 	 CC
# screams 	 VERB 	 VBZ
# echo 	 VERB 	 VB
# up 	 ADP 	 RP
# the 	 DET 	 DT
# slope 	 NOUN 	 NN
# from 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# one 	 NUM 	 CD
# of 	 ADP 	 IN
# the 	 DET 	 DT
# lower 	 ADJ 	 JJR
# caves 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# he 	 PRON 	 PRP
# does 	 AUX 	 VBZ
# not 	 PART 	 RB
# need 	 VERB 	 VB
# to 	 PART 	 TO
# hear 	 VERB 	 VB
# the 	 DET 	 DT
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 NUM 	 CD
# 										  	 SPACE 	 _SP
# a8 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 X 	 XX
#
#  	 SPACE 	 _SP
# A7 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
#  	 SPACE 	 _SP
# occasional 	 ADJ 	 JJ
# growl 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# lion 	 NOUN 	 NN
# to 	 PART 	 TO
# know 	 VERB 	 VB
# what 	 PRON 	 WP
# is 	 AUX 	 VBZ
# happening 	 VERB 	 VBG
# . 	 PUNCT 	 .
# Down 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# there 	 ADV 	 RB
# in 	 ADP 	 IN
# the 	 DET 	 DT
# darkness 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# old 	 ADJ 	 JJ
# One 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# Eye 	 PROPN 	 NNP
# and 	 CCONJ 	 CC
# his 	 PRON 	 PRP$
# family 	 NOUN 	 NN
# are 	 AUX 	 VBP
# dying 	 VERB 	 VBG
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# the 	 DET 	 DT
# thought 	 NOUN 	 NN
# that 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# might 	 AUX 	 MD
# help 	 VERB 	 VB
# in 	 ADP 	 IN
# some 	 DET 	 DT
# way 	 NOUN 	 NN
# never 	 ADV 	 RB
# crosses 	 VERB 	 VBZ
#
#  	 SPACE 	 _SP
# Moonwatcher 	 PROPN 	 NNP
# 's 	 PART 	 POS
# mind 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# harsh 	 ADJ 	 JJ
# logic 	 NOUN 	 NN
# of 	 ADP 	 IN
# survival 	 NOUN 	 NN
# rules 	 VERB 	 VBZ
# out 	 ADP 	 RP
#
#  	 SPACE 	 _SP
# such 	 ADJ 	 JJ
# fancies 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# Every 	 DET 	 DT
# cave 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# silent 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# lest 	 SCONJ 	 IN
# it 	 PRON 	 PRP
# attract 	 VERB 	 VBP
# disaster 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# And 	 CCONJ 	 CC
# in 	 ADP 	 IN
# the 	 DET 	 DT
# caves 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# in 	 ADP 	 IN
# tortured 	 VERB 	 VBN
# spells 	 NOUN 	 NNS
# of 	 ADP 	 IN
# fitful 	 ADJ 	 JJ
# dozing 	 NOUN 	 NN
# and 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# fearful 	 ADJ 	 JJ
# waiting 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# were 	 AUX 	 VBD
# gathered 	 VERB 	 VBN
# the 	 DET 	 DT
# nightmares 	 NOUN 	 NNS
# of 	 ADP 	 IN
# generations 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# yet 	 ADV 	 RB
# to 	 PART 	 TO
# come 	 VERB 	 VB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a9 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 X 	 XX
#
#  	 SPACE 	 _SP
# A8 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# THE 	 DET 	 DT
# STREAM 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# INVASION 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# Others 	 PROPN 	 NNPS
# are 	 AUX 	 VBP
# growing 	 VERB 	 VBG
# desperate 	 ADJ 	 JJ
# ; 	 PUNCT 	 :
# the 	 DET 	 DT
# forage 	 NOUN 	 NN
# on 	 ADP 	 IN
# their 	 PRON 	 PRP$
# side 	 NOUN 	 NN
# of 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# valley 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# almost 	 ADV 	 RB
# exhausted 	 ADJ 	 JJ
# . 	 PUNCT 	 .
# Perhaps 	 ADV 	 RB
# they 	 PRON 	 PRP
# realise 	 VERB 	 VBP
# that 	 SCONJ 	 IN
#
#  	 SPACE 	 _SP
# Moonwatcher 	 PROPN 	 NNP
# 's 	 PART 	 POS
# tribe 	 NOUN 	 NN
# has 	 AUX 	 VBZ
# lost 	 VERB 	 VBN
# three 	 NUM 	 CD
# of 	 ADP 	 IN
# its 	 PRON 	 PRP$
# numbers 	 NOUN 	 NNS
# during 	 ADP 	 IN
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# night 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# for 	 SCONJ 	 IN
# they 	 PRON 	 PRP
# choose 	 VERB 	 VBP
# this 	 DET 	 DT
# mourning 	 NOUN 	 NN
# to 	 PART 	 TO
# break 	 VERB 	 VB
# the 	 DET 	 DT
# truce 	 NOUN 	 NN
# . 	 PUNCT 	 .
# When 	 SCONJ 	 WRB
#
#  	 SPACE 	 _SP
# they 	 PRON 	 PRP
# meet 	 VERB 	 VBP
# at 	 ADP 	 IN
# the 	 DET 	 DT
# river 	 NOUN 	 NN
# in 	 ADP 	 IN
# the 	 DET 	 DT
# still 	 ADV 	 RB
# , 	 PUNCT 	 ,
# misty 	 ADJ 	 JJ
# dawn 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# there 	 PRON 	 EX
# is 	 VERB 	 VBZ
# a 	 DET 	 DT
#
#  	 SPACE 	 _SP
# deeper 	 ADJ 	 JJR
# and 	 CCONJ 	 CC
# more 	 ADV 	 RBR
# menacing 	 ADJ 	 JJ
# note 	 NOUN 	 NN
# in 	 ADP 	 IN
# their 	 PRON 	 PRP$
# challenge 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# noisy 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# but 	 CCONJ 	 CC
# usually 	 ADV 	 RB
# harmless 	 ADJ 	 JJ
# confrontation 	 NOUN 	 NN
# lasts 	 VERB 	 VBZ
# only 	 ADV 	 RB
# a 	 DET 	 DT
# few 	 ADJ 	 JJ
# seconds 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# before 	 SCONJ 	 IN
# the 	 DET 	 DT
# invasion 	 NOUN 	 NN
# begins 	 VERB 	 VBZ
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# In 	 ADP 	 IN
# an 	 DET 	 DT
# uncertainly 	 ADV 	 RB
# - 	 PUNCT 	 HYPH
# moving 	 VERB 	 VBG
# horde 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# Others 	 PROPN 	 NNPS
# cross 	 VERB 	 VBP
# the 	 DET 	 DT
# river 	 NOUN 	 NN
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# shieking 	 NOUN 	 NN
# threats 	 NOUN 	 NNS
# and 	 CCONJ 	 CC
# hunched 	 VERB 	 VBN
# for 	 ADP 	 IN
# the 	 DET 	 DT
# attack 	 NOUN 	 NN
# . 	 PUNCT 	 .
# They 	 PRON 	 PRP
# are 	 AUX 	 VBP
# led 	 VERB 	 VBN
#
#  	 SPACE 	 _SP
# by 	 ADP 	 IN
# a 	 DET 	 DT
# big 	 ADJ 	 JJ
# - 	 PUNCT 	 HYPH
# toothed 	 ADJ 	 JJ
# hominid 	 NOUN 	 NN
# of 	 ADP 	 IN
# Moonwatcher 	 PROPN 	 NNP
# 's 	 PART 	 POS
# own 	 ADJ 	 JJ
# size 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# age 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Startled 	 VERB 	 VBP
# and 	 CCONJ 	 CC
# frightened 	 VERB 	 VBD
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# tribe 	 NOUN 	 NN
# retreats 	 VERB 	 VBZ
# before 	 ADP 	 IN
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# advance 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# throwing 	 VERB 	 VBG
# nothing 	 PRON 	 NN
# more 	 ADV 	 RBR
# substantial 	 ADJ 	 JJ
# than 	 ADP 	 IN
# imprecations 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# at 	 ADP 	 IN
# the 	 DET 	 DT
# invaders 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# Moonwatcher 	 NOUN 	 NN
# moves 	 VERB 	 VBZ
# with 	 ADP 	 IN
# them 	 PRON 	 PRP
# , 	 PUNCT 	 ,
# his 	 PRON 	 PRP$
# mind 	 NOUN 	 NN
# a 	 DET 	 DT
#
#  	 SPACE 	 _SP
# mist 	 NOUN 	 NN
# of 	 ADP 	 IN
# rage 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# confusion 	 NOUN 	 NN
# . 	 PUNCT 	 .
# To 	 PART 	 TO
# be 	 AUX 	 VB
# driven 	 VERB 	 VBN
# from 	 ADP 	 IN
# their 	 PRON 	 PRP$
# own 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# territory 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# great 	 ADJ 	 JJ
# badness 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# to 	 PART 	 TO
# lose 	 VERB 	 VB
# the 	 DET 	 DT
# river 	 NOUN 	 NN
# is 	 AUX 	 VBZ
# death 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# He 	 PRON 	 PRP
# does 	 AUX 	 VBZ
# not 	 PART 	 RB
# know 	 VERB 	 VB
# what 	 PRON 	 WP
# to 	 PART 	 TO
# do 	 VERB 	 VB
# ; 	 PUNCT 	 :
# it 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# situation 	 NOUN 	 NN
# beyond 	 ADP 	 IN
# his 	 PRON 	 PRP$
#
#  	 SPACE 	 _SP
# experience 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Then 	 ADV 	 RB
# he 	 PRON 	 PRP
# becomes 	 VERB 	 VBZ
# dimly 	 ADV 	 RB
# aware 	 ADJ 	 JJ
# that 	 SCONJ 	 IN
# the 	 DET 	 DT
# Others 	 PROPN 	 NNPS
# are 	 AUX 	 VBP
# slowing 	 VERB 	 VBG
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 NUM 	 CD
# 										  	 SPACE 	 _SP
# a10 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A8 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
#  	 SPACE 	 _SP
# down 	 ADP 	 RP
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# advancing 	 VERB 	 VBG
# with 	 ADP 	 IN
# obvious 	 ADJ 	 JJ
# reluctance 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 PRON 	 DT
# further 	 ADJ 	 JJ
# they 	 PRON 	 PRP
#
#  	 SPACE 	 _SP
# move 	 VERB 	 VBP
# from 	 ADP 	 IN
# their 	 PRON 	 PRP$
# own 	 ADJ 	 JJ
# side 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# the 	 PRON 	 DT
# more 	 ADV 	 RBR
# uncertain 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# unhappy 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# they 	 PRON 	 PRP
# become 	 VERB 	 VBP
# . 	 PUNCT 	 .
# Only 	 ADV 	 RB
# Big 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# Tooth 	 PROPN 	 NNP
# still 	 ADV 	 RB
# retains 	 VERB 	 VBZ
# any 	 PRON 	 DT
# of 	 ADP 	 IN
# his 	 PRON 	 PRP$
# original 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# drive 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# he 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# rapidly 	 ADV 	 RB
# being 	 AUX 	 VBG
# seperated 	 VERB 	 VBN
# from 	 ADP 	 IN
# his 	 PRON 	 PRP$
# followers 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# As 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# sees 	 VERB 	 VBZ
# this 	 PRON 	 DT
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
# 's 	 PART 	 POS
# own 	 ADJ 	 JJ
# morale 	 NOUN 	 NN
# immediately 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# revives 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# He 	 PRON 	 PRP
# slows 	 VERB 	 VBZ
# down 	 ADP 	 RP
# his 	 PRON 	 PRP$
# retreat 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# begins 	 VERB 	 VBZ
# to 	 PART 	 TO
# make 	 VERB 	 VB
#
#  	 SPACE 	 _SP
# reassuring 	 ADJ 	 JJ
# noises 	 NOUN 	 NNS
# to 	 ADP 	 IN
# his 	 PRON 	 PRP$
# companions 	 NOUN 	 NNS
# . 	 PUNCT 	 .
# Novel 	 NOUN 	 NN
# sensations 	 NOUN 	 NNS
# fill 	 VERB 	 VBP
#
#  	 SPACE 	 _SP
# his 	 PRON 	 PRP$
# dim 	 ADJ 	 JJ
# mind 	 NOUN 	 NN
# - 	 PUNCT 	 :
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# faint 	 ADJ 	 JJ
# precursors 	 NOUN 	 NNS
# of 	 ADP 	 IN
# bravery 	 NOUN 	 NN
# and 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# leadership 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Before 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# realizes 	 VERB 	 VBZ
# it 	 PRON 	 PRP
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# face 	 NOUN 	 NN
# to 	 PART 	 TO
# face 	 VERB 	 VB
# with 	 ADP 	 IN
# Big 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# Tooth 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# the 	 DET 	 DT
# two 	 NUM 	 CD
# tribes 	 NOUN 	 NNS
# come 	 VERB 	 VBP
# to 	 ADP 	 IN
# a 	 DET 	 DT
# halt 	 NOUN 	 NN
# many 	 ADJ 	 JJ
# paces 	 NOUN 	 NNS
# away 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# disorganized 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# unscientific 	 ADJ 	 JJ
# conflict 	 NOUN 	 NN
# could 	 AUX 	 MD
# have 	 AUX 	 VB
# ended 	 VERB 	 VBN
#
#  	 SPACE 	 _SP
# quickly 	 ADV 	 RB
# if 	 SCONJ 	 IN
# either 	 PRON 	 DT
# had 	 AUX 	 VBD
# used 	 VERB 	 VBN
# his 	 PRON 	 PRP$
# fist 	 NOUN 	 NN
# as 	 ADP 	 IN
# a 	 DET 	 DT
# club 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# this 	 DET 	 DT
#
#  	 SPACE 	 _SP
# innovation 	 NOUN 	 NN
# still 	 ADV 	 RB
# lay 	 VERB 	 VBP
# hundreds 	 NOUN 	 NNS
# of 	 ADP 	 IN
# thousands 	 NOUN 	 NNS
# of 	 ADP 	 IN
# years 	 NOUN 	 NNS
# in 	 ADP 	 IN
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# future 	 NOUN 	 NN
# . 	 PUNCT 	 .
# Instead 	 ADV 	 RB
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# slowly 	 ADV 	 RB
# weakening 	 VERB 	 VBG
# fighters 	 NOUN 	 NNS
# claw 	 NOUN 	 NN
# and 	 CCONJ 	 CC
#
#  	 SPACE 	 _SP
# scratch 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# try 	 VERB 	 VB
# to 	 PART 	 TO
# bite 	 VERB 	 VB
# each 	 DET 	 DT
# other 	 ADJ 	 JJ
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Rolling 	 VERB 	 VBG
# over 	 ADV 	 RB
# and 	 CCONJ 	 CC
# over 	 ADV 	 RB
# , 	 PUNCT 	 ,
# they 	 PRON 	 PRP
# come 	 VERB 	 VBP
# to 	 ADP 	 IN
# a 	 DET 	 DT
# patch 	 NOUN 	 NN
# of 	 ADP 	 IN
# stony 	 ADJ 	 JJ
# ground 	 NOUN 	 NN
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# when 	 SCONJ 	 WRB
# they 	 PRON 	 PRP
# reach 	 VERB 	 VBP
# it 	 PRON 	 PRP
# Moonwatcher 	 PROPN 	 NNP
# is 	 AUX 	 VBZ
# on 	 ADP 	 IN
# top 	 ADJ 	 JJ
# . 	 PUNCT 	 .
# By 	 ADP 	 IN
# chance 	 NOUN 	 NN
# , 	 PUNCT 	 ,
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 NUM 	 CD
# 										  	 SPACE 	 _SP
# a11 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A8 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
#  	 SPACE 	 _SP
# he 	 PRON 	 PRP
# chooses 	 VERB 	 VBZ
# this 	 DET 	 DT
# moment 	 NOUN 	 NN
# to 	 PART 	 TO
# grab 	 VERB 	 VB
# the 	 DET 	 DT
# hair 	 NOUN 	 NN
# on 	 ADP 	 IN
# Big 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# Tooth 	 PROPN 	 NNP
# 's 	 PART 	 POS
# scalp 	 NOUN 	 NN
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# bang 	 VERB 	 VB
# his 	 PRON 	 PRP$
# head 	 NOUN 	 NN
# on 	 ADP 	 IN
# the 	 DET 	 DT
# ground 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# resulting 	 VERB 	 VBG
# CRACK 	 NOUN 	 NN
# is 	 AUX 	 VBZ
#
#  	 SPACE 	 _SP
# so 	 ADV 	 RB
# satisfactory 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# produces 	 VERB 	 VBZ
# such 	 DET 	 PDT
# an 	 DET 	 DT
# immediate 	 ADJ 	 JJ
# weakening 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# In 	 ADP 	 IN
# Big 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# Tooth 	 PROPN 	 NNP
# 's 	 PART 	 POS
# resistance 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# that 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# quickly 	 ADV 	 RB
# repeats 	 VERB 	 VBZ
# it 	 PRON 	 PRP
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# Even 	 ADV 	 RB
# when 	 SCONJ 	 WRB
# Big 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# Tooth 	 PROPN 	 NNP
# ceases 	 VERB 	 VBZ
# to 	 PART 	 TO
# move 	 VERB 	 VB
# for 	 ADP 	 IN
# some 	 DET 	 DT
# time 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# Moon- 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# watcher 	 NOUN 	 NN
# keeps 	 VERB 	 VBZ
# up 	 ADP 	 RP
# the 	 DET 	 DT
# exhilirating 	 ADJ 	 JJ
# game 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# With 	 ADP 	 IN
# shrieks 	 NOUN 	 NNS
# of 	 ADP 	 IN
# panic 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# Others 	 PROPN 	 NNPS
# retreat 	 VERB 	 VBP
# back 	 ADV 	 RB
# , 	 PUNCT 	 ,
# across 	 ADP 	 IN
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# stream 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# defenders 	 NOUN 	 NNS
# cautiously 	 ADV 	 RB
# pursue 	 VERB 	 VBP
# them 	 PRON 	 PRP
# as 	 ADV 	 RB
# far 	 ADV 	 RB
# as 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# The 	 DET 	 DT
# water 	 NOUN 	 NN
# 's 	 PART 	 POS
# edge 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a12 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
#   	 SPACE 	 _SP
# CAVE 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# NEW 	 ADJ 	 JJ
# SOUND 	 NOUN 	 NN
#
#
#  	 SPACE 	 _SP
# Dozing 	 VERB 	 VBG
# fitfully 	 ADV 	 RB
# and 	 CCONJ 	 CC
# weakened 	 VERB 	 VBN
# by 	 ADP 	 IN
# his 	 PRON 	 PRP$
# stuggle 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# Moonwatcher 	 PROPN 	 NNP
# is 	 AUX 	 VBZ
#
#  	 SPACE 	 _SP
# startled 	 ADJ 	 JJ
# by 	 ADP 	 IN
# a 	 DET 	 DT
# sound 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# He 	 PRON 	 PRP
# sits 	 VERB 	 VBZ
# up 	 ADP 	 RP
# in 	 ADP 	 IN
# the 	 DET 	 DT
# fetid 	 ADJ 	 JJ
# darkness 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# cave 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# straining 	 VERB 	 VBG
# his 	 PRON 	 PRP$
#
#  	 SPACE 	 _SP
# senses 	 NOUN 	 NNS
# out 	 ADP 	 RP
# into 	 ADP 	 IN
# the 	 DET 	 DT
# night 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# fear 	 VERB 	 VBP
# creeps 	 NOUN 	 NNS
# slowly 	 ADV 	 RB
# into 	 ADP 	 IN
# his 	 PRON 	 PRP$
# soul 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# Never 	 ADV 	 RB
# in 	 ADP 	 IN
# his 	 PRON 	 PRP$
# life 	 NOUN 	 NN
# - 	 PUNCT 	 :
# already 	 ADV 	 RB
# twice 	 ADV 	 RB
# as 	 ADV 	 RB
# long 	 ADV 	 RB
# as 	 SCONJ 	 IN
# most 	 ADJ 	 JJS
# members 	 NOUN 	 NNS
# of 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# his 	 PRON 	 PRP$
# species 	 NOUN 	 NNS
# could 	 AUX 	 MD
# expect 	 VERB 	 VB
# - 	 PUNCT 	 :
# has 	 AUX 	 VBZ
# he 	 PRON 	 PRP
# heard 	 VERB 	 VBD
# a 	 DET 	 DT
# sound 	 NOUN 	 NN
# like 	 ADP 	 IN
# this 	 PRON 	 DT
# . 	 PUNCT 	 .
# The 	 DET 	 DT
#
#  	 SPACE 	 _SP
# great 	 ADJ 	 JJ
# cats 	 NOUN 	 NNS
# approached 	 VERB 	 VBN
# in 	 ADP 	 IN
# silence 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# the 	 DET 	 DT
# only 	 ADJ 	 JJ
# thing 	 NOUN 	 NN
# that 	 PRON 	 WDT
#
#  	 SPACE 	 _SP
# betrayed 	 VERB 	 VBN
# them 	 PRON 	 PRP
# was 	 AUX 	 VBD
# a 	 DET 	 DT
# rare 	 ADJ 	 JJ
# slide 	 NOUN 	 NN
# of 	 ADP 	 IN
# earth 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# or 	 CCONJ 	 CC
# the 	 DET 	 DT
# occasional 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# cracking 	 NOUN 	 NN
# of 	 ADP 	 IN
# a 	 DET 	 DT
# twig 	 NOUN 	 NN
# . 	 PUNCT 	 .
# Yet 	 CCONJ 	 CC
# this 	 PRON 	 DT
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# continuing 	 VERB 	 VBG
# crunching 	 NOUN 	 NN
# noise 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# that 	 PRON 	 WDT
# grows 	 VERB 	 VBZ
# steadily 	 ADV 	 RB
# louder 	 ADV 	 RBR
# . 	 PUNCT 	 .
# It 	 PRON 	 PRP
# seemed 	 VERB 	 VBD
# that 	 SCONJ 	 IN
# some 	 DET 	 DT
# enormous 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# beast 	 NOUN 	 NN
# was 	 AUX 	 VBD
# moving 	 VERB 	 VBG
# through 	 ADP 	 IN
# the 	 DET 	 DT
# night 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# making 	 VERB 	 VBG
# no 	 DET 	 DT
# attempt 	 NOUN 	 NN
# at 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# concealment 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# ignoring 	 VERB 	 VBG
# all 	 DET 	 DT
# obstacles 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# And 	 CCONJ 	 CC
# then 	 ADV 	 RB
# there 	 PRON 	 EX
# came 	 VERB 	 VBD
# a 	 DET 	 DT
# sound 	 NOUN 	 NN
# which 	 PRON 	 WDT
# Moonwatcher 	 PROPN 	 NNP
# could 	 AUX 	 MD
# not 	 PART 	 RB
#
#  	 SPACE 	 _SP
# possibly 	 ADV 	 RB
# have 	 AUX 	 VB
# identified 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# for 	 SCONJ 	 IN
# it 	 PRON 	 PRP
# had 	 AUX 	 VBD
# never 	 ADV 	 RB
# been 	 AUX 	 VBN
# heard 	 VERB 	 VBN
# before 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# in 	 ADP 	 IN
# the 	 DET 	 DT
# history 	 NOUN 	 NN
# of 	 ADP 	 IN
# this 	 DET 	 DT
# planet 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a13 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A10 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
# CAVE 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# NEW 	 ADJ 	 JJ
# ROCK 	 NOUN 	 NNS
#
#
#  	 SPACE 	 _SP
# Moonwatcher 	 PROPN 	 NNP
# comes 	 VERB 	 VBZ
# face 	 NOUN 	 NN
# to 	 PART 	 TO
# face 	 NOUN 	 NN
# with 	 ADP 	 IN
# the 	 DET 	 DT
# New 	 PROPN 	 NNP
# Rock 	 PROPN 	 NNP
# when 	 SCONJ 	 WRB
# he 	 PRON 	 PRP
#
#  	 SPACE 	 _SP
# leads 	 VERB 	 VBZ
# the 	 DET 	 DT
# tribe 	 NOUN 	 NN
# down 	 ADP 	 RP
# to 	 ADP 	 IN
# the 	 DET 	 DT
# river 	 NOUN 	 NN
# in 	 ADP 	 IN
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# light 	 NOUN 	 NN
# of 	 ADP 	 IN
# morning 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# He 	 PRON 	 PRP
# had 	 AUX 	 VBD
# almost 	 ADV 	 RB
# forgotten 	 VERB 	 VBN
# the 	 DET 	 DT
# terror 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# night 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# because 	 SCONJ 	 IN
# nothing 	 PRON 	 NN
#
#  	 SPACE 	 _SP
# had 	 AUX 	 VBD
# happened 	 VERB 	 VBN
# after 	 ADP 	 IN
# that 	 DET 	 DT
# initial 	 ADJ 	 JJ
# noise 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# so 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# does 	 AUX 	 VBZ
# not 	 PART 	 RB
# even 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# associate 	 VERB 	 VB
# this 	 DET 	 DT
# strange 	 ADJ 	 JJ
# thing 	 NOUN 	 NN
# with 	 ADP 	 IN
# danger 	 NOUN 	 NN
# or 	 CCONJ 	 CC
# with 	 ADP 	 IN
# fear 	 NOUN 	 NN
# . 	 PUNCT 	 .
# There 	 ADV 	 RB
#
#  	 SPACE 	 _SP
# is 	 AUX 	 VBZ
# nothing 	 PRON 	 NN
# in 	 ADP 	 IN
# the 	 DET 	 DT
# least 	 ADJ 	 JJS
# alarming 	 ADJ 	 JJ
# about 	 ADP 	 IN
# it 	 PRON 	 PRP
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# It 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# cube 	 NOUN 	 NN
# about 	 ADP 	 IN
# fifteen 	 NUM 	 CD
# feet 	 NOUN 	 NNS
# on 	 ADP 	 IN
# a 	 DET 	 DT
# side 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# it 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# made 	 VERB 	 VBN
# of 	 ADP 	 IN
#
#  	 SPACE 	 _SP
# some 	 DET 	 DT
# completely 	 ADV 	 RB
# transparent 	 ADJ 	 JJ
# material 	 NOUN 	 NN
# ; 	 PUNCT 	 :
# indeed 	 ADV 	 RB
# , 	 PUNCT 	 ,
# it 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# not 	 PART 	 RB
# easy 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# to 	 PART 	 TO
# see 	 VERB 	 VB
# except 	 SCONJ 	 IN
# when 	 SCONJ 	 WRB
# the 	 DET 	 DT
# light 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# sun 	 NOUN 	 NN
# glints 	 NOUN 	 NNS
# on 	 ADP 	 IN
# its 	 PRON 	 PRP$
# edges 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# There 	 PRON 	 EX
# are 	 VERB 	 VBP
# no 	 DET 	 DT
# natural 	 ADJ 	 JJ
# objects 	 NOUN 	 NNS
# to 	 PART 	 TO
# which 	 PRON 	 WDT
# Moonwatcher 	 PROPN 	 NNP
# can 	 AUX 	 MD
#
#  	 SPACE 	 _SP
# compare 	 VERB 	 VB
# this 	 DET 	 DT
# apparition 	 NOUN 	 NN
# . 	 PUNCT 	 .
# Though 	 SCONJ 	 IN
# he 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# wisely 	 ADV 	 RB
# cautious 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# of 	 ADP 	 IN
# most 	 ADJ 	 JJS
# new 	 ADJ 	 JJ
# things 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
# does 	 AUX 	 VBZ
# not 	 PART 	 RB
# hesitate 	 VERB 	 VB
# to 	 PART 	 TO
# walk 	 VERB 	 VB
# up 	 ADP 	 IN
# to 	 ADP 	 IN
# it 	 PRON 	 PRP
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# As 	 SCONJ 	 IN
# nothing 	 PRON 	 NN
# happens 	 VERB 	 VBZ
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
# puts 	 VERB 	 VBZ
# out 	 ADP 	 RP
# his 	 PRON 	 PRP$
# hand 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# feels 	 VERB 	 VBZ
# a 	 DET 	 DT
# warm 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# hard 	 ADJ 	 JJ
# surface 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# After 	 ADP 	 IN
# several 	 ADJ 	 JJ
# minutes 	 NOUN 	 NNS
# of 	 ADP 	 IN
# intense 	 ADJ 	 JJ
# thought 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
# arrives 	 VERB 	 VBZ
# at 	 ADP 	 IN
# a 	 DET 	 DT
#
#  	 SPACE 	 _SP
# brilliant 	 ADJ 	 JJ
# explanation 	 NOUN 	 NN
# . 	 PUNCT 	 .
# It 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# a 	 DET 	 DT
# rock 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# of 	 ADP 	 IN
# course 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# it 	 PRON 	 PRP
#
#  	 SPACE 	 _SP
# must 	 AUX 	 MD
# have 	 AUX 	 VB
# grown 	 VERB 	 VBN
# during 	 ADP 	 IN
# the 	 DET 	 DT
# night 	 NOUN 	 NN
# . 	 PUNCT 	 .
# There 	 PRON 	 EX
# are 	 VERB 	 VBP
# many 	 ADJ 	 JJ
# plants 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# that 	 PRON 	 WDT
# do 	 VERB 	 VBP
# this 	 PRON 	 DT
# - 	 PUNCT 	 HYPH
# white 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# pulpy 	 NOUN 	 NN
# things 	 NOUN 	 NNS
# shaped 	 VERB 	 VBN
# like 	 ADP 	 IN
# pebbles 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# that 	 SCONJ 	 IN
#
#  	 SPACE 	 _SP
# seem 	 VERB 	 VBP
# to 	 PART 	 TO
# shoot 	 VERB 	 VB
# up 	 ADP 	 RP
# in 	 ADP 	 IN
# the 	 DET 	 DT
# hours 	 NOUN 	 NNS
# of 	 ADP 	 IN
# darkness 	 NOUN 	 NN
# . 	 PUNCT 	 .
# It 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# true 	 ADJ 	 JJ
# that 	 SCONJ 	 IN
#
#  	 SPACE 	 _SP
# they 	 PRON 	 PRP
# are 	 AUX 	 VBP
# small 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# round 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# whereas 	 SCONJ 	 IN
# this 	 PRON 	 DT
# is 	 AUX 	 VBZ
# large 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# square 	 ADJ 	 JJ
# ; 	 PUNCT 	 :
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 NUM 	 CD
# 										  	 SPACE 	 _SP
# a14 	 NOUN 	 NNS
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A10 	 VERB 	 VB
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
#  	 SPACE 	 _SP
# but 	 CCONJ 	 CC
# greater 	 ADJ 	 JJR
# and 	 CCONJ 	 CC
# later 	 ADJ 	 JJ
# philosophers 	 NOUN 	 NNS
# than 	 ADP 	 IN
# Moonwatcher 	 PROPN 	 NNP
# would 	 AUX 	 MD
# be 	 AUX 	 VB
#
#  	 SPACE 	 _SP
# prepared 	 VERB 	 VBN
# to 	 PART 	 TO
# overlook 	 VERB 	 VB
# equally 	 ADV 	 RB
# striking 	 ADJ 	 JJ
# exceptions 	 NOUN 	 NNS
# to 	 ADP 	 IN
# their 	 PRON 	 PRP$
# laws 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# This 	 DET 	 DT
# really 	 ADV 	 RB
# superb 	 ADJ 	 JJ
# piece 	 NOUN 	 NN
# of 	 ADP 	 IN
# abstract 	 ADJ 	 JJ
# thinking 	 NOUN 	 NN
# leads 	 VERB 	 VBZ
# Moonwatcher 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# to 	 ADP 	 IN
# a 	 DET 	 DT
# deduction 	 NOUN 	 NN
# which 	 PRON 	 WDT
# he 	 PRON 	 PRP
# immediately 	 ADV 	 RB
# puts 	 VERB 	 VBZ
# to 	 ADP 	 IN
# the 	 DET 	 DT
# test 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# white 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
#
#  	 SPACE 	 _SP
# round 	 NOUN 	 NN
# pebble 	 ADJ 	 JJ
# - 	 PUNCT 	 HYPH
# plants 	 NOUN 	 NNS
# are 	 AUX 	 VBP
# very 	 ADV 	 RB
# tasty 	 ADJ 	 JJ
# ( 	 PUNCT 	 -LRB-
# though 	 SCONJ 	 IN
# there 	 PRON 	 EX
# were 	 VERB 	 VBD
# a 	 DET 	 DT
# few 	 ADJ 	 JJ
#
#  	 SPACE 	 _SP
# that 	 PRON 	 WDT
# made 	 VERB 	 VBD
# one 	 NUM 	 CD
# violently 	 ADV 	 RB
# sick 	 ADJ 	 JJ
# ) 	 PUNCT 	 -RRB-
# ; 	 PUNCT 	 :
# perhaps 	 ADV 	 RB
# this 	 DET 	 DT
# square 	 ADJ 	 JJ
# one 	 NUM 	 CD
# ... 	 PUNCT 	 .
# ? 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# A 	 DET 	 DT
# few 	 ADJ 	 JJ
# licks 	 NOUN 	 NNS
# and 	 CCONJ 	 CC
# attempted 	 VERB 	 VBN
# nibbles 	 NOUN 	 NNS
# quickly 	 ADV 	 RB
# disillusion 	 VERB 	 VBP
# him 	 PRON 	 PRP
# . 	 PUNCT 	 .
#
#  	 SPACE 	 _SP
# There 	 PRON 	 EX
# is 	 VERB 	 VBZ
# no 	 DET 	 DT
# nourishment 	 NOUN 	 NN
# here 	 ADV 	 RB
# ; 	 PUNCT 	 :
# so 	 ADV 	 RB
# like 	 ADP 	 IN
# a 	 DET 	 DT
# sensible 	 ADJ 	 JJ
# hominid 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# he 	 PRON 	 PRP
#
#  	 SPACE 	 _SP
# continues 	 VERB 	 VBZ
# on 	 ADP 	 IN
# his 	 PRON 	 PRP$
# way 	 NOUN 	 NN
# to 	 ADP 	 IN
# the 	 DET 	 DT
# river 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# forgets 	 VERB 	 VBZ
# all 	 ADV 	 RB
# about 	 ADP 	 IN
# the 	 DET 	 DT
# Cube 	 PROPN 	 NNP
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 10/13/65 	 VERB 	 VBP
# 										  	 SPACE 	 _SP
# a15 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# A11 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# EXT 	 PROPN 	 NNP
# CUBE 	 PROPN 	 NNPS
# - 	 PUNCT 	 HYPH
# FIRST 	 PROPN 	 NNP
# LESSON 	 PROPN 	 NNP
#
#
#  	 SPACE 	 _SP
# They 	 PRON 	 PRP
# are 	 AUX 	 VBP
# still 	 ADV 	 RB
# a 	 DET 	 DT
# hundred 	 NUM 	 CD
# yards 	 NOUN 	 NNS
# from 	 ADP 	 IN
# the 	 DET 	 DT
# New 	 PROPN 	 NNP
# Rock 	 PROPN 	 NNP
# when 	 SCONJ 	 WRB
# the 	 DET 	 DT
#
#  	 SPACE 	 _SP
# sound 	 NOUN 	 NN
# begins 	 VERB 	 VBZ
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# It 	 PRON 	 PRP
# is 	 AUX 	 VBZ
# quite 	 ADV 	 RB
# soft 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# it 	 PRON 	 PRP
# stops 	 VERB 	 VBZ
# them 	 PRON 	 PRP
# ...
# do 	 VERB 	 VB
# the 	 DET 	 DT
# rest 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
# 										   	 SPACE 	 _SP
# ( 	 PUNCT 	 -LRB-
# con't 	 VERB 	 VB
# ) 	 PUNCT 	 -RRB-
#
#
#  	 SPACE 	 _SP
# 12/9/65 	 NUM 	 CD
# 										   	 SPACE 	 _SP
# d3 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 PUNCT 	 :
#
#  	 SPACE 	 _SP
# D1 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
# 					     	 SPACE 	 _SP
# NARRATOR 	 NOUN 	 NN
# ( 	 PUNCT 	 -LRB-
# con't 	 ADJ 	 JJ
# ) 	 PUNCT 	 -RRB-
#
# 					     	 SPACE 	 _SP
# On 	 ADP 	 IN
# Earth 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# glaciers 	 NOUN 	 NNS
# came 	 VERB 	 VBD
# and 	 CCONJ 	 CC
#
# 					     	 SPACE 	 _SP
# went 	 VERB 	 VBD
# , 	 PUNCT 	 ,
# while 	 SCONJ 	 IN
# above 	 ADP 	 IN
# them 	 PRON 	 PRP
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# changeless 	 NOUN 	 NN
# Moon 	 PROPN 	 NNP
# still 	 ADV 	 RB
# carried 	 VERB 	 VBD
# its 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# secret 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# With 	 ADP 	 IN
# a 	 DET 	 DT
# yet 	 ADV 	 RB
# slower 	 ADJ 	 JJR
# rhythm 	 NOUN 	 NN
# than 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# the 	 DET 	 DT
# Polar 	 PROPN 	 NNP
# ice 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# tide 	 NOUN 	 NN
# of 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# civilization 	 NOUN 	 NN
# ebbed 	 VERB 	 VBN
# and 	 CCONJ 	 CC
# flowed 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# across 	 ADP 	 IN
# the 	 DET 	 DT
# galaxy 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Strange 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# beautiful 	 ADJ 	 JJ
# and 	 CCONJ 	 CC
# terrible 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# empires 	 NOUN 	 NNS
# rose 	 VERB 	 VBD
# and 	 CCONJ 	 CC
# fell 	 VERB 	 VBD
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# passed 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# on 	 ADP 	 IN
# their 	 PRON 	 PRP$
# knowledge 	 NOUN 	 NN
# to 	 ADP 	 IN
# their 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# successors 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Earth 	 PROPN 	 NNP
# was 	 AUX 	 VBD
# not 	 PART 	 RB
# forgotten 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# it 	 PRON 	 PRP
# was 	 AUX 	 VBD
#
# 					     	 SPACE 	 _SP
# one 	 NUM 	 CD
# of 	 ADP 	 IN
# a 	 DET 	 DT
# million 	 NUM 	 CD
# silent 	 ADJ 	 JJ
# worlds 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# a 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# few 	 ADJ 	 JJ
# of 	 ADP 	 IN
# which 	 PRON 	 WDT
# would 	 AUX 	 MD
# ever 	 ADV 	 RB
# speak 	 VERB 	 VB
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Then 	 ADV 	 RB
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# explorers 	 NOUN 	 NNS
# of 	 ADP 	 IN
# Earth 	 PROPN 	 NNP
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# recognising 	 VERB 	 VBG
# the 	 DET 	 DT
# limitations 	 NOUN 	 NNS
# of 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# their 	 PRON 	 PRP$
# minds 	 NOUN 	 NNS
# and 	 CCONJ 	 CC
# bodies 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# passed 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# on 	 ADP 	 IN
# their 	 PRON 	 PRP$
# knowledge 	 NOUN 	 NN
# to 	 ADP 	 IN
# the 	 DET 	 DT
# great 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# machines 	 NOUN 	 NNS
# they 	 PRON 	 PRP
# had 	 AUX 	 VBD
# created 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
#
# 					     	 SPACE 	 _SP
# who 	 PRON 	 WP
# now 	 ADV 	 RB
# trnscended 	 VERB 	 VBD
# them 	 PRON 	 PRP
# in 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# every 	 DET 	 DT
# way 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
# 										   	 SPACE 	 _SP
# ( 	 PUNCT 	 -LRB-
# con't 	 VERB 	 VB
# ) 	 PUNCT 	 -RRB-
#
#
#  	 SPACE 	 _SP
# 12/9/65 	 NUM 	 CD
# 										   	 SPACE 	 _SP
# d4 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 X 	 XX
#
#  	 SPACE 	 _SP
# D1 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
# 					     	 SPACE 	 _SP
# NARRATOR 	 PROPN 	 NNP
#
# 					     	 SPACE 	 _SP
# For 	 ADP 	 IN
# a 	 DET 	 DT
# few 	 ADJ 	 JJ
# thousand 	 NUM 	 CD
# years 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# they 	 PRON 	 PRP
#
# 					     	 SPACE 	 _SP
# shared 	 VERB 	 VBD
# their 	 PRON 	 PRP$
# Universe 	 PROPN 	 NNP
# with 	 ADP 	 IN
# their 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# machine 	 NOUN 	 NN
# children 	 NOUN 	 NNS
# ; 	 PUNCT 	 :
# then 	 ADV 	 RB
# , 	 PUNCT 	 ,
# realizing 	 VERB 	 VBG
#
# 					     	 SPACE 	 _SP
# that 	 SCONJ 	 IN
# it 	 PRON 	 PRP
# was 	 AUX 	 VBD
# folly 	 ADJ 	 JJ
# to 	 PART 	 TO
# linger 	 VERB 	 VB
# when 	 SCONJ 	 WRB
#
# 					     	 SPACE 	 _SP
# their 	 PRON 	 PRP$
# task 	 NOUN 	 NN
# was 	 AUX 	 VBD
# done 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# they 	 PRON 	 PRP
# passed 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# into 	 ADP 	 IN
# history 	 NOUN 	 NN
# without 	 ADP 	 IN
# regret 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Not 	 PART 	 RB
# one 	 NUM 	 CD
# of 	 ADP 	 IN
# them 	 PRON 	 PRP
# ever 	 ADV 	 RB
# looked 	 VERB 	 VBD
# through 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# his 	 PRON 	 PRP$
# own 	 ADJ 	 JJ
# eyes 	 NOUN 	 NNS
# upon 	 SCONJ 	 IN
# the 	 DET 	 DT
# planet 	 NOUN 	 NN
# Earth 	 PROPN 	 NNP
#
# 					     	 SPACE 	 _SP
# again 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# But 	 CCONJ 	 CC
# even 	 ADV 	 RB
# the 	 DET 	 DT
# age 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
# Machine 	 PROPN 	 NNP
#
# 					     	 SPACE 	 _SP
# Entities 	 PROPN 	 NNP
# passed 	 VERB 	 VBD
# swiftly 	 ADV 	 RB
# . 	 PUNCT 	 .
# In 	 ADP 	 IN
# their 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# ceaseless 	 NOUN 	 NN
# experimenting 	 VERB 	 VBG
# , 	 PUNCT 	 ,
# they 	 PRON 	 PRP
#
# 					     	 SPACE 	 _SP
# had 	 AUX 	 VBD
# learned 	 VERB 	 VBN
# to 	 PART 	 TO
# store 	 VERB 	 VB
# knowledge 	 NOUN 	 NN
#
# 					     	 SPACE 	 _SP
# in 	 ADP 	 IN
# the 	 DET 	 DT
# structure 	 NOUN 	 NN
# of 	 ADP 	 IN
# space 	 NOUN 	 NN
# itself 	 PRON 	 PRP
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# to 	 PART 	 TO
# preserve 	 VERB 	 VB
# their 	 PRON 	 PRP$
# thoughts 	 NOUN 	 NNS
#
# 					     	 SPACE 	 _SP
# for 	 ADP 	 IN
# eternity 	 NOUN 	 NN
# in 	 ADP 	 IN
# frozen 	 ADJ 	 JJ
# lattices 	 NOUN 	 NNS
#
# 					     	 SPACE 	 _SP
# of 	 ADP 	 IN
# light 	 NOUN 	 NN
# . 	 PUNCT 	 .
# They 	 PRON 	 PRP
# could 	 AUX 	 MD
# become 	 VERB 	 VB
#
# 					     	 SPACE 	 _SP
# creatures 	 NOUN 	 NNS
# of 	 ADP 	 IN
# radiation 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# free 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# at 	 ADP 	 IN
# last 	 ADJ 	 JJ
# from 	 ADP 	 IN
# the 	 DET 	 DT
# tyranny 	 NOUN 	 NN
# of 	 ADP 	 IN
# matter 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Now 	 ADV 	 RB
# , 	 PUNCT 	 ,
# they 	 PRON 	 PRP
# were 	 AUX 	 VBD
# Lords 	 NOUN 	 NNS
# of 	 ADP 	 IN
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# galaxy 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# beyond 	 ADP 	 IN
# the 	 DET 	 DT
# reach 	 NOUN 	 NN
#
# 					     	 SPACE 	 _SP
# of 	 ADP 	 IN
# time 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# They 	 PRON 	 PRP
# could 	 AUX 	 MD
# rove 	 VERB 	 VB
# at 	 ADP 	 IN
# will 	 NOUN 	 NN
# among 	 ADP 	 IN
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# stars 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# and 	 CCONJ 	 CC
# sink 	 VERB 	 VB
# like 	 ADP 	 IN
# a 	 DET 	 DT
# subtle 	 ADJ 	 JJ
# mist 	 NOUN 	 NN
#
# 					     	 SPACE 	 _SP
# through 	 ADP 	 IN
# the 	 DET 	 DT
# very 	 ADJ 	 JJ
# interstices 	 NOUN 	 NNS
# of 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# space 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 12/9/65 	 NUM 	 CD
# 										   	 SPACE 	 _SP
# d5 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# D1 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
# 					     	 SPACE 	 _SP
# NARRATOR 	 NOUN 	 NN
# ( 	 PUNCT 	 -LRB-
# con't 	 ADJ 	 JJ
# ) 	 PUNCT 	 -RRB-
#
# 					     	 SPACE 	 _SP
# But 	 CCONJ 	 CC
# despite 	 SCONJ 	 IN
# their 	 PRON 	 PRP$
# God 	 PROPN 	 NNP
# - 	 PUNCT 	 HYPH
# like 	 ADJ 	 JJ
# powers 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# they 	 PRON 	 PRP
# still 	 ADV 	 RB
# watched 	 VERB 	 VBD
# over 	 ADP 	 IN
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# experiments 	 NOUN 	 NNS
# their 	 PRON 	 PRP$
# ancestors 	 NOUN 	 NNS
#
# 					     	 SPACE 	 _SP
# had 	 AUX 	 VBD
# started 	 VERB 	 VBN
# so 	 ADV 	 RB
# many 	 ADJ 	 JJ
# generations 	 NOUN 	 NNS
#
# 					     	 SPACE 	 _SP
# ago 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# The 	 DET 	 DT
# companion 	 NOUN 	 NN
# of 	 ADP 	 IN
# Saturn 	 PROPN 	 NNP
# knew 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# nothing 	 PRON 	 NN
# of 	 ADP 	 IN
# this 	 PRON 	 DT
# , 	 PUNCT 	 ,
# as 	 SCONJ 	 IN
# it 	 PRON 	 PRP
# orbited 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# in 	 ADP 	 IN
# its 	 PRON 	 PRP$
# no 	 DET 	 DT
# man 	 NOUN 	 NN
# 's 	 PART 	 POS
# land 	 NOUN 	 NN
# between 	 ADP 	 IN
# Mimas 	 PROPN 	 NNP
#
# 					     	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# the 	 DET 	 DT
# outer 	 ADJ 	 JJ
# edge 	 NOUN 	 NN
# of 	 ADP 	 IN
# rings 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# It 	 PRON 	 PRP
# had 	 VERB 	 VBD
# only 	 ADV 	 RB
# to 	 PART 	 TO
# remember 	 VERB 	 VB
# and 	 CCONJ 	 CC
# wait 	 VERB 	 VB
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# and 	 CCONJ 	 CC
# to 	 PART 	 TO
# look 	 VERB 	 VB
# forever 	 ADV 	 RB
# Sunward 	 PROPN 	 NNP
# with 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# its 	 PRON 	 PRP$
# strange 	 ADJ 	 JJ
# senses 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# For 	 ADP 	 IN
# many 	 ADJ 	 JJ
# weeks 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# it 	 PRON 	 PRP
# had 	 AUX 	 VBD
# watched 	 VERB 	 VBN
#
# 					     	 SPACE 	 _SP
# the 	 DET 	 DT
# approaching 	 VERB 	 VBG
# ship 	 NOUN 	 NN
# . 	 PUNCT 	 .
# Its 	 PRON 	 PRP$
# long- 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# dead 	 ADJ 	 JJ
# makers 	 NOUN 	 NNS
# had 	 AUX 	 VBD
# prepared 	 VERB 	 VBN
# it 	 PRON 	 PRP
# for 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# many 	 ADJ 	 JJ
# things 	 NOUN 	 NNS
# and 	 CCONJ 	 CC
# this 	 PRON 	 DT
# was 	 AUX 	 VBD
# one 	 NUM 	 CD
# of 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# them 	 PRON 	 PRP
# . 	 PUNCT 	 .
# And 	 CCONJ 	 CC
# it 	 PRON 	 PRP
# recognised 	 VERB 	 VBD
# what 	 PRON 	 WP
#
# 					     	 SPACE 	 _SP
# was 	 AUX 	 VBD
# climbing 	 VERB 	 VBG
# starward 	 NOUN 	 NN
# from 	 ADP 	 IN
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# Sun 	 PROPN 	 NNP
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# If 	 SCONJ 	 IN
# it 	 PRON 	 PRP
# had 	 AUX 	 VBD
# been 	 AUX 	 VBN
# alive 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# it 	 PRON 	 PRP
# would 	 AUX 	 MD
# have 	 VERB 	 VB
#
# 					     	 SPACE 	 _SP
# felt 	 VERB 	 VBN
# excitement 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# but 	 CCONJ 	 CC
# such 	 DET 	 PDT
# an 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# emotion 	 NOUN 	 NN
# was 	 AUX 	 VBD
# irrelevant 	 ADJ 	 JJ
# to 	 ADP 	 IN
# its 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# great 	 ADJ 	 JJ
# powers 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
# 										    	 SPACE 	 _SP
# ( 	 PUNCT 	 -LRB-
# con't 	 PROPN 	 NNP
# ) 	 PUNCT 	 -RRB-
#
#  	 SPACE 	 _SP
# 12/9/65 	 NUM 	 CD
# 										   	 SPACE 	 _SP
# d6 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# D1 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# NARRATOR 	 PROPN 	 NNP
# ( 	 PUNCT 	 -LRB-
# con't 	 ADJ 	 JJ
# ) 	 PUNCT 	 -RRB-
#
# 					     	 SPACE 	 _SP
# Even 	 ADV 	 RB
# if 	 SCONJ 	 IN
# the 	 DET 	 DT
# ship 	 NOUN 	 NN
# had 	 AUX 	 VBD
# passed 	 VERB 	 VBN
# it 	 PRON 	 PRP
# by 	 ADV 	 RB
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# it 	 PRON 	 PRP
# would 	 AUX 	 MD
# not 	 PART 	 RB
# have 	 AUX 	 VB
# known 	 VERB 	 VBN
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# slightest 	 ADJ 	 JJS
# trace 	 NOUN 	 NN
# of 	 ADP 	 IN
# disappointment 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# It 	 PRON 	 PRP
# had 	 AUX 	 VBD
# waited 	 VERB 	 VBN
# four 	 NUM 	 CD
# million 	 NUM 	 CD
# years 	 NOUN 	 NNS
# ; 	 PUNCT 	 :
#
# 					     	 SPACE 	 _SP
# it 	 PRON 	 PRP
# was 	 AUX 	 VBD
# prepared 	 ADJ 	 JJ
# to 	 PART 	 TO
# wait 	 VERB 	 VB
# for 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# eternity 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Presently 	 ADV 	 RB
# , 	 PUNCT 	 ,
# it 	 PRON 	 PRP
# felt 	 VERB 	 VBD
# the 	 DET 	 DT
# gentle 	 ADJ 	 JJ
# touch 	 NOUN 	 NN
#
# 					     	 SPACE 	 _SP
# of 	 ADP 	 IN
# radiations 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# trying 	 VERB 	 VBG
# to 	 PART 	 TO
# probe 	 VERB 	 VB
# its 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# secrets 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Now 	 ADV 	 RB
# , 	 PUNCT 	 ,
# the 	 DET 	 DT
# ship 	 NOUN 	 NN
# was 	 AUX 	 VBD
# in 	 ADP 	 IN
# orbit 	 NOUN 	 NN
# and 	 CCONJ 	 CC
# it 	 PRON 	 PRP
#
# 					     	 SPACE 	 _SP
# began 	 VERB 	 VBD
# to 	 PART 	 TO
# speak 	 VERB 	 VB
# , 	 PUNCT 	 ,
# with 	 ADP 	 IN
# prime 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# numbers 	 NOUN 	 NNS
# from 	 ADP 	 IN
# one 	 NUM 	 CD
# to 	 ADP 	 IN
# eleven 	 NUM 	 CD
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# over 	 ADP 	 IN
# and 	 CCONJ 	 CC
# over 	 ADV 	 RB
# again 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Soon 	 ADV 	 RB
# , 	 PUNCT 	 ,
# these 	 PRON 	 DT
# gave 	 VERB 	 VBD
# way 	 NOUN 	 NN
# to 	 ADP 	 IN
# more 	 ADJ 	 JJR
#
# 					     	 SPACE 	 _SP
# complex 	 ADJ 	 JJ
# signals 	 NOUN 	 NNS
# at 	 ADP 	 IN
# many 	 ADJ 	 JJ
# frequen- 	 ADJ 	 JJ
#
# 					     	 SPACE 	 _SP
# cies 	 NOUN 	 NNS
# , 	 PUNCT 	 ,
# ultra 	 ADJ 	 JJ
# - 	 ADJ 	 JJ
# violet 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
# infra 	 NOUN 	 NN
# - 	 PUNCT 	 HYPH
# red 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# X 	 NOUN 	 NNS
# - 	 NOUN 	 NNS
# rays 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# The 	 DET 	 DT
# machine 	 NOUN 	 NN
# made 	 VERB 	 VBD
# no 	 DET 	 DT
# reply 	 NOUN 	 NN
# . 	 PUNCT 	 .
# It 	 PRON 	 PRP
#
# 					     	 SPACE 	 _SP
# had 	 VERB 	 VBD
# nothing 	 PRON 	 NN
# to 	 PART 	 TO
# say 	 VERB 	 VB
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Then 	 ADV 	 RB
# it 	 PRON 	 PRP
# saw 	 VERB 	 VBD
# the 	 DET 	 DT
# first 	 ADJ 	 JJ
# robot 	 NOUN 	 NN
#
# 					     	 SPACE 	 _SP
# probe 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# which 	 PRON 	 WDT
# descended 	 VERB 	 VBD
# and 	 CCONJ 	 CC
#
# 					     	 SPACE 	 _SP
# hovered 	 VERB 	 VBD
# above 	 ADP 	 IN
# the 	 DET 	 DT
# chasm 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
# 									     	 SPACE 	 _SP
# ( 	 PUNCT 	 -LRB-
# con't 	 NOUN 	 NN
# ) 	 PUNCT 	 -RRB-
#
#
#  	 SPACE 	 _SP
# 12/9/65 	 NUM 	 CD
# 										   	 SPACE 	 _SP
# d7 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 SYM 	 SYM
#
#  	 SPACE 	 _SP
# D1 	 NOUN 	 NN
#
#  	 SPACE 	 _SP
# CONTINUED 	 ADJ 	 JJ
#
#
# 					     	 SPACE 	 _SP
# NARRATOR 	 NOUN 	 NN
# ( 	 PUNCT 	 -LRB-
# con't 	 ADJ 	 JJ
# ) 	 PUNCT 	 -RRB-
#
# 					     	 SPACE 	 _SP
# Then 	 ADV 	 RB
# , 	 PUNCT 	 ,
# it 	 PRON 	 PRP
# dropped 	 VERB 	 VBD
# into 	 ADP 	 IN
# darkness 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# The 	 DET 	 DT
# great 	 ADJ 	 JJ
# machine 	 NOUN 	 NN
# knew 	 VERB 	 VBD
# that 	 SCONJ 	 IN
# this 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# tiny 	 ADJ 	 JJ
# scout 	 NOUN 	 NN
# was 	 AUX 	 VBD
# reporting 	 VERB 	 VBG
# back 	 ADV 	 RB
# to 	 ADP 	 IN
#
# 					     	 SPACE 	 _SP
# its 	 PRON 	 PRP$
# parent 	 NOUN 	 NN
# ; 	 PUNCT 	 :
# but 	 CCONJ 	 CC
# it 	 PRON 	 PRP
# was 	 AUX 	 VBD
# too 	 ADV 	 RB
# simple 	 ADJ 	 JJ
# , 	 PUNCT 	 ,
#
# 					     	 SPACE 	 _SP
# too 	 ADV 	 RB
# primative 	 ADJ 	 JJ
# a 	 DET 	 DT
# device 	 NOUN 	 NN
# to 	 PART 	 TO
# detect 	 VERB 	 VB
#
# 					     	 SPACE 	 _SP
# the 	 DET 	 DT
# forces 	 NOUN 	 NNS
# that 	 PRON 	 WDT
# were 	 AUX 	 VBD
# gathering 	 VERB 	 VBG
#
# 					     	 SPACE 	 _SP
# round 	 VERB 	 VB
# it 	 PRON 	 PRP
# now 	 ADV 	 RB
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# Then 	 ADV 	 RB
# the 	 DET 	 DT
# pod 	 NOUN 	 NN
# came 	 VERB 	 VBD
# , 	 PUNCT 	 ,
# carrying 	 VERB 	 VBG
#
# 					     	 SPACE 	 _SP
# life 	 NOUN 	 NN
# . 	 PUNCT 	 .
# The 	 DET 	 DT
# great 	 ADJ 	 JJ
# machine 	 NOUN 	 NN
# searched 	 VERB 	 VBD
#
# 					     	 SPACE 	 _SP
# its 	 PRON 	 PRP$
# memories 	 NOUN 	 NNS
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# The 	 DET 	 DT
# logic 	 NOUN 	 NN
# circuits 	 NOUN 	 NNS
# made 	 VERB 	 VBD
# their 	 PRON 	 PRP$
#
# 					     	 SPACE 	 _SP
# decision 	 NOUN 	 NN
# when 	 SCONJ 	 WRB
# the 	 DET 	 DT
# pod 	 NOUN 	 NN
# had 	 AUX 	 VBD
# fallen 	 VERB 	 VBN
#
# 					     	 SPACE 	 _SP
# beyond 	 ADP 	 IN
# the 	 DET 	 DT
# last 	 ADJ 	 JJ
# faint 	 ADJ 	 JJ
# glow 	 NOUN 	 NN
# of 	 ADP 	 IN
# the 	 DET 	 DT
#
# 					     	 SPACE 	 _SP
# reflected 	 VERB 	 VBD
# Saturnian 	 ADJ 	 JJ
# light 	 NOUN 	 NN
# . 	 PUNCT 	 .
#
#
# 					     	 SPACE 	 _SP
# In 	 ADP 	 IN
# a 	 DET 	 DT
# moment 	 NOUN 	 NN
# of 	 ADP 	 IN
# time 	 NOUN 	 NN
# , 	 PUNCT 	 ,
# too 	 ADV 	 RB
# short 	 ADJ 	 JJ
# to 	 AUX 	 IN
#
# 					     	 SPACE 	 _SP
# be 	 AUX 	 VB
# measured 	 VERB 	 VBN
# , 	 PUNCT 	 ,
# space 	 NOUN 	 NN
# turned 	 VERB 	 VBD
# and 	 CCONJ 	 CC
#
# 					     	 SPACE 	 _SP
# twisted 	 VERB 	 VBD
# upon 	 SCONJ 	 IN
# itself 	 PRON 	 PRP
# . 	 PUNCT 	 .
#
#
#  	 SPACE 	 _SP
# 12/9/65 	 NUM 	 CD
# 										   	 SPACE 	 _SP
# d8 	 PROPN 	 NNP
#
#  	 SPACE 	 _SP
# ------------------------------------------------------------------------ 	 PUNCT 	 NFP
#
# 					  	 SPACE 	 _SP
# END 	 PROPN 	 NNP
# OF 	 ADP 	 IN
# SCREENPLAY 	 ADJ 	 JJ
#
# 					    	 SPACE 	 _SP
# END 	 PROPN 	 NNP
# OF 	 ADP 	 IN
# FILE 	 NOUN 	 NN
#
#
#  	 SPACE 	 _SP

# %% [markdown]
# * For more info. about PARTS OF SPEECH (TAGGING):
# https://universaldependencies.org/u/pos/
