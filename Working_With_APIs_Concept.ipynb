# %% [markdown]
# ### Demo 1:

# %%
# loading the packages
# requests provides us with the capabilities of sending a HTTP request to a server
# JSON: A useful library for JSON manipulation 

import requests
import json

# %%
# Define the base URL
# Base URL: the part of the URL common to all requests, not containing the parameters
base_url = "http://universities.hipolabs.com/search?country=India"

# %% [markdown]
# - The get() method sends a GET request to the specified url.
# - This method returns the response from the server
# - We store this response in a variable for future processing

# %%
# We can make a GET request to this API endpoint with requests.get
response = requests.get(base_url)

# %% [markdown]
# - response.ok returns True if status_code is less than 400, otherwise False.
# - Python requests are generally used to fetch the content from a particular resource URI.
# - Whenever we make a request to a specified URI through Python, it returns a response object.

# %%
# Checking if the request went through ok

response.ok
# Out:
# True

# %% [markdown]
# - response.status_code returns a number that indicates the status (200 is OK, 404 is Not Found).

# %%
# Checking the status code of the response
response.status_code
# Out:
# 200

# %% [markdown]
# - response.text returns the content of the response, in unicode.
# - Basically, it refers to Binary Response content.

# %%
# Inspecting the content body of the response (as a regular 'string')
response.text
# Out:
# '[{"alpha_two_code": "IN", "domains": ["upes.ac.in"], "country": "India", "state-province": "Dehradun", "web_pages": ["https://www.upes.ac.in/"], "name": "University of Petroleum and Energy Studies"}, {"alpha_two_code": "IN", "domains": ["davietjal.org"], "country": "India", "state-province": "Punjab", "web_pages": ["http://www.davietjal.org/"], "name": "DAV Institute of Engineering & Technology"}, {"alpha_two_code": "IN", "domains": ["lpu.in"], "country": "India", "state-province": "Punjab", "web_pages": ["http://www.lpu.in/"], "name": "Lovely Professional University"}, {"alpha_two_code": "IN", "domains": ["somaiya.edu"], "country": "India", "state-province": null, "web_pages": ["https://somaiya.edu/"], "name": "Somaiya Vidyavihar"}, {"alpha_two_code": "IN", "domains": ["ncuindia.edu"], "country": "India", "state-province": "Haryana", "web_pages": ["http://www.ncuindia.edu/"], "name": "NorthCap University"}, {"alpha_two_code": "IN", "domains": ["ddu.ac.in"], "country": "India", "state-province": "Gujarat", "web_pages": ["http://www.ddu.ac.in/"], "name": "Dharamsinh Desai University"}, {"alpha_two_code": "IN", "domains": ["ntruhs.ap.nic.in"], "country": "India", "state-province": "Andhra Pradesh", "web_pages": ["http://ntruhs.ap.nic.in/"], "name": "University of Health Sciences Andhra Pradesh"}, {"alpha_two_code": "IN", "domains": ["aaidu.org"], "country": "India", "state-province": null, "web_pages": ["http://www.aaidu.org/"], "name": "Allahabad Agricultural Institute, Deemed University"}, {"alpha_two_code": "IN", "domains": ["aau.ac.in"], "country": "India", "state-province": "Assam", "web_pages": ["http://www.aau.ac.in/"], "name": "Assam Agricultural University"}, {"alpha_two_code": "IN", "domains": ["ahduni.edu.in"], "country": "India", "state-province": "Gujarat", "web_pages": ["http://www.ahduni.edu.in/"], "name": "Ahmedabad University"}, {"alpha_two_code": "IN", "domains": ["aiims.ac.in"], "country": "India", "state-province": null, "web_pages": ["http://www.aiims.ac.in/"], "name": "All India Institute of Medical Sciences"}, {"alpha_two_code": "IN", "domains": ["aisectuniversity.ac.in"], "country": "India", "state-province": null, "web_pages": ["http://www.aisectuniversity.ac.in/"], "name": "AISECT University"}, {"alpha_two_code": "IN", "domains": ["alagappauniversity.ac.in"], "country": "India", "state-province": "Tamil Nadu", "web_pages": ["http://www.alagappauniversity.ac.in/"], "name": "Alagappa University"}, {"alpha_two_code": "IN", "domains": ["alldunivpio.org"], "country": "India", "state-province": "Uttar Pradesh", "web_pages": ["http://www.alldunivpio.org/"], "name": "Allahabad University"}, {"alpha_two_code": "IN", "domains": ["altmeduniversity.com"], "country": "India", "state-province": null, "web_pages": ["http://www.altmeduniversity.com/"], "name": "Open International University for Alternative Medicines"}, {"alpha_two_code": "IN", "domains": ["altmedworld.net"], "country": "India", "state-province": "West Bengal", "web_pages": ["http://www.altmedworld.net/"], "name": "Indian Board of Alternative Medicine"}, {"alpha_two_code": "IN", "domains": ["amity.edu"], "country": "India", "state-province": null, "web_pages": ["http://www.amity.edu/"], "name": "Amity University"}, {"alpha_two_code": "IN", "domains": ["amrita.edu"], "country": "India", "state-province": null, "web_pages": ["http://www.amrita.edu/"], "name": "Amrita Vishwa Vidyapeetham (Deemed University)"}, {"alpha_two_code": "IN", "domains": ["amtuni.com"], "country": "India", "state-province": null, "web_pages": ["http://www.amtuni.com/"], "name": "Amravati University"}, {"alpha_two_code": "IN", "domains": ["amu.ac.in"], "country": "India", "state-province": null, "web_pages": ["http://www.amu.ac.in/"], "name": "Aligarh Muslim University"}, {"alpha_two_code": "IN", "domains": ["andhrauniversity.info"], "country": "India", "state-province": null, "web_pages": ["http://www.andhrauniversity.info/"], "name": "Andhra University"}, {"alpha_two_code": "IN", ...

# %% [markdown]
# - response.content returns the content of the response, in bytes

# %%
# Inspecting the content of the response (in 'bytes' format)
response.content
# Out:
# b'[{"id":379,"type":"programming","setup":"A programmer puts two glasses on his bedside table before going to sleep.","punchline":"A full one, in case he gets thirsty, and an empty one, in case he doesn\xe2\x80\x99t."},{"id":382,"type":"programming","setup":"What did the router say to the doctor?","punchline":"It hurts when IP."},{"id":380,"type":"programming","setup":"There are 10 kinds of people in this world.","punchline":"Those who understand binary, those who don\'t, and those who weren\'t expecting a base 3 joke."},{"id":18,"type":"programming","setup":"Why did the programmer quit his job?","punchline":"Because he didn\'t get arrays."},{"id":28,"type":"programming","setup":"To understand what recursion is...","punchline":"You must first understand what recursion is"},{"id":35,"type":"programming","setup":"Why do Java programmers wear glasses?","punchline":"Because they don\'t C#"},{"id":385,"type":"programming","setup":"3 SQL statements walk into a NoSQL bar. Soon, they walk out","punchline":"They couldn\'t find a table."},{"id":73,"type":"programming","setup":"The punchline often arrives before the set-up.","punchline":"Do you know the problem with UDP jokes?"},{"id":17,"type":"programming","setup":"Where do programmers like to hangout?","punchline":"The Foo Bar."},{"id":15,"type":"programming","setup":"What\'s the best thing about a Boolean?","punchline":"Even if you\'re wrong, you\'re only off by a bit."}]'

# %% [markdown]
# ### Demo 2

# %% [markdown]
# - response.json() returns a JSON object of the result

# %%
# Requests has in-built method to directly convert the response to JSON format
data = response.json()
data
# Out:
# [{'alpha_two_code': 'IN',
#   'domains': ['upes.ac.in'],
#   'country': 'India',
#   'state-province': 'Dehradun',
#   'web_pages': ['https://www.upes.ac.in/'],
#   'name': 'University of Petroleum and Energy Studies'},
#  {'alpha_two_code': 'IN',
#   'domains': ['davietjal.org'],
#   'country': 'India',
#   'state-province': 'Punjab',
#   'web_pages': ['http://www.davietjal.org/'],
#   'name': 'DAV Institute of Engineering & Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['lpu.in'],
#   'country': 'India',
#   'state-province': 'Punjab',
#   'web_pages': ['http://www.lpu.in/'],
#   'name': 'Lovely Professional University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['somaiya.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://somaiya.edu/'],
#   'name': 'Somaiya Vidyavihar'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ncuindia.edu'],
#   'country': 'India',
#   'state-province': 'Haryana',
#   'web_pages': ['http://www.ncuindia.edu/'],
#   'name': 'NorthCap University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ddu.ac.in'],
#   'country': 'India',
#   'state-province': 'Gujarat',
#   'web_pages': ['http://www.ddu.ac.in/'],
#   'name': 'Dharamsinh Desai University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ntruhs.ap.nic.in'],
#   'country': 'India',
#   'state-province': 'Andhra Pradesh',
#   'web_pages': ['http://ntruhs.ap.nic.in/'],
#   'name': 'University of Health Sciences Andhra Pradesh'},
#  {'alpha_two_code': 'IN',
#   'domains': ['aaidu.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.aaidu.org/'],
#   'name': 'Allahabad Agricultural Institute, Deemed University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['aau.ac.in'],
#   'country': 'India',
#   'state-province': 'Assam',
#   'web_pages': ['http://www.aau.ac.in/'],
#   'name': 'Assam Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ahduni.edu.in'],
#   'country': 'India',
#   'state-province': 'Gujarat',
#   'web_pages': ['http://www.ahduni.edu.in/'],
#   'name': 'Ahmedabad University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['aiims.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.aiims.ac.in/'],
#   'name': 'All India Institute of Medical Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['aisectuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.aisectuniversity.ac.in/'],
#   'name': 'AISECT University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['alagappauniversity.ac.in'],
#   'country': 'India',
#   'state-province': 'Tamil Nadu',
#   'web_pages': ['http://www.alagappauniversity.ac.in/'],
#   'name': 'Alagappa University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['alldunivpio.org'],
#   'country': 'India',
#   'state-province': 'Uttar Pradesh',
#   'web_pages': ['http://www.alldunivpio.org/'],
#   'name': 'Allahabad University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['altmeduniversity.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.altmeduniversity.com/'],
#   'name': 'Open International University for Alternative Medicines'},
#  {'alpha_two_code': 'IN',
#   'domains': ['altmedworld.net'],
#   'country': 'India',
#   'state-province': 'West Bengal',
#   'web_pages': ['http://www.altmedworld.net/'],
#   'name': 'Indian Board of Alternative Medicine'},
#  {'alpha_two_code': 'IN',
#   'domains': ['amity.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.amity.edu/'],
#   'name': 'Amity University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['amrita.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.amrita.edu/'],
#   'name': 'Amrita Vishwa Vidyapeetham (Deemed University)'},
#  {'alpha_two_code': 'IN',
#   'domains': ['amtuni.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.amtuni.com/'],
#   'name': 'Amravati University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['amu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.amu.ac.in/'],
#   'name': 'Aligarh Muslim University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['andhrauniversity.info'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.andhrauniversity.info/'],
#   'name': 'Andhra University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['angrau.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.angrau.net/'],
#   'name': 'Acharya Ranga Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['annamalaiuniversity.ac.in'],
#   'country': 'India',
#   'state-province': 'Tamil Nadu',
#   'web_pages': ['http://www.annamalaiuniversity.ac.in/'],
#   'name': 'Annamalai University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['annauniv.edu.in'],
#   'country': 'India',
#   'state-province': 'Tamil Nadu',
#   'web_pages': ['http://www.annauniv.edu.in/'],
#   'name': 'Anna University of Technology, Tirunelveli'},
#  {'alpha_two_code': 'IN',
#   'domains': ['annauniv.edu'],
#   'country': 'India',
#   'state-province': 'Tamil Nadu',
#   'web_pages': ['http://www.annauniv.edu/'],
#   'name': 'Anna University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['apsurewa.nic.in'],
#   'country': 'India',
#   'state-province': 'Madhya Pradesh',
#   'web_pages': ['http://www.apsurewa.nic.in/'],
#   'name': 'Awadhesh Pratap Singh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['aryainstitutejpr.com'],
#   'country': 'India',
#   'state-province': 'Rajasthan',
#   'web_pages': ['http://www.aryainstitutejpr.com/'],
#   'name': 'ARYA Institute of Engineering & Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['assamuniversity.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.assamuniversity.nic.in/'],
#   'name': 'Assam University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ayurveduniversity.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ayurveduniversity.com/'],
#   'name': 'Gujarat Ayurved University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bamu.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bamu.net/'],
#   'name': 'Dr. Babasaheb Ambedkar Marathwada Universtiy'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bamu.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bamu.nic.in/'],
#   'name': 'Berhampur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['banasthali.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.banasthali.org/'],
#   'name': 'Banasthali University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bankurauniv.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bankurauniv.com/'],
#   'name': 'Bankura University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bau.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bau.nic.in/'],
#   'name': 'Birsa Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bbauindia.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bbauindia.org/'],
#   'name': 'Babasaheb Bhimrao Ambedkar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bckv.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bckv.edu.in/'],
#   'name': 'Bidhan Chandra Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bdu.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bdu.ernet.in/'],
#   'name': 'Bharathidasan University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['becs.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.becs.ac.in/'],
#   'name': 'Bengal Engineering College'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bengaluruuniversity.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://bengaluruuniversity.com/'],
#   'name': 'Bangalore University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bhagwantuniversity.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bhagwantuniversity.com/'],
#   'name': 'Bhagwant University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bharathi.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bharathi.ernet.in/'],
#   'name': 'Bharathiar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bharathuniv.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bharathuniv.com/'],
#   'name': 'Bharath Institue Of Higher Education & Research'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bharatividyapeeth.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bharatividyapeeth.edu/'],
#   'name': 'Bharati Vidyapeeth University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bhavuni.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bhavuni.edu/'],
#   'name': 'Bhavnagar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bhu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bhu.ac.in/'],
#   'name': 'Banaras Hindu University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bhub.ori.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://bhub.ori.nic.in/ouat/'],
#   'name': 'Orissa University of Agriculture and Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bitmesraranchi.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://bitmesraranchi.org/'],
#   'name': 'Birla Institute of Technology, Ranchi'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bits-pilani.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bits-pilani.ac.in/'],
#   'name': 'Birla Institute of Technology and Science'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bnmu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bnmu.in/'],
#   'name': 'Bhupendra Narayan Mandal University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bput.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bput.org/'],
#   'name': 'Biju Pattnaik University of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['brabu.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.brabu.net/'],
#   'name': 'B. R. Ambedkar Bihar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['braou.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.braou.ac.in/'],
#   'name': 'Dr. B.R. Ambedkar Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nitj.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nitj.ac.in/'],
#   'name': 'Dr. B. R. Ambedkar National Institute of Technology Jalandhar'},
#  {'alpha_two_code': 'IN',
#   'domains': ['brauagra.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.brauagra.com/'],
#   'name': 'Dr. Bhim Rao Abdekar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bsauniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bsauniv.ac.in/'],
#   'name': 'B. S. Abdur Rahman University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bubhopal.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bubhopal.nic.in/'],
#   'name': 'Barkatullah University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['bundelkhanduniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.bundelkhanduniversity.org/'],
#   'name': 'Bundelkhand University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['burdwanuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.burdwanuniversity.ac.in/'],
#   'name': 'University of Burdwan'},
#  {'alpha_two_code': 'IN',
#   'domains': ['caluniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.caluniv.ac.in/'],
#   'name': 'University of Calcutta'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cau.org.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cau.org.in/'],
#   'name': 'Central Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ccsuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ccsuniversity.ac.in/'],
#   'name': 'Chaudhary Charan Singh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ccsuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ccsuniversity.org/'],
#   'name': 'Ch. Charan Singh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cesbm.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cesbm.ac.in/'],
#   'name': 'Center for Entrepreneurship and Small Business Management'},
#  {'alpha_two_code': 'IN',
#   'domains': ['christuniversity.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.christuniversity.in/'],
#   'name': 'Christ University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ciefl.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ciefl.org/'],
#   'name': 'Central Institute of English and Foreign Languages'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cife.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cife.edu.in/'],
#   'name': 'Central Institute of Fisheries Education'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cihts.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cihts.ac.in/'],
#   'name': 'Central Institute of Higher Tibetan Studies'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cmjuniversity.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cmjuniversity.edu.in/'],
#   'name': 'CMJ University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['csauk.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.csauk.ac.in/'],
#   'name': 'Chandra Shekhar Azad University of Agriculture and Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cusat.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cusat.ac.in/'],
#   'name': 'Cochin University of Science and Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['cvru.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.cvru.ac.in/'],
#   'name': 'Dr. C.V. Raman University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['da-iict.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.da-iict.org/'],
#   'name': 'Dhirubhai Ambani Institute of Information and Communication Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['darulhuda.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.darulhuda.com/'],
#   'name': 'Darul Huda Islamic University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['davuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.davuniversity.org/'],
#   'name': 'Dav University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['davv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.davv.ac.in/'],
#   'name': 'Devi Ahilya University of Indore'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dbatechuni.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dbatechuni.org/'],
#   'name': 'Dr. Babasaheb Ambedkar Technological University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dbskkv.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dbskkv.org/'],
#   'name': 'Konkan Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dbs.tn.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://dbs.tn.nic.in/tnau/'],
#   'name': 'Tamil Nadu Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dceonline.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dceonline.net/'],
#   'name': 'Delhi College of Engineering (DCE)'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ddugu.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ddugu.edu.in/'],
#   'name': 'Deen Dayal Upadhyay Gorakhpur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['deccancollegepune.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.deccancollegepune.ac.in/'],
#   'name': 'Deccan College Postgraduate and Research Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dei.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dei.ac.in/'],
#   'name': 'Dayalbagh Educational Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dibru.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dibru.ernet.in/'],
#   'name': 'Dibrugarh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dravidianuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dravidianuniversity.ac.in/'],
#   'name': 'Dravidian University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['du.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.du.ac.in/'],
#   'name': 'University of Delhi'},
#  {'alpha_two_code': 'IN',
#   'domains': ['dypatiluniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.dypatiluniversity.org/'],
#   'name': 'Dr. D.Y. Patil University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['eiilmuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.eiilmuniversity.ac.in/'],
#   'name': 'Eiilm University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['fatimacollege.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.fatimacollege.net/'],
#   'name': 'Fatima mata national college kollam kerala'},
#  {'alpha_two_code': 'IN',
#   'domains': ['fri.icfre.gov.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://fri.icfre.gov.in/'],
#   'name': 'Forest Research Institute Dehradun'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gbpuat.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gbpuat.ac.in/'],
#   'name': 'Govind Ballabh Pant University of Agriculture and Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ggu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ggu.ac.in/'],
#   'name': 'Guru Ghasidas University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gipe.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gipe.ernet.in/'],
#   'name': 'Gokhale Institute of Politics and Economics'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gitam.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gitam.edu/'],
#   'name': 'Gandhi Institute of Technology and Managment'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gju.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gju.ernet.in/'],
#   'name': 'Guru Jambeshwar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gkvharidwar.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gkvharidwar.org/'],
#   'name': 'Gurukula Kangri University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gnduonline.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gnduonline.org/'],
#   'name': 'Guru Nanak Dev University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['government.ind.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.government.ind.in/'],
#   'name': 'Global Open University , Nagaland'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gtu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gtu.ac.in/'],
#   'name': 'Gujarat Technological University Ahmedabad'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gujaratuniversity.org.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gujaratuniversity.org.in/'],
#   'name': 'Gujarat University Ahmedabad'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gulbargauniversity.kar.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gulbargauniversity.kar.nic.in/'],
#   'name': 'Gulbarga University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gu.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gu.nic.in/'],
#   'name': 'Gauhati University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['gurukuluniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.gurukuluniversity.org/'],
#   'name': 'Gurukul University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hau.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://hau.ernet.in/'],
#   'name': 'CCS Haryana Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hau.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.hau.ernet.in/'],
#   'name': 'Chaudhary Charan Singh Haryana Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hillagric.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://hillagric.ernet.in/'],
#   'name': 'Himachal Pradesh Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hnbgu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.hnbgu.ac.in/'],
#   'name': 'Hemwati Nandan Bahuguna Garhwal University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hnluraipur.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.hnluraipur.com/'],
#   'name': 'Hidayatullah National Law University, Raipur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hostindia.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.hostindia.com/srmc/'],
#   'name': 'Sri Ramachardra Medical College and Research Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['hpuniv.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://hpuniv.nic.in/'],
#   'name': 'Himachal Pradesh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iari.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iari.ernet.in/'],
#   'name': 'Indian Agricultural Research Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iaseduniv.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iaseduniv.org/'],
#   'name': 'IASE (Institute of Advanced Studies) Deemed University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['icfai.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.icfai.org/'],
#   'name': 'ICFAI University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iudehradun.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iudehradun.edu.in/'],
#   'name': 'ICFAI University, Dehradun'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iutripura.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iutripura.edu.in/'],
#   'name': 'ICFAI University, Tripura'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iusikkim.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iusikkim.edu.in/'],
#   'name': 'ICFAI University, Sikkim'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iumizoram.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iumizoram.edu.in/'],
#   'name': 'ICFAI University, Mizoram'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iumeghalaya.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iumeghalaya.edu.in/'],
#   'name': 'ICFAI University, Meghalaya'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iujharkhand.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iujharkhand.edu.in/'],
#   'name': 'ICFAI University, Jharkhand'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iunagaland.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iunagaland.edu.in/'],
#   'name': 'ICFAI University, Nagaland'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iujaipur.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iujaipur.edu.in/'],
#   'name': 'ICFAI University, Jaipur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iuraipur.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iuraipur.edu.in/'],
#   'name': 'ICFAI University, Raipur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iuhimachal.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.iuhimachal.edu.in/'],
#   'name': 'ICFAI University, Himachal Pradesh'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ifheindia.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.ifheindia.org/'],
#   'name': 'ICFAI University, Hyderabad'},
#  {'alpha_two_code': 'IN',
#   'domains': ['igau.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.igau.edu.in/'],
#   'name': 'Indira Gandhi Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['igidr.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.igidr.ac.in/'],
#   'name': 'Indira Gandhi Institute of Development and Research'},
#  {'alpha_two_code': 'IN',
#   'domains': ['igims.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.igims.org/'],
#   'name': 'Indira Gandhi Institute of Medical Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ignou.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ignou.ac.in/'],
#   'name': 'Indira Gandhi National Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiita.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iiita.com/'],
#   'name': 'Indian Institute of Information Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitmk.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iiitmk.ac.in/'],
#   'name': 'Indian Institute of Information Technology and Management - Kerala'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitm.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iiitm.ac.in/'],
#   'name': 'Indian Institute of Information Technology and Management - Gwalior'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitd.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iiitd.ac.in/'],
#   'name': 'Indraprastha Institute of Information Technology, Delhi'},
#  {'alpha_two_code': 'IN',
#   'domains': ['squareit.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['www.isquareit.ac.in/'],
#   'name': 'International Institute of Information Technology, Pune'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiit-bh.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['www.iiit-bh.ac.in/'],
#   'name': 'International Institute of Information Technology, Bhubaneswar'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitb.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['www.iiitb.ac.in/'],
#   'name': 'International Institute of Information Technology, Bangalore'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iimtrichy.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iimtrichy.ac.in/'],
#   'name': 'Indian Institute of Management, Tiruchirappalli'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitg.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iimtrichy.ac.in/'],
#   'name': 'Indian Institute of Information Technology, Guwahati'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitvadodara.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://iiitvadodara.ac.in/'],
#   'name': 'Indian Institute of Information Technology, Vadodara'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitkota.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://iiitkota.ac.in/'],
#   'name': 'Indian Institute of Information Technology, Kota'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iipsindia.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iipsindia.org/'],
#   'name': 'International Institute for Population Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iisc.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iisc.ernet.in/'],
#   'name': 'Indian Institute of Science'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitb.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitb.ac.in/'],
#   'name': 'Indian Institute of Technology, Bombay'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitd.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitd.ernet.in/'],
#   'name': 'Indian Institute of Technology, Delhi'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitgn.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://iitgn.ac.in/'],
#   'name': 'Indian Institute of Technology, Gandhinagar'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitg.ernet.in', 'iitg.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitg.ernet.in/', 'http://www.iitg.ac.in/'],
#   'name': 'Indian Institute of Technology, Guwahati'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iith.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iith.ac.in/'],
#   'name': 'Indian Institute of Technology, Hyderabad'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitk.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitk.ac.in/'],
#   'name': 'Indian Institute of Technology, Kanpur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitkgp.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitkgp.ernet.in/'],
#   'name': 'Indian Institute of Technology, Kharagpur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitm.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitm.ac.in/'],
#   'name': 'Indian Institute of Technology, Madras'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mitindia.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.mitindia.edu/en/'],
#   'name': 'Madras Institute of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitr.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitr.ac.in/'],
#   'name': 'Indian Institute of Technology, Roorkee'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitp.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitp.ac.in/'],
#   'name': 'Indian Institute of Technology, Patna'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiti.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iiti.ac.in/'],
#   'name': 'Indian Institute of Technology, Indore'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iitj.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iitj.ac.in/'],
#   'name': 'Indian Institute of Technology, Jodhpur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iksvv.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iksvv.com/'],
#   'name': 'University of Music and Fine Arts'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ilidelhi.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ilidelhi.org/'],
#   'name': 'Indian Law Institue'},
#  {'alpha_two_code': 'IN',
#   'domains': ['indusuni.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.indusuni.ac.in/'],
#   'name': 'Indus University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['integraluniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.integraluniversity.ac.in/'],
#   'name': 'Integral University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ipu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ipu.ac.in/'],
#   'name': 'Guru Gobind Singh Indraprastha University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['isbm.org.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://isbm.org.in/'],
#   'name': 'Indian School of Business Management and Administration'},
#  {'alpha_two_code': 'IN',
#   'domains': ['isical.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.isical.ac.in/'],
#   'name': 'Indian Statistical Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ismdhanbad.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ismdhanbad.ac.in/'],
#   'name': 'Indian School of Mines (ISM)'},
#  {'alpha_two_code': 'IN',
#   'domains': ['itmindia.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.itmindia.edu/'],
#   'name': 'Institute of Technology and Management'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iur.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.iur.ac.in/'],
#   'name': 'Indian University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ivri.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ivri.nic.in/'],
#   'name': 'Indian Veterinary Research Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jadavpur.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jadavpur.edu/'],
#   'name': 'Jadavpur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jainuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jainuniversity.org/'],
#   'name': 'First Global University to teaching Jainism'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jamiahamdard.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jamiahamdard.edu/'],
#   'name': 'Jamia Hamdard University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jammuvarsity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jammuvarsity.org/'],
#   'name': 'University of Jammu'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jiit.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jiit.ac.in/'],
#   'name': 'Jaypee Institute of Information Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jiwaji.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jiwaji.edu/'],
#   'name': 'Jiwaji University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jmi.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://jmi.nic.in/'],
#   'name': 'Jamia Millia Islamia University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jncasr.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jncasr.ac.in/'],
#   'name': 'Jawaharlal Nehru Centre for Advanced  Scientific Research'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jnkvv.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jnkvv.nic.in/'],
#   'name': 'Jawaharlal Nehru Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jntu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jntu.ac.in/'],
#   'name': 'Jawaharlal Nehru Technological University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jnu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jnu.ac.in/'],
#   'name': 'Jawaharlal Nehru University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jnujaipur.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jnujaipur.ac.in/'],
#   'name': 'Jaipur National University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jodhpurnationaluniversity.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jodhpurnationaluniversity.com/'],
#   'name': 'Jodhpur National University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jpv.bih.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://jpv.bih.nic.in/'],
#   'name': 'Jai Prakash University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jrnrvu.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jrnrvu.org/'],
#   'name': 'Rajasthan Vidyapeeth University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['jvbi.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.jvbi.ac.in/'],
#   'name': 'Jain Vishva Bharati Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kalingauniversity.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kalingauniversity.com/'],
#   'name': 'Kalinga University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kanchiuniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kanchiuniv.ac.in/'],
#   'name': 'Sri Chandrasekharendra Saraswathi Viswa Mahavidyalaya'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kannadauniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kannadauniversity.org/'],
#   'name': 'Kannada University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kannuruniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kannuruniversity.ac.in/'],
#   'name': 'Kannur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kanpuruniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kanpuruniversity.org/'],
#   'name': 'Chhatrapati Shahu Ji Maharaj University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kanpuruniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kanpuruniversity.org/'],
#   'name': 'Kanpur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['karnatakastateopenuniversity.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.karnatakastateopenuniversity.in/'],
#   'name': 'Karnataka State Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['karpagamuniv.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.karpagamuniv.com/'],
#   'name': 'Karpagam University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['karunya.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.karunya.edu/'],
#   'name': 'Karunya Institute Of Technology ( Deemed University)'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kashmiruniversity.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://kashmiruniversity.net/'],
#   'name': 'University of Kashmir'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kau.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kau.edu/'],
#   'name': 'Kerala Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['keralauniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.keralauniversity.ac.in/'],
#   'name': 'University of Kerala'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kimi.kohinoor.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://kimi.kohinoor.ac.in/'],
#   'name': 'Kohinoor School of Hospitality Management'},
#  {'alpha_two_code': 'IN',
#   'domains': ['klyuniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.klyuniv.ac.in/'],
#   'name': 'University of Kalyani'},
#  {'alpha_two_code': 'IN',
#   'domains': ['krishnauniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.krishnauniversity.ac.in/'],
#   'name': 'Krishna University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ksdsu.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ksdsu.edu.in/'],
#   'name': 'Kameshwar Singh Darbhanga Sanskrit University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kslu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kslu.ac.in/'],
#   'name': 'Karnataka State Law University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kud.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kud.ac.in/'],
#   'name': 'Karnatak University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kufos.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kufos.ac.in/'],
#   'name': 'Kerala University of Fisheries and Ocean Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kukinfo.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kukinfo.com/'],
#   'name': 'Kurukshetra University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kct.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kct.ac.in/'],
#   'name': 'Kumaraguru College of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kumaununiversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kumaununiversity.org/'],
#   'name': 'Kumaun University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kuvempu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kuvempu.ac.in/'],
#   'name': 'Kuvempu University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['kuwarangal.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.kuwarangal.com/'],
#   'name': 'Kakatiya University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ldceahd.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ldceahd.org/'],
#   'name': 'L.D.College of Engineering'},
#  {'alpha_two_code': 'IN',
#   'domains': ['lnipe.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.lnipe.edu/'],
#   'name': 'Lakshmibai National Institute of Physical Education'},
#  {'alpha_two_code': 'IN',
#   'domains': ['lnmu.bih.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://lnmu.bih.nic.in/'],
#   'name': 'Lalit Narayan Mithila University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['lucknowuniv.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.lucknowuniv.org/'],
#   'name': 'University of Lucknow'},
#  {'alpha_two_code': 'IN',
#   'domains': ['macfast.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.macfast.org/'],
#   'name': 'Mar Athanasios College for Advanced Studies'},
#  {'alpha_two_code': 'IN',
#   'domains': ['magadhuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.magadhuniversity.org/'],
#   'name': 'Magadh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mangaloreuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mangaloreuniversity.ac.in/'],
#   'name': 'Mangalore University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['manipal.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.manipal.edu/'],
#   'name': 'Manipal University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['manipur.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.manipur.nic.in/maniuniversity.htm'],
#   'name': 'Manipur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['manuu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.manuu.ac.in/'],
#   'name': 'Moulana Azad national Urdu University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mcu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mcu.ac.in/'],
#   'name': 'Makanlal Chutur Vedi University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mcu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mcu.ac.in/'],
#   'name': 'Makhanlal Chaturvedi National University of Journalism and Communication'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mdsuajmer.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mdsuajmer.ac.in/'],
#   'name': 'Maharshi Dayanand Sarswati University Ajmer'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mdurohtak.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mdurohtak.com/'],
#   'name': 'Maharishi Dayanand University, Rohtak (Haryana )'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mgkvp.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mgkvp.ac.in/'],
#   'name': 'Mahatma Gandhi Kashi Vidyapith'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mgsubikaner.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mgsubikaner.ac.in/'],
#   'name': 'Maharaja Ganga Singh University, Bikaner'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mgu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mgu.ac.in/'],
#   'name': 'Mahatma Gandhi University, Kerala'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mjpru.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mjpru.ac.in/'],
#   'name': 'Mahatma Jyotiba Phule Rohilkhand University Bareilly'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mkuhyd.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mkuhyd.com/'],
#   'name': 'Madurai Kamaraj University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mkv2.mah.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://mkv2.mah.nic.in/'],
#   'name': 'Marathwada Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mlsu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mlsu.ac.in/'],
#   'name': 'Mohan Lal Sukhadia University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mnnit.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mnnit.ac.in/'],
#   'name': 'Motilal Nehru National Institute Of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mpbou.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mpbou.org/'],
#   'name': 'Madhya Pradesh Bhoj (Open) University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mpkv.mah.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://mpkv.mah.nic.in/'],
#   'name': 'Mahatma Phule Agricultural University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['msubaroda.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.msubaroda.ac.in/'],
#   'name': 'Maharaja Sayajirao University of Baroda'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mu.ac.in/'],
#   'name': 'University of Mumbai'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nagarjunauniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nagarjunauniversity.ac.in/'],
#   'name': 'Acharya Nagarjuna University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nagauniv.org.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nagauniv.org.in/'],
#   'name': 'Nagaland University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nagpur-university.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nagpur-university.com/'],
#   'name': 'Nagpur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nalandaopenuniversity.info'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nalandaopenuniversity.info/'],
#   'name': 'Nalanda Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nationalmuseumindia.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nationalmuseumindia.org/nmi/index.htm'],
#   'name': 'National Museum Institute of History of Art, Conservation and Museology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nbu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.nbu.ac.in/'],
#   'name': 'University of North Bengal'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ndri.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://ndri.nic.in/'],
# ...
#   'name': 'SMK Fomra Institute of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['smu.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.smu.edu.in/'],
#   'name': 'Sikkim Manipal University of Health, Medical and Technological Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['sndt.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.sndt.edu/'],
#   'name': "Shreemati Nathibai Damodar Thackersey Women's University"},
#  {'alpha_two_code': 'IN',
#   'domains': ['soauniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.soauniversity.ac.in/'],
#   'name': "Sikha 'O' Anushandhan University"},
#  {'alpha_two_code': 'IN',
#   'domains': ['southasianuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.southasianuniversity.org/'],
#   'name': 'South Asian University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['spa.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.spa.ac.in/'],
#   'name': 'School of Planning and Architecture'},
#  {'alpha_two_code': 'IN',
#   'domains': ['spuniv.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.spuniv.org/'],
#   'name': 'Periyar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['spuvvn.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.spuvvn.edu/'],
#   'name': 'Sardar Patel University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['srisathyasai.org.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.srisathyasai.org.in/pages/instts/HighLearn.htm'],
#   'name': 'Sri Sathya Sai Institute of Higher Learning'},
#  {'alpha_two_code': 'IN',
#   'domains': ['srkdc.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.srkdc.org/'],
#   'name': 'Sree Rama Krishna Degree College'},
#  {'alpha_two_code': 'IN',
#   'domains': ['srmuniv.ac.in'],
#   'country': 'India',
#   'state-province': 'Tamil Nadu',
#   'web_pages': ['http://www.srmuniv.ac.in/'],
#   'name': 'SRM Institute Of Science & Technology ( Deemed University)'},
#  {'alpha_two_code': 'IN',
#   'domains': ['srtmun.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.srtmun.org/'],
#   'name': 'Swami Ramanand Teerth Marathwada University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ssgmce.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ssgmce.org/'],
#   'name': 'Sri Sant Gajanan Maharaj College of Engineering'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ssus.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ssus.ac.in/'],
#   'name': 'Sree Sankaracharya University of Sanskrit'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ssvv.up.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://ssvv.up.nic.in/'],
#   'name': 'Sampurnanand Sanskrit University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['su.digitaluniversity.ac'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://su.digitaluniversity.ac/'],
#   'name': 'Solapur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['svbpuctm.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.svbpuctm.org/'],
#   'name': 'Sardar Vallabhai Patel University of Agriculture Amd Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['svnit.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.svnit.ac.in/'],
#   'name': 'Sardar Vallabhbhai National Institute of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['svimstpt.ap.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://svimstpt.ap.nic.in/'],
#   'name': 'Sri Venkateswara Institute of Medical Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['svuni.ap.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://svuni.ap.nic.in/'],
#   'name': 'Sri Venkateswara University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tamiluniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tamiluniversity.ac.in/'],
#   'name': 'Tamil University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tanuvas.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tanuvas.com/'],
#   'name': 'Tamil Nadu Veterinary and Animal Sciences University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tce.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tce.edu/'],
#   'name': 'Thiagarajar College of Engineering'},
#  {'alpha_two_code': 'IN',
#   'domains': ['teluguuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.teluguuniversity.ac.in/'],
#   'name': 'Potti Sreeramulu Telugu University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['teluguuniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.teluguuniversity.ac.in/'],
#   'name': 'Telugu University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tezu.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tezu.ernet.in/'],
#   'name': 'Tezpur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['thenewcollege.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.thenewcollege.org/'],
#   'name': 'The New College'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tiet.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tiet.ac.in/'],
#   'name': 'Thapar Institute of Engineering and Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tiss.edu'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tiss.edu/'],
#   'name': 'Tata Institute of Social Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tmbu.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tmbu.org/'],
#   'name': 'Tilka Manjhi Bhagalpur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tmv.edu.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tmv.edu.in/'],
#   'name': 'Tilak Maharashtra Vidyapeeth'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tndalu.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tndalu.org/'],
#   'name': 'Tamil Nadu Dr. Ambedkar Law University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tnmmu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tnmmu.ac.in/'],
#   'name': 'Tamil Nadu Dr. M.G.R. Medical University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tnuniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tnuniv.ac.in/adu/'],
#   'name': 'Avinashilingam Institute for Home Science and Higher Education for Women'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tnuniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tnuniv.ac.in/gri/'],
#   'name': 'Gandhigram Rural Institute'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tnuniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tnuniv.ac.in/msu/'],
#   'name': 'Manonmaniam Sundaranar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tnuniv.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tnuniv.ac.in/mteresa/'],
#   'name': "Mother Teresa Women's University"},
#  {'alpha_two_code': 'IN',
#   'domains': ['manit.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.manit.ac.in/'],
#   'name': 'Maulana Azad National Institute of Technology Bhopal'},
#  {'alpha_two_code': 'IN',
#   'domains': ['mnit.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.mnit.ac.in/'],
#   'name': 'Malaviya National Institute of Technology Jaipur'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tripurauniv.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tripurauniv.in/'],
#   'name': 'Tripura University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tshmc.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tshmc.org/'],
#   'name': 'Takhatmal Shrivallabh Homoeopathic Medical College'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tumkuruniversity.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tumkuruniversity.ac.in/'],
#   'name': 'Tumkur University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['tvuni.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.tvuni.in/'],
#   'name': 'Thiruvalluvar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uasbng.kar.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://uasbng.kar.nic.in/'],
#   'name': 'University of Agricultural Sciences, Bangalore'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uasd.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uasd.net/'],
#   'name': 'University of Agricultural Sciences, Dharwad'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uktech.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uktech.ac.in/'],
#   'name': 'Uttarakhand Technical University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uma.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uma.ac.in/'],
#   'name': 'University of Media Arts'},
#  {'alpha_two_code': 'IN',
#   'domains': ['unical.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://unical.ac.in/'],
#   'name': 'University of Calicut'},
#  {'alpha_two_code': 'IN',
#   'domains': ['unigoa.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.unigoa.ac.in/'],
#   'name': 'Goa University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uni-mysore.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uni-mysore.ac.in/'],
#   'name': 'University of Mysore'},
#  {'alpha_two_code': 'IN',
#   'domains': ['unipune.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.unipune.ernet.in/'],
#   'name': 'University of Pune'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uniraj.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uniraj.org/'],
#   'name': 'University of Rajasthan'},
#  {'alpha_two_code': 'IN',
#   'domains': ['unishivaji.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.unishivaji.ac.in/'],
#   'name': 'Shivaji University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['unom.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.unom.ac.in/'],
#   'name': 'University of Madras'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uohyd.ernet.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uohyd.ernet.in/'],
#   'name': 'University of Hyderabad'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uok.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uok.ac.in/'],
#   'name': 'University of Kota'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uor.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uor.org/'],
#   'name': 'University of Roorkee'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uou.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uou.ac.in/'],
#   'name': 'Uttarakhand Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['uptu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.uptu.ac.in/'],
#   'name': 'Uttar Pradesh Technical University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['utkaluniv.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.utkaluniv.org/'],
#   'name': 'Utkal University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vbspu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://vbspu.ac.in/'],
#   'name': 'VBS Purvanchal University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vbu.co.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vbu.co.in/'],
#   'name': 'Vinoba Bhave University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vidyasagar.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vidyasagar.ac.in/'],
#   'name': 'Vidyasagar University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vignanuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vignanuniversity.org/'],
#   'name': 'Vignan University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vikramuniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vikramuniversity.org/'],
#   'name': 'Vikram University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vinayakamissions.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vinayakamissions.com/'],
#   'name': "Vinayaka Mission's Research Foundation-Deemed University"},
#  {'alpha_two_code': 'IN',
#   'domains': ['visva-bharati.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.visva-bharati.ac.in/'],
#   'name': 'Visva-Bharati University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vit.ac.in'],
#   'country': 'India',
#   'state-province': 'Tamil Nadu',
#   'web_pages': ['http://www.vit.ac.in/'],
#   'name': 'Vellore Institute of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vksu-ara.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vksu-ara.org/'],
#   'name': 'Veer Kunwar Singh University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vmou.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vmou.ac.in/'],
#   'name': 'Vardhaman Mahaveer Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vnitnagpur.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vnitnagpur.ac.in/'],
#   'name': 'Visvesvaraya National Institute of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vssut.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vssut.ac.in/'],
#   'name': 'Veer Surendra Sai University of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['vtu.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.vtu.ac.in/'],
#   'name': 'Visvesvaraya Technological University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['wbuafs.nic.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.wbuafs.nic.in/'],
#   'name': 'West Bengal University of Animal and Fishery Sciences'},
#  {'alpha_two_code': 'IN',
#   'domains': ['wbut.net'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.wbut.net/'],
#   'name': 'West Bengal University of Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ycmou.com'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ycmou.com/'],
#   'name': 'Yashawantrao Chavan Maharashtra Open University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['ysparmaruniversity.org'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['http://www.ysparmaruniversity.org/'],
#   'name': 'Dr. YS Parmar University of Horticulture and Forestry'},
#  {'alpha_two_code': 'IN',
#   'domains': ['charusat.ac.in'],
#   'country': 'India',
#   'state-province': None,
#   'web_pages': ['https://www.charusat.ac.in/'],
#   'name': 'Charotar University of Science and Technology'},
#  {'alpha_two_code': 'IN',
#   'domains': ['nuv.ac.in'],
#   'country': 'India',
#   'state-province': 'Gujarat',
#   'web_pages': ['https://www.nuv.ac.in/'],
#   'name': 'Navrachana University'},
#  {'alpha_two_code': 'IN',
#   'domains': ['iiitm.ac.in'],
#   'country': 'India',
#   'state-province': 'Madhya Pradesh',
#   'web_pages': ['https://www.iiitm.ac.in/'],
#   'name': 'Atal Bihari Vajpayee Indian Institute of Information Technology and Management, Gwalior'}]

# %%
# In Python, this JSON is stored as a dictionary
type(response.json())
# Out:
# list

# %% [markdown]
# It has two main methods:
#
#     - json.loads(), which creates a Python dictionary from a JSON format string (just as response.json() does)
#     - json.dumps() function converts a Python object into a json string.
#         - If indent parameter is a non-negative integer or string, then JSON array elements and object members will be pretty-printed with that indent level.

# %%
# A useful library for JSON manipulation and pretty print
import json
print(json.dumps(data, indent=5))
# Out:
# [
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "upes.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Dehradun",
#           "web_pages": [
#                "https://www.upes.ac.in/"
#           ],
#           "name": "University of Petroleum and Energy Studies"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "davietjal.org"
#           ],
#           "country": "India",
#           "state-province": "Punjab",
#           "web_pages": [
#                "http://www.davietjal.org/"
#           ],
#           "name": "DAV Institute of Engineering & Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "lpu.in"
#           ],
#           "country": "India",
#           "state-province": "Punjab",
#           "web_pages": [
#                "http://www.lpu.in/"
#           ],
#           "name": "Lovely Professional University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "somaiya.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://somaiya.edu/"
#           ],
#           "name": "Somaiya Vidyavihar"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ncuindia.edu"
#           ],
#           "country": "India",
#           "state-province": "Haryana",
#           "web_pages": [
#                "http://www.ncuindia.edu/"
#           ],
#           "name": "NorthCap University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ddu.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Gujarat",
#           "web_pages": [
#                "http://www.ddu.ac.in/"
#           ],
#           "name": "Dharamsinh Desai University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ntruhs.ap.nic.in"
#           ],
#           "country": "India",
#           "state-province": "Andhra Pradesh",
#           "web_pages": [
#                "http://ntruhs.ap.nic.in/"
#           ],
#           "name": "University of Health Sciences Andhra Pradesh"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "aaidu.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.aaidu.org/"
#           ],
#           "name": "Allahabad Agricultural Institute, Deemed University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "aau.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Assam",
#           "web_pages": [
#                "http://www.aau.ac.in/"
#           ],
#           "name": "Assam Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ahduni.edu.in"
#           ],
#           "country": "India",
#           "state-province": "Gujarat",
#           "web_pages": [
#                "http://www.ahduni.edu.in/"
#           ],
#           "name": "Ahmedabad University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "aiims.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.aiims.ac.in/"
#           ],
#           "name": "All India Institute of Medical Sciences"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "aisectuniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.aisectuniversity.ac.in/"
#           ],
#           "name": "AISECT University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "alagappauniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Tamil Nadu",
#           "web_pages": [
#                "http://www.alagappauniversity.ac.in/"
#           ],
#           "name": "Alagappa University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "alldunivpio.org"
#           ],
#           "country": "India",
#           "state-province": "Uttar Pradesh",
#           "web_pages": [
#                "http://www.alldunivpio.org/"
#           ],
#           "name": "Allahabad University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "altmeduniversity.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.altmeduniversity.com/"
#           ],
#           "name": "Open International University for Alternative Medicines"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "altmedworld.net"
#           ],
#           "country": "India",
#           "state-province": "West Bengal",
#           "web_pages": [
#                "http://www.altmedworld.net/"
#           ],
#           "name": "Indian Board of Alternative Medicine"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "amity.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.amity.edu/"
#           ],
#           "name": "Amity University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "amrita.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.amrita.edu/"
#           ],
#           "name": "Amrita Vishwa Vidyapeetham (Deemed University)"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "amtuni.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.amtuni.com/"
#           ],
#           "name": "Amravati University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "amu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.amu.ac.in/"
#           ],
#           "name": "Aligarh Muslim University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "andhrauniversity.info"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.andhrauniversity.info/"
#           ],
#           "name": "Andhra University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "angrau.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.angrau.net/"
#           ],
#           "name": "Acharya Ranga Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "annamalaiuniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Tamil Nadu",
#           "web_pages": [
#                "http://www.annamalaiuniversity.ac.in/"
#           ],
#           "name": "Annamalai University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "annauniv.edu.in"
#           ],
#           "country": "India",
#           "state-province": "Tamil Nadu",
#           "web_pages": [
#                "http://www.annauniv.edu.in/"
#           ],
#           "name": "Anna University of Technology, Tirunelveli"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "annauniv.edu"
#           ],
#           "country": "India",
#           "state-province": "Tamil Nadu",
#           "web_pages": [
#                "http://www.annauniv.edu/"
#           ],
#           "name": "Anna University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "apsurewa.nic.in"
#           ],
#           "country": "India",
#           "state-province": "Madhya Pradesh",
#           "web_pages": [
#                "http://www.apsurewa.nic.in/"
#           ],
#           "name": "Awadhesh Pratap Singh University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "aryainstitutejpr.com"
#           ],
#           "country": "India",
#           "state-province": "Rajasthan",
#           "web_pages": [
#                "http://www.aryainstitutejpr.com/"
#           ],
#           "name": "ARYA Institute of Engineering & Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "assamuniversity.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.assamuniversity.nic.in/"
#           ],
#           "name": "Assam University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ayurveduniversity.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ayurveduniversity.com/"
#           ],
#           "name": "Gujarat Ayurved University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bamu.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bamu.net/"
#           ],
#           "name": "Dr. Babasaheb Ambedkar Marathwada Universtiy"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bamu.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bamu.nic.in/"
#           ],
#           "name": "Berhampur University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "banasthali.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.banasthali.org/"
#           ],
#           "name": "Banasthali University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bankurauniv.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bankurauniv.com/"
#           ],
#           "name": "Bankura University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bau.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bau.nic.in/"
#           ],
#           "name": "Birsa Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bbauindia.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bbauindia.org/"
#           ],
#           "name": "Babasaheb Bhimrao Ambedkar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bckv.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bckv.edu.in/"
#           ],
#           "name": "Bidhan Chandra Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bdu.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bdu.ernet.in/"
#           ],
#           "name": "Bharathidasan University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "becs.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.becs.ac.in/"
#           ],
#           "name": "Bengal Engineering College"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bengaluruuniversity.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://bengaluruuniversity.com/"
#           ],
#           "name": "Bangalore University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bhagwantuniversity.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bhagwantuniversity.com/"
#           ],
#           "name": "Bhagwant University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bharathi.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bharathi.ernet.in/"
#           ],
#           "name": "Bharathiar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bharathuniv.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bharathuniv.com/"
#           ],
#           "name": "Bharath Institue Of Higher Education & Research"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bharatividyapeeth.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bharatividyapeeth.edu/"
#           ],
#           "name": "Bharati Vidyapeeth University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bhavuni.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bhavuni.edu/"
#           ],
#           "name": "Bhavnagar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bhu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bhu.ac.in/"
#           ],
#           "name": "Banaras Hindu University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bhub.ori.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://bhub.ori.nic.in/ouat/"
#           ],
#           "name": "Orissa University of Agriculture and Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bitmesraranchi.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://bitmesraranchi.org/"
#           ],
#           "name": "Birla Institute of Technology, Ranchi"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bits-pilani.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bits-pilani.ac.in/"
#           ],
#           "name": "Birla Institute of Technology and Science"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bnmu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bnmu.in/"
#           ],
#           "name": "Bhupendra Narayan Mandal University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bput.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bput.org/"
#           ],
#           "name": "Biju Pattnaik University of Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "brabu.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.brabu.net/"
#           ],
#           "name": "B. R. Ambedkar Bihar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "braou.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.braou.ac.in/"
#           ],
#           "name": "Dr. B.R. Ambedkar Open University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "nitj.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.nitj.ac.in/"
#           ],
#           "name": "Dr. B. R. Ambedkar National Institute of Technology Jalandhar"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "brauagra.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.brauagra.com/"
#           ],
#           "name": "Dr. Bhim Rao Abdekar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bsauniv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bsauniv.ac.in/"
#           ],
#           "name": "B. S. Abdur Rahman University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bubhopal.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bubhopal.nic.in/"
#           ],
#           "name": "Barkatullah University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "bundelkhanduniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.bundelkhanduniversity.org/"
#           ],
#           "name": "Bundelkhand University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "burdwanuniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.burdwanuniversity.ac.in/"
#           ],
#           "name": "University of Burdwan"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "caluniv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.caluniv.ac.in/"
#           ],
#           "name": "University of Calcutta"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cau.org.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cau.org.in/"
#           ],
#           "name": "Central Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ccsuniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ccsuniversity.ac.in/"
#           ],
#           "name": "Chaudhary Charan Singh University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ccsuniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ccsuniversity.org/"
#           ],
#           "name": "Ch. Charan Singh University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cesbm.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cesbm.ac.in/"
#           ],
#           "name": "Center for Entrepreneurship and Small Business Management"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "christuniversity.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.christuniversity.in/"
#           ],
#           "name": "Christ University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ciefl.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ciefl.org/"
#           ],
#           "name": "Central Institute of English and Foreign Languages"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cife.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cife.edu.in/"
#           ],
#           "name": "Central Institute of Fisheries Education"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cihts.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cihts.ac.in/"
#           ],
#           "name": "Central Institute of Higher Tibetan Studies"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cmjuniversity.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cmjuniversity.edu.in/"
#           ],
#           "name": "CMJ University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "csauk.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.csauk.ac.in/"
#           ],
#           "name": "Chandra Shekhar Azad University of Agriculture and Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cusat.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cusat.ac.in/"
#           ],
#           "name": "Cochin University of Science and Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "cvru.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.cvru.ac.in/"
#           ],
#           "name": "Dr. C.V. Raman University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "da-iict.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.da-iict.org/"
#           ],
#           "name": "Dhirubhai Ambani Institute of Information and Communication Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "darulhuda.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.darulhuda.com/"
#           ],
#           "name": "Darul Huda Islamic University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "davuniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.davuniversity.org/"
#           ],
#           "name": "Dav University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "davv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.davv.ac.in/"
#           ],
#           "name": "Devi Ahilya University of Indore"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dbatechuni.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dbatechuni.org/"
#           ],
#           "name": "Dr. Babasaheb Ambedkar Technological University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dbskkv.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dbskkv.org/"
#           ],
#           "name": "Konkan Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dbs.tn.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://dbs.tn.nic.in/tnau/"
#           ],
#           "name": "Tamil Nadu Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dceonline.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dceonline.net/"
#           ],
#           "name": "Delhi College of Engineering (DCE)"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ddugu.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ddugu.edu.in/"
#           ],
#           "name": "Deen Dayal Upadhyay Gorakhpur University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "deccancollegepune.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.deccancollegepune.ac.in/"
#           ],
#           "name": "Deccan College Postgraduate and Research Institute"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dei.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dei.ac.in/"
#           ],
#           "name": "Dayalbagh Educational Institute"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dibru.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dibru.ernet.in/"
#           ],
#           "name": "Dibrugarh University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dravidianuniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dravidianuniversity.ac.in/"
#           ],
#           "name": "Dravidian University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "du.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.du.ac.in/"
#           ],
#           "name": "University of Delhi"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "dypatiluniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.dypatiluniversity.org/"
#           ],
#           "name": "Dr. D.Y. Patil University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "eiilmuniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.eiilmuniversity.ac.in/"
#           ],
#           "name": "Eiilm University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "fatimacollege.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.fatimacollege.net/"
#           ],
#           "name": "Fatima mata national college kollam kerala"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "fri.icfre.gov.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://fri.icfre.gov.in/"
#           ],
#           "name": "Forest Research Institute Dehradun"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gbpuat.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gbpuat.ac.in/"
#           ],
#           "name": "Govind Ballabh Pant University of Agriculture and Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ggu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ggu.ac.in/"
#           ],
#           "name": "Guru Ghasidas University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gipe.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gipe.ernet.in/"
#           ],
#           "name": "Gokhale Institute of Politics and Economics"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gitam.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gitam.edu/"
#           ],
#           "name": "Gandhi Institute of Technology and Managment"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gju.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gju.ernet.in/"
#           ],
#           "name": "Guru Jambeshwar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gkvharidwar.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gkvharidwar.org/"
#           ],
#           "name": "Gurukula Kangri University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gnduonline.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gnduonline.org/"
#           ],
#           "name": "Guru Nanak Dev University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "government.ind.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.government.ind.in/"
#           ],
#           "name": "Global Open University , Nagaland"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gtu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gtu.ac.in/"
#           ],
#           "name": "Gujarat Technological University Ahmedabad"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gujaratuniversity.org.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gujaratuniversity.org.in/"
#           ],
#           "name": "Gujarat University Ahmedabad"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gulbargauniversity.kar.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gulbargauniversity.kar.nic.in/"
#           ],
#           "name": "Gulbarga University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gu.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gu.nic.in/"
#           ],
#           "name": "Gauhati University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "gurukuluniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.gurukuluniversity.org/"
#           ],
#           "name": "Gurukul University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hau.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://hau.ernet.in/"
#           ],
#           "name": "CCS Haryana Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hau.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.hau.ernet.in/"
#           ],
#           "name": "Chaudhary Charan Singh Haryana Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hillagric.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://hillagric.ernet.in/"
#           ],
#           "name": "Himachal Pradesh Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hnbgu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.hnbgu.ac.in/"
#           ],
#           "name": "Hemwati Nandan Bahuguna Garhwal University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hnluraipur.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.hnluraipur.com/"
#           ],
#           "name": "Hidayatullah National Law University, Raipur"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hostindia.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.hostindia.com/srmc/"
#           ],
#           "name": "Sri Ramachardra Medical College and Research Institute"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "hpuniv.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://hpuniv.nic.in/"
#           ],
#           "name": "Himachal Pradesh University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iari.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iari.ernet.in/"
#           ],
#           "name": "Indian Agricultural Research Institute"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iaseduniv.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iaseduniv.org/"
#           ],
#           "name": "IASE (Institute of Advanced Studies) Deemed University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "icfai.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.icfai.org/"
#           ],
#           "name": "ICFAI University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iudehradun.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iudehradun.edu.in/"
#           ],
#           "name": "ICFAI University, Dehradun"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iutripura.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iutripura.edu.in/"
#           ],
#           "name": "ICFAI University, Tripura"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iusikkim.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iusikkim.edu.in/"
#           ],
#           "name": "ICFAI University, Sikkim"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iumizoram.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iumizoram.edu.in/"
#           ],
#           "name": "ICFAI University, Mizoram"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iumeghalaya.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iumeghalaya.edu.in/"
#           ],
#           "name": "ICFAI University, Meghalaya"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iujharkhand.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iujharkhand.edu.in/"
#           ],
#           "name": "ICFAI University, Jharkhand"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iunagaland.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iunagaland.edu.in/"
#           ],
#           "name": "ICFAI University, Nagaland"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iujaipur.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iujaipur.edu.in/"
#           ],
#           "name": "ICFAI University, Jaipur"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iuraipur.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iuraipur.edu.in/"
#           ],
#           "name": "ICFAI University, Raipur"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iuhimachal.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.iuhimachal.edu.in/"
#           ],
#           "name": "ICFAI University, Himachal Pradesh"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ifheindia.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.ifheindia.org/"
#           ],
#           "name": "ICFAI University, Hyderabad"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "igau.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.igau.edu.in/"
#           ],
#           "name": "Indira Gandhi Agricultural University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "igidr.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.igidr.ac.in/"
#           ],
#           "name": "Indira Gandhi Institute of Development and Research"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "igims.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.igims.org/"
#           ],
#           "name": "Indira Gandhi Institute of Medical Sciences"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ignou.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ignou.ac.in/"
#           ],
#           "name": "Indira Gandhi National Open University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiita.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iiita.com/"
#           ],
#           "name": "Indian Institute of Information Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitmk.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iiitmk.ac.in/"
#           ],
#           "name": "Indian Institute of Information Technology and Management - Kerala"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitm.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iiitm.ac.in/"
#           ],
#           "name": "Indian Institute of Information Technology and Management - Gwalior"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitd.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iiitd.ac.in/"
#           ],
#           "name": "Indraprastha Institute of Information Technology, Delhi"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "squareit.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "www.isquareit.ac.in/"
#           ],
#           "name": "International Institute of Information Technology, Pune"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiit-bh.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "www.iiit-bh.ac.in/"
#           ],
#           "name": "International Institute of Information Technology, Bhubaneswar"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitb.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "www.iiitb.ac.in/"
#           ],
#           "name": "International Institute of Information Technology, Bangalore"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iimtrichy.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iimtrichy.ac.in/"
#           ],
#           "name": "Indian Institute of Management, Tiruchirappalli"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitg.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iimtrichy.ac.in/"
#           ],
#           "name": "Indian Institute of Information Technology, Guwahati"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitvadodara.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://iiitvadodara.ac.in/"
#           ],
#           "name": "Indian Institute of Information Technology, Vadodara"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitkota.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://iiitkota.ac.in/"
#           ],
#           "name": "Indian Institute of Information Technology, Kota"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iipsindia.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iipsindia.org/"
#           ],
#           "name": "International Institute for Population Sciences"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iisc.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iisc.ernet.in/"
#           ],
#           "name": "Indian Institute of Science"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitb.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitb.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Bombay"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitd.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitd.ernet.in/"
#           ],
#           "name": "Indian Institute of Technology, Delhi"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitgn.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://iitgn.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Gandhinagar"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitg.ernet.in",
#                "iitg.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitg.ernet.in/",
#                "http://www.iitg.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Guwahati"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iith.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iith.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Hyderabad"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitk.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitk.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Kanpur"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitkgp.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitkgp.ernet.in/"
#           ],
#           "name": "Indian Institute of Technology, Kharagpur"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitm.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitm.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Madras"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "mitindia.edu"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.mitindia.edu/en/"
#           ],
#           "name": "Madras Institute of Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitr.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.iitr.ac.in/"
#           ],
#           "name": "Indian Institute of Technology, Roorkee"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iitp.ac.in"
#           ],
#           "country": "India",
# ...
#           "domains": [
#                "tmbu.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tmbu.org/"
#           ],
#           "name": "Tilka Manjhi Bhagalpur University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tmv.edu.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tmv.edu.in/"
#           ],
#           "name": "Tilak Maharashtra Vidyapeeth"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tndalu.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tndalu.org/"
#           ],
#           "name": "Tamil Nadu Dr. Ambedkar Law University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tnmmu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tnmmu.ac.in/"
#           ],
#           "name": "Tamil Nadu Dr. M.G.R. Medical University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tnuniv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tnuniv.ac.in/adu/"
#           ],
#           "name": "Avinashilingam Institute for Home Science and Higher Education for Women"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tnuniv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tnuniv.ac.in/gri/"
#           ],
#           "name": "Gandhigram Rural Institute"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tnuniv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tnuniv.ac.in/msu/"
#           ],
#           "name": "Manonmaniam Sundaranar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tnuniv.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tnuniv.ac.in/mteresa/"
#           ],
#           "name": "Mother Teresa Women's University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "manit.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.manit.ac.in/"
#           ],
#           "name": "Maulana Azad National Institute of Technology Bhopal"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "mnit.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.mnit.ac.in/"
#           ],
#           "name": "Malaviya National Institute of Technology Jaipur"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tripurauniv.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tripurauniv.in/"
#           ],
#           "name": "Tripura University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tshmc.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tshmc.org/"
#           ],
#           "name": "Takhatmal Shrivallabh Homoeopathic Medical College"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tumkuruniversity.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tumkuruniversity.ac.in/"
#           ],
#           "name": "Tumkur University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "tvuni.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.tvuni.in/"
#           ],
#           "name": "Thiruvalluvar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uasbng.kar.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://uasbng.kar.nic.in/"
#           ],
#           "name": "University of Agricultural Sciences, Bangalore"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uasd.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uasd.net/"
#           ],
#           "name": "University of Agricultural Sciences, Dharwad"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uktech.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uktech.ac.in/"
#           ],
#           "name": "Uttarakhand Technical University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uma.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uma.ac.in/"
#           ],
#           "name": "University of Media Arts"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "unical.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://unical.ac.in/"
#           ],
#           "name": "University of Calicut"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "unigoa.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.unigoa.ac.in/"
#           ],
#           "name": "Goa University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uni-mysore.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uni-mysore.ac.in/"
#           ],
#           "name": "University of Mysore"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "unipune.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.unipune.ernet.in/"
#           ],
#           "name": "University of Pune"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uniraj.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uniraj.org/"
#           ],
#           "name": "University of Rajasthan"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "unishivaji.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.unishivaji.ac.in/"
#           ],
#           "name": "Shivaji University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "unom.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.unom.ac.in/"
#           ],
#           "name": "University of Madras"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uohyd.ernet.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uohyd.ernet.in/"
#           ],
#           "name": "University of Hyderabad"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uok.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uok.ac.in/"
#           ],
#           "name": "University of Kota"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uor.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uor.org/"
#           ],
#           "name": "University of Roorkee"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uou.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uou.ac.in/"
#           ],
#           "name": "Uttarakhand Open University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "uptu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.uptu.ac.in/"
#           ],
#           "name": "Uttar Pradesh Technical University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "utkaluniv.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.utkaluniv.org/"
#           ],
#           "name": "Utkal University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vbspu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://vbspu.ac.in/"
#           ],
#           "name": "VBS Purvanchal University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vbu.co.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vbu.co.in/"
#           ],
#           "name": "Vinoba Bhave University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vidyasagar.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vidyasagar.ac.in/"
#           ],
#           "name": "Vidyasagar University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vignanuniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vignanuniversity.org/"
#           ],
#           "name": "Vignan University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vikramuniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vikramuniversity.org/"
#           ],
#           "name": "Vikram University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vinayakamissions.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vinayakamissions.com/"
#           ],
#           "name": "Vinayaka Mission's Research Foundation-Deemed University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "visva-bharati.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.visva-bharati.ac.in/"
#           ],
#           "name": "Visva-Bharati University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vit.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Tamil Nadu",
#           "web_pages": [
#                "http://www.vit.ac.in/"
#           ],
#           "name": "Vellore Institute of Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vksu-ara.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vksu-ara.org/"
#           ],
#           "name": "Veer Kunwar Singh University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vmou.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vmou.ac.in/"
#           ],
#           "name": "Vardhaman Mahaveer Open University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vnitnagpur.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vnitnagpur.ac.in/"
#           ],
#           "name": "Visvesvaraya National Institute of Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vssut.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vssut.ac.in/"
#           ],
#           "name": "Veer Surendra Sai University of Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "vtu.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.vtu.ac.in/"
#           ],
#           "name": "Visvesvaraya Technological University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "wbuafs.nic.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.wbuafs.nic.in/"
#           ],
#           "name": "West Bengal University of Animal and Fishery Sciences"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "wbut.net"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.wbut.net/"
#           ],
#           "name": "West Bengal University of Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ycmou.com"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ycmou.com/"
#           ],
#           "name": "Yashawantrao Chavan Maharashtra Open University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "ysparmaruniversity.org"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "http://www.ysparmaruniversity.org/"
#           ],
#           "name": "Dr. YS Parmar University of Horticulture and Forestry"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "charusat.ac.in"
#           ],
#           "country": "India",
#           "state-province": null,
#           "web_pages": [
#                "https://www.charusat.ac.in/"
#           ],
#           "name": "Charotar University of Science and Technology"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "nuv.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Gujarat",
#           "web_pages": [
#                "https://www.nuv.ac.in/"
#           ],
#           "name": "Navrachana University"
#      },
#      {
#           "alpha_two_code": "IN",
#           "domains": [
#                "iiitm.ac.in"
#           ],
#           "country": "India",
#           "state-province": "Madhya Pradesh",
#           "web_pages": [
#                "https://www.iiitm.ac.in/"
#           ],
#           "name": "Atal Bihari Vajpayee Indian Institute of Information Technology and Management, Gwalior"
#      }
# ]

# %%
# Accessing the zeroth record from the data.

# %%
data[0]
# Out:
# {'alpha_two_code': 'IN',
#  'domains': ['upes.ac.in'],
#  'country': 'India',
#  'state-province': 'Dehradun',
#  'web_pages': ['https://www.upes.ac.in/'],
#  'name': 'University of Petroleum and Energy Studies'}

# %%
# Accessing the id of the zeroth record
#data[0]['id']
data[0]['country']
# Out:
# 'India'

# %%
# Accessing all the punchlines from the data
for i in data:
    print(i['web_pages'])
# Out:
# ['https://www.upes.ac.in/']
# ['http://www.davietjal.org/']
# ['http://www.lpu.in/']
# ['https://somaiya.edu/']
# ['http://www.ncuindia.edu/']
# ['http://www.ddu.ac.in/']
# ['http://ntruhs.ap.nic.in/']
# ['http://www.aaidu.org/']
# ['http://www.aau.ac.in/']
# ['http://www.ahduni.edu.in/']
# ['http://www.aiims.ac.in/']
# ['http://www.aisectuniversity.ac.in/']
# ['http://www.alagappauniversity.ac.in/']
# ['http://www.alldunivpio.org/']
# ['http://www.altmeduniversity.com/']
# ['http://www.altmedworld.net/']
# ['http://www.amity.edu/']
# ['http://www.amrita.edu/']
# ['http://www.amtuni.com/']
# ['http://www.amu.ac.in/']
# ['http://www.andhrauniversity.info/']
# ['http://www.angrau.net/']
# ['http://www.annamalaiuniversity.ac.in/']
# ['http://www.annauniv.edu.in/']
# ['http://www.annauniv.edu/']
# ['http://www.apsurewa.nic.in/']
# ['http://www.aryainstitutejpr.com/']
# ['http://www.assamuniversity.nic.in/']
# ['http://www.ayurveduniversity.com/']
# ['http://www.bamu.net/']
# ['http://www.bamu.nic.in/']
# ['http://www.banasthali.org/']
# ['http://www.bankurauniv.com/']
# ['http://www.bau.nic.in/']
# ['http://www.bbauindia.org/']
# ['http://www.bckv.edu.in/']
# ['http://www.bdu.ernet.in/']
# ['http://www.becs.ac.in/']
# ['http://bengaluruuniversity.com/']
# ['http://www.bhagwantuniversity.com/']
# ['http://www.bharathi.ernet.in/']
# ['http://www.bharathuniv.com/']
# ['http://www.bharatividyapeeth.edu/']
# ['http://www.bhavuni.edu/']
# ['http://www.bhu.ac.in/']
# ['http://bhub.ori.nic.in/ouat/']
# ['http://bitmesraranchi.org/']
# ['http://www.bits-pilani.ac.in/']
# ['http://www.bnmu.in/']
# ['http://www.bput.org/']
# ['http://www.brabu.net/']
# ['http://www.braou.ac.in/']
# ['http://www.nitj.ac.in/']
# ['http://www.brauagra.com/']
# ['http://www.bsauniv.ac.in/']
# ['http://www.bubhopal.nic.in/']
# ['http://www.bundelkhanduniversity.org/']
# ['http://www.burdwanuniversity.ac.in/']
# ['http://www.caluniv.ac.in/']
# ['http://www.cau.org.in/']
# ['http://www.ccsuniversity.ac.in/']
# ['http://www.ccsuniversity.org/']
# ['http://www.cesbm.ac.in/']
# ['http://www.christuniversity.in/']
# ['http://www.ciefl.org/']
# ['http://www.cife.edu.in/']
# ['http://www.cihts.ac.in/']
# ['http://www.cmjuniversity.edu.in/']
# ['http://www.csauk.ac.in/']
# ['http://www.cusat.ac.in/']
# ['http://www.cvru.ac.in/']
# ['http://www.da-iict.org/']
# ['http://www.darulhuda.com/']
# ['http://www.davuniversity.org/']
# ['http://www.davv.ac.in/']
# ['http://www.dbatechuni.org/']
# ['http://www.dbskkv.org/']
# ['http://dbs.tn.nic.in/tnau/']
# ['http://www.dceonline.net/']
# ['http://www.ddugu.edu.in/']
# ['http://www.deccancollegepune.ac.in/']
# ['http://www.dei.ac.in/']
# ['http://www.dibru.ernet.in/']
# ['http://www.dravidianuniversity.ac.in/']
# ['http://www.du.ac.in/']
# ['http://www.dypatiluniversity.org/']
# ['http://www.eiilmuniversity.ac.in/']
# ['http://www.fatimacollege.net/']
# ['http://fri.icfre.gov.in/']
# ['http://www.gbpuat.ac.in/']
# ['http://www.ggu.ac.in/']
# ['http://www.gipe.ernet.in/']
# ['http://www.gitam.edu/']
# ['http://www.gju.ernet.in/']
# ['http://www.gkvharidwar.org/']
# ['http://www.gnduonline.org/']
# ['http://www.government.ind.in/']
# ['http://www.gtu.ac.in/']
# ['http://www.gujaratuniversity.org.in/']
# ['http://www.gulbargauniversity.kar.nic.in/']
# ['http://www.gu.nic.in/']
# ['http://www.gurukuluniversity.org/']
# ['http://hau.ernet.in/']
# ['http://www.hau.ernet.in/']
# ['http://hillagric.ernet.in/']
# ['http://www.hnbgu.ac.in/']
# ['http://www.hnluraipur.com/']
# ['http://www.hostindia.com/srmc/']
# ['http://hpuniv.nic.in/']
# ['http://www.iari.ernet.in/']
# ['http://www.iaseduniv.org/']
# ['http://www.icfai.org/']
# ['https://www.iudehradun.edu.in/']
# ['https://www.iutripura.edu.in/']
# ['https://www.iusikkim.edu.in/']
# ['https://www.iumizoram.edu.in/']
# ['https://www.iumeghalaya.edu.in/']
# ['https://www.iujharkhand.edu.in/']
# ['https://www.iunagaland.edu.in/']
# ['https://www.iujaipur.edu.in/']
# ['https://www.iuraipur.edu.in/']
# ['https://www.iuhimachal.edu.in/']
# ['https://www.ifheindia.org/']
# ['http://www.igau.edu.in/']
# ['http://www.igidr.ac.in/']
# ['http://www.igims.org/']
# ['http://www.ignou.ac.in/']
# ['http://www.iiita.com/']
# ['http://www.iiitmk.ac.in/']
# ['http://www.iiitm.ac.in/']
# ['http://www.iiitd.ac.in/']
# ['www.isquareit.ac.in/']
# ['www.iiit-bh.ac.in/']
# ['www.iiitb.ac.in/']
# ['http://www.iimtrichy.ac.in/']
# ['http://www.iimtrichy.ac.in/']
# ['http://iiitvadodara.ac.in/']
# ['http://iiitkota.ac.in/']
# ['http://www.iipsindia.org/']
# ['http://www.iisc.ernet.in/']
# ['http://www.iitb.ac.in/']
# ['http://www.iitd.ernet.in/']
# ['https://iitgn.ac.in/']
# ['http://www.iitg.ernet.in/', 'http://www.iitg.ac.in/']
# ['http://www.iith.ac.in/']
# ['http://www.iitk.ac.in/']
# ['http://www.iitkgp.ernet.in/']
# ['http://www.iitm.ac.in/']
# ['https://www.mitindia.edu/en/']
# ['http://www.iitr.ac.in/']
# ['http://www.iitp.ac.in/']
# ['http://www.iiti.ac.in/']
# ['http://www.iitj.ac.in/']
# ['http://www.iksvv.com/']
# ['http://www.ilidelhi.org/']
# ['http://www.indusuni.ac.in/']
# ['http://www.integraluniversity.ac.in/']
# ['http://www.ipu.ac.in/']
# ['http://isbm.org.in/']
# ['http://www.isical.ac.in/']
# ['http://www.ismdhanbad.ac.in/']
# ['http://www.itmindia.edu/']
# ['http://www.iur.ac.in/']
# ['http://www.ivri.nic.in/']
# ['http://www.jadavpur.edu/']
# ['http://www.jainuniversity.org/']
# ['http://www.jamiahamdard.edu/']
# ['http://www.jammuvarsity.org/']
# ['http://www.jiit.ac.in/']
# ['http://www.jiwaji.edu/']
# ['http://jmi.nic.in/']
# ['http://www.jncasr.ac.in/']
# ['http://www.jnkvv.nic.in/']
# ['http://www.jntu.ac.in/']
# ['http://www.jnu.ac.in/']
# ['http://www.jnujaipur.ac.in/']
# ['http://www.jodhpurnationaluniversity.com/']
# ['http://jpv.bih.nic.in/']
# ['http://www.jrnrvu.org/']
# ['http://www.jvbi.ac.in/']
# ['http://www.kalingauniversity.com/']
# ['http://www.kanchiuniv.ac.in/']
# ['http://www.kannadauniversity.org/']
# ['http://www.kannuruniversity.ac.in/']
# ['http://www.kanpuruniversity.org/']
# ['http://www.kanpuruniversity.org/']
# ['http://www.karnatakastateopenuniversity.in/']
# ['http://www.karpagamuniv.com/']
# ['http://www.karunya.edu/']
# ['http://kashmiruniversity.net/']
# ['http://www.kau.edu/']
# ['http://www.keralauniversity.ac.in/']
# ['http://kimi.kohinoor.ac.in/']
# ['http://www.klyuniv.ac.in/']
# ['http://www.krishnauniversity.ac.in/']
# ['http://www.ksdsu.edu.in/']
# ['http://www.kslu.ac.in/']
# ['http://www.kud.ac.in/']
# ['http://www.kufos.ac.in/']
# ['http://www.kukinfo.com/']
# ['http://www.kct.ac.in/']
# ['http://www.kumaununiversity.org/']
# ['http://www.kuvempu.ac.in/']
# ['http://www.kuwarangal.com/']
# ['http://www.ldceahd.org/']
# ['http://www.lnipe.edu/']
# ['http://lnmu.bih.nic.in/']
# ['http://www.lucknowuniv.org/']
# ['http://www.macfast.org/']
# ['http://www.magadhuniversity.org/']
# ['http://www.mangaloreuniversity.ac.in/']
# ['http://www.manipal.edu/']
# ['http://www.manipur.nic.in/maniuniversity.htm']
# ['http://www.manuu.ac.in/']
# ['http://www.mcu.ac.in/']
# ['http://www.mcu.ac.in/']
# ['http://www.mdsuajmer.ac.in/']
# ['http://www.mdurohtak.com/']
# ['http://www.mgkvp.ac.in/']
# ['http://www.mgsubikaner.ac.in/']
# ['http://www.mgu.ac.in/']
# ['http://www.mjpru.ac.in/']
# ['http://www.mkuhyd.com/']
# ['http://mkv2.mah.nic.in/']
# ['http://www.mlsu.ac.in/']
# ['http://www.mnnit.ac.in/']
# ['http://www.mpbou.org/']
# ['http://mpkv.mah.nic.in/']
# ['http://www.msubaroda.ac.in/']
# ['http://www.mu.ac.in/']
# ['http://www.nagarjunauniversity.ac.in/']
# ['http://www.nagauniv.org.in/']
# ['http://www.nagpur-university.com/']
# ['http://www.nalandaopenuniversity.info/']
# ['http://www.nationalmuseumindia.org/nmi/index.htm']
# ['http://www.nbu.ac.in/']
# ['http://ndri.nic.in/']
# ['http://www.nduat.nic.in/']
# ['http://www.nehu.ac.in/']
# ['http://www.ngu.ac.in/']
# ['http://www.nimhans.kar.nic.in/']
# ['http://nims.ap.nic.in/']
# ['http://www.nims.net.in/']
# ['http://www.nirmauni.ac.in/']
# ['http://www.nitie.edu/']
# ['http://www.nita.ac.in/']
# ['http://www.nitandhra.ac.in/']
# ['http://www.nitap.in/']
# ['http://www.nitc.ac.in/']
# ['http://www.nitdelhi.ac.in/']
# ['http://www.nitdgp.ac.in/']
# ['http://www.nitgoa.ac.in/']
# ['http://www.nith.ac.in/']
# ['http://www.nitjsr.ac.in/']
# ['http://www.nitkkr.net/']
# ['http://www.nitmanipur.ac.in']
# ['http://www.nitm.ac.in']
# ['http://www.nitmz.ac.in']
# ['http://www.nitnagaland.ac.in']
# ['http://www.nitp.ac.in']
# ['http://www.nitpy.ac.in']
# ['http://www.nitrr.ac.in']
# ['http://www.nitrkl.ac.in/']
# ['http://www.nitsikkim.ac.in/']
# ['http://www.nits.ac.in/']
# ['http://www.nitsri.net/']
# ['http://www.nitk.ac.in/']
# ['http://www.nitt.edu/']
# ['http://www.nituk.ac.in/']
# ['http://www.nitw.ernet.in/']
# ['http://www.nls.ac.in/']
# ['http://www.nmims.edu/']
# ['http://www.nmu.ac.in/']
# ['http://www.nsit.ac.in/']
# ['http://www.osmania.ac.in/']
# ['http://www.padmavatiwomen-univ.org/']
# ['http://www.pdpu.ac.in/']
# ['http://www.pau.edu/']
# ['http://www.pdkv.ac.in/']
# ['http://www.paruluniversity.ac.in/']
# ['http://www.pec.ac.in/']
# ['http://www.pes.edu/']
# ['http://www.pgimer.nic.in/']
# ['http://www.pondiuni.org/']
# ['http://www.psgtech.edu/']
# ['http://www.ptetjnvu.org/']
# ['http://www.ptu.ac.in/']
# ['http://www.puchd.ac.in/']
# ['http://www.punjabiuniversity.ac.in/']
# ['http://puonline.bih.nic.in/']
# ['http://www.pusavarsity.org.in/']
# ['http://www.rabindrabharatiuniversity.net/']
# ['http://www.ranchiuniversity.org.in/']
# ['http://www.raubikaner.org/']
# ['http://www.rdunijbpin.org/']
# ['http://www.rgtu.net/']
# ['http://www.rgu.ac.in/']
# ['http://www.riths.ac.in/']
# ['http://www.rmlau.ac.in/']
# ['http://www.rsuniversity.com/']
# ['http://www.rtu.ac.in/']
# ['http://www.ruraluniversity-chitrakoot.org/']
# ['http://www.sagaruniversity.nic.in/']
# ['http://www.sambalpuruniversitypgc.in/']
# ['http://www.sanskrit.nic.in/']
# ['http://www.sastra.edu/']
# ['http://www.sathyabamauniv.ac.in/']
# ['http://www.saurashtrauniversity.edu/']
# ['http://www.sce.ac.in/']
# ['http://sctimst.ker.nic.in/']
# ['http://www.sdau.edu.in/']
# ['http://www.sgpgi.ac.in/']
# ['http://www.sgu.ernet.in/']
# ['http://www.shobhituniversity.ac.in/']
# ['http://www.shridharuniversity.ac.in/']
# ['http://www.simhapuriuniv.ac.in/']
# ['http://www.siu.edu.in/']
# ['http://www.sjsv.nic.in/']
# ['http://www.skmu.edu.in/']
# ['http://www.skuastkashmir.ac.in/']
# ['http://skuniv.ap.nic.in/']
# ['http://www.slbsrsv.ac.in/']
# ['http://www.smkfomra.net/']
# ['http://www.smu.edu.in/']
# ['http://www.sndt.edu/']
# ['http://www.soauniversity.ac.in/']
# ['http://www.southasianuniversity.org/']
# ['http://www.spa.ac.in/']
# ['http://www.spuniv.org/']
# ['http://www.spuvvn.edu/']
# ['http://www.srisathyasai.org.in/pages/instts/HighLearn.htm']
# ['http://www.srkdc.org/']
# ['http://www.srmuniv.ac.in/']
# ['http://www.srtmun.org/']
# ['http://www.ssgmce.org/']
# ['http://www.ssus.ac.in/']
# ['http://ssvv.up.nic.in/']
# ['http://su.digitaluniversity.ac/']
# ['http://www.svbpuctm.org/']
# ['http://www.svnit.ac.in/']
# ['http://svimstpt.ap.nic.in/']
# ['http://svuni.ap.nic.in/']
# ['http://www.tamiluniversity.ac.in/']
# ['http://www.tanuvas.com/']
# ['http://www.tce.edu/']
# ['http://www.teluguuniversity.ac.in/']
# ['http://www.teluguuniversity.ac.in/']
# ['http://www.tezu.ernet.in/']
# ['http://www.thenewcollege.org/']
# ['http://www.tiet.ac.in/']
# ['http://www.tiss.edu/']
# ['http://www.tmbu.org/']
# ['http://www.tmv.edu.in/']
# ['http://www.tndalu.org/']
# ['http://www.tnmmu.ac.in/']
# ['http://www.tnuniv.ac.in/adu/']
# ['http://www.tnuniv.ac.in/gri/']
# ['http://www.tnuniv.ac.in/msu/']
# ['http://www.tnuniv.ac.in/mteresa/']
# ['http://www.manit.ac.in/']
# ['http://www.mnit.ac.in/']
# ['http://www.tripurauniv.in/']
# ['http://www.tshmc.org/']
# ['http://www.tumkuruniversity.ac.in/']
# ['http://www.tvuni.in/']
# ['http://uasbng.kar.nic.in/']
# ['http://www.uasd.net/']
# ['http://www.uktech.ac.in/']
# ['http://www.uma.ac.in/']
# ['http://unical.ac.in/']
# ['http://www.unigoa.ac.in/']
# ['http://www.uni-mysore.ac.in/']
# ['http://www.unipune.ernet.in/']
# ['http://www.uniraj.org/']
# ['http://www.unishivaji.ac.in/']
# ['http://www.unom.ac.in/']
# ['http://www.uohyd.ernet.in/']
# ['http://www.uok.ac.in/']
# ['http://www.uor.org/']
# ['http://www.uou.ac.in/']
# ['http://www.uptu.ac.in/']
# ['http://www.utkaluniv.org/']
# ['http://vbspu.ac.in/']
# ['http://www.vbu.co.in/']
# ['http://www.vidyasagar.ac.in/']
# ['http://www.vignanuniversity.org/']
# ['http://www.vikramuniversity.org/']
# ['http://www.vinayakamissions.com/']
# ['http://www.visva-bharati.ac.in/']
# ['http://www.vit.ac.in/']
# ['http://www.vksu-ara.org/']
# ['http://www.vmou.ac.in/']
# ['http://www.vnitnagpur.ac.in/']
# ['http://www.vssut.ac.in/']
# ['http://www.vtu.ac.in/']
# ['http://www.wbuafs.nic.in/']
# ['http://www.wbut.net/']
# ['http://www.ycmou.com/']
# ['http://www.ysparmaruniversity.org/']
# ['https://www.charusat.ac.in/']
# ['https://www.nuv.ac.in/']
# ['https://www.iiitm.ac.in/']

# %% [markdown]
# The parameters need to be prefixed by a single question mark (?) and separate key/value pairs need to be delimited from another by an ampersand (&). Keys are separated from values with an equals sign (=).

# %%
# Accessing the url with the parameter
r = requests.get(base_url, params = {"web_pages": "http://www.aaidu.org/"})
#r = requests.get(base_url, params = {"id": 379})
r.ok
# Out:
# True

# %% [markdown]
# response.url returns the URL of the response. It will show the main url which has returned the content, after all redirections, if done.

# %%
r.url
# Out:
# 'http://universities.hipolabs.com/search?country=India&web_pages=http%3A%2F%2Fwww.aaidu.org%2F'

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[{"alpha_two_code": "IN", "domains": ["upes.ac.in"], "country": "India", "state-province": "Dehradun", "web_pages": ["https://www.upes.ac.in/"], "name": "University of Petroleum and Energy Studies"}, {"alpha_two_code": "IN", "domains": ["davietjal.org"], "country": "India", "state-province": "Punjab", "web_pages": ["http://www.davietjal.org/"], "name": "DAV Institute of Engineering & Technology"}, {"alpha_two_code": "IN", "domains": ["lpu.in"], "country": "India", "state-province": "Punjab", "web_pages": ["http://www.lpu.in/"], "name": "Lovely Professional University"}, {"alpha_two_code": "IN", "domains": ["somaiya.edu"], "country": "India", "state-province": null, "web_pages": ["https://somaiya.edu/"], "name": "Somaiya Vidyavihar"}, {"alpha_two_code": "IN", "domains": ["ncuindia.edu"], "country": "India", "state-province": "Haryana", "web_pages": ["http://www.ncuindia.edu/"], "name": "NorthCap University"}, {"alpha_two_code": "IN", "domains": ["ddu.ac.in"], "country": "India", "state-province": "Gujarat", "web_pages": ["http://www.ddu.ac.in/"], "name": "Dharamsinh Desai University"}, {"alpha_two_code": "IN", "domains": ["ntruhs.ap.nic.in"], "country": "India", "state-province": "Andhra Pradesh", "web_pages": ["http://ntruhs.ap.nic.in/"], "name": "University of Health Sciences Andhra Pradesh"}, {"alpha_two_code": "IN", "domains": ["aaidu.org"], "country": "India", "state-province": null, "web_pages": ["http://www.aaidu.org/"], "name": "Allahabad Agricultural Institute, Deemed University"}, {"alpha_two_code": "IN", "domains": ["aau.ac.in"], "country": "India", "state-province": "Assam", "web_pages": ["http://www.aau.ac.in/"], "name": "Assam Agricultural University"}, {"alpha_two_code": "IN", "domains": ["ahduni.edu.in"], "country": "India", "state-province": "Gujarat", "web_pages": ["http://www.ahduni.edu.in/"], "name": "Ahmedabad University"}, {"alpha_two_code": "IN", "domains": ["aiims.ac.in"], "country": "India", "state-province": null, "web_pages": ["http://www.aiims.ac.in/"], "name": "All India Institute of Medical Sciences"}, {"alpha_two_code": "IN", "domains": ["aisectuniversity.ac.in"], "country": "India", "state-province": null, "web_pages": ["http://www.aisectuniversity.ac.in/"], "name": "AISECT University"}, {"alpha_two_code": "IN", "domains": ["alagappauniversity.ac.in"], "country": "India", "state-province": "Tamil Nadu", "web_pages": ["http://www.alagappauniversity.ac.in/"], "name": "Alagappa University"}, {"alpha_two_code": "IN", "domains": ["alldunivpio.org"], "country": "India", "state-province": "Uttar Pradesh", "web_pages": ["http://www.alldunivpio.org/"], "name": "Allahabad University"}, {"alpha_two_code": "IN", "domains": ["altmeduniversity.com"], "country": "India", "state-province": null, "web_pages": ["http://www.altmeduniversity.com/"], "name": "Open International University for Alternative Medicines"}, {"alpha_two_code": "IN", "domains": ["altmedworld.net"], "country": "India", "state-province": "West Bengal", "web_pages": ["http://www.altmedworld.net/"], "name": "Indian Board of Alternative Medicine"}, {"alpha_two_code": "IN", "domains": ["amity.edu"], "country": "India", "state-province": null, "web_pages": ["http://www.amity.edu/"], "name": "Amity University"}, {"alpha_two_code": "IN", "domains": ["amrita.edu"], "country": "India", "state-province": null, "web_pages": ["http://www.amrita.edu/"], "name": "Amrita Vishwa Vidyapeetham (Deemed University)"}, {"alpha_two_code": "IN", "domains": ["amtuni.com"], "country": "India", "state-province": null, "web_pages": ["http://www.amtuni.com/"], "name": "Amravati University"}, {"alpha_two_code": "IN", "domains": ["amu.ac.in"], "country": "India", "state-province": null, "web_pages": ["http://www.amu.ac.in/"], "name": "Aligarh Muslim University"}, {"alpha_two_code": "IN", "domains": ["andhrauniversity.info"], "country": "India", "state-province": null, "web_pages": ["http://www.andhrauniversity.info/"], "name": "Andhra University"}, {"alpha_two_code": "IN", ...

# %%
# API requiring registration - POST request

# %% [markdown]
# ### API Key Setting Scenario:

# %% [markdown]
# ### Setup API Key

# %% [markdown]
# You can sign-up for the Developer (Free) edition and get your API Key from - : https://thecatapi.com/#pricing
#
# #### API documentation:  https://docs.thecatapi.com/

# %%
import requests
import json

# %% [markdown]
# - Click the URL
# - Select Pricing
# - Click sign up for free
# - Enter your email address and hit the signup button
# - You will receive your API key on email as shown below:
# ![image.png](attachment:image.png)

# %%
APP_KEY = "a2573bc5-e4a6-4dd1-a635-a956836b0c53"

# %%
# Setting up the request URL
api_endpoint = "https://api.thecatapi.com/v1/images/search"

# %% [markdown]
# ### Adding API key as a parameter to the endpoint.
# - Parameters are added at the end of the base_url seperated by a question mark.

# %%
url = api_endpoint + "?"+ "&app_key=" + APP_KEY

# %%
url
# Out:
# 'https://api.thecatapi.com/v1/images/search?&app_key=a2573bc5-e4a6-4dd1-a635-a956836b0c53'

# %% [markdown]
# #### Making a GET request to the url and storing the response object

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ##### response.text returns the content of the response, in unicode.

# %%
response.text
# Out:
# '[{"breeds":[{"weight":{"imperial":"8 - 16","metric":"4 - 7"},"id":"sibe","name":"Siberian","cfa_url":"http://cfa.org/Breeds/BreedsSthruT/Siberian.aspx","vetstreet_url":"http://www.vetstreet.com/cats/siberian","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/siberian","temperament":"Curious, Intelligent, Loyal, Sweet, Agile, Playful, Affectionate","origin":"Russia","country_codes":"RU","country_code":"RU","description":"The Siberians dog like temperament and affection makes the ideal lap cat and will live quite happily indoors. Very agile and powerful, the Siberian cat can easily leap and reach high places, including the tops of refrigerators and even doors. ","life_span":"12 - 15","indoor":0,"lap":1,"alt_names":"Moscow Semi-longhair, HairSiberian Forest Cat","adaptability":5,"affection_level":5,"child_friendly":4,"dog_friendly":5,"energy_level":5,"grooming":2,"health_issues":2,"intelligence":5,"shedding_level":3,"social_needs":4,"stranger_friendly":3,"vocalisation":1,"experimental":0,"hairless":0,"natural":1,"rare":0,"rex":0,"suppressed_tail":0,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/Siberian_(cat)","hypoallergenic":1,"reference_image_id":"3bkZAjRh1"}],"id":"YmPlzWUvb","url":"https://cdn2.thecatapi.com/images/YmPlzWUvb.jpg","width":880,"height":703}]'

# %%
r = requests.get(url, params = {"attach_breed": 2})
r
# Out:
# <Response [200]>

# %% [markdown]
# #### Retrieving the data only of the breed_id bengal

# %%
r = requests.get("https://api.thecatapi.com/v1/images/search?breed_id=beng")
r.text
# Out:
# '[{"breeds":[{"weight":{"imperial":"6 - 12","metric":"3 - 7"},"id":"beng","name":"Bengal","cfa_url":"http://cfa.org/Breeds/BreedsAB/Bengal.aspx","vetstreet_url":"http://www.vetstreet.com/cats/bengal","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/bengal","temperament":"Alert, Agile, Energetic, Demanding, Intelligent","origin":"United States","country_codes":"US","country_code":"US","description":"Bengals are a lot of fun to live with, but they\'re definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn\'t provide it.","life_span":"12 - 15","indoor":0,"lap":0,"adaptability":5,"affection_level":5,"child_friendly":4,"cat_friendly":4,"dog_friendly":5,"energy_level":5,"grooming":1,"health_issues":3,"intelligence":5,"shedding_level":3,"social_needs":5,"stranger_friendly":3,"vocalisation":5,"bidability":3,"experimental":0,"hairless":0,"natural":0,"rare":0,"rex":0,"suppressed_tail":0,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/Bengal_(cat)","hypoallergenic":1,"reference_image_id":"O3btzLlsO"}],"id":"UhqCZ7tC4","url":"https://cdn2.thecatapi.com/images/UhqCZ7tC4.jpg","width":1600,"height":1200}]'

# %% [markdown]
# ### Establishing the connection to the CAT API using http client:
#     This module defines classes which implement the client side of the HTTP and HTTPS protocols.
#     Accessing the endpoint using the API key
#     An HTTPConnection instance represents one transaction with an HTTP server.

# %%
import http.client

conn = http.client.HTTPSConnection("api.thecatapi.com")

headers = { 'x-api-key': "a2573bc5-e4a6-4dd1-a635-a956836b0c53" }

#This will send a request to the server using the HTTP request method method and the selector url.
# Syntax: HTTPConnection.request(method, url)
conn.request("GET", "/v1/breeds?attach_breed=0", headers=headers)

# HTTPConnection.getresponse()
# Should be called after a request is sent to get the response from the server. Returns an HTTPResponse instance.
res = conn.getresponse()

# Read the response using read method in the form of bytes
data = res.read()

data
# Out:
# b'[{"weight":{"imperial":"7  -  10","metric":"3 - 5"},"id":"abys","name":"Abyssinian","cfa_url":"http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx","vetstreet_url":"http://www.vetstreet.com/cats/abyssinian","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/abyssinian","temperament":"Active, Energetic, Independent, Intelligent, Gentle","origin":"Egypt","country_codes":"EG","country_code":"EG","description":"The Abyssinian is easy to care for, and a joy to have in your home. They\xe2\x80\x99re affectionate cats and love both people and other animals.","life_span":"14 - 15","indoor":0,"lap":1,"alt_names":"","adaptability":5,"affection_level":5,"child_friendly":3,"dog_friendly":4,"energy_level":5,"grooming":1,"health_issues":2,"intelligence":5,"shedding_level":2,"social_needs":5,"stranger_friendly":5,"vocalisation":1,"experimental":0,"hairless":0,"natural":1,"rare":0,"rex":0,"suppressed_tail":0,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/Abyssinian_(cat)","hypoallergenic":0,"reference_image_id":"0XYvRd7oD","image":{"id":"0XYvRd7oD","width":1204,"height":1445,"url":"https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg"}},{"weight":{"imperial":"7 - 10","metric":"3 - 5"},"id":"aege","name":"Aegean","vetstreet_url":"http://www.vetstreet.com/cats/aegean-cat","temperament":"Affectionate, Social, Intelligent, Playful, Active","origin":"Greece","country_codes":"GR","country_code":"GR","description":"Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.","life_span":"9 - 12","indoor":0,"alt_names":"","adaptability":5,"affection_level":4,"child_friendly":4,"dog_friendly":4,"energy_level":3,"grooming":3,"health_issues":1,"intelligence":3,"shedding_level":3,"social_needs":4,"stranger_friendly":4,"vocalisation":3,"experimental":0,"hairless":0,"natural":0,"rare":0,"rex":0,"suppressed_tail":0,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/Aegean_cat","hypoallergenic":0,"reference_image_id":"ozEvzdVM-","image":{"id":"ozEvzdVM-","width":1200,"height":800,"url":"https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg"}},{"weight":{"imperial":"7 - 16","metric":"3 - 7"},"id":"abob","name":"American Bobtail","cfa_url":"http://cfa.org/Breeds/BreedsAB/AmericanBobtail.aspx","vetstreet_url":"http://www.vetstreet.com/cats/american-bobtail","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/american-bobtail","temperament":"Intelligent, Interactive, Lively, Playful, Sensitive","origin":"United States","country_codes":"US","country_code":"US","description":"American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.","life_span":"11 - 15","indoor":0,"lap":1,"alt_names":"","adaptability":5,"affection_level":5,"child_friendly":4,"dog_friendly":5,"energy_level":3,"grooming":1,"health_issues":1,"intelligence":5,"shedding_level":3,"social_needs":3,"stranger_friendly":3,"vocalisation":3,"experimental":0,"hairless":0,"natural":0,"rare":0,"rex":0,"suppressed_tail":1,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/American_Bobtail","hypoallergenic":0,"reference_image_id":"hBXicehMA","image":{"id":"hBXicehMA","width":1600,"height":951,"url":"https://cdn2.thecatapi.com/images/hBXicehMA.jpg"}},{"weight":{"imperial":"5 - 10","metric":"2 - 5"},"id":"acur","name":"American Curl","cfa_url":"http://cfa.org/Breeds/BreedsAB/AmericanCurl.aspx","vetstreet_url":"http://www.vetstreet.com/cats/american-curl","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/american-curl","temperament":"Affectionate, Curious, Intelligent, Interactive, Lively, Playful, Social","origin":"United ...

# %% [markdown]
# #### Python string method decode() decodes the string using the codec registered for encoding. It defaults to the default string encoding.
#     Gets you from bytes -> Unicode

# %%
print(data.decode("utf-8"))
# Out:
# [{"weight":{"imperial":"7  -  10","metric":"3 - 5"},"id":"abys","name":"Abyssinian","cfa_url":"http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx","vetstreet_url":"http://www.vetstreet.com/cats/abyssinian","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/abyssinian","temperament":"Active, Energetic, Independent, Intelligent, Gentle","origin":"Egypt","country_codes":"EG","country_code":"EG","description":"The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.","life_span":"14 - 15","indoor":0,"lap":1,"alt_names":"","adaptability":5,"affection_level":5,"child_friendly":3,"dog_friendly":4,"energy_level":5,"grooming":1,"health_issues":2,"intelligence":5,"shedding_level":2,"social_needs":5,"stranger_friendly":5,"vocalisation":1,"experimental":0,"hairless":0,"natural":1,"rare":0,"rex":0,"suppressed_tail":0,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/Abyssinian_(cat)","hypoallergenic":0,"reference_image_id":"0XYvRd7oD","image":{"id":"0XYvRd7oD","width":1204,"height":1445,"url":"https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg"}},{"weight":{"imperial":"7 - 10","metric":"3 - 5"},"id":"aege","name":"Aegean","vetstreet_url":"http://www.vetstreet.com/cats/aegean-cat","temperament":"Affectionate, Social, Intelligent, Playful, Active","origin":"Greece","country_codes":"GR","country_code":"GR","description":"Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.","life_span":"9 - 12","indoor":0,"alt_names":"","adaptability":5,"affection_level":4,"child_friendly":4,"dog_friendly":4,"energy_level":3,"grooming":3,"health_issues":1,"intelligence":3,"shedding_level":3,"social_needs":4,"stranger_friendly":4,"vocalisation":3,"experimental":0,"hairless":0,"natural":0,"rare":0,"rex":0,"suppressed_tail":0,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/Aegean_cat","hypoallergenic":0,"reference_image_id":"ozEvzdVM-","image":{"id":"ozEvzdVM-","width":1200,"height":800,"url":"https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg"}},{"weight":{"imperial":"7 - 16","metric":"3 - 7"},"id":"abob","name":"American Bobtail","cfa_url":"http://cfa.org/Breeds/BreedsAB/AmericanBobtail.aspx","vetstreet_url":"http://www.vetstreet.com/cats/american-bobtail","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/american-bobtail","temperament":"Intelligent, Interactive, Lively, Playful, Sensitive","origin":"United States","country_codes":"US","country_code":"US","description":"American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.","life_span":"11 - 15","indoor":0,"lap":1,"alt_names":"","adaptability":5,"affection_level":5,"child_friendly":4,"dog_friendly":5,"energy_level":3,"grooming":1,"health_issues":1,"intelligence":5,"shedding_level":3,"social_needs":3,"stranger_friendly":3,"vocalisation":3,"experimental":0,"hairless":0,"natural":0,"rare":0,"rex":0,"suppressed_tail":1,"short_legs":0,"wikipedia_url":"https://en.wikipedia.org/wiki/American_Bobtail","hypoallergenic":0,"reference_image_id":"hBXicehMA","image":{"id":"hBXicehMA","width":1600,"height":951,"url":"https://cdn2.thecatapi.com/images/hBXicehMA.jpg"}},{"weight":{"imperial":"5 - 10","metric":"2 - 5"},"id":"acur","name":"American Curl","cfa_url":"http://cfa.org/Breeds/BreedsAB/AmericanCurl.aspx","vetstreet_url":"http://www.vetstreet.com/cats/american-curl","vcahospitals_url":"https://vcahospitals.com/know-your-pet/cat-breeds/american-curl","temperament":"Affectionate, Curious, Intelligent, Interactive, Lively, Playful, Social","origin":"United States","cou ...

# %% [markdown]
# ### json.loads() method can be used to parse a valid JSON string and convert it into a Python Dictionary.

# %%
jsonResponse = json.loads(data.decode('utf-8'))
jsonResponse
# Out:
# [{'weight': {'imperial': '7  -  10', 'metric': '3 - 5'},
#   'id': 'abys',
#   'name': 'Abyssinian',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/abyssinian',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/abyssinian',
#   'temperament': 'Active, Energetic, Independent, Intelligent, Gentle',
#   'origin': 'Egypt',
#   'country_codes': 'EG',
#   'country_code': 'EG',
#   'description': 'The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.',
#   'life_span': '14 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 4,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 2,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Abyssinian_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '0XYvRd7oD',
#   'image': {'id': '0XYvRd7oD',
#    'width': 1204,
#    'height': 1445,
#    'url': 'https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg'}},
#  {'weight': {'imperial': '7 - 10', 'metric': '3 - 5'},
#   'id': 'aege',
#   'name': 'Aegean',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/aegean-cat',
#   'temperament': 'Affectionate, Social, Intelligent, Playful, Active',
#   'origin': 'Greece',
#   'country_codes': 'GR',
#   'country_code': 'GR',
#   'description': 'Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.',
#   'life_span': '9 - 12',
#   'indoor': 0,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 4,
#   'child_friendly': 4,
#   'dog_friendly': 4,
#   'energy_level': 3,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Aegean_cat',
#   'hypoallergenic': 0,
#   'reference_image_id': 'ozEvzdVM-',
#   'image': {'id': 'ozEvzdVM-',
#    'width': 1200,
#    'height': 800,
#    'url': 'https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg'}},
#  {'weight': {'imperial': '7 - 16', 'metric': '3 - 7'},
#   'id': 'abob',
#   'name': 'American Bobtail',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanBobtail.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-bobtail',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/american-bobtail',
#   'temperament': 'Intelligent, Interactive, Lively, Playful, Sensitive',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.',
#   'life_span': '11 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 1,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Bobtail',
#   'hypoallergenic': 0,
#   'reference_image_id': 'hBXicehMA',
#   'image': {'id': 'hBXicehMA',
#    'width': 1600,
#    'height': 951,
#    'url': 'https://cdn2.thecatapi.com/images/hBXicehMA.jpg'}},
#  {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'id': 'acur',
#   'name': 'American Curl',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanCurl.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-curl',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/american-curl',
#   'temperament': 'Affectionate, Curious, Intelligent, Interactive, Lively, Playful, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Distinguished by truly unique ears that curl back in a graceful arc, offering an alert, perky, happily surprised expression, they cause people to break out into a big smile when viewing their first Curl. Curls are very people-oriented, faithful, affectionate soulmates, adjusting remarkably fast to other pets, children, and new situations.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Curl',
#   'hypoallergenic': 0,
#   'reference_image_id': 'xnsqonbjW',
#   'image': {'id': 'xnsqonbjW',
#    'width': 1000,
#    'height': 964,
#    'url': 'https://cdn2.thecatapi.com/images/xnsqonbjW.jpg'}},
#  {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'id': 'asho',
#   'name': 'American Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanShorthair.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-shorthair',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/american-shorthair',
#   'temperament': 'Active, Curious, Easy Going, Playful, Calm',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and other pets.',
#   'life_span': '15 - 17',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Domestic Shorthair',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 'JFPROfGtQ',
#   'image': {'id': 'JFPROfGtQ',
#    'width': 1600,
#    'height': 1200,
#    'url': 'https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg'}},
#  {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'id': 'awir',
#   'name': 'American Wirehair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanWirehair.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-wirehair',
#   'temperament': 'Affectionate, Curious, Gentle, Intelligent, Interactive, Lively, Loyal, Playful, Sensible, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The American Wirehair tends to be a calm and tolerant cat who takes life as it comes. His favorite hobby is bird-watching from a sunny windowsill, and his hunting ability will stand you in good stead if insects enter the house.',
#   'life_span': '14 - 18',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Wirehair',
#   'hypoallergenic': 0,
#   'reference_image_id': '8D--jCd21',
#   'image': {'id': '8D--jCd21',
#    'width': 1280,
#    'height': 936,
#    'url': 'https://cdn2.thecatapi.com/images/8D--jCd21.jpg'}},
#  {'weight': {'imperial': '8 - 16', 'metric': '4 - 7'},
#   'id': 'amau',
#   'name': 'Arabian Mau',
#   'vcahospitals_url': '',
#   'temperament': 'Affectionate, Agile, Curious, Independent, Playful, Loyal',
#   'origin': 'United Arab Emirates',
#   'country_codes': 'AE',
#   'country_code': 'AE',
#   'description': 'Arabian Mau cats are social and energetic. Due to their energy levels, these cats do best in homes where their owners will be able to provide them with plenty of playtime, attention and interaction from their owners. These kitties are friendly, intelligent, and adaptable, and will even get along well with other pets and children.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': 'Alley cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Arabian_Mau',
#   'hypoallergenic': 0,
#   'reference_image_id': 'k71ULYfRr',
#   'image': {'id': 'k71ULYfRr',
#    'width': 2048,
#    'height': 1554,
#    'url': 'https://cdn2.thecatapi.com/images/k71ULYfRr.jpg'}},
#  {'weight': {'imperial': '7 - 15', 'metric': '3 - 7'},
#   'id': 'amis',
#   'name': 'Australian Mist',
#   'temperament': 'Lively, Social, Fun-loving, Relaxed, Affectionate',
#   'origin': 'Australia',
#   'country_codes': 'AU',
#   'country_code': 'AU',
#   'description': 'The Australian Mist thrives on human companionship. Tolerant of even the youngest of children, these friendly felines enjoy playing games and being part of the hustle and bustle of a busy household. They make entertaining companions for people of all ages, and are happy to remain indoors between dusk and dawn or to be wholly indoor pets.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Spotted Mist',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 4,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Australian_Mist',
#   'hypoallergenic': 0,
#   'reference_image_id': '_6x-3TiCA',
#   'image': {'id': '_6x-3TiCA',
#    'width': 1231,
#    'height': 1165,
#    'url': 'https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg'}},
#  {'weight': {'imperial': '4 - 10', 'metric': '2 - 5'},
#   'id': 'bali',
#   'name': 'Balinese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Balinese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/balinese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/balinese',
#   'temperament': 'Affectionate, Intelligent, Playful',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner. ',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'alt_names': 'Long-haired Siamese',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Balinese_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': '13MkvUreZ',
#   'image': {'id': '13MkvUreZ',
#    'width': 1600,
#    'height': 1000,
#    'url': 'https://cdn2.thecatapi.com/images/13MkvUreZ.jpg'}},
#  {'weight': {'imperial': '4 - 9', 'metric': '2 - 4'},
#   'id': 'bamb',
#   'name': 'Bambino',
#   'temperament': 'Affectionate, Lively, Friendly, Intelligent',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 1,
#   'hairless': 1,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 1,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bambino_cat',
#   'hypoallergenic': 0,
#   'reference_image_id': '5AdhMjeEu',
#   'image': {'id': '5AdhMjeEu',
#    'width': 1296,
#    'height': 1030,
#    'url': 'https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg'}},
#  {'weight': {'imperial': '6 - 12', 'metric': '3 - 7'},
#   'id': 'beng',
#   'name': 'Bengal',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Bengal.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/bengal',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/bengal',
#   'temperament': 'Alert, Agile, Energetic, Demanding, Intelligent',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it.",
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 0,
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'cat_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 5,
#   'bidability': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bengal_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': 'O3btzLlsO',
#   'image': {'id': 'O3btzLlsO',
#    'width': 1100,
#    'height': 739,
#    'url': 'https://cdn2.thecatapi.com/images/O3btzLlsO.png'}},
#  {'weight': {'imperial': '6 - 15', 'metric': '3 - 7'},
#   'id': 'birm',
#   'name': 'Birman',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Birman.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/birman',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/birman',
#   'temperament': 'Affectionate, Active, Gentle, Social',
#   'origin': 'France',
#   'country_codes': 'FR',
#   'country_code': 'FR',
#   'description': 'The Birman is a docile, quiet cat who loves people and will follow them from room to room. Expect the Birman to want to be involved in what you’re doing. He communicates in a soft voice, mainly to remind you that perhaps it’s time for dinner or maybe for a nice cuddle on the sofa. He enjoys being held and will relax in your arms like a furry baby.',
#   'life_span': '14 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Sacred Birman, Sacred Cat Of Burma',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Birman',
#   'hypoallergenic': 0,
#   'reference_image_id': 'HOrX5gwLS',
#   'image': {'id': 'HOrX5gwLS',
#    'width': 1376,
#    'height': 814,
#    'url': 'https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg'}},
#  {'weight': {'imperial': '6 - 11', 'metric': '3 - 5'},
#   'id': 'bomb',
#   'name': 'Bombay',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Bombay.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/bombay',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/bombay',
#   'temperament': 'Affectionate, Dependent, Gentle, Intelligent, Playful',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his caregiver's shoulder.",
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Small black Panther',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bombay_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '5iYq9NmT1',
#   'image': {'id': '5iYq9NmT1',
#    'width': 1250,
#    'height': 650,
#    'url': 'https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg'}},
#  {'weight': {'imperial': '8 - 18', 'metric': '4 - 8'},
#   'id': 'bslo',
#   'name': 'British Longhair',
#   'temperament': 'Affectionate, Easy Going, Independent, Intelligent, Loyal, Social',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 5,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/British_Longhair',
#   'hypoallergenic': 0,
#   'reference_image_id': '7isAO4Cav',
#   'image': {'id': '7isAO4Cav',
#    'width': 960,
#    'height': 960,
#    'url': 'https://cdn2.thecatapi.com/images/7isAO4Cav.jpg'}},
#  {'weight': {'imperial': '12 - 20', 'metric': '5 - 9'},
#   'id': 'bsho',
#   'name': 'British Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/BritishShorthair.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/british-shorthair',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/british-shorthair',
#   'temperament': 'Affectionate, Easy Going, Gentle, Loyal, Patient, calm',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': "The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people.",
#   'life_span': '12 - 17',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Highlander, Highland Straight, Britannica',
#   'adaptability': 5,
#   'affection_level': 4,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 2,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 3,
#   'shedding_level': 4,
#   'social_needs': 3,
#   'stranger_friendly': 2,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/British_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 's4wQfYoEk',
#   'image': {'id': 's4wQfYoEk',
#    'width': 1600,
#    'height': 1457,
#    'url': 'https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg'}},
#  {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'id': 'bure',
#   'name': 'Burmese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Burmese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/burmese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/burmese',
#   'temperament': 'Curious, Intelligent, Gentle, Social, Interactive, Playful, Lively',
#   'origin': 'Burma',
#   'country_codes': 'MM',
#   'country_code': 'MM',
#   'description': 'Burmese love being with people, playing with them, and keeping them entertained. They crave close physical contact and abhor an empty lap. They will follow their humans from room to room, and sleep in bed with them, preferably under the covers, cuddled as close as possible. At play, they will turn around to see if their human is watching and being entertained by their crazy antics.',
#   'life_span': '15 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Burmese_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': '4lXnnfxac',
#   'image': {'id': '4lXnnfxac',
#    'width': 1250,
#    'height': 650,
#    'url': 'https://cdn2.thecatapi.com/images/4lXnnfxac.jpg'}},
#  {'weight': {'imperial': '6 - 13', 'metric': '3 - 6'},
#   'id': 'buri',
#   'name': 'Burmilla',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Burmilla.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/burmilla',
#   'temperament': 'Easy Going, Friendly, Intelligent, Lively, Playful, Social',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The Burmilla is a fairly placid cat. She tends to be an easy cat to get along with, requiring minimal care. The Burmilla is affectionate and sweet and makes a good companion, the Burmilla is an ideal companion to while away a lonely evening. Loyal, devoted, and affectionate, this cat will stay by its owner, always keeping them company.',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 4,
#   'energy_level': 3,
#   'grooming': 3,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Burmilla',
#   'hypoallergenic': 0,
#   'reference_image_id': 'jvg3XfEdC',
#   'image': {'id': 'jvg3XfEdC',
#    'width': 960,
#    'height': 960,
#    'url': 'https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg'}},
#  {'weight': {'imperial': '10 - 15', 'metric': '5 - 7'},
#   'id': 'cspa',
#   'name': 'California Spangled',
#   'temperament': 'Affectionate, Curious, Intelligent, Loyal, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Perhaps the only thing about the California spangled cat that isn’t wild-like is its personality. Known to be affectionate, gentle and sociable, this breed enjoys spending a great deal of time with its owners. They are very playful, often choosing to perch in high locations and show off their acrobatic skills.',
#   'life_span': '10 - 14',
#   'indoor': 0,
#   'alt_names': 'Spangle',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/California_Spangled',
#   'hypoallergenic': 0,
#   'reference_image_id': 'B1ERTmgph',
#   'image': {'id': 'B1ERTmgph',
#    'width': 1200,
#    'height': 688,
#    'url': 'https://cdn2.thecatapi.com/images/B1ERTmgph.jpg'}},
#  {'weight': {'imperial': '7 - 12', 'metric': '3 - 5'},
#   'id': 'ctif',
#   'name': 'Chantilly-Tiffany',
#   'temperament': 'Affectionate, Demanding, Interactive, Loyal',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of its loved one. This quality makes the Tiffany an ideal traveling companion, and an ideal house companion for senior citizens and the physically handicapped.',
#   'life_span': '14 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Chantilly, Foreign Longhair',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 5,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 5,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Chantilly-Tiffany',
#   'hypoallergenic': 0,
#   'reference_image_id': 'TR-5nAd_S',
#   'image': {'id': 'TR-5nAd_S',
#    'width': 2901,
#    'height': 2938,
#    'url': 'https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg'}},
#  {'weight': {'imperial': '6 - 15', 'metric': '3 - 7'},
#   'id': 'char',
#   'name': 'Chartreux',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/Chartreux.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/chartreux',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/chartreux',
#   'temperament': 'Affectionate, Loyal, Intelligent, Social, Lively, Playful',
#   'origin': 'France',
#   'country_codes': 'FR',
#   'country_code': 'FR',
#   'description': 'The Chartreux is generally silent but communicative. Short play sessions, mixed with naps and meals are their perfect day. Whilst appreciating any attention you give them, they are not demanding, content instead to follow you around devotedly, sleep on your bed and snuggle with you if you’re not feeling well.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 2,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 4,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Chartreux',
#   'hypoallergenic': 1,
#   'reference_image_id': 'j6oFGLpRG',
#   'image': {'id': 'j6oFGLpRG',
#    'width': 768,
#    'height': 1024,
#    'url': 'https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg'}},
#  {'weight': {'imperial': '7 - 15', 'metric': '3 - 7'},
#   'id': 'chau',
#   'name': 'Chausie',
#   'temperament': 'Affectionate, Intelligent, Playful, Social',
#   'origin': 'Egypt',
#   'country_codes': 'EG',
#   'country_code': 'EG',
#   'description': 'For those owners who desire a feline capable of evoking the great outdoors, the strikingly beautiful Chausie retains a bit of the wild in its appearance but has the house manners of our friendly, familiar moggies. Very playful, this cat needs a large amount of space to be able to fully embrace its hunting instincts.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': 'Nile Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 1,
#   'experimental': 1,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Chausie',
#   'hypoallergenic': 0,
#   'reference_image_id': 'vJ3lEYgXr',
#   'image': {'id': 'vJ3lEYgXr',
#    'width': 1100,
#    'height': 786,
#    'url': 'https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg'}},
#  {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'id': 'chee',
#   'name': 'Cheetoh',
#   'temperament': 'Affectionate, Gentle, Intelligent, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Cheetoh has a super affectionate nature and real love for their human companions; they are intelligent with the ability to learn quickly. You can expect that a Cheetoh will be a fun-loving kitty who enjoys playing, running, and jumping through every room in your house.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': '\xa0',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bengal_cat#Cheetoh',
#   'hypoallergenic': 0,
#   'reference_image_id': 'IFXsxmXLm',
#   'image': {'id': 'IFXsxmXLm',
#    'width': 973,
#    'height': 973,
#    'url': 'https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg'}},
#  {'weight': {'imperial': '4 - 10', 'metric': '2 - 5'},
#   'id': 'csho',
#   'name': 'Colorpoint Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/ColorpointShorthair.aspx',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/colorpoint-shorthair',
#   'temperament': 'Affectionate, Intelligent, Playful, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Colorpoint Shorthairs are an affectionate breed, devoted and loyal to their people. Sensitive to their owner’s moods, Colorpoints are more than happy to sit at your side or on your lap and purr words of encouragement on a bad day. They will constantly seek out your lap whenever it is open and in the moments when your lap is preoccupied they will stretch out in sunny spots on the ground.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 3,
#   'affection_level': 4,
#   'child_friendly': 4,
#   'cat_friendly': 3,
#   'dog_friendly': 4,
#   'energy_level': 4,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 5,
#   'bidability': 4,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Colorpoint_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 'oSpqGyUDS',
#   'image': {'id': 'oSpqGyUDS',
#    'width': 1363,
#    'height': 1600,
#    'url': 'https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg'}},
#  {'weight': {'imperial': '5 - 9', 'metric': '2 - 4'},
#   'id': 'crex',
#   'name': 'Cornish Rex',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/CornishRex.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/cornish-rex',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/cornish-rex',
#   'temperament': 'Affectionate, Intelligent, Active, Curious, Playful',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'This is a confident cat who loves people and will follow them around, waiting for any opportunity to sit in a lap or give a kiss. He enjoys being handled, making it easy to take him to the veterinarian or train him for therapy work. The Cornish Rex stay in kitten mode most of their lives and well into their senior years. ',
#   'life_span': '11 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'cat_friendly': 2,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Cornish_Rex',
#   'hypoallergenic': 1,
#   'reference_image_id': 'unX21IBVB',
#   'image': {'id': 'unX21IBVB',
#    'width': 2976,
#    'height': 1784,
#    'url': 'https://cdn2.thecatapi.com/images/unX21IBVB.jpg'}},
#  {'weight': {'imperial': '8 - 13', 'metric': '4 - 6'},
#   'id': 'cymr',
#   'name': 'Cymric',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/cymric',
#   'temperament': 'Gentle, Loyal, Intelligent, Playful',
#   'origin': 'Canada',
#   'country_codes': 'CA',
#   'country_code': 'CA',
#   'description': 'The Cymric is a placid, sweet cat. They do not get too upset about anything that happens in their world. They are loving companions and adore people. They are smart and dexterous, capable of using his paws to get into cabinets or to open doors.',
#   'life_span': '8 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Spangle',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 5,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 1,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Cymric_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '3dbtapCWM',
#   'image': {'id': '3dbtapCWM',
#    'width': 1440,
#    'height': 900,
#    'url': 'https://cdn2.thecatapi.com/images/3dbtapCWM.jpg'}},
#  {'weight': {'imperial': '8 - 16', 'metric': '4 - 7'},
#   'id': 'cypr',
#   'name': 'Cyprus',
#   'temperament': 'Affectionate, Social',
#   'origin': 'Cyprus',
#   'country_codes': 'CY',
#   'country_code': 'CY',
#   'description': 'Loving, loyal, social and inquisitive, the Cyprus cat forms strong ties with their families and love nothing more than to be involved in everything that goes on in their surroundings. They are not overly active by nature which makes them the perfect companion for people who would like to share their homes with a laid-back relaxed feline companion. ',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Cypriot cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Cyprus_cat',
#   'hypoallergenic': 0,
#   'reference_image_id': 'tJbzb7FKo',
#   'image': {'id': 'tJbzb7FKo',
#    'width': 1024,
#    'height': 768,
#    'url': 'https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg'}},
#  {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'id': 'drex',
#   'name': 'Devon Rex',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/DevonRex.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/devon-rex',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/devon-rex',
#   'temperament': 'Highly interactive, Mischievous, Loyal, Social, Playful',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The favourite perch of the Devon Rex is right at head level, on the shoulder of her favorite person. She takes a lively interest in everything that is going on and refuses to be left out of any activity. Count on her to stay as close to you as possible, occasionally communicating his opinions in a quiet voice. She loves people and welcomes the attentions of friends and family alike.',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Pixie cat, Alien cat, Poodle cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Devon_Rex',
#   'hypoallergenic': 1,
#   'reference_image_id': '4RzEwvyzz',
#   'image': {'id': '4RzEwvyzz',
#    'width': 1729,
#    'height': 1160,
#    'url': 'https://cdn2.thecatapi.com/images/4RzEwvyzz.png'}},
#  {'weight': {'imperial': '10 - 12', 'metric': '5 - 6'},
#   'id': 'dons',
#   'name': 'Donskoy',
#   'temperament': 'Playful, affectionate, loyal, social',
#   'origin': 'Russia',
#   'country_codes': 'RU',
#   'country_code': 'RU',
#   'description': 'Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'adaptability': 4,
#   'affection_level': 4,
#   'child_friendly': 3,
#   'cat_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 4,
#   'grooming': 2,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 2,
#   'experimental': 0,
#   'hairless': 1,
#   'natural': 0,
#   'rare': 1,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Donskoy_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '3KG57GfMW',
#   'image': {'id': '3KG57GfMW',
#    'width': 750,
#    'height': 750,
#    'url': 'https://cdn2.thecatapi.com/images/3KG57GfMW.jpg'}},
#  {'weight': {'imperial': '9 - 12', 'metric': '4 - 6'},
#   'id': 'lihu',
#   'name': 'Dragon Li',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/li-hua',
#   'temperament': 'Intelligent, Friendly, Gentle, Loving, Loyal',
#   'origin': 'China',
#   'country_codes': 'CN',
#   'country_code': 'CN',
#   'description': "The Dragon Li is loyal, but not particularly affectionate. They are known to be very intelligent, and their natural breed status means that they're very active. She is is gentle with people, and has a reputation as a talented hunter of rats and other vermin.",
#   'life_span': '12 - 15',
#   'indoor': 1,
#   'alt_names': 'Chinese Lia Hua, Lí hua māo (貍花貓), Li Hua',
#   'adaptability': 3,
#   'affection_level': 3,
#   'child_friendly': 3,
#   'cat_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Dragon_Li',
#   'hypoallergenic': 0,
#   'reference_image_id': 'BQMSld0A0',
#   'image': {'id': 'BQMSld0A0',
#    'width': 1080,
#    'height': 1080,
#    'url': 'https://cdn2.thecatapi.com/images/BQMSld0A0.jpg'}},
#  {'weight': {'imperial': '6 - 14', 'metric': '3 - 6'},
#   'id': 'emau',
#   'name': 'Egyptian Mau',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/EgyptianMau.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/egyptian-mau',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/egyptian-mau',
#   'temperament': 'Agile, Dependent, Gentle, Intelligent, Lively, Loyal, Playful',
#   'origin': 'Egypt',
#   'country_codes': 'EG',
#   'country_code': 'EG',
#   'description': 'The Egyptian Mau is gentle and reserved. She loves her people and desires attention and affection from them but is wary of others. Early, continuing socialization is essential with this sensitive and sometimes shy cat, especially if you plan to show or travel with her. Otherwise, she can be easily startled by unexpected noises or events.',
#   'life_span': '18 - 20',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Pharaoh Cat',
#   'adaptability': 2,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 4,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Egyptian_Mau',
#   'hypoallergenic': 0,
#   'reference_image_id': 'TuSyTkt2n',
#   'image': {'id': 'TuSyTkt2n',
#    'width': 2475,
#    'height': 2147,
#    'url': 'https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg'}},
#  {'weight': {'imperial': '7 - 14', 'metric': '3 - 6'},
#   'id': 'ebur',
#   'name': 'European Burmese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/EuropeanBurmese.aspx',
#   'temperament': 'Sweet, Affectionate, Loyal',
#   'origin': 'Burma',
#   'country_codes': 'MM',
#   'country_code': 'MM',
#   'description': 'The European Burmese is a very affectionate, intelligent, and loyal cat. They thrive on companionship and will want to be with you, participating in everything you do. While they might pick a favorite family member, chances are that they will interact with everyone in the home, as well as any visitors that come to call. They are inquisitive and playful, even as adults. ',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'cat_friendly': 4,
#   'dog_friendly': 4,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 4,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 4,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'hypoallergenic': 0},
#  {'weight': {'imperial': '7 - 14', 'metric': '3 - 6'},
#   'id': 'esho',
#   'name': 'Exotic Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/Exotic.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/exotic-shorthair',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/exotic-shorthair',
#   'temperament': 'Affectionate, Sweet, Loyal, Quiet, Peaceful',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Exotic Shorthair is a gentle friendly cat that has the same personality as the Persian. They love having fun, don’t mind the company of other cats and dogs, also love to curl up for a sleep in a safe place. Exotics love their own people, but around strangers they are cautious at first. Given time, they usually warm up to visitors.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Exotic',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 2,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Exotic_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 'YnPrYEmfe',
#   'image': {'id': 'YnPrYEmfe',
#    'width': 1024,
#    'height': 768,
#    'url': 'https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg'}},
#  {'weight': {'imperial': '6 - 10', 'metric': '3 - 5'},
#   'id': 'hbro',
#   'name': 'Havana Brown',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/HavanaBrown.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/havana-brown',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/havana-brown',
#   'temperament': 'Affectionate, Curious, Demanding, Friendly, Intelligent, Playful',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The Havana Brown is human oriented, playful, and curious. She has a strong desire to spend time with her people and involve herself in everything they do. Being naturally inquisitive, the Havana Brown reaches out with a paw to touch and feel when investigating curiosities in its environment. They are truly sensitive by nature and frequently gently touch their human companions as if they are extending a paw of friendship.',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Havana, HB',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Havana_Brown',
#   'hypoallergenic': 0,
#   'reference_image_id': 'njK25knLH',
#   'image': {'id': 'njK25knLH',
#    'width': 1024,
#    'height': 823,
#    'url': 'https://cdn2.thecatapi.com/images/njK25knLH.jpg'}},
#  {'weight': {'imperial': '7 - 14', 'metric': '3 - 6'},
#   'id': 'hima',
#   'name': 'Himalayan',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/himalayan',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/himalayan',
#   'temperament': 'Dependent, Gentle, Intelligent, Quiet, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Calm and devoted, Himalayans make excellent companions, though they prefer a quieter home. They are playful in a sedate kind of way and enjoy having an assortment of toys. The Himalayan will stretch out next to you, sleep in your bed and even sit on your lap when she is in the mood.',
#   'life_span': '9 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Himalayan Persian, Colourpoint Persian, Longhaired Colourpoint, Himmy',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 2,
#   'dog_friendly': 2,
#   'energy_level': 1,
#   'grooming': 5,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 4,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
# ...
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 4,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Selkirk_Rex',
#   'hypoallergenic': 1,
#   'reference_image_id': 'II9dOZmrw',
#   'image': {'id': 'II9dOZmrw',
#    'width': 1920,
#    'height': 902,
#    'url': 'https://cdn2.thecatapi.com/images/II9dOZmrw.jpg'}},
#  {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'id': 'siam',
#   'name': 'Siamese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Siamese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/siamese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/siamese',
#   'temperament': 'Active, Agile, Clever, Sociable, Loving, Energetic',
#   'origin': 'Thailand',
#   'country_codes': 'TH',
#   'country_code': 'TH',
#   'description': 'While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Siam, Thai Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 2,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Siamese_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': 'ai6Jps4sx',
#   'image': {'id': 'ai6Jps4sx',
#    'width': 1110,
#    'height': 811,
#    'url': 'https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg'}},
#  {'weight': {'imperial': '8 - 16', 'metric': '4 - 7'},
#   'id': 'sibe',
#   'name': 'Siberian',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Siberian.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/siberian',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/siberian',
#   'temperament': 'Curious, Intelligent, Loyal, Sweet, Agile, Playful, Affectionate',
#   'origin': 'Russia',
#   'country_codes': 'RU',
#   'country_code': 'RU',
#   'description': 'The Siberians dog like temperament and affection makes the ideal lap cat and will live quite happily indoors. Very agile and powerful, the Siberian cat can easily leap and reach high places, including the tops of refrigerators and even doors. ',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Moscow Semi-longhair, HairSiberian Forest Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Siberian_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': '3bkZAjRh1',
#   'image': {'id': '3bkZAjRh1',
#    'width': 4232,
#    'height': 2560,
#    'url': 'https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg'}},
#  {'weight': {'imperial': '5 - 8', 'metric': '2 - 4'},
#   'id': 'sing',
#   'name': 'Singapura',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Singapura.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/singapura',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/singapura',
#   'temperament': 'Affectionate, Curious, Easy Going, Intelligent, Interactive, Lively, Loyal',
#   'origin': 'Singapore',
#   'country_codes': 'SP',
#   'country_code': 'SP',
#   'description': 'The Singapura is usually cautious when it comes to meeting new people, but loves attention from his family so much that she sometimes has the reputation of being a pest. This is a highly active, curious and affectionate cat. She may be small, but she knows she’s in charge',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Drain Cat, Kucinta, Pura',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Singapura_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'Qtncp2nRe',
#   'image': {'id': 'Qtncp2nRe',
#    'width': 1080,
#    'height': 1350,
#    'url': 'https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg'}},
#  {'weight': {'imperial': '7 - 12', 'metric': '3 - 5'},
#   'id': 'snow',
#   'name': 'Snowshoe',
#   'temperament': 'Affectionate, Social, Intelligent, Sweet-tempered',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Snowshoe is a vibrant, energetic, affectionate and intelligent cat. They love being around people which makes them ideal for families, and becomes unhappy when left alone for long periods of time. Usually attaching themselves to one person, they do whatever they can to get your attention.',
#   'life_span': '14 - 19',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Snowshoe_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'MK-sYESvO',
#   'image': {'id': 'MK-sYESvO',
#    'width': 1170,
#    'height': 750,
#    'url': 'https://cdn2.thecatapi.com/images/MK-sYESvO.jpg'}},
#  {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'id': 'soma',
#   'name': 'Somali',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Somali.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/somali',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/somali',
#   'temperament': 'Mischievous, Tenacious, Intelligent, Affectionate, Gentle, Interactive, Loyal',
#   'origin': 'Somalia',
#   'country_codes': 'SO',
#   'country_code': 'SO',
#   'description': 'The Somali lives life to the fullest. He climbs higher, jumps farther, plays harder. Nothing escapes the notice of this highly intelligent and inquisitive cat. Somalis love the company of humans and other animals.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'alt_names': 'Fox Cat, Long-Haired Abyssinian',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 4,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 4,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Somali_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'EPF2ejNS0',
#   'image': {'id': 'EPF2ejNS0',
#    'width': 850,
#    'height': 1008,
#    'url': 'https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg'}},
#  {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'id': 'sphy',
#   'name': 'Sphynx',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Sphynx.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/sphynx',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/sphynx',
#   'temperament': 'Loyal, Inquisitive, Friendly, Quiet, Gentle',
#   'origin': 'Canada',
#   'country_codes': 'CA',
#   'country_code': 'CA',
#   'description': 'The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Canadian Hairless, Canadian Sphynx',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 4,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 1,
#   'natural': 0,
#   'rare': 1,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Sphynx_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': 'BDb8ZXb1v',
#   'image': {'id': 'BDb8ZXb1v',
#    'width': 1600,
#    'height': 1067,
#    'url': 'https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg'}},
#  {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'id': 'tonk',
#   'name': 'Tonkinese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Tonkinese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/tonkinese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/tonkinese',
#   'temperament': 'Curious, Intelligent, Social, Lively, Outgoing, Playful, Affectionate',
#   'origin': 'Canada',
#   'country_codes': 'CA',
#   'country_code': 'CA',
#   'description': 'Intelligent and generous with their affection, a Tonkinese will supervise all activities with curiosity. Loving, social, active, playful, yet content to be a lap cat',
#   'life_span': '14 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Tonk',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Tonkinese_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'KBroiVNCM',
#   'image': {'id': 'KBroiVNCM',
#    'width': 1080,
#    'height': 1080,
#    'url': 'https://cdn2.thecatapi.com/images/KBroiVNCM.jpg'}},
#  {'weight': {'imperial': '7 - 15', 'metric': '3 - 7'},
#   'id': 'toyg',
#   'name': 'Toyger',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/toyger',
#   'temperament': 'Playful, Social, Intelligent',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "The Toyger has a sweet, calm personality and is generally friendly. He's outgoing enough to walk on a leash, energetic enough to play fetch and other interactive games, and confident enough to get along with other cats and friendly dogs.",
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Toyger',
#   'hypoallergenic': 0,
#   'reference_image_id': 'O3F3_S1XN',
#   'image': {'id': 'O3F3_S1XN',
#    'width': 1080,
#    'height': 1080,
#    'url': 'https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg'}},
#  {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'id': 'tang',
#   'name': 'Turkish Angora',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/TurkishAngora.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/turkish-angora',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/turkish-angora',
#   'temperament': 'Affectionate, Agile, Clever, Gentle, Intelligent, Playful, Social',
#   'origin': 'Turkey',
#   'country_codes': 'TR',
#   'country_code': 'TR',
#   'description': 'This is a smart and intelligent cat which bonds well with humans. With its affectionate and playful personality the Angora is a top choice for families. The Angora gets along great with other pets in the home, but it will make clear who is in charge, and who the house belongs to',
#   'life_span': '15 - 18',
#   'indoor': 0,
#   'alt_names': 'Ankara',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 2,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Turkish_Angora',
#   'hypoallergenic': 0,
#   'reference_image_id': '7CGV6WVXq',
#   'image': {'id': '7CGV6WVXq',
#    'width': 736,
#    'height': 1104,
#    'url': 'https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg'}},
#  {'weight': {'imperial': '7 - 20', 'metric': '3 - 9'},
#   'id': 'tvan',
#   'name': 'Turkish Van',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/TurkishVan.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/turkish-van',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/turkish-van',
#   'temperament': 'Agile, Intelligent, Loyal, Playful, Energetic',
#   'origin': 'Turkey',
#   'country_codes': 'TR',
#   'country_code': 'TR',
#   'description': 'While the Turkish Van loves to jump and climb, play with toys, retrieve and play chase, she is is big and ungainly; this is one cat who doesn’t always land on his feet. While not much of a lap cat, the Van will be happy to cuddle next to you and sleep in your bed. ',
#   'life_span': '12 - 17',
#   'indoor': 0,
#   'alt_names': 'Turkish Cat, Swimming cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 2,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Turkish_Van',
#   'hypoallergenic': 0,
#   'reference_image_id': 'sxIXJax6h',
#   'image': {'id': 'sxIXJax6h',
#    'width': 960,
#    'height': 1280,
#    'url': 'https://cdn2.thecatapi.com/images/sxIXJax6h.jpg'}},
#  {'weight': {'imperial': '12 - 18', 'metric': '5 - 8'},
#   'id': 'ycho',
#   'name': 'York Chocolate',
#   'temperament': 'Playful, Social, Intelligent, Curious, Friendly',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it.",
#   'life_span': '13 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'York',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/York_Chocolate',
#   'hypoallergenic': 0,
#   'reference_image_id': '0SxW2SQ_S',
#   'image': {'id': '0SxW2SQ_S',
#    'width': 800,
#    'height': 1203,
#    'url': 'https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg'}}]

# %% [markdown]
# - jsonResponse is a list of dictionaries.
# - Generating a dictoriay format response eliminating the list.

# %%
new_dict={}

for i in jsonResponse:
    new_dict[i['id']]={}
    for k in i.keys():
        if k =='id': continue
        new_dict[i['id']][k]=i[k]

new_dict
# Out:
# {'abys': {'weight': {'imperial': '7  -  10', 'metric': '3 - 5'},
#   'name': 'Abyssinian',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/abyssinian',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/abyssinian',
#   'temperament': 'Active, Energetic, Independent, Intelligent, Gentle',
#   'origin': 'Egypt',
#   'country_codes': 'EG',
#   'country_code': 'EG',
#   'description': 'The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.',
#   'life_span': '14 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 4,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 2,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Abyssinian_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '0XYvRd7oD',
#   'image': {'id': '0XYvRd7oD',
#    'width': 1204,
#    'height': 1445,
#    'url': 'https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg'}},
#  'aege': {'weight': {'imperial': '7 - 10', 'metric': '3 - 5'},
#   'name': 'Aegean',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/aegean-cat',
#   'temperament': 'Affectionate, Social, Intelligent, Playful, Active',
#   'origin': 'Greece',
#   'country_codes': 'GR',
#   'country_code': 'GR',
#   'description': 'Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.',
#   'life_span': '9 - 12',
#   'indoor': 0,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 4,
#   'child_friendly': 4,
#   'dog_friendly': 4,
#   'energy_level': 3,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Aegean_cat',
#   'hypoallergenic': 0,
#   'reference_image_id': 'ozEvzdVM-',
#   'image': {'id': 'ozEvzdVM-',
#    'width': 1200,
#    'height': 800,
#    'url': 'https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg'}},
#  'abob': {'weight': {'imperial': '7 - 16', 'metric': '3 - 7'},
#   'name': 'American Bobtail',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanBobtail.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-bobtail',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/american-bobtail',
#   'temperament': 'Intelligent, Interactive, Lively, Playful, Sensitive',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.',
#   'life_span': '11 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 1,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Bobtail',
#   'hypoallergenic': 0,
#   'reference_image_id': 'hBXicehMA',
#   'image': {'id': 'hBXicehMA',
#    'width': 1600,
#    'height': 951,
#    'url': 'https://cdn2.thecatapi.com/images/hBXicehMA.jpg'}},
#  'acur': {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'name': 'American Curl',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanCurl.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-curl',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/american-curl',
#   'temperament': 'Affectionate, Curious, Intelligent, Interactive, Lively, Playful, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Distinguished by truly unique ears that curl back in a graceful arc, offering an alert, perky, happily surprised expression, they cause people to break out into a big smile when viewing their first Curl. Curls are very people-oriented, faithful, affectionate soulmates, adjusting remarkably fast to other pets, children, and new situations.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Curl',
#   'hypoallergenic': 0,
#   'reference_image_id': 'xnsqonbjW',
#   'image': {'id': 'xnsqonbjW',
#    'width': 1000,
#    'height': 964,
#    'url': 'https://cdn2.thecatapi.com/images/xnsqonbjW.jpg'}},
#  'asho': {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'name': 'American Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanShorthair.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-shorthair',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/american-shorthair',
#   'temperament': 'Active, Curious, Easy Going, Playful, Calm',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and other pets.',
#   'life_span': '15 - 17',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Domestic Shorthair',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 'JFPROfGtQ',
#   'image': {'id': 'JFPROfGtQ',
#    'width': 1600,
#    'height': 1200,
#    'url': 'https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg'}},
#  'awir': {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'name': 'American Wirehair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/AmericanWirehair.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/american-wirehair',
#   'temperament': 'Affectionate, Curious, Gentle, Intelligent, Interactive, Lively, Loyal, Playful, Sensible, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The American Wirehair tends to be a calm and tolerant cat who takes life as it comes. His favorite hobby is bird-watching from a sunny windowsill, and his hunting ability will stand you in good stead if insects enter the house.',
#   'life_span': '14 - 18',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/American_Wirehair',
#   'hypoallergenic': 0,
#   'reference_image_id': '8D--jCd21',
#   'image': {'id': '8D--jCd21',
#    'width': 1280,
#    'height': 936,
#    'url': 'https://cdn2.thecatapi.com/images/8D--jCd21.jpg'}},
#  'amau': {'weight': {'imperial': '8 - 16', 'metric': '4 - 7'},
#   'name': 'Arabian Mau',
#   'vcahospitals_url': '',
#   'temperament': 'Affectionate, Agile, Curious, Independent, Playful, Loyal',
#   'origin': 'United Arab Emirates',
#   'country_codes': 'AE',
#   'country_code': 'AE',
#   'description': 'Arabian Mau cats are social and energetic. Due to their energy levels, these cats do best in homes where their owners will be able to provide them with plenty of playtime, attention and interaction from their owners. These kitties are friendly, intelligent, and adaptable, and will even get along well with other pets and children.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': 'Alley cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Arabian_Mau',
#   'hypoallergenic': 0,
#   'reference_image_id': 'k71ULYfRr',
#   'image': {'id': 'k71ULYfRr',
#    'width': 2048,
#    'height': 1554,
#    'url': 'https://cdn2.thecatapi.com/images/k71ULYfRr.jpg'}},
#  'amis': {'weight': {'imperial': '7 - 15', 'metric': '3 - 7'},
#   'name': 'Australian Mist',
#   'temperament': 'Lively, Social, Fun-loving, Relaxed, Affectionate',
#   'origin': 'Australia',
#   'country_codes': 'AU',
#   'country_code': 'AU',
#   'description': 'The Australian Mist thrives on human companionship. Tolerant of even the youngest of children, these friendly felines enjoy playing games and being part of the hustle and bustle of a busy household. They make entertaining companions for people of all ages, and are happy to remain indoors between dusk and dawn or to be wholly indoor pets.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Spotted Mist',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 4,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Australian_Mist',
#   'hypoallergenic': 0,
#   'reference_image_id': '_6x-3TiCA',
#   'image': {'id': '_6x-3TiCA',
#    'width': 1231,
#    'height': 1165,
#    'url': 'https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg'}},
#  'bali': {'weight': {'imperial': '4 - 10', 'metric': '2 - 5'},
#   'name': 'Balinese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Balinese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/balinese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/balinese',
#   'temperament': 'Affectionate, Intelligent, Playful',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner. ',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'alt_names': 'Long-haired Siamese',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Balinese_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': '13MkvUreZ',
#   'image': {'id': '13MkvUreZ',
#    'width': 1600,
#    'height': 1000,
#    'url': 'https://cdn2.thecatapi.com/images/13MkvUreZ.jpg'}},
#  'bamb': {'weight': {'imperial': '4 - 9', 'metric': '2 - 4'},
#   'name': 'Bambino',
#   'temperament': 'Affectionate, Lively, Friendly, Intelligent',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 1,
#   'hairless': 1,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 1,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bambino_cat',
#   'hypoallergenic': 0,
#   'reference_image_id': '5AdhMjeEu',
#   'image': {'id': '5AdhMjeEu',
#    'width': 1296,
#    'height': 1030,
#    'url': 'https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg'}},
#  'beng': {'weight': {'imperial': '6 - 12', 'metric': '3 - 7'},
#   'name': 'Bengal',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Bengal.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/bengal',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/bengal',
#   'temperament': 'Alert, Agile, Energetic, Demanding, Intelligent',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it.",
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 0,
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'cat_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 5,
#   'bidability': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bengal_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': 'O3btzLlsO',
#   'image': {'id': 'O3btzLlsO',
#    'width': 1100,
#    'height': 739,
#    'url': 'https://cdn2.thecatapi.com/images/O3btzLlsO.png'}},
#  'birm': {'weight': {'imperial': '6 - 15', 'metric': '3 - 7'},
#   'name': 'Birman',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Birman.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/birman',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/birman',
#   'temperament': 'Affectionate, Active, Gentle, Social',
#   'origin': 'France',
#   'country_codes': 'FR',
#   'country_code': 'FR',
#   'description': 'The Birman is a docile, quiet cat who loves people and will follow them from room to room. Expect the Birman to want to be involved in what you’re doing. He communicates in a soft voice, mainly to remind you that perhaps it’s time for dinner or maybe for a nice cuddle on the sofa. He enjoys being held and will relax in your arms like a furry baby.',
#   'life_span': '14 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Sacred Birman, Sacred Cat Of Burma',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Birman',
#   'hypoallergenic': 0,
#   'reference_image_id': 'HOrX5gwLS',
#   'image': {'id': 'HOrX5gwLS',
#    'width': 1376,
#    'height': 814,
#    'url': 'https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg'}},
#  'bomb': {'weight': {'imperial': '6 - 11', 'metric': '3 - 5'},
#   'name': 'Bombay',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Bombay.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/bombay',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/bombay',
#   'temperament': 'Affectionate, Dependent, Gentle, Intelligent, Playful',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his caregiver's shoulder.",
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Small black Panther',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bombay_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '5iYq9NmT1',
#   'image': {'id': '5iYq9NmT1',
#    'width': 1250,
#    'height': 650,
#    'url': 'https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg'}},
#  'bslo': {'weight': {'imperial': '8 - 18', 'metric': '4 - 8'},
#   'name': 'British Longhair',
#   'temperament': 'Affectionate, Easy Going, Independent, Intelligent, Loyal, Social',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 5,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/British_Longhair',
#   'hypoallergenic': 0,
#   'reference_image_id': '7isAO4Cav',
#   'image': {'id': '7isAO4Cav',
#    'width': 960,
#    'height': 960,
#    'url': 'https://cdn2.thecatapi.com/images/7isAO4Cav.jpg'}},
#  'bsho': {'weight': {'imperial': '12 - 20', 'metric': '5 - 9'},
#   'name': 'British Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/BritishShorthair.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/british-shorthair',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/british-shorthair',
#   'temperament': 'Affectionate, Easy Going, Gentle, Loyal, Patient, calm',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': "The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people.",
#   'life_span': '12 - 17',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Highlander, Highland Straight, Britannica',
#   'adaptability': 5,
#   'affection_level': 4,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 2,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 3,
#   'shedding_level': 4,
#   'social_needs': 3,
#   'stranger_friendly': 2,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/British_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 's4wQfYoEk',
#   'image': {'id': 's4wQfYoEk',
#    'width': 1600,
#    'height': 1457,
#    'url': 'https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg'}},
#  'bure': {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'name': 'Burmese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Burmese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/burmese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/burmese',
#   'temperament': 'Curious, Intelligent, Gentle, Social, Interactive, Playful, Lively',
#   'origin': 'Burma',
#   'country_codes': 'MM',
#   'country_code': 'MM',
#   'description': 'Burmese love being with people, playing with them, and keeping them entertained. They crave close physical contact and abhor an empty lap. They will follow their humans from room to room, and sleep in bed with them, preferably under the covers, cuddled as close as possible. At play, they will turn around to see if their human is watching and being entertained by their crazy antics.',
#   'life_span': '15 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Burmese_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': '4lXnnfxac',
#   'image': {'id': '4lXnnfxac',
#    'width': 1250,
#    'height': 650,
#    'url': 'https://cdn2.thecatapi.com/images/4lXnnfxac.jpg'}},
#  'buri': {'weight': {'imperial': '6 - 13', 'metric': '3 - 6'},
#   'name': 'Burmilla',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Burmilla.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/burmilla',
#   'temperament': 'Easy Going, Friendly, Intelligent, Lively, Playful, Social',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The Burmilla is a fairly placid cat. She tends to be an easy cat to get along with, requiring minimal care. The Burmilla is affectionate and sweet and makes a good companion, the Burmilla is an ideal companion to while away a lonely evening. Loyal, devoted, and affectionate, this cat will stay by its owner, always keeping them company.',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 4,
#   'energy_level': 3,
#   'grooming': 3,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Burmilla',
#   'hypoallergenic': 0,
#   'reference_image_id': 'jvg3XfEdC',
#   'image': {'id': 'jvg3XfEdC',
#    'width': 960,
#    'height': 960,
#    'url': 'https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg'}},
#  'cspa': {'weight': {'imperial': '10 - 15', 'metric': '5 - 7'},
#   'name': 'California Spangled',
#   'temperament': 'Affectionate, Curious, Intelligent, Loyal, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Perhaps the only thing about the California spangled cat that isn’t wild-like is its personality. Known to be affectionate, gentle and sociable, this breed enjoys spending a great deal of time with its owners. They are very playful, often choosing to perch in high locations and show off their acrobatic skills.',
#   'life_span': '10 - 14',
#   'indoor': 0,
#   'alt_names': 'Spangle',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/California_Spangled',
#   'hypoallergenic': 0,
#   'reference_image_id': 'B1ERTmgph',
#   'image': {'id': 'B1ERTmgph',
#    'width': 1200,
#    'height': 688,
#    'url': 'https://cdn2.thecatapi.com/images/B1ERTmgph.jpg'}},
#  'ctif': {'weight': {'imperial': '7 - 12', 'metric': '3 - 5'},
#   'name': 'Chantilly-Tiffany',
#   'temperament': 'Affectionate, Demanding, Interactive, Loyal',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of its loved one. This quality makes the Tiffany an ideal traveling companion, and an ideal house companion for senior citizens and the physically handicapped.',
#   'life_span': '14 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Chantilly, Foreign Longhair',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 5,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 5,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Chantilly-Tiffany',
#   'hypoallergenic': 0,
#   'reference_image_id': 'TR-5nAd_S',
#   'image': {'id': 'TR-5nAd_S',
#    'width': 2901,
#    'height': 2938,
#    'url': 'https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg'}},
#  'char': {'weight': {'imperial': '6 - 15', 'metric': '3 - 7'},
#   'name': 'Chartreux',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/Chartreux.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/chartreux',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/chartreux',
#   'temperament': 'Affectionate, Loyal, Intelligent, Social, Lively, Playful',
#   'origin': 'France',
#   'country_codes': 'FR',
#   'country_code': 'FR',
#   'description': 'The Chartreux is generally silent but communicative. Short play sessions, mixed with naps and meals are their perfect day. Whilst appreciating any attention you give them, they are not demanding, content instead to follow you around devotedly, sleep on your bed and snuggle with you if you’re not feeling well.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 2,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 4,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Chartreux',
#   'hypoallergenic': 1,
#   'reference_image_id': 'j6oFGLpRG',
#   'image': {'id': 'j6oFGLpRG',
#    'width': 768,
#    'height': 1024,
#    'url': 'https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg'}},
#  'chau': {'weight': {'imperial': '7 - 15', 'metric': '3 - 7'},
#   'name': 'Chausie',
#   'temperament': 'Affectionate, Intelligent, Playful, Social',
#   'origin': 'Egypt',
#   'country_codes': 'EG',
#   'country_code': 'EG',
#   'description': 'For those owners who desire a feline capable of evoking the great outdoors, the strikingly beautiful Chausie retains a bit of the wild in its appearance but has the house manners of our friendly, familiar moggies. Very playful, this cat needs a large amount of space to be able to fully embrace its hunting instincts.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': 'Nile Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 1,
#   'experimental': 1,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Chausie',
#   'hypoallergenic': 0,
#   'reference_image_id': 'vJ3lEYgXr',
#   'image': {'id': 'vJ3lEYgXr',
#    'width': 1100,
#    'height': 786,
#    'url': 'https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg'}},
#  'chee': {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'name': 'Cheetoh',
#   'temperament': 'Affectionate, Gentle, Intelligent, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Cheetoh has a super affectionate nature and real love for their human companions; they are intelligent with the ability to learn quickly. You can expect that a Cheetoh will be a fun-loving kitty who enjoys playing, running, and jumping through every room in your house.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'alt_names': '\xa0',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Bengal_cat#Cheetoh',
#   'hypoallergenic': 0,
#   'reference_image_id': 'IFXsxmXLm',
#   'image': {'id': 'IFXsxmXLm',
#    'width': 973,
#    'height': 973,
#    'url': 'https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg'}},
#  'csho': {'weight': {'imperial': '4 - 10', 'metric': '2 - 5'},
#   'name': 'Colorpoint Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/ColorpointShorthair.aspx',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/colorpoint-shorthair',
#   'temperament': 'Affectionate, Intelligent, Playful, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Colorpoint Shorthairs are an affectionate breed, devoted and loyal to their people. Sensitive to their owner’s moods, Colorpoints are more than happy to sit at your side or on your lap and purr words of encouragement on a bad day. They will constantly seek out your lap whenever it is open and in the moments when your lap is preoccupied they will stretch out in sunny spots on the ground.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 3,
#   'affection_level': 4,
#   'child_friendly': 4,
#   'cat_friendly': 3,
#   'dog_friendly': 4,
#   'energy_level': 4,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 5,
#   'bidability': 4,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Colorpoint_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 'oSpqGyUDS',
#   'image': {'id': 'oSpqGyUDS',
#    'width': 1363,
#    'height': 1600,
#    'url': 'https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg'}},
#  'crex': {'weight': {'imperial': '5 - 9', 'metric': '2 - 4'},
#   'name': 'Cornish Rex',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/CornishRex.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/cornish-rex',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/cornish-rex',
#   'temperament': 'Affectionate, Intelligent, Active, Curious, Playful',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'This is a confident cat who loves people and will follow them around, waiting for any opportunity to sit in a lap or give a kiss. He enjoys being handled, making it easy to take him to the veterinarian or train him for therapy work. The Cornish Rex stay in kitten mode most of their lives and well into their senior years. ',
#   'life_span': '11 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'cat_friendly': 2,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Cornish_Rex',
#   'hypoallergenic': 1,
#   'reference_image_id': 'unX21IBVB',
#   'image': {'id': 'unX21IBVB',
#    'width': 2976,
#    'height': 1784,
#    'url': 'https://cdn2.thecatapi.com/images/unX21IBVB.jpg'}},
#  'cymr': {'weight': {'imperial': '8 - 13', 'metric': '4 - 6'},
#   'name': 'Cymric',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/cymric',
#   'temperament': 'Gentle, Loyal, Intelligent, Playful',
#   'origin': 'Canada',
#   'country_codes': 'CA',
#   'country_code': 'CA',
#   'description': 'The Cymric is a placid, sweet cat. They do not get too upset about anything that happens in their world. They are loving companions and adore people. They are smart and dexterous, capable of using his paws to get into cabinets or to open doors.',
#   'life_span': '8 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Spangle',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 5,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 1,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Cymric_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '3dbtapCWM',
#   'image': {'id': '3dbtapCWM',
#    'width': 1440,
#    'height': 900,
#    'url': 'https://cdn2.thecatapi.com/images/3dbtapCWM.jpg'}},
#  'cypr': {'weight': {'imperial': '8 - 16', 'metric': '4 - 7'},
#   'name': 'Cyprus',
#   'temperament': 'Affectionate, Social',
#   'origin': 'Cyprus',
#   'country_codes': 'CY',
#   'country_code': 'CY',
#   'description': 'Loving, loyal, social and inquisitive, the Cyprus cat forms strong ties with their families and love nothing more than to be involved in everything that goes on in their surroundings. They are not overly active by nature which makes them the perfect companion for people who would like to share their homes with a laid-back relaxed feline companion. ',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Cypriot cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 4,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Cyprus_cat',
#   'hypoallergenic': 0,
#   'reference_image_id': 'tJbzb7FKo',
#   'image': {'id': 'tJbzb7FKo',
#    'width': 1024,
#    'height': 768,
#    'url': 'https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg'}},
#  'drex': {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'name': 'Devon Rex',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/DevonRex.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/devon-rex',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/devon-rex',
#   'temperament': 'Highly interactive, Mischievous, Loyal, Social, Playful',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The favourite perch of the Devon Rex is right at head level, on the shoulder of her favorite person. She takes a lively interest in everything that is going on and refuses to be left out of any activity. Count on her to stay as close to you as possible, occasionally communicating his opinions in a quiet voice. She loves people and welcomes the attentions of friends and family alike.',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Pixie cat, Alien cat, Poodle cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Devon_Rex',
#   'hypoallergenic': 1,
#   'reference_image_id': '4RzEwvyzz',
#   'image': {'id': '4RzEwvyzz',
#    'width': 1729,
#    'height': 1160,
#    'url': 'https://cdn2.thecatapi.com/images/4RzEwvyzz.png'}},
#  'dons': {'weight': {'imperial': '10 - 12', 'metric': '5 - 6'},
#   'name': 'Donskoy',
#   'temperament': 'Playful, affectionate, loyal, social',
#   'origin': 'Russia',
#   'country_codes': 'RU',
#   'country_code': 'RU',
#   'description': 'Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'adaptability': 4,
#   'affection_level': 4,
#   'child_friendly': 3,
#   'cat_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 4,
#   'grooming': 2,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 2,
#   'experimental': 0,
#   'hairless': 1,
#   'natural': 0,
#   'rare': 1,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Donskoy_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': '3KG57GfMW',
#   'image': {'id': '3KG57GfMW',
#    'width': 750,
#    'height': 750,
#    'url': 'https://cdn2.thecatapi.com/images/3KG57GfMW.jpg'}},
#  'lihu': {'weight': {'imperial': '9 - 12', 'metric': '4 - 6'},
#   'name': 'Dragon Li',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/li-hua',
#   'temperament': 'Intelligent, Friendly, Gentle, Loving, Loyal',
#   'origin': 'China',
#   'country_codes': 'CN',
#   'country_code': 'CN',
#   'description': "The Dragon Li is loyal, but not particularly affectionate. They are known to be very intelligent, and their natural breed status means that they're very active. She is is gentle with people, and has a reputation as a talented hunter of rats and other vermin.",
#   'life_span': '12 - 15',
#   'indoor': 1,
#   'alt_names': 'Chinese Lia Hua, Lí hua māo (貍花貓), Li Hua',
#   'adaptability': 3,
#   'affection_level': 3,
#   'child_friendly': 3,
#   'cat_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 3,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Dragon_Li',
#   'hypoallergenic': 0,
#   'reference_image_id': 'BQMSld0A0',
#   'image': {'id': 'BQMSld0A0',
#    'width': 1080,
#    'height': 1080,
#    'url': 'https://cdn2.thecatapi.com/images/BQMSld0A0.jpg'}},
#  'emau': {'weight': {'imperial': '6 - 14', 'metric': '3 - 6'},
#   'name': 'Egyptian Mau',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/EgyptianMau.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/egyptian-mau',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/egyptian-mau',
#   'temperament': 'Agile, Dependent, Gentle, Intelligent, Lively, Loyal, Playful',
#   'origin': 'Egypt',
#   'country_codes': 'EG',
#   'country_code': 'EG',
#   'description': 'The Egyptian Mau is gentle and reserved. She loves her people and desires attention and affection from them but is wary of others. Early, continuing socialization is essential with this sensitive and sometimes shy cat, especially if you plan to show or travel with her. Otherwise, she can be easily startled by unexpected noises or events.',
#   'life_span': '18 - 20',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Pharaoh Cat',
#   'adaptability': 2,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 3,
#   'intelligence': 4,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Egyptian_Mau',
#   'hypoallergenic': 0,
#   'reference_image_id': 'TuSyTkt2n',
#   'image': {'id': 'TuSyTkt2n',
#    'width': 2475,
#    'height': 2147,
#    'url': 'https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg'}},
#  'ebur': {'weight': {'imperial': '7 - 14', 'metric': '3 - 6'},
#   'name': 'European Burmese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/EuropeanBurmese.aspx',
#   'temperament': 'Sweet, Affectionate, Loyal',
#   'origin': 'Burma',
#   'country_codes': 'MM',
#   'country_code': 'MM',
#   'description': 'The European Burmese is a very affectionate, intelligent, and loyal cat. They thrive on companionship and will want to be with you, participating in everything you do. While they might pick a favorite family member, chances are that they will interact with everyone in the home, as well as any visitors that come to call. They are inquisitive and playful, even as adults. ',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'cat_friendly': 4,
#   'dog_friendly': 4,
#   'energy_level': 4,
#   'grooming': 1,
#   'health_issues': 4,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 4,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'hypoallergenic': 0},
#  'esho': {'weight': {'imperial': '7 - 14', 'metric': '3 - 6'},
#   'name': 'Exotic Shorthair',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/Exotic.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/exotic-shorthair',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/exotic-shorthair',
#   'temperament': 'Affectionate, Sweet, Loyal, Quiet, Peaceful',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Exotic Shorthair is a gentle friendly cat that has the same personality as the Persian. They love having fun, don’t mind the company of other cats and dogs, also love to curl up for a sleep in a safe place. Exotics love their own people, but around strangers they are cautious at first. Given time, they usually warm up to visitors.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Exotic',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 3,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 2,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Exotic_Shorthair',
#   'hypoallergenic': 0,
#   'reference_image_id': 'YnPrYEmfe',
#   'image': {'id': 'YnPrYEmfe',
#    'width': 1024,
#    'height': 768,
#    'url': 'https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg'}},
#  'hbro': {'weight': {'imperial': '6 - 10', 'metric': '3 - 5'},
#   'name': 'Havana Brown',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsCJ/HavanaBrown.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/havana-brown',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/havana-brown',
#   'temperament': 'Affectionate, Curious, Demanding, Friendly, Intelligent, Playful',
#   'origin': 'United Kingdom',
#   'country_codes': 'GB',
#   'country_code': 'GB',
#   'description': 'The Havana Brown is human oriented, playful, and curious. She has a strong desire to spend time with her people and involve herself in everything they do. Being naturally inquisitive, the Havana Brown reaches out with a paw to touch and feel when investigating curiosities in its environment. They are truly sensitive by nature and frequently gently touch their human companions as if they are extending a paw of friendship.',
#   'life_span': '10 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Havana, HB',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Havana_Brown',
#   'hypoallergenic': 0,
#   'reference_image_id': 'njK25knLH',
#   'image': {'id': 'njK25knLH',
#    'width': 1024,
#    'height': 823,
#    'url': 'https://cdn2.thecatapi.com/images/njK25knLH.jpg'}},
#  'hima': {'weight': {'imperial': '7 - 14', 'metric': '3 - 6'},
#   'name': 'Himalayan',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/himalayan',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/himalayan',
#   'temperament': 'Dependent, Gentle, Intelligent, Quiet, Social',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'Calm and devoted, Himalayans make excellent companions, though they prefer a quieter home. They are playful in a sedate kind of way and enjoy having an assortment of toys. The Himalayan will stretch out next to you, sleep in your bed and even sit on your lap when she is in the mood.',
#   'life_span': '9 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Himalayan Persian, Colourpoint Persian, Longhaired Colourpoint, Himmy',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 2,
#   'dog_friendly': 2,
#   'energy_level': 1,
#   'grooming': 5,
#   'health_issues': 3,
#   'intelligence': 3,
#   'shedding_level': 4,
#   'social_needs': 4,
#   'stranger_friendly': 2,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Himalayan_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'CDhOtM-Ig',
#   'image': {'id': 'CDhOtM-Ig',
#    'width': 1200,
#    'height': 961,
#    'url': 'https://cdn2.thecatapi.com/images/CDhOtM-Ig.jpg'}},
#  'jbob': {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
# ...
#   'lap': 1,
#   'alt_names': 'Shepherd Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 4,
#   'intelligence': 3,
#   'shedding_level': 1,
#   'social_needs': 3,
#   'stranger_friendly': 3,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 1,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Selkirk_Rex',
#   'hypoallergenic': 1,
#   'reference_image_id': 'II9dOZmrw',
#   'image': {'id': 'II9dOZmrw',
#    'width': 1920,
#    'height': 902,
#    'url': 'https://cdn2.thecatapi.com/images/II9dOZmrw.jpg'}},
#  'siam': {'weight': {'imperial': '8 - 15', 'metric': '4 - 7'},
#   'name': 'Siamese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Siamese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/siamese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/siamese',
#   'temperament': 'Active, Agile, Clever, Sociable, Loving, Energetic',
#   'origin': 'Thailand',
#   'country_codes': 'TH',
#   'country_code': 'TH',
#   'description': 'While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods.',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Siam, Thai Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 2,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Siamese_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': 'ai6Jps4sx',
#   'image': {'id': 'ai6Jps4sx',
#    'width': 1110,
#    'height': 811,
#    'url': 'https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg'}},
#  'sibe': {'weight': {'imperial': '8 - 16', 'metric': '4 - 7'},
#   'name': 'Siberian',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Siberian.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/siberian',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/siberian',
#   'temperament': 'Curious, Intelligent, Loyal, Sweet, Agile, Playful, Affectionate',
#   'origin': 'Russia',
#   'country_codes': 'RU',
#   'country_code': 'RU',
#   'description': 'The Siberians dog like temperament and affection makes the ideal lap cat and will live quite happily indoors. Very agile and powerful, the Siberian cat can easily leap and reach high places, including the tops of refrigerators and even doors. ',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Moscow Semi-longhair, HairSiberian Forest Cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 3,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Siberian_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': '3bkZAjRh1',
#   'image': {'id': '3bkZAjRh1',
#    'width': 4232,
#    'height': 2560,
#    'url': 'https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg'}},
#  'sing': {'weight': {'imperial': '5 - 8', 'metric': '2 - 4'},
#   'name': 'Singapura',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Singapura.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/singapura',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/singapura',
#   'temperament': 'Affectionate, Curious, Easy Going, Intelligent, Interactive, Lively, Loyal',
#   'origin': 'Singapore',
#   'country_codes': 'SP',
#   'country_code': 'SP',
#   'description': 'The Singapura is usually cautious when it comes to meeting new people, but loves attention from his family so much that she sometimes has the reputation of being a pest. This is a highly active, curious and affectionate cat. She may be small, but she knows she’s in charge',
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Drain Cat, Kucinta, Pura',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Singapura_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'Qtncp2nRe',
#   'image': {'id': 'Qtncp2nRe',
#    'width': 1080,
#    'height': 1350,
#    'url': 'https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg'}},
#  'snow': {'weight': {'imperial': '7 - 12', 'metric': '3 - 5'},
#   'name': 'Snowshoe',
#   'temperament': 'Affectionate, Social, Intelligent, Sweet-tempered',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': 'The Snowshoe is a vibrant, energetic, affectionate and intelligent cat. They love being around people which makes them ideal for families, and becomes unhappy when left alone for long periods of time. Usually attaching themselves to one person, they do whatever they can to get your attention.',
#   'life_span': '14 - 19',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 4,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Snowshoe_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'MK-sYESvO',
#   'image': {'id': 'MK-sYESvO',
#    'width': 1170,
#    'height': 750,
#    'url': 'https://cdn2.thecatapi.com/images/MK-sYESvO.jpg'}},
#  'soma': {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'name': 'Somali',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Somali.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/somali',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/somali',
#   'temperament': 'Mischievous, Tenacious, Intelligent, Affectionate, Gentle, Interactive, Loyal',
#   'origin': 'Somalia',
#   'country_codes': 'SO',
#   'country_code': 'SO',
#   'description': 'The Somali lives life to the fullest. He climbs higher, jumps farther, plays harder. Nothing escapes the notice of this highly intelligent and inquisitive cat. Somalis love the company of humans and other animals.',
#   'life_span': '12 - 16',
#   'indoor': 0,
#   'alt_names': 'Fox Cat, Long-Haired Abyssinian',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 3,
#   'dog_friendly': 4,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 4,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 1,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Somali_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'EPF2ejNS0',
#   'image': {'id': 'EPF2ejNS0',
#    'width': 850,
#    'height': 1008,
#    'url': 'https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg'}},
#  'sphy': {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'name': 'Sphynx',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Sphynx.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/sphynx',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/sphynx',
#   'temperament': 'Loyal, Inquisitive, Friendly, Quiet, Gentle',
#   'origin': 'Canada',
#   'country_codes': 'CA',
#   'country_code': 'CA',
#   'description': 'The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression.',
#   'life_span': '12 - 14',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Canadian Hairless, Canadian Sphynx',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 3,
#   'grooming': 2,
#   'health_issues': 4,
#   'intelligence': 5,
#   'shedding_level': 1,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 1,
#   'natural': 0,
#   'rare': 1,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Sphynx_(cat)',
#   'hypoallergenic': 1,
#   'reference_image_id': 'BDb8ZXb1v',
#   'image': {'id': 'BDb8ZXb1v',
#    'width': 1600,
#    'height': 1067,
#    'url': 'https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg'}},
#  'tonk': {'weight': {'imperial': '6 - 12', 'metric': '3 - 5'},
#   'name': 'Tonkinese',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/Tonkinese.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/tonkinese',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/tonkinese',
#   'temperament': 'Curious, Intelligent, Social, Lively, Outgoing, Playful, Affectionate',
#   'origin': 'Canada',
#   'country_codes': 'CA',
#   'country_code': 'CA',
#   'description': 'Intelligent and generous with their affection, a Tonkinese will supervise all activities with curiosity. Loving, social, active, playful, yet content to be a lap cat',
#   'life_span': '14 - 16',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'Tonk',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Tonkinese_(cat)',
#   'hypoallergenic': 0,
#   'reference_image_id': 'KBroiVNCM',
#   'image': {'id': 'KBroiVNCM',
#    'width': 1080,
#    'height': 1080,
#    'url': 'https://cdn2.thecatapi.com/images/KBroiVNCM.jpg'}},
#  'toyg': {'weight': {'imperial': '7 - 15', 'metric': '3 - 7'},
#   'name': 'Toyger',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/toyger',
#   'temperament': 'Playful, Social, Intelligent',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "The Toyger has a sweet, calm personality and is generally friendly. He's outgoing enough to walk on a leash, energetic enough to play fetch and other interactive games, and confident enough to get along with other cats and friendly dogs.",
#   'life_span': '12 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': '',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 1,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 3,
#   'stranger_friendly': 5,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Toyger',
#   'hypoallergenic': 0,
#   'reference_image_id': 'O3F3_S1XN',
#   'image': {'id': 'O3F3_S1XN',
#    'width': 1080,
#    'height': 1080,
#    'url': 'https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg'}},
#  'tang': {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'name': 'Turkish Angora',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/TurkishAngora.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/turkish-angora',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/turkish-angora',
#   'temperament': 'Affectionate, Agile, Clever, Gentle, Intelligent, Playful, Social',
#   'origin': 'Turkey',
#   'country_codes': 'TR',
#   'country_code': 'TR',
#   'description': 'This is a smart and intelligent cat which bonds well with humans. With its affectionate and playful personality the Angora is a top choice for families. The Angora gets along great with other pets in the home, but it will make clear who is in charge, and who the house belongs to',
#   'life_span': '15 - 18',
#   'indoor': 0,
#   'alt_names': 'Ankara',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 2,
#   'health_issues': 2,
#   'intelligence': 5,
#   'shedding_level': 2,
#   'social_needs': 5,
#   'stranger_friendly': 5,
#   'vocalisation': 3,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Turkish_Angora',
#   'hypoallergenic': 0,
#   'reference_image_id': '7CGV6WVXq',
#   'image': {'id': '7CGV6WVXq',
#    'width': 736,
#    'height': 1104,
#    'url': 'https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg'}},
#  'tvan': {'weight': {'imperial': '7 - 20', 'metric': '3 - 9'},
#   'name': 'Turkish Van',
#   'cfa_url': 'http://cfa.org/Breeds/BreedsSthruT/TurkishVan.aspx',
#   'vetstreet_url': 'http://www.vetstreet.com/cats/turkish-van',
#   'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/turkish-van',
#   'temperament': 'Agile, Intelligent, Loyal, Playful, Energetic',
#   'origin': 'Turkey',
#   'country_codes': 'TR',
#   'country_code': 'TR',
#   'description': 'While the Turkish Van loves to jump and climb, play with toys, retrieve and play chase, she is is big and ungainly; this is one cat who doesn’t always land on his feet. While not much of a lap cat, the Van will be happy to cuddle next to you and sleep in your bed. ',
#   'life_span': '12 - 17',
#   'indoor': 0,
#   'alt_names': 'Turkish Cat, Swimming cat',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 2,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 1,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Turkish_Van',
#   'hypoallergenic': 0,
#   'reference_image_id': 'sxIXJax6h',
#   'image': {'id': 'sxIXJax6h',
#    'width': 960,
#    'height': 1280,
#    'url': 'https://cdn2.thecatapi.com/images/sxIXJax6h.jpg'}},
#  'ycho': {'weight': {'imperial': '12 - 18', 'metric': '5 - 8'},
#   'name': 'York Chocolate',
#   'temperament': 'Playful, Social, Intelligent, Curious, Friendly',
#   'origin': 'United States',
#   'country_codes': 'US',
#   'country_code': 'US',
#   'description': "York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it.",
#   'life_span': '13 - 15',
#   'indoor': 0,
#   'lap': 1,
#   'alt_names': 'York',
#   'adaptability': 5,
#   'affection_level': 5,
#   'child_friendly': 4,
#   'dog_friendly': 5,
#   'energy_level': 5,
#   'grooming': 3,
#   'health_issues': 1,
#   'intelligence': 5,
#   'shedding_level': 3,
#   'social_needs': 4,
#   'stranger_friendly': 4,
#   'vocalisation': 5,
#   'experimental': 0,
#   'hairless': 0,
#   'natural': 0,
#   'rare': 0,
#   'rex': 0,
#   'suppressed_tail': 0,
#   'short_legs': 0,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/York_Chocolate',
#   'hypoallergenic': 0,
#   'reference_image_id': '0SxW2SQ_S',
#   'image': {'id': '0SxW2SQ_S',
#    'width': 800,
#    'height': 1203,
#    'url': 'https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg'}}}

# %% [markdown]
# ### Accessing the keys of the json response using keys method

# %%
new_dict.keys()
# Out:
# dict_keys(['abys', 'aege', 'abob', 'acur', 'asho', 'awir', 'amau', 'amis', 'bali', 'bamb', 'beng', 'birm', 'bomb', 'bslo', 'bsho', 'bure', 'buri', 'cspa', 'ctif', 'char', 'chau', 'chee', 'csho', 'crex', 'cymr', 'cypr', 'drex', 'dons', 'lihu', 'emau', 'ebur', 'esho', 'hbro', 'hima', 'jbob', 'java', 'khao', 'kora', 'kuri', 'lape', 'mcoo', 'mala', 'manx', 'munc', 'nebe', 'norw', 'ocic', 'orie', 'pers', 'pixi', 'raga', 'ragd', 'rblu', 'sava', 'sfol', 'srex', 'siam', 'sibe', 'sing', 'snow', 'soma', 'sphy', 'tonk', 'toyg', 'tang', 'tvan', 'ycho'])

# %% [markdown]
# #### Extracting the asho breed info using a for loop

# %%
for i in new_dict['asho']:
    print(i)
# Out:
# weight
# name
# cfa_url
# vetstreet_url
# vcahospitals_url
# temperament
# origin
# country_codes
# country_code
# description
# life_span
# indoor
# lap
# alt_names
# adaptability
# affection_level
# child_friendly
# dog_friendly
# energy_level
# grooming
# health_issues
# intelligence
# shedding_level
# social_needs
# stranger_friendly
# vocalisation
# experimental
# hairless
# natural
# rare
# rex
# suppressed_tail
# short_legs
# wikipedia_url
# hypoallergenic
# reference_image_id
# image

# %% [markdown]
# Accessing the abys breed info

# %%
new_dict['abys']
# Out:
# {'weight': {'imperial': '7  -  10', 'metric': '3 - 5'},
#  'name': 'Abyssinian',
#  'cfa_url': 'http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx',
#  'vetstreet_url': 'http://www.vetstreet.com/cats/abyssinian',
#  'vcahospitals_url': 'https://vcahospitals.com/know-your-pet/cat-breeds/abyssinian',
#  'temperament': 'Active, Energetic, Independent, Intelligent, Gentle',
#  'origin': 'Egypt',
#  'country_codes': 'EG',
#  'country_code': 'EG',
#  'description': 'The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.',
#  'life_span': '14 - 15',
#  'indoor': 0,
#  'lap': 1,
#  'alt_names': '',
#  'adaptability': 5,
#  'affection_level': 5,
#  'child_friendly': 3,
#  'dog_friendly': 4,
#  'energy_level': 5,
#  'grooming': 1,
#  'health_issues': 2,
#  'intelligence': 5,
#  'shedding_level': 2,
#  'social_needs': 5,
#  'stranger_friendly': 5,
#  'vocalisation': 1,
#  'experimental': 0,
#  'hairless': 0,
#  'natural': 1,
#  'rare': 0,
#  'rex': 0,
#  'suppressed_tail': 0,
#  'short_legs': 0,
#  'wikipedia_url': 'https://en.wikipedia.org/wiki/Abyssinian_(cat)',
#  'hypoallergenic': 0,
#  'reference_image_id': '0XYvRd7oD',
#  'image': {'id': '0XYvRd7oD',
#   'width': 1204,
#   'height': 1445,
#   'url': 'https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg'}}

# %% [markdown]
# - Initialize an empty list
# - Get the count of the json response entries
# - Access the abys breed info and adding to the list in each and every iteration

# %%
id1 = []
print("Number of items", len(new_dict))
for i in new_dict['abys']:
    id1.append(i)
id1
# Out:
# Number of items 67
# ['weight',
#  'name',
#  'cfa_url',
#  'vetstreet_url',
#  'vcahospitals_url',
#  'temperament',
#  'origin',
#  'country_codes',
#  'country_code',
#  'description',
#  'life_span',
#  'indoor',
#  'lap',
#  'alt_names',
#  'adaptability',
#  'affection_level',
#  'child_friendly',
#  'dog_friendly',
#  'energy_level',
#  'grooming',
#  'health_issues',
#  'intelligence',
#  'shedding_level',
#  'social_needs',
#  'stranger_friendly',
#  'vocalisation',
#  'experimental',
#  'hairless',
#  'natural',
#  'rare',
#  'rex',
#  'suppressed_tail',
#  'short_legs',
#  'wikipedia_url',
#  'hypoallergenic',
#  'reference_image_id',
#  'image']

# %%
# https://docs.thecatapi.com/

# %% [markdown]
# #### Creating a dataframe from the json response

# %%
import pandas as pd

abys = pd.DataFrame(new_dict["abys"])
# Out:
#             weight        name  \
# imperial  7  -  10  Abyssinian
# metric       3 - 5  Abyssinian
# id             NaN  Abyssinian
# width          NaN  Abyssinian
# height         NaN  Abyssinian
# url            NaN  Abyssinian
#
#                                                  cfa_url  \
# imperial  http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# metric    http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# id        http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# width     http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# height    http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# url       http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
#
#                                      vetstreet_url  \
# imperial  http://www.vetstreet.com/cats/abyssinian
# metric    http://www.vetstreet.com/cats/abyssinian
# id        http://www.vetstreet.com/cats/abyssinian
# width     http://www.vetstreet.com/cats/abyssinian
# height    http://www.vetstreet.com/cats/abyssinian
# url       http://www.vetstreet.com/cats/abyssinian
#
#                                            vcahospitals_url  \
# imperial  https://vcahospitals.com/know-your-pet/cat-bre...
# metric    https://vcahospitals.com/know-your-pet/cat-bre...
# id        https://vcahospitals.com/know-your-pet/cat-bre...
# width     https://vcahospitals.com/know-your-pet/cat-bre...
# height    https://vcahospitals.com/know-your-pet/cat-bre...
# url       https://vcahospitals.com/know-your-pet/cat-bre...
#
#                                                 temperament origin  \
# imperial  Active, Energetic, Independent, Intelligent, G...  Egypt
# metric    Active, Energetic, Independent, Intelligent, G...  Egypt
# id        Active, Energetic, Independent, Intelligent, G...  Egypt
# width     Active, Energetic, Independent, Intelligent, G...  Egypt
# height    Active, Energetic, Independent, Intelligent, G...  Egypt
# url       Active, Energetic, Independent, Intelligent, G...  Egypt
#
#          country_codes country_code  \
# imperial            EG           EG
# metric              EG           EG
# id                  EG           EG
# width               EG           EG
# height              EG           EG
# url                 EG           EG
#
#                                                 description  ... hairless  \
# imperial  The Abyssinian is easy to care for, and a joy ...  ...        0
# metric    The Abyssinian is easy to care for, and a joy ...  ...        0
# id        The Abyssinian is easy to care for, and a joy ...  ...        0
# width     The Abyssinian is easy to care for, and a joy ...  ...        0
# height    The Abyssinian is easy to care for, and a joy ...  ...        0
# url       The Abyssinian is easy to care for, and a joy ...  ...        0
#
#           natural  rare rex  suppressed_tail  short_legs  \
# imperial        1     0   0                0           0
# metric          1     0   0                0           0
# id              1     0   0                0           0
# width           1     0   0                0           0
# height          1     0   0                0           0
# url             1     0   0                0           0
#
#                                            wikipedia_url  hypoallergenic  \
# imperial  https://en.wikipedia.org/wiki/Abyssinian_(cat)               0
# metric    https://en.wikipedia.org/wiki/Abyssinian_(cat)               0
# id        https://en.wikipedia.org/wiki/Abyssinian_(cat)               0
# width     https://en.wikipedia.org/wiki/Abyssinian_(cat)               0
# height    https://en.wikipedia.org/wiki/Abyssinian_(cat)               0
# url       https://en.wikipedia.org/wiki/Abyssinian_(cat)               0
#
#           reference_image_id                                            image
# imperial           0XYvRd7oD                                              NaN
# metric             0XYvRd7oD                                              NaN
# id                 0XYvRd7oD                                        0XYvRd7oD
# width              0XYvRd7oD                                             1204
# height             0XYvRd7oD                                             1445
# url                0XYvRd7oD  https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
#
# [6 rows x 37 columns]

# %% [markdown]
# ### Transpose index and columns.
#
# - Reflect the DataFrame over its main diagonal by writing rows as columns and vice-versa. The property T is an accessor to the method transpose().

# %%
abys = pd.DataFrame(new_dict["abys"]).transpose()
abys
# Out:
#                                                              imperial  \
# weight                                                       7  -  10
# name                                                       Abyssinian
# cfa_url                http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# vetstreet_url                http://www.vetstreet.com/cats/abyssinian
# vcahospitals_url    https://vcahospitals.com/know-your-pet/cat-bre...
# temperament         Active, Energetic, Independent, Intelligent, G...
# origin                                                          Egypt
# country_codes                                                      EG
# country_code                                                       EG
# description         The Abyssinian is easy to care for, and a joy ...
# life_span                                                     14 - 15
# indoor                                                              0
# lap                                                                 1
# alt_names
# adaptability                                                        5
# affection_level                                                     5
# child_friendly                                                      3
# dog_friendly                                                        4
# energy_level                                                        5
# grooming                                                            1
# health_issues                                                       2
# intelligence                                                        5
# shedding_level                                                      2
# social_needs                                                        5
# stranger_friendly                                                   5
# vocalisation                                                        1
# experimental                                                        0
# hairless                                                            0
# natural                                                             1
# rare                                                                0
# rex                                                                 0
# suppressed_tail                                                     0
# short_legs                                                          0
# wikipedia_url          https://en.wikipedia.org/wiki/Abyssinian_(cat)
# hypoallergenic                                                      0
# reference_image_id                                          0XYvRd7oD
# image                                                             NaN
#
#                                                                metric  \
# weight                                                          3 - 5
# name                                                       Abyssinian
# cfa_url                http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# vetstreet_url                http://www.vetstreet.com/cats/abyssinian
# vcahospitals_url    https://vcahospitals.com/know-your-pet/cat-bre...
# temperament         Active, Energetic, Independent, Intelligent, G...
# origin                                                          Egypt
# country_codes                                                      EG
# country_code                                                       EG
# description         The Abyssinian is easy to care for, and a joy ...
# life_span                                                     14 - 15
# indoor                                                              0
# lap                                                                 1
# alt_names
# adaptability                                                        5
# affection_level                                                     5
# child_friendly                                                      3
# dog_friendly                                                        4
# energy_level                                                        5
# grooming                                                            1
# health_issues                                                       2
# intelligence                                                        5
# shedding_level                                                      2
# social_needs                                                        5
# stranger_friendly                                                   5
# vocalisation                                                        1
# experimental                                                        0
# hairless                                                            0
# natural                                                             1
# rare                                                                0
# rex                                                                 0
# suppressed_tail                                                     0
# short_legs                                                          0
# wikipedia_url          https://en.wikipedia.org/wiki/Abyssinian_(cat)
# hypoallergenic                                                      0
# reference_image_id                                          0XYvRd7oD
# image                                                             NaN
#
#                                                                    id  \
# weight                                                            NaN
# name                                                       Abyssinian
# cfa_url                http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# vetstreet_url                http://www.vetstreet.com/cats/abyssinian
# vcahospitals_url    https://vcahospitals.com/know-your-pet/cat-bre...
# temperament         Active, Energetic, Independent, Intelligent, G...
# origin                                                          Egypt
# country_codes                                                      EG
# country_code                                                       EG
# description         The Abyssinian is easy to care for, and a joy ...
# life_span                                                     14 - 15
# indoor                                                              0
# lap                                                                 1
# alt_names
# adaptability                                                        5
# affection_level                                                     5
# child_friendly                                                      3
# dog_friendly                                                        4
# energy_level                                                        5
# grooming                                                            1
# health_issues                                                       2
# intelligence                                                        5
# shedding_level                                                      2
# social_needs                                                        5
# stranger_friendly                                                   5
# vocalisation                                                        1
# experimental                                                        0
# hairless                                                            0
# natural                                                             1
# rare                                                                0
# rex                                                                 0
# suppressed_tail                                                     0
# short_legs                                                          0
# wikipedia_url          https://en.wikipedia.org/wiki/Abyssinian_(cat)
# hypoallergenic                                                      0
# reference_image_id                                          0XYvRd7oD
# image                                                       0XYvRd7oD
#
#                                                                 width  \
# weight                                                            NaN
# name                                                       Abyssinian
# cfa_url                http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# vetstreet_url                http://www.vetstreet.com/cats/abyssinian
# vcahospitals_url    https://vcahospitals.com/know-your-pet/cat-bre...
# temperament         Active, Energetic, Independent, Intelligent, G...
# origin                                                          Egypt
# country_codes                                                      EG
# country_code                                                       EG
# description         The Abyssinian is easy to care for, and a joy ...
# life_span                                                     14 - 15
# indoor                                                              0
# lap                                                                 1
# alt_names
# adaptability                                                        5
# affection_level                                                     5
# child_friendly                                                      3
# dog_friendly                                                        4
# energy_level                                                        5
# grooming                                                            1
# health_issues                                                       2
# intelligence                                                        5
# shedding_level                                                      2
# social_needs                                                        5
# stranger_friendly                                                   5
# vocalisation                                                        1
# experimental                                                        0
# hairless                                                            0
# natural                                                             1
# rare                                                                0
# rex                                                                 0
# suppressed_tail                                                     0
# short_legs                                                          0
# wikipedia_url          https://en.wikipedia.org/wiki/Abyssinian_(cat)
# hypoallergenic                                                      0
# reference_image_id                                          0XYvRd7oD
# image                                                            1204
#
#                                                                height  \
# weight                                                            NaN
# name                                                       Abyssinian
# cfa_url                http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# vetstreet_url                http://www.vetstreet.com/cats/abyssinian
# vcahospitals_url    https://vcahospitals.com/know-your-pet/cat-bre...
# temperament         Active, Energetic, Independent, Intelligent, G...
# origin                                                          Egypt
# country_codes                                                      EG
# country_code                                                       EG
# description         The Abyssinian is easy to care for, and a joy ...
# life_span                                                     14 - 15
# indoor                                                              0
# lap                                                                 1
# alt_names
# adaptability                                                        5
# affection_level                                                     5
# child_friendly                                                      3
# dog_friendly                                                        4
# energy_level                                                        5
# grooming                                                            1
# health_issues                                                       2
# intelligence                                                        5
# shedding_level                                                      2
# social_needs                                                        5
# stranger_friendly                                                   5
# vocalisation                                                        1
# experimental                                                        0
# hairless                                                            0
# natural                                                             1
# rare                                                                0
# rex                                                                 0
# suppressed_tail                                                     0
# short_legs                                                          0
# wikipedia_url          https://en.wikipedia.org/wiki/Abyssinian_(cat)
# hypoallergenic                                                      0
# reference_image_id                                          0XYvRd7oD
# image                                                            1445
#
#                                                                   url
# weight                                                            NaN
# name                                                       Abyssinian
# cfa_url                http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# vetstreet_url                http://www.vetstreet.com/cats/abyssinian
# vcahospitals_url    https://vcahospitals.com/know-your-pet/cat-bre...
# temperament         Active, Energetic, Independent, Intelligent, G...
# origin                                                          Egypt
# country_codes                                                      EG
# country_code                                                       EG
# description         The Abyssinian is easy to care for, and a joy ...
# life_span                                                     14 - 15
# indoor                                                              0
# lap                                                                 1
# alt_names
# adaptability                                                        5
# affection_level                                                     5
# child_friendly                                                      3
# dog_friendly                                                        4
# energy_level                                                        5
# grooming                                                            1
# health_issues                                                       2
# intelligence                                                        5
# shedding_level                                                      2
# social_needs                                                        5
# stranger_friendly                                                   5
# vocalisation                                                        1
# experimental                                                        0
# hairless                                                            0
# natural                                                             1
# rare                                                                0
# rex                                                                 0
# suppressed_tail                                                     0
# short_legs                                                          0
# wikipedia_url          https://en.wikipedia.org/wiki/Abyssinian_(cat)
# hypoallergenic                                                      0
# reference_image_id                                          0XYvRd7oD
# image                 https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg

# %%
# Exporting the abyssian values to a CSV file
abys.to_csv("abyssian.csv")

# %% [markdown]
# ## POST Request

# %%
import http.client
import json

# First you'll need to create a Tconnection that you will use to communicate with the remote server.
connection = http.client.HTTPSConnection('api.github.com')

# Specify the request headers.
# In this case we're saying that the request body is of the type application/json.
headers = {'Content-type': 'application/json','User-Agent': 'request'}

#Next we will generate the json data from a python dict()
foo = {'text': 'Hello world github/linguist#1 **cool**, and #1!'}
json_foo = json.dumps(foo)

#Then we send an HTTP request to over the HTTPS connection.
connection.request('POST', '/markdown', json_foo, headers)

# Get the response and read it.
response = connection.getresponse()
print(response.read().decode())
# Out:
# <p>Hello world github/linguist#1 <strong>cool</strong>, and #1!</p>

# %% [markdown]
# ### Demo 3:

# %% [markdown]
# ### Downloading files with requests

# %% [markdown]
# ###### Downloading the python logo from the given URL using requests

# %%
import requests

# defining the base-url
url = 'https://www.python.org/static/img/python-logo@2x.png'

# Reading the image using get request
myfile = requests.get(url)

# %% [markdown]
# - Now to write a file we can use an open function which is boilerplate straight out of python’s built-in functions.
# - We specify the filename and the ‘wb’ refers to writing bytes.
# - Python 3 needs to be explicit in knowing whether data is binary or not, this is why we define it

# %% [markdown]
# For the purposes of downloading a file, we will want to get the request object in the form of bytes and not string. To do this we call upon the response.content method instead, this ensures the data we receive is in byte format.

# %%
open('py_logo.png', 'wb').write(myfile.content)
# Out:
# 15770

# %% [markdown]
# #### Downloading the pdf using requests library

# %%
import requests

url = 'https://readthedocs.org/projects/python-guide/downloads/pdf/latest/'

myfile = requests.get(url, allow_redirects=True)

open('hello.pdf', 'wb').write(myfile.content)
# Out:
# 4889945
